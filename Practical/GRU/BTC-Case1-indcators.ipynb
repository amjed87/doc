# %%
import pandas as pd
import numpy as np
import pandas_ta as ta
import yfinance as yf
from datetime import timedelta
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error 
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import GRU, Dense, Dropout

# For PLotting we will use these library

import matplotlib.pyplot as plt

from itertools import cycle
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

# %%
# Step 1: Data cleaning
data = yf.download(tickers='BTC-usd', start='2014-12-31', end='2022-12-31', interval='1d')
#data = yf.download(tickers='BTC-USD', period='max', interval='1d')
data.dropna(inplace=True)
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                     Open          High           Low         Close  \
# Date
# 2014-12-31    310.914001    320.192993    310.210999    320.192993
# 2015-01-01    320.434998    320.434998    314.002991    314.248993
# 2015-01-02    314.079010    315.838989    313.565002    315.032013
# 2015-01-03    314.846008    315.149994    281.082001    281.082001
# 2015-01-04    281.145996    287.230011    257.612000    264.195007
# ...                  ...           ...           ...           ...
# 2022-12-26  16842.250000  16920.123047  16812.369141  16919.804688
# 2022-12-27  16919.291016  16959.845703  16642.072266  16717.173828
# 2022-12-28  16716.400391  16768.169922  16497.556641  16552.572266
# 2022-12-29  16552.322266  16651.755859  16508.683594  16642.341797
# 2022-12-30  16641.330078  16643.427734  16408.474609  16602.585938
#
#                Adj Close       Volume
# Date
# 2014-12-31    320.192993     13942900
# 2015-01-01    314.248993      8036550
# 2015-01-02    315.032013      7860650
# 2015-01-03    281.082001     33054400
# 2015-01-04    264.195007     55629100
# ...                  ...          ...
# 2022-12-26  16919.804688  11886957804
# 2022-12-27  16717.173828  15748580239
# 2022-12-28  16552.572266  17005713920
# 2022-12-29  16642.341797  14472237479
# 2022-12-30  16602.585938  15929162910
#
# [2922 rows x 6 columns]

# %%
# Step 2: Feature engineering
data['RSI']       = ta.rsi(data.Close, length=15)
data['EMA_short'] = ta.ema(data.Close, length=20)
data['EMA_long']  = ta.ema(data.Close, length=100)
data.dropna(inplace=True)
data.reset_index(inplace=True)
data.drop(['Close'], axis=1, inplace=True)
# Setting the index
data.set_index('Date', inplace=True)

# Dropping any NaNs
data.dropna(inplace=True)

data.info()
data.tail(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2823 entries, 2015-04-09 to 2022-12-30
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2823 non-null   float64
#  1   High       2823 non-null   float64
#  2   Low        2823 non-null   float64
#  3   Adj Close  2823 non-null   float64
#  4   Volume     2823 non-null   int64
#  5   RSI        2823 non-null   float64
#  6   EMA_short  2823 non-null   float64
#  7   EMA_long   2823 non-null   float64
# dtypes: float64(7), int64(1)
# memory usage: 198.5 KB
#                     Open          High           Low     Adj Close  \
# Date
# 2022-12-21  16904.527344  16916.800781  16755.912109  16817.535156
# 2022-12-22  16818.380859  16866.673828  16592.408203  16830.341797
# 2022-12-23  16829.644531  16905.218750  16794.458984  16796.953125
# 2022-12-24  16796.976562  16864.703125  16793.527344  16847.755859
# 2022-12-25  16847.505859  16860.554688  16755.253906  16841.986328
# 2022-12-26  16842.250000  16920.123047  16812.369141  16919.804688
# 2022-12-27  16919.291016  16959.845703  16642.072266  16717.173828
# 2022-12-28  16716.400391  16768.169922  16497.556641  16552.572266
# 2022-12-29  16552.322266  16651.755859  16508.683594  16642.341797
# 2022-12-30  16641.330078  16643.427734  16408.474609  16602.585938
#
#                  Volume        RSI     EMA_short      EMA_long
# Date
# 2022-12-21  14882945045  46.354643  16990.208226  18631.716275
# 2022-12-22  16441573050  46.537922  16974.982852  18596.045493
# 2022-12-23  15329265213  46.097985  16958.027640  18560.419901
# 2022-12-24   9744636213  46.916068  16947.525565  18526.505762
# 2022-12-25  11656379938  46.829585  16937.474209  18493.148941
# 2022-12-26  11886957804  48.209222  16935.791398  18461.993610
# 2022-12-27  15748580239  44.954914  16914.970677  18427.442723
# 2022-12-28  17005713920  42.460302  16880.456542  18390.316575
# 2022-12-29  14472237479  44.267447  16857.778948  18355.703213
# 2022-12-30  15929162910  43.617436  16833.474851  18320.988020

# %%
data= data.to_csv('btc-2015-2022_case1.csv')

# %%
from datetime import datetime

def date_parser(date_str):
    date_obj = datetime.strptime(date_str, '%m/%d/%Y')
    return date_obj.strftime('%m-%d-%Y')

# %%
data_csv = pd.read_csv('btc-2015-2022_case1.csv')
data_csv.dropna(inplace=True)
# Setting the index

data_csv.set_index('Date', inplace=True)
# Dropping any NaNs
data_csv.dropna(inplace=True)
data_csv.info()
data_csv.tail(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2823 entries, 2015-04-09 to 2022-12-30
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2823 non-null   float64
#  1   High       2823 non-null   float64
#  2   Low        2823 non-null   float64
#  3   Adj Close  2823 non-null   float64
#  4   Volume     2823 non-null   int64
#  5   RSI        2823 non-null   float64
#  6   EMA_short  2823 non-null   float64
#  7   EMA_long   2823 non-null   float64
# dtypes: float64(7), int64(1)
# memory usage: 198.5+ KB
#                     Open          High           Low     Adj Close  \
# Date
# 2022-12-21  16904.527344  16916.800781  16755.912109  16817.535156
# 2022-12-22  16818.380859  16866.673828  16592.408203  16830.341797
# 2022-12-23  16829.644531  16905.218750  16794.458984  16796.953125
# 2022-12-24  16796.976562  16864.703125  16793.527344  16847.755859
# 2022-12-25  16847.505859  16860.554688  16755.253906  16841.986328
# 2022-12-26  16842.250000  16920.123047  16812.369141  16919.804688
# 2022-12-27  16919.291016  16959.845703  16642.072266  16717.173828
# 2022-12-28  16716.400391  16768.169922  16497.556641  16552.572266
# 2022-12-29  16552.322266  16651.755859  16508.683594  16642.341797
# 2022-12-30  16641.330078  16643.427734  16408.474609  16602.585938
#
#                  Volume        RSI     EMA_short      EMA_long
# Date
# 2022-12-21  14882945045  46.354643  16990.208226  18631.716275
# 2022-12-22  16441573050  46.537922  16974.982852  18596.045493
# 2022-12-23  15329265213  46.097985  16958.027640  18560.419901
# 2022-12-24   9744636213  46.916068  16947.525565  18526.505762
# 2022-12-25  11656379938  46.829585  16937.474209  18493.148941
# 2022-12-26  11886957804  48.209222  16935.791398  18461.993610
# 2022-12-27  15748580239  44.954914  16914.970677  18427.442723
# 2022-12-28  17005713920  42.460302  16880.456542  18390.316575
# 2022-12-29  14472237479  44.267447  16857.778948  18355.703213
# 2022-12-30  15929162910  43.617436  16833.474851  18320.988020

# %%
# Split the data into training and test sets
train_df = data_csv[:int(len(data_csv)*0.8)]
test_df = data_csv[int(len(data_csv)*0.8):]
data_csv.shape
# Out:
# (2823, 8)

# %%
test_data =test_df.copy()

# %%
train_x = train_df.index
train_y = train_df['Adj Close']
test_x = test_df.index
test_y = test_df['Adj Close']

fig = go.Figure()
fig.add_trace(go.Scatter(x=train_x, y=train_y, name='train Data'))
fig.add_trace(go.Scatter(x=test_x, y=test_y, name='Test Data'))

fig.update_layout(
    xaxis_title='Date',
    yaxis_title='Price',
    title='Price over time'
)

fig.show()

# %%
print(train_df.info())
print(test_df.info())
print('test_data', test_data.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2258 entries, 2015-04-09 to 2021-06-13
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2258 non-null   float64
#  1   High       2258 non-null   float64
#  2   Low        2258 non-null   float64
#  3   Adj Close  2258 non-null   float64
#  4   Volume     2258 non-null   int64
#  5   RSI        2258 non-null   float64
#  6   EMA_short  2258 non-null   float64
#  7   EMA_long   2258 non-null   float64
# dtypes: float64(7), int64(1)
# memory usage: 158.8+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 565 entries, 2021-06-14 to 2022-12-30
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       565 non-null    float64
#  1   High       565 non-null    float64
#  2   Low        565 non-null    float64
#  3   Adj Close  565 non-null    float64
#  4   Volume     565 non-null    int64
#  5   RSI        565 non-null    float64
#  6   EMA_short  565 non-null    float64
#  7   EMA_long   565 non-null    float64
# dtypes: float64(7), int64(1)
# memory usage: 39.7+ KB
# None
# test_data (565, 8)

# %%
# Preprocess the data
X_train = train_df.drop(['Adj Close'], axis=1).values
y_train = train_df['Adj Close'].values

X_test = test_df.drop(['Adj Close'], axis=1).values
y_test = test_df['Adj Close'].values

print("x_train", X_train.shape)
print("y_train", y_train.shape)
print("X_test", X_test.shape)
print("y_test", y_test.shape)
# Out:
# x_train (2258, 7)
# y_train (2258,)
# X_test (565, 7)
# y_test (565,)

# %%
scaler  = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test  = scaler.fit_transform(X_test)
y_train = y_train.reshape(-1,1)
y_train = scaler.fit_transform(y_train)
y_test  = y_test.reshape(-1,1)
y_test  = scaler.fit_transform(y_test)
#------------------------------------------
print("x_train", X_train.shape)
print("y_train", y_train.shape)
print("X_test", X_test.shape)
print("y_test", y_test.shape)
# Out:
# x_train (2258, 7)
# y_train (2258, 1)
# X_test (565, 7)
# y_test (565, 1)

# %%
# Step 5: Reshaping the data
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

print('X_train', X_train.shape)
print('y_train', y_train.shape)
print('X_test', X_test.shape)
print('Y_test', y_test.shape)
print('X_train.shape[1]', X_train.shape[1])
print('X_train.shape[2]', X_train.shape[2])
# Out:
# X_train (2258, 1, 7)
# y_train (2258, 1)
# X_test (565, 1, 7)
# Y_test (565, 1)
# X_train.shape[1] 1
# X_train.shape[2] 7

# %%
# Step 6: Building the LSTM model (cont.)

model = Sequential()
model.add(GRU(100, input_shape=( X_train.shape[1], X_train.shape[2]), return_sequences=True, activation='tanh'))
model.add(Dropout(0.2))
model.add(GRU(100, return_sequences=True, activation='tanh'))
model.add(Dropout(0.2))
model.add(GRU(75, return_sequences=True, activation='tanh'))
model.add(Dropout(0.25))
model.add(GRU(50, activation='tanh'))
model.add(Dropout(0.3))
model.add(Dense(1, activation='linear'))
model.compile(loss='mean_squared_error', optimizer='adam',
              metrics=['accuracy', 'mean_absolute_error'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 1, 100)            32700
#
#  dropout (Dropout)           (None, 1, 100)            0
#
#  gru_1 (GRU)                 (None, 1, 100)            60600
#
#  dropout_1 (Dropout)         (None, 1, 100)            0
#
#  gru_2 (GRU)                 (None, 1, 75)             39825
#
#  dropout_2 (Dropout)         (None, 1, 75)             0
#
#  gru_3 (GRU)                 (None, 50)                19050
#
#  dropout_3 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 152,226
# Trainable params: 152,226
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Step 7: Training and evaluating the model
history = model.fit(X_train, y_train, epochs=1000, batch_size=32)
# Out:
# Epoch 1/1000
# 71/71 [==============================] - 22s 16ms/step - loss: 0.0101 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0527
# Epoch 2/1000
# 71/71 [==============================] - 1s 18ms/step - loss: 0.0019 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0232
# Epoch 3/1000
# 71/71 [==============================] - 1s 17ms/step - loss: 0.0018 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0223
# Epoch 4/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 0.0017 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0227
# Epoch 5/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 0.0014 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0201
# Epoch 6/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 0.0015 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0216
# Epoch 7/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 0.0014 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0194
# Epoch 8/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 0.0012 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0185
# Epoch 9/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 0.0015 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0203
# Epoch 10/1000
# 71/71 [==============================] - 1s 18ms/step - loss: 0.0010 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0182
# Epoch 11/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 0.0011 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0181
# Epoch 12/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 0.0011 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0182
# Epoch 13/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 9.9333e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0171
# Epoch 14/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 8.4380e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0159
# Epoch 15/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 0.0013 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0189
# Epoch 16/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 8.8470e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0165
# Epoch 17/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 0.0013 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0192
# Epoch 18/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 9.0734e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0159
# Epoch 19/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 0.0012 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0185
# Epoch 20/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 0.0011 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0179
# Epoch 21/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 8.2676e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0165
# Epoch 22/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 8.6532e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0162
# Epoch 23/1000
# 71/71 [==============================] - 1s 14ms/step - loss: 7.6579e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0154
# Epoch 24/1000
# 71/71 [==============================] - 1s 15ms/step - loss: 7.2705e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0149
# Epoch 25/1000
# 71/71 [==============================] - 1s 18ms/step - loss: 8.5860e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0159
# Epoch 26/1000
# 71/71 [==============================] - 1s 17ms/step - loss: 8.9556e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0158
# Epoch 27/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 9.8583e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0170
# Epoch 28/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 7.1495e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0153
# Epoch 29/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 7.8605e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0150
# Epoch 30/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 8.7574e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0162
# Epoch 31/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 8.4123e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0160
# Epoch 32/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 9.0191e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0165
# Epoch 33/1000
# 71/71 [==============================] - 1s 18ms/step - loss: 7.9673e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0153
# Epoch 34/1000
# 71/71 [==============================] - 1s 18ms/step - loss: 7.9695e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0155
# Epoch 35/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 8.8390e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0158
# Epoch 36/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 9.1152e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0154
# Epoch 37/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 7.5280e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0150
# Epoch 38/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 7.1403e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0150
# Epoch 39/1000
# 71/71 [==============================] - 2s 21ms/step - loss: 7.4442e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0153
# Epoch 40/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 7.9838e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0149
# Epoch 41/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 6.8957e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0147
# Epoch 42/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 7.2851e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0145
# Epoch 43/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 7.5851e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0144
# Epoch 44/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 9.2200e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0162
# Epoch 45/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 7.0323e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0151
# Epoch 46/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 8.4220e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0158
# Epoch 47/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 9.2659e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0167
# Epoch 48/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 7.2361e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0150
# Epoch 49/1000
# 71/71 [==============================] - 2s 21ms/step - loss: 7.5301e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0155
# Epoch 50/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 8.4158e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0157
# Epoch 51/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 8.0655e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0158
# Epoch 52/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 7.6385e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0159
# Epoch 53/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 9.7175e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0173
# Epoch 54/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 6.6471e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0144
# Epoch 55/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 7.5982e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0148
# Epoch 56/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 7.4991e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0155
# Epoch 57/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 8.2163e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0158
# Epoch 58/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 6.6408e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0149
# Epoch 59/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 6.2879e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0147
# Epoch 60/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 0.0010 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0174
# Epoch 61/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 6.8553e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0153
# Epoch 62/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 7.0106e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0148
# Epoch 63/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 6.9100e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0150
# Epoch 64/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 7.5597e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0161
# Epoch 65/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 7.6651e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0157
# Epoch 66/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 7.6610e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0150
# Epoch 67/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 7.3038e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0159
# Epoch 68/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 6.4953e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0148
# Epoch 69/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 8.2933e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0168
# Epoch 70/1000
# 71/71 [==============================] - 2s 21ms/step - loss: 8.0818e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0158
# Epoch 71/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 6.6911e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0152
# Epoch 72/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 8.1087e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0158
# Epoch 73/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 8.1176e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0162
# Epoch 74/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 6.3482e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0144
# Epoch 75/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 7.5382e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0146
# Epoch 76/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 7.3801e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0153
# Epoch 77/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 8.1151e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0157
# Epoch 78/1000
# 71/71 [==============================] - 1s 18ms/step - loss: 7.6089e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0155
# Epoch 79/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 6.6902e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0148
# Epoch 80/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 7.5971e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0147
# Epoch 81/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 9.8855e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0175
# Epoch 82/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 9.2912e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0165
# Epoch 83/1000
# 71/71 [==============================] - 1s 18ms/step - loss: 6.4584e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0149
# Epoch 84/1000
# 71/71 [==============================] - 2s 21ms/step - loss: 8.6941e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0163
# Epoch 85/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 8.2440e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0159
# Epoch 86/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 7.6461e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0155
# Epoch 87/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 6.1169e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0141
# Epoch 88/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 7.5767e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0152
# Epoch 89/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 7.0172e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0156
# Epoch 90/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 7.7152e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0151
# Epoch 91/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 7.1082e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0153
# Epoch 92/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 6.7281e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0143
# Epoch 93/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 7.8646e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0152
# Epoch 94/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 7.1397e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0151
# Epoch 95/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 7.2715e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0158
# Epoch 96/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 6.9581e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0142
# Epoch 97/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 6.6681e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0142
# Epoch 98/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 6.3442e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0144
# Epoch 99/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 7.9736e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0164
# Epoch 100/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 6.6990e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0153
# Epoch 101/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 7.0152e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0148
# Epoch 102/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 6.0584e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0144
# Epoch 103/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 9.2667e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0160
# Epoch 104/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 9.6017e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0182
# Epoch 105/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 6.7320e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0150
# Epoch 106/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 7.5771e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0149
# Epoch 107/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 6.6673e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0144
# Epoch 108/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 7.3112e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0147
# Epoch 109/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 7.0443e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0153
# Epoch 110/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 7.0416e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0152
# Epoch 111/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 7.9912e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0154
# Epoch 112/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 7.2478e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0148
# Epoch 113/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 6.2753e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0145
# Epoch 114/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 6.0498e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0141
# Epoch 115/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 6.4931e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0142
# Epoch 116/1000
# 71/71 [==============================] - 2s 21ms/step - loss: 7.0444e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0155
# Epoch 117/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 6.6337e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0147
# Epoch 118/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 8.2330e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0160
# Epoch 119/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 7.1813e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0153
# Epoch 120/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 6.7885e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0145
# Epoch 121/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 8.4684e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0158
# Epoch 122/1000
# 71/71 [==============================] - 2s 21ms/step - loss: 7.2696e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0151
# Epoch 123/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 7.1144e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0148
# Epoch 124/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 7.7673e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0154
# Epoch 125/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 8.6335e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0160
# Epoch 126/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 6.5760e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0146
# Epoch 127/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 6.1939e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0139
# Epoch 128/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 7.2073e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0150
# Epoch 129/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 8.7021e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0159
# Epoch 130/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 6.3824e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0143
# Epoch 131/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 7.2032e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0150
# Epoch 132/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 7.8205e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0151
# Epoch 133/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 7.1134e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0147
# Epoch 134/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 7.1218e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0151
# Epoch 135/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 7.1650e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0152
# Epoch 136/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 6.6871e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0163
# Epoch 137/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 6.6721e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0138
# Epoch 138/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 6.5838e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0150
# Epoch 139/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 8.0363e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0162
# Epoch 140/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 6.0007e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0139
# Epoch 141/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 6.4289e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0141
# Epoch 142/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 6.2920e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0146
# Epoch 143/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 7.1344e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0152
# Epoch 144/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 6.3276e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0142
# Epoch 145/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 5.6266e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0135
# Epoch 146/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 6.2737e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0145
# Epoch 147/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 6.5796e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0143
# Epoch 148/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 6.5120e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0145
# Epoch 149/1000
# 71/71 [==============================] - 2s 21ms/step - loss: 6.2262e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0138
# Epoch 150/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 7.5509e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0146
# Epoch 151/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 6.9465e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0151
# Epoch 152/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 6.4302e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0140
# Epoch 153/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 8.2802e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0162
# Epoch 154/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 5.8317e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0134
# Epoch 155/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 7.1854e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0146
# Epoch 156/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 7.0995e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0147
# Epoch 157/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 6.8602e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0148
# Epoch 158/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 7.0535e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0153
# Epoch 159/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 5.8418e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0141
# Epoch 160/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 7.1187e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0147
# Epoch 161/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 6.3768e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0145
# Epoch 162/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 6.7543e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0149
# Epoch 163/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 7.5171e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0155
# Epoch 164/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 6.4095e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0145
# Epoch 165/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 6.2746e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0143
# Epoch 166/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 7.0262e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0147
# Epoch 167/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 6.4964e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0146
# Epoch 168/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 6.4431e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0142
# Epoch 169/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 5.7709e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0137
# Epoch 170/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 7.1436e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0150
# Epoch 171/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 6.7484e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0145
# Epoch 172/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 5.9436e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0142
# Epoch 173/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 6.9963e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0149
# Epoch 174/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 5.8578e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0149
# Epoch 175/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 7.5978e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0146
# Epoch 176/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 7.8522e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0149
# Epoch 177/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 7.3315e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0151
# Epoch 178/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 7.8559e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0160
# Epoch 179/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 6.1727e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0147
# Epoch 180/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 6.3807e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0144
# Epoch 181/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 6.5885e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0144
# Epoch 182/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 5.4728e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0131
# Epoch 183/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 5.6529e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0135
# Epoch 184/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 6.0400e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0135
# Epoch 185/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 6.6557e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0145
# Epoch 186/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 6.3337e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0143
# Epoch 187/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 5.1576e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0130
# Epoch 188/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 6.9352e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0150
# Epoch 189/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 6.9503e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0148
# Epoch 190/1000
# 71/71 [==============================] - 2s 21ms/step - loss: 5.4887e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0133
# Epoch 191/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 6.5853e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0141
# Epoch 192/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 6.7892e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0151
# Epoch 193/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 5.8940e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0133
# Epoch 194/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 5.5692e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0144
# Epoch 195/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 5.8237e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0131
# Epoch 196/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 6.0789e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0139
# Epoch 197/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 5.8236e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0135
# Epoch 198/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 6.2047e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0142
# Epoch 199/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 5.0351e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0131
# Epoch 200/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 7.6076e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0145
# Epoch 201/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 6.7350e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0147
# Epoch 202/1000
# 71/71 [==============================] - 2s 21ms/step - loss: 5.9019e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0140
# Epoch 203/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 6.0625e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0149
# Epoch 204/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 5.4568e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0132
# Epoch 205/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 6.6362e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0137
# Epoch 206/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 5.8127e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0140
# Epoch 207/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 7.3890e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0154
# Epoch 208/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 5.6209e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0132
# Epoch 209/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 5.7194e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0133
# Epoch 210/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 6.4885e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0137
# Epoch 211/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 6.2600e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0140
# Epoch 212/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 5.1087e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0131
# Epoch 213/1000
# 71/71 [==============================] - 2s 21ms/step - loss: 7.6685e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0145
# Epoch 214/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 5.9796e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0138
# Epoch 215/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 6.4688e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0147
# Epoch 216/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 5.5558e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0129
# Epoch 217/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 5.4486e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0135
# Epoch 218/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 6.8224e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0147
# Epoch 219/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 7.0976e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0143
# Epoch 220/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 6.3934e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0140
# Epoch 221/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 6.3079e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0137
# Epoch 222/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 5.6261e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0135
# Epoch 223/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 5.6136e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0135
# Epoch 224/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 5.8800e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0134
# Epoch 225/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 5.7052e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0135
# Epoch 226/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 5.3688e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0138
# Epoch 227/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 7.5658e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0150
# Epoch 228/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 5.7210e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0135
# Epoch 229/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 6.7296e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0144
# Epoch 230/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 8.4246e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0156
# Epoch 231/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 6.5385e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0152
# Epoch 232/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 6.3488e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0143
# Epoch 233/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 6.6518e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0149
# Epoch 234/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 5.8868e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0140
# Epoch 235/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 6.7641e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0143
# Epoch 236/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 6.8319e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0146
# Epoch 237/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 6.0027e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0136
# Epoch 238/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 5.9731e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0140
# Epoch 239/1000
# 71/71 [==============================] - 1s 18ms/step - loss: 6.7032e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0145
# Epoch 240/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 7.6729e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0152
# Epoch 241/1000
# 71/71 [==============================] - 1s 16ms/step - loss: 6.0370e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0136
# Epoch 242/1000
# 71/71 [==============================] - 1s 17ms/step - loss: 6.0213e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0138
# Epoch 243/1000
# 71/71 [==============================] - 1s 18ms/step - loss: 6.2065e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0136
# Epoch 244/1000
# 71/71 [==============================] - 1s 18ms/step - loss: 6.5179e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0145
# Epoch 245/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 6.3109e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0141
# Epoch 246/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 5.9706e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0141
# Epoch 247/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 6.1609e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0145
# Epoch 248/1000
# 71/71 [==============================] - 2s 21ms/step - loss: 5.7655e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0133
# Epoch 249/1000
# 71/71 [==============================] - 1s 18ms/step - loss: 5.3453e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0140
# Epoch 250/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 7.2713e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0144
# Epoch 251/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 4.6230e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0129
# Epoch 252/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 6.3864e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0142
# Epoch 253/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 6.0407e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0135
# Epoch 254/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 5.9975e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0139
# Epoch 255/1000
# 71/71 [==============================] - 1s 18ms/step - loss: 5.5686e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0141
# Epoch 256/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 5.8468e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0136
# Epoch 257/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 5.1096e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0133
# Epoch 258/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 6.3448e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0139
# Epoch 259/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 6.0193e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0146
# Epoch 260/1000
# 71/71 [==============================] - 1s 18ms/step - loss: 7.0320e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0151
# Epoch 261/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 7.8061e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0149
# Epoch 262/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 5.5017e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0134
# Epoch 263/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 6.0147e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0135
# Epoch 264/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 6.2824e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0140
# Epoch 265/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 5.9714e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0143
# Epoch 266/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 5.6762e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0133
# Epoch 267/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 5.9161e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0142
# Epoch 268/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 6.1604e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0133
# Epoch 269/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 5.0588e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0133
# Epoch 270/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 6.9432e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0150
# Epoch 271/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 6.4824e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0140
# Epoch 272/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 5.5351e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0136
# Epoch 273/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 6.1929e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0138
# Epoch 274/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 6.5620e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0143
# Epoch 275/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 5.7247e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0138
# Epoch 276/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 6.1448e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0138
# Epoch 277/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 5.3963e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0134
# Epoch 278/1000
# 71/71 [==============================] - 2s 21ms/step - loss: 5.6445e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0137
# Epoch 279/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 4.7707e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0130
# Epoch 280/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 5.8736e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0142
# Epoch 281/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 5.2616e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0131
# Epoch 282/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 5.8933e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0139
# Epoch 283/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 6.3682e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0139
# Epoch 284/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 6.6035e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0143
# Epoch 285/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 5.3249e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0138
# Epoch 286/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 5.3774e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0133
# Epoch 287/1000
# 71/71 [==============================] - 2s 21ms/step - loss: 5.9656e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0134
# Epoch 288/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 5.7539e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0134
# Epoch 289/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 5.3988e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0135
# Epoch 290/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 6.2319e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0136
# Epoch 291/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 5.3696e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0130
# Epoch 292/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 6.5911e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0147
# Epoch 293/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 5.7753e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0135
# Epoch 294/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 4.7011e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0127
# Epoch 295/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 6.2296e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0137
# Epoch 296/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 4.6357e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0128
# Epoch 297/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 5.0876e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0129
# Epoch 298/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 5.5009e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0133
# Epoch 299/1000
# 71/71 [==============================] - 2s 21ms/step - loss: 5.7047e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0137
# Epoch 300/1000
# 71/71 [==============================] - 1s 19ms/step - loss: 6.4570e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0140
# Epoch 301/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 5.8271e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0136
# Epoch 302/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 6.3571e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0141
# Epoch 303/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 5.7570e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0143
# Epoch 304/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 5.9212e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0136
# Epoch 305/1000
# 71/71 [==============================] - 2s 21ms/step - loss: 6.1960e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0143
# Epoch 306/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 4.9586e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0128
# Epoch 307/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 6.5677e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0139
# Epoch 308/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 5.5764e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0135
# Epoch 309/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 6.2021e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0140
# Epoch 310/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 5.0206e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0130
# Epoch 311/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 5.8081e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0137
# Epoch 312/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 5.4587e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0138
# Epoch 313/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 6.3970e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0137
# Epoch 314/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 5.6484e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0137
# Epoch 315/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 5.4993e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0130
# Epoch 316/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 5.9235e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0135
# Epoch 317/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 5.3714e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0138
# Epoch 318/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 5.2029e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0128
# Epoch 319/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 5.7366e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0135
# Epoch 320/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 4.5925e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0126
# Epoch 321/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 5.0253e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0127
# Epoch 322/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 5.4458e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0133
# Epoch 323/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 6.0846e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0141
# Epoch 324/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 5.3777e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0134
# Epoch 325/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 4.7922e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0129
# Epoch 326/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 5.4048e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0130
# Epoch 327/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 5.3678e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0136
# Epoch 328/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 6.9853e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0148
# Epoch 329/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 6.7645e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0140
# Epoch 330/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 5.8580e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0136
# Epoch 331/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 5.1905e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0137
# Epoch 332/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 5.0049e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0128
# Epoch 333/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 5.6685e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0137
# Epoch 334/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 5.3420e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0132
# Epoch 335/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 5.0544e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0129
# Epoch 336/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 6.9240e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0147
# Epoch 337/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 4.3809e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0129
# Epoch 338/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 6.2575e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0136
# Epoch 339/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 5.3503e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0133
# Epoch 340/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 5.6465e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0132
# Epoch 341/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 5.9175e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0137
# Epoch 342/1000
# ...
# Epoch 888/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 5.3298e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0127
# Epoch 889/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 4.4216e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0121
# Epoch 890/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 4.1447e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0119
# Epoch 891/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 4.5363e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0120
# Epoch 892/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 3.8987e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0117
# Epoch 893/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 4.9883e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0123
# Epoch 894/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 4.2462e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0124
# Epoch 895/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 4.8636e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0124
# Epoch 896/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 4.6486e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0124
# Epoch 897/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 5.2504e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0126
# Epoch 898/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 4.9066e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0127
# Epoch 899/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 4.5625e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0124
# Epoch 900/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 6.3773e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0136
# Epoch 901/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 4.7912e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0126
# Epoch 902/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 5.5193e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0135
# Epoch 903/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 4.6612e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0120
# Epoch 904/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 4.0763e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0119
# Epoch 905/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 4.2485e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0118
# Epoch 906/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 5.1678e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0127
# Epoch 907/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 4.5342e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0118
# Epoch 908/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 4.3982e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0117
# Epoch 909/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 4.7726e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0129
# Epoch 910/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 4.4931e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0120
# Epoch 911/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 5.1880e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0125
# Epoch 912/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.4310e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0118
# Epoch 913/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 5.1531e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0123
# Epoch 914/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 5.2179e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0126
# Epoch 915/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 4.1560e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0123
# Epoch 916/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 4.4293e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0120
# Epoch 917/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.2439e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0124
# Epoch 918/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 5.8997e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0131
# Epoch 919/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.9542e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0132
# Epoch 920/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 5.2287e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0127
# Epoch 921/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 5.0947e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0125
# Epoch 922/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 4.9006e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0120
# Epoch 923/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 5.5649e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0131
# Epoch 924/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 5.3063e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0127
# Epoch 925/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 4.5890e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0120
# Epoch 926/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 4.4352e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0121
# Epoch 927/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 5.2186e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0126
# Epoch 928/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 4.4480e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0119
# Epoch 929/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 4.0742e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0120
# Epoch 930/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 5.4577e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0126
# Epoch 931/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 5.7738e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0129
# Epoch 932/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 4.4472e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0123
# Epoch 933/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 4.7600e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0128
# Epoch 934/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 4.3226e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0119
# Epoch 935/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 4.6373e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0121
# Epoch 936/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 4.7935e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0128
# Epoch 937/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 5.7402e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0129
# Epoch 938/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 4.0475e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0117
# Epoch 939/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 5.1332e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0124
# Epoch 940/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 4.9513e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0122
# Epoch 941/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 5.0726e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0130
# Epoch 942/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 5.9961e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0132
# Epoch 943/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 4.5065e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0124
# Epoch 944/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 4.6981e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0120
# Epoch 945/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.1050e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0122
# Epoch 946/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 5.1262e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0127
# Epoch 947/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 4.9044e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0127
# Epoch 948/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 4.8230e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0127
# Epoch 949/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 4.3866e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0120
# Epoch 950/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 4.7519e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0126
# Epoch 951/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 4.4924e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0123
# Epoch 952/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 4.3105e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0122
# Epoch 953/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 4.5091e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0122
# Epoch 954/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 4.6305e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0124
# Epoch 955/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 4.6870e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0125
# Epoch 956/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 4.4267e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0122
# Epoch 957/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 4.9564e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0128
# Epoch 958/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 4.5690e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0123
# Epoch 959/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 4.3877e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0120
# Epoch 960/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 4.1223e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0118
# Epoch 961/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 5.0369e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0120
# Epoch 962/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 5.0214e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0124
# Epoch 963/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 5.5041e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0130
# Epoch 964/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 5.1469e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0125
# Epoch 965/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 4.8747e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0123
# Epoch 966/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 4.7432e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0125
# Epoch 967/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.5363e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0123
# Epoch 968/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 4.4084e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0120
# Epoch 969/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.3351e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0122
# Epoch 970/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 5.0008e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0130
# Epoch 971/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 5.1103e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0122
# Epoch 972/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.3332e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0119
# Epoch 973/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 4.4251e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0118
# Epoch 974/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 4.3585e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0123
# Epoch 975/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.7818e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0122
# Epoch 976/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.7527e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0121
# Epoch 977/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 4.8784e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0123
# Epoch 978/1000
# 71/71 [==============================] - 2s 21ms/step - loss: 4.5573e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0120
# Epoch 979/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 4.8071e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0123
# Epoch 980/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.4085e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0121
# Epoch 981/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 4.8165e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0121
# Epoch 982/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 5.1847e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0126
# Epoch 983/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.7770e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0122
# Epoch 984/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.7681e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0120
# Epoch 985/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 5.0486e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0127
# Epoch 986/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 5.1060e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0125
# Epoch 987/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 4.0429e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0118
# Epoch 988/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 5.0017e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0122
# Epoch 989/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 5.0457e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0127
# Epoch 990/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 4.7942e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0125
# Epoch 991/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 5.4447e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0126
# Epoch 992/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 5.1009e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0128
# Epoch 993/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 4.8904e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0128
# Epoch 994/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 4.8775e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0123
# Epoch 995/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 4.6430e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0123
# Epoch 996/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 4.5506e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0121
# Epoch 997/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.9344e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0123
# Epoch 998/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 4.7837e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0124
# Epoch 999/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 5.2274e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0128
# Epoch 1000/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.8615e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0123

# %%
def visualize_training_results(results):
    """
    Plots the loss and accuracy for the training and testing data
    """
    history = results.history

    plt.figure(figsize=(16, 5))
    # plt.plot(history['val_mean_absolute_error'])
    plt.plot(history['mean_absolute_error'])
    plt.legend(['val_mean_absolute_error', 'mean_absolute_error'])
    plt.title('mean_absolute_error')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.show()

    plt.figure(figsize=(16, 5))
    # plt.plot(history['val_loss'])
    plt.plot(history['loss'])
    plt.legend(['val_loss', 'loss'])
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.show()

    plt.figure(figsize=(16, 5))
    # plt.plot(history['val_accuracy'])
    plt.plot(history['accuracy'])
    plt.legend(['val_accuracy', 'accuracy'])
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.show()

# %%
visualize_training_results(history)

# %%
# Evaluate the model on the test set
mse, accuracy, mae = model.evaluate(X_test, y_test)
# Out:
# 18/18 [==============================] - 6s 11ms/step - loss: 3.4736e-04 - accuracy: 0.0035 - mean_absolute_error: 0.0142

# %%
# Step 8: Tuning the Hyperparameters
# You can use techniques such as grid search or random search to find the best values for the model's hyperparameters

# Step 9: Testing the model
y_pred = model.predict(X_test)
print('y_pred', y_pred.shape)
print('y_test', y_test.shape)




# evaluat
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

rmse = np.sqrt(mean_squared_error(y_test, y_pred))



print("RMSE: {:.4f}".format(rmse))
print("MSE: {:.4f}".format(mse))
print("MAE:{:.4f}".format(mae))
# Out:
# 18/18 [==============================] - 7s 8ms/step
# y_pred (565, 1)
# y_test (565, 1)
# RMSE: 0.0186
# MSE: 0.0003
# MAE:0.0142

# %%
# convert to original data
y_pred = scaler.inverse_transform(y_pred)
y_test= scaler.inverse_transform(y_test)


# evaluat
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mape = 100 * np.mean(np.abs((y_test - y_pred) / y_test))
rmse = np.sqrt(mean_squared_error(y_test, y_pred))


print("MAPE: {:.4f}%".format(mape))
print("RMSE: {:.4f}".format(rmse))
print("MSE: {:.4f}".format(mse))
print("MAE:{:.4f}".format(mae))
# Out:
# MAPE: 2.0743%
# RMSE: 965.0426
# MSE: 931307.2362
# MAE:736.8278

# %%
y_pred_df = pd.DataFrame(y_pred, columns=["Adj Close"])
y_test_df = pd.DataFrame(y_test, columns=["Adj Close"])

# Get the length of y_pred
y_pred_length = y_pred.shape[0]
y_test_length = y_test.shape[0]


today = pd.Timestamp.now().date()
prediction_dates = today - timedelta(days=y_pred_length-1)
test = today - timedelta(days=y_test_length-1)
prediction = pd.date_range(start=test_data.index[0], end=test_data.index[-1], freq='D')
test_dates = pd.date_range(start=test_data.index[0], end=test_data.index[-1], freq='D')

# Use the generated dates as the index of the DataFrame
y_pred_df['Date'] = prediction

y_test_df['Date'] = test_dates

# Set the index of the dataframes to be the 'Date' column
y_pred_df.set_index('Date', inplace=True)
y_test_df.set_index('Date', inplace=True)


# Assuming y_pred is a numpy array

# %%
#y_test_df.to_csv("y_test_2021_2022.csv")
y_test_df
# Out:
#                Adj Close
# Date
# 2021-06-14  40218.476562
# 2021-06-15  40406.269531
# 2021-06-16  38347.062500
# 2021-06-17  38053.503906
# 2021-06-18  35787.246094
# ...                  ...
# 2022-12-26  16919.804688
# 2022-12-27  16717.173828
# 2022-12-28  16552.572266
# 2022-12-29  16642.341797
# 2022-12-30  16602.585938
#
# [565 rows x 1 columns]

# %%
#y_pred_df.to_csv("y_pred_2021_2022.csv")  # index=False to exclude index column in CSV
y_pred_df
# Out:
#                Adj Close
# Date
# 2021-06-14  40785.640625
# 2021-06-15  41129.859375
# 2021-06-16  39791.300781
# 2021-06-17  39289.273438
# 2021-06-18  37461.796875
# ...                  ...
# 2022-12-26  16568.464844
# 2022-12-27  16529.031250
# 2022-12-28  16393.185547
# 2022-12-29  16339.136719
# 2022-12-30  16283.055664
#
# [565 rows x 1 columns]

# %%
names = cycle(['Predictions', 'Test Data'])

fig = go.Figure()
fig.add_trace(go.Scatter(x=y_test_df.index, y=y_pred_df['Adj Close'], name='Predictions',
                         line=dict(width=2, color='blue')))
fig.add_trace(go.Scatter(x=y_test_df.index, y=y_test_df['Adj Close'], name='Test Data',
                         line=dict(width=2, color='red')))
fig.update_layout(xaxis_title='Date', yaxis_title='Price',
                  font_size=15, font_color='black', legend_title_text=' Parameters')
fig.show()

# %%
# Calculate mean absolute percentage error (MAPE)
def mape(y_true, y_pred):
    return 100 * np.mean(np.abs((y_true - y_pred) / y_true))


mape_value = mape(y_test, y_pred)
print(f'MAPE: {mape_value:.4f}%')
# Out:
# MAPE: 2.0743%

# %%
def smape(y_true, y_pred):
    return 200 * np.mean(np.abs(y_pred - y_true) / (np.abs(y_pred) + np.abs(y_true)))


SMAPE1 = smape(y_test, y_pred)
print("smape: {:.4f}%".format(SMAPE1))
# Out:
# smape: 2.0603%

# %%
# Step 1: Data cleaning
#data = yf.download(tickers='BTC-usd', start='2014-12-31', end='2022-12-31', interval='1d')
data_new = yf.download(tickers='BTC-USD', period='max', interval='1d')
data_new.dropna(inplace=True)
data_new
# Out:
# [*********************100%***********************]  1 of 1 completed
#                     Open          High           Low         Close  \
# Date
# 2014-09-17    465.864014    468.174011    452.421997    457.334015
# 2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2023-03-06  22436.816406  22584.292969  22331.314453  22429.757812
# 2023-03-07  22428.322266  22527.417969  22011.261719  22219.769531
# 2023-03-08  22216.441406  22268.896484  21708.050781  21718.080078
# 2023-03-09  21720.080078  21802.716797  20210.306641  20363.021484
# 2023-03-10  20355.517578  20355.517578  19851.787109  19958.080078
#
#                Adj Close       Volume
# Date
# 2014-09-17    457.334015     21056800
# 2014-09-18    424.440002     34483200
# 2014-09-19    394.795990     37919700
# 2014-09-20    408.903992     36863600
# 2014-09-21    398.821014     26580100
# ...                  ...          ...
# 2023-03-06  22429.757812  17353192895
# 2023-03-07  22219.769531  22765452204
# 2023-03-08  21718.080078  22536575684
# 2023-03-09  20363.021484  30364664171
# 2023-03-10  19958.080078  37571887104
#
# [3097 rows x 6 columns]

# %%
# Step 2: Feature engineering
data_new['RSI']       = ta.rsi(data_new.Close, length=15)
data_new['EMA_short'] = ta.ema(data_new.Close, length=20)
data_new['EMA_long']  = ta.ema(data_new.Close, length=100)
data_new.dropna(inplace=True)
data_new.reset_index(inplace=True)
data_new.drop(['Close'], axis=1, inplace=True)
# Setting the index
data_new.set_index('Date', inplace=True)

# Dropping any NaNs
data_new.dropna(inplace=True)

data_new.info()
data_new.tail(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2998 entries, 2014-12-25 to 2023-03-10
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2998 non-null   float64
#  1   High       2998 non-null   float64
#  2   Low        2998 non-null   float64
#  3   Adj Close  2998 non-null   float64
#  4   Volume     2998 non-null   int64
#  5   RSI        2998 non-null   float64
#  6   EMA_short  2998 non-null   float64
#  7   EMA_long   2998 non-null   float64
# dtypes: float64(7), int64(1)
# memory usage: 210.8 KB
#                     Open          High           Low     Adj Close  \
# Date
# 2023-03-01  23150.929688  23880.632812  23088.626953  23646.550781
# 2023-03-02  23647.019531  23739.138672  23245.021484  23475.466797
# 2023-03-03  23476.632812  23479.347656  22213.238281  22362.679688
# 2023-03-04  22362.923828  22405.177734  22198.980469  22353.349609
# 2023-03-05  22354.144531  22613.685547  22307.142578  22435.513672
# 2023-03-06  22436.816406  22584.292969  22331.314453  22429.757812
# 2023-03-07  22428.322266  22527.417969  22011.261719  22219.769531
# 2023-03-08  22216.441406  22268.896484  21708.050781  21718.080078
# 2023-03-09  21720.080078  21802.716797  20210.306641  20363.021484
# 2023-03-10  20355.517578  20355.517578  19851.787109  19958.080078
#
#                  Volume        RSI     EMA_short      EMA_long
# Date
# 2023-03-01  24662841200  54.381735  23441.354855  21145.104585
# 2023-03-02  20386398516  52.763703  23444.603611  21191.250372
# 2023-03-03  26062404610  43.702150  23341.563237  21214.446992
# 2023-03-04  11166012913  43.634831  23247.447654  21236.999519
# 2023-03-05  13317001733  44.442323  23170.120608  21260.732473
# 2023-03-06  17353192895  44.394587  23099.609865  21283.881489
# 2023-03-07  22765452204  42.605759  23015.815548  21302.413926
# 2023-03-08  22536575684  38.622138  22892.221694  21310.644939
# 2023-03-09  30364664171  30.397245  22651.345483  21291.880118
# 2023-03-10  37571887104  28.456900  22394.844016  21265.468236

# %%
future_data = data_new.iloc[-30:, :]
future_data = future_data.values
future_data = pd.DataFrame(future_data, columns=["Open", "High", "Low", "Adj Close", "Volume", "RSI",
                                                 "EMA_short", "EMA_long"])

# Get the length of future_data
future_length = future_data.shape[0]

# Generate dates for the next 30 days
today = pd.Timestamp.now().date()
future_dates = today + timedelta(days=1)

future = pd.date_range(start=future_dates, end=today +
                       timedelta(days=30), freq='D')

# Generate dates for the next 10 days for predict
today = pd.Timestamp.now().date()
future_dates_pred = pd.date_range(start=today + timedelta(days=1), periods=10, freq='D')

# Use the generated dates as the index of the DataFrame
future_data['Date'] = future

# Set the index of the dataframes to be the 'Date' column
future_data.set_index('Date', inplace=True)

future_data.tail(10)
x_future_data = future_data.drop(['Adj Close'], axis=1).values
y_future_data = future_data['Adj Close'].values
y_future_data = y_future_data.reshape(-1, 1)

print("x_future_data:", x_future_data.shape)
print("y_future_data:", y_future_data.shape)

# x_future_data= np.reshape(x_future_data, (x_future_data.shape[0], 1, x_future_data.shape[1]))

print("x_future_data:", x_future_data.shape)
x_future_data = scaler.fit_transform(x_future_data)
y_future_data = scaler.fit_transform(y_future_data)
for i in range(10):
    future_data_temp = x_future_data[i:i+30, :]
    # future_data_temp = future_data_temp.reshape(-1, 1)
    print("future_data_temp", future_data_temp.shape)
# Out:
# x_future_data: (30, 7)
# y_future_data: (30, 1)
# x_future_data: (30, 7)
# future_data_temp (30, 7)
# future_data_temp (29, 7)
# future_data_temp (28, 7)
# future_data_temp (27, 7)
# future_data_temp (26, 7)
# future_data_temp (25, 7)
# future_data_temp (24, 7)
# future_data_temp (23, 7)
# future_data_temp (22, 7)
# future_data_temp (21, 7)

# %%
# Initialize a numpy array to store the predictions
prediction = np.zeros((10, 1))

for i in range(10):
    future_data_temp = x_future_data[i:i+30, :]

    print("future_data_temp1", future_data_temp.shape)
    future_data_temp = np.reshape(future_data_temp, (future_data_temp.shape[0],
                                                     1, future_data_temp.shape[1]))
    pred = model.predict(future_data_temp)
    print("future_data_temp2", future_data_temp.shape)
    print('---------------------------------------------------')
    prediction[i][0] = pred[0][0]
    x_future_data[i+future_data_temp.shape[0]-1][0] = pred[0][0]
print('3', future_data.shape)
print('prediction:', prediction.shape)
# Reverse the MinMaxScaler
y_future_data = y_future_data.reshape(-1, 1)
y_future_data = scaler.inverse_transform(y_future_data)
prediction = scaler.inverse_transform(prediction)

# Create a new dataframe with the predicted values and the dates as the index
prediction_df = pd.DataFrame(
    prediction, index=future_dates_pred, columns=['Adj Close'])
print('y_future_data', y_future_data.shape)
# Get the length of future_data

y_future_data = pd.DataFrame(y_future_data,  columns=['Adj Close'])

future_length = future_data.shape[0]
test = today - timedelta(days=future_length-1)
test_dates = pd.date_range(start=test, end=today, freq='D')
# Use the generated dates as the index of the DataFrame


y_future_data['Date'] = test_dates

# Set the index of the dataframes to be the 'Date' column

y_future_data.set_index('Date', inplace=True)
# Out:
# future_data_temp1 (30, 7)
# 1/1 [==============================] - 0s 86ms/step
# future_data_temp2 (30, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (29, 7)
# 1/1 [==============================] - 0s 146ms/step
# future_data_temp2 (29, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (28, 7)
# 1/1 [==============================] - 0s 151ms/step
# future_data_temp2 (28, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (27, 7)
# 1/1 [==============================] - 0s 111ms/step
# future_data_temp2 (27, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (26, 7)
# 1/1 [==============================] - 0s 117ms/step
# future_data_temp2 (26, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (25, 7)
# 1/1 [==============================] - 0s 138ms/step
# future_data_temp2 (25, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (24, 7)
# 1/1 [==============================] - 0s 121ms/step
# future_data_temp2 (24, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (23, 7)
# 1/1 [==============================] - 0s 116ms/step
# future_data_temp2 (23, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (22, 7)
# 1/1 [==============================] - 0s 105ms/step
# future_data_temp2 (22, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (21, 7)
# 1/1 [==============================] - 0s 142ms/step
# future_data_temp2 (21, 1, 7)
# ---------------------------------------------------
# 3 (30, 8)
# prediction: (10, 1)
# y_future_data (30, 1)

# %%
prediction_df
# Out:
#                Adj Close
# 2023-03-11  21826.645982
# 2023-03-12  21350.676552
# 2023-03-13  21385.410739
# 2023-03-14  21408.264428
# 2023-03-15  21200.363189
# 2023-03-16  21503.540393
# 2023-03-17  22832.077641
# 2023-03-18  23568.921984
# 2023-03-19  23751.093879
# 2023-03-20  24305.349402

# %%
y_future_data
# Out:
#                Adj Close
# Date
# 2023-02-09  21819.039062
# 2023-02-10  21651.183594
# 2023-02-11  21870.875000
# 2023-02-12  21788.203125
# 2023-02-13  21808.101562
# 2023-02-14  22220.804688
# 2023-02-15  24307.841797
# 2023-02-16  23623.474609
# 2023-02-17  24565.601562
# 2023-02-18  24641.277344
# 2023-02-19  24327.642578
# 2023-02-20  24829.148438
# 2023-02-21  24436.353516
# 2023-02-22  24188.843750
# 2023-02-23  23947.492188
# 2023-02-24  23198.126953
# 2023-02-25  23175.375000
# 2023-02-26  23561.212891
# 2023-02-27  23522.871094
# 2023-02-28  23147.353516
# 2023-03-01  23646.550781
# 2023-03-02  23475.466797
# 2023-03-03  22362.679688
# 2023-03-04  22353.349609
# 2023-03-05  22435.513672
# 2023-03-06  22429.757812
# 2023-03-07  22219.769531
# 2023-03-08  21718.080078
# 2023-03-09  20363.021484
# 2023-03-10  19958.080078

# %%
names = cycle(['Predictions next 10 day', 'Actual data '])

fig = go.Figure()

fig.add_trace(go.Scatter(x=y_future_data.index, y=y_future_data['Adj Close'], name='Actual data ',
                         line=dict(width=2, color='red')))
fig.add_trace(go.Scatter(x=prediction_df.index, y=prediction_df['Adj Close'], name='Predictions next 10 day',
                         line=dict(width=2, color='blue')))

fig.add_shape(type='line',
              x0=prediction_df.index[0], y0=prediction_df['Adj Close'][0],
              x1=y_future_data.index[-1], y1=y_future_data['Adj Close'][-1],
              line=dict(color='grey', width=2))
fig.update_layout(xaxis_title='Date', yaxis_title='Price',
                  font_size=15, font_color='black', legend_title_text=' Parameters')
fig.show()

# %%
actual_x = y_future_data.index
actual_y = y_future_data['Adj Close']
pred_x = prediction_df.index
pred_y = prediction_df['Adj Close']

fig = go.Figure()
fig.add_trace(go.Scatter(x=actual_x, y=actual_y, name='Actual Data'))
fig.add_trace(go.Scatter(x=pred_x, y=pred_y,
              name='Predictions Data for 10 day'))

fig.add_shape(type='line',
              x0=actual_x[-1], y0=actual_y[-1],
              x1=pred_x[0], y1=pred_y[0],
              line=dict(color='grey', width=2, dash='dot'))

fig.update_layout(
    xaxis_title='Date',
    yaxis_title='Price',
    title='predict next 10 day '
)

fig.show()

# %%
future_data_all = data_new.copy()

future_data_all = pd.DataFrame(future_data_all, index= future_data_all.index, 
                               columns=future_data_all.columns)

x_future_data_all = future_data_all.drop(['Adj Close'], axis=1).values
y_future_data_all = future_data_all['Adj Close'].values
y_future_data_all = y_future_data_all.reshape(-1, 1)

print("x_future_data:", x_future_data_all.shape)
print("y_future_data:", y_future_data_all.shape)
# Out:
# x_future_data: (2998, 7)
# y_future_data: (2998, 1)

# %%
x_future_data_all = scaler.fit_transform(x_future_data_all)
y_future_data_all = scaler.fit_transform(y_future_data_all)

x_future_data_all = np.reshape(x_future_data_all, (x_future_data_all.shape[0], 1, x_future_data_all.shape[1]))

pred_future_all = model.predict(x_future_data_all)
# Out:
# 94/94 [==============================] - 1s 7ms/step

# %%
y_future_data_all = scaler.inverse_transform(y_future_data_all)
pred_future_all = scaler.inverse_transform(pred_future_all)
y_future_all = pd.DataFrame(y_future_data_all, index= future_data_all.index,  columns=['Adj Close'])
pred_future_all_df = pd.DataFrame(pred_future_all, index= future_data_all.index,  columns=['Adj Close'])
print("pred_future_all:", pred_future_all.shape)
print("y_future_data:", y_future_data_all.shape)
# Out:
# pred_future_all: (2998, 1)
# y_future_data: (2998, 1)

# %%
names = cycle(['Predictions', 'Test Data'])

fig = go.Figure()
fig.add_trace(go.Scatter(x=y_future_all.index, y=pred_future_all_df['Adj Close'], name='Predictions',
                         line=dict(width=2, color='blue')))
fig.add_trace(go.Scatter(x=y_future_all.index, y=y_future_all['Adj Close'], name='Actual Data',
                         line=dict(width=2, color='red')))
fig.add_trace(go.Scatter(x=prediction_df.index, y=prediction_df['Adj Close'], name='Predictions next 10 day',
                         line=dict(width=2, color='gray')))
fig.add_shape(type='line',
              x0=prediction_df.index[0], y0=prediction_df['Adj Close'][0],
              x1=pred_future_all_df.index[-1], y1=pred_future_all_df['Adj Close'][-1],
              line=dict(color='grey', width=2))

fig.update_layout(xaxis_title='Date', yaxis_title='Price',
                  font_size=15, font_color='black', legend_title_text=' Parameters')
fig.show()
