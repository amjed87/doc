# %%
import pandas as pd
import numpy as np
import pandas_ta as ta
import yfinance as yf
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error 
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout

# %%
# Step 1: Data cleaning
data = yf.download(tickers='ETH-usd', period='max', interval='1d')
data.dropna(inplace=True)
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2017-11-09   308.644989   329.451996   307.056000   320.884003   320.884003
# 2017-11-10   320.670990   324.717987   294.541992   299.252991   299.252991
# 2017-11-11   298.585999   319.453003   298.191986   314.681000   314.681000
# 2017-11-12   314.690002   319.153015   298.513000   307.907990   307.907990
# 2017-11-13   307.024994   328.415009   307.024994   316.716003   316.716003
# ...                 ...          ...          ...          ...          ...
# 2023-01-19  1515.249634  1557.970337  1514.380005  1552.556519  1552.556519
# 2023-01-20  1552.373657  1659.885742  1544.917847  1659.754150  1659.754150
# 2023-01-21  1659.706055  1674.179321  1626.812988  1627.118164  1627.118164
# 2023-01-22  1627.365967  1658.023438  1612.085693  1628.382080  1628.382080
# 2023-01-23  1627.538208  1640.932129  1612.744141  1622.512207  1622.512207
#
#                 Volume
# Date
# 2017-11-09   893249984
# 2017-11-10   885985984
# 2017-11-11   842300992
# 2017-11-12  1613479936
# 2017-11-13  1041889984
# ...                ...
# 2023-01-19  6432638856
# 2023-01-20  8528894754
# 2023-01-21  8859250310
# 2023-01-22  7517988734
# 2023-01-23  7946470912
#
# [1902 rows x 6 columns]

# %%
data.drop([ 'Close'], axis=1, inplace=True)
data
# Out:
#                    Open         High          Low    Adj Close      Volume
# Date
# 2017-11-09   308.644989   329.451996   307.056000   320.884003   893249984
# 2017-11-10   320.670990   324.717987   294.541992   299.252991   885985984
# 2017-11-11   298.585999   319.453003   298.191986   314.681000   842300992
# 2017-11-12   314.690002   319.153015   298.513000   307.907990  1613479936
# 2017-11-13   307.024994   328.415009   307.024994   316.716003  1041889984
# ...                 ...          ...          ...          ...         ...
# 2023-01-19  1515.249634  1557.970337  1514.380005  1552.556519  6432638856
# 2023-01-20  1552.373657  1659.885742  1544.917847  1659.754150  8528894754
# 2023-01-21  1659.706055  1674.179321  1626.812988  1627.118164  8859250310
# 2023-01-22  1627.365967  1658.023438  1612.085693  1628.382080  7517988734
# 2023-01-23  1627.538208  1640.932129  1612.744141  1622.512207  7946470912
#
# [1902 rows x 5 columns]

# %%
# Step 3: Data normalization (cont.)
scaler = MinMaxScaler()
data_close = data[['Adj Close']]
data_close = scaler.fit_transform(data_close)
data_close
# Out:
# array([[0.0500395 ],
#        [0.0454642 ],
#        [0.04872747],
#        ...,
#        [0.32632867],
#        [0.32659601],
#        [0.32535444]])

# %%
# Step 4: Splitting the data
X = data[['Open', 'High', 'Low', 'Volume']]
X = scaler.fit_transform(X)
y = data_close
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %%
# Step 5: Reshaping the data
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))
print("x", X.shape)
print('y',y.shape)
print('X_train', X_train.shape)
print('y_train', y_train.shape)
print('X_test', X_test.shape)
print('Y_test', y_test.shape) 
print('X_train.shape[1]', X_train.shape[1])
print('X_train.shape[2]', X_train.shape[2])
# Out:
# x (1902, 4)
# y (1902, 1)
# X_train (1521, 1, 4)
# y_train (1521, 1)
# X_test (381, 1, 4)
# Y_test (381, 1)
# X_train.shape[1] 1
# X_train.shape[2] 4

# %%
# Step 6: Building the LSTM model (cont.)

model = Sequential()
model.add(LSTM(100, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True , activation= 'softmax'))
model.add(Dropout(0.2))
model.add(LSTM(100, activation= 'softmax'))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 1, 100)            42000
#
#  dropout (Dropout)           (None, 1, 100)            0
#
#  lstm_1 (LSTM)               (None, 100)               80400
#
#  dropout_1 (Dropout)         (None, 100)               0
#
#  dense (Dense)               (None, 1)                 101
#
# =================================================================
# Total params: 122,501
# Trainable params: 122,501
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Step 7: Training and evaluating the model
history = model.fit(X_train, y_train, epochs=250, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/250
# 48/48 [==============================] - 6s 23ms/step - loss: 0.0871 - val_loss: 0.1320
# Epoch 2/250
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0723 - val_loss: 0.1014
# Epoch 3/250
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0659 - val_loss: 0.0837
# Epoch 4/250
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0640 - val_loss: 0.0750
# Epoch 5/250
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0633 - val_loss: 0.0712
# Epoch 6/250
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0633 - val_loss: 0.0684
# Epoch 7/250
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0633 - val_loss: 0.0682
# Epoch 8/250
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0632 - val_loss: 0.0675
# Epoch 9/250
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0631 - val_loss: 0.0679
# Epoch 10/250
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0631 - val_loss: 0.0686
# Epoch 11/250
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0631 - val_loss: 0.0678
# Epoch 12/250
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0630 - val_loss: 0.0677
# Epoch 13/250
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0630 - val_loss: 0.0674
# Epoch 14/250
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0630 - val_loss: 0.0659
# Epoch 15/250
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0628 - val_loss: 0.0672
# Epoch 16/250
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0629 - val_loss: 0.0674
# Epoch 17/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0628 - val_loss: 0.0672
# Epoch 18/250
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0626 - val_loss: 0.0650
# Epoch 19/250
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0625 - val_loss: 0.0653
# Epoch 20/250
# 48/48 [==============================] - 0s 9ms/step - loss: 0.0623 - val_loss: 0.0666
# Epoch 21/250
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0622 - val_loss: 0.0658
# Epoch 22/250
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0620 - val_loss: 0.0669
# Epoch 23/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0619 - val_loss: 0.0643
# Epoch 24/250
# 48/48 [==============================] - 0s 9ms/step - loss: 0.0616 - val_loss: 0.0650
# Epoch 25/250
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0615 - val_loss: 0.0646
# Epoch 26/250
# 48/48 [==============================] - 0s 9ms/step - loss: 0.0609 - val_loss: 0.0647
# Epoch 27/250
# 48/48 [==============================] - 0s 9ms/step - loss: 0.0607 - val_loss: 0.0640
# Epoch 28/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0604 - val_loss: 0.0622
# Epoch 29/250
# 48/48 [==============================] - 1s 14ms/step - loss: 0.0600 - val_loss: 0.0629
# Epoch 30/250
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0595 - val_loss: 0.0606
# Epoch 31/250
# 48/48 [==============================] - 0s 9ms/step - loss: 0.0588 - val_loss: 0.0610
# Epoch 32/250
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0582 - val_loss: 0.0609
# Epoch 33/250
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0576 - val_loss: 0.0593
# Epoch 34/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0566 - val_loss: 0.0572
# Epoch 35/250
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0557 - val_loss: 0.0570
# Epoch 36/250
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0546 - val_loss: 0.0548
# Epoch 37/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0534 - val_loss: 0.0521
# Epoch 38/250
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0522 - val_loss: 0.0513
# Epoch 39/250
# 48/48 [==============================] - 0s 9ms/step - loss: 0.0507 - val_loss: 0.0498
# Epoch 40/250
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0492 - val_loss: 0.0473
# Epoch 41/250
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0475 - val_loss: 0.0458
# Epoch 42/250
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0454 - val_loss: 0.0428
# Epoch 43/250
# 48/48 [==============================] - 0s 9ms/step - loss: 0.0436 - val_loss: 0.0396
# Epoch 44/250
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0418 - val_loss: 0.0376
# Epoch 45/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0397 - val_loss: 0.0349
# Epoch 46/250
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0372 - val_loss: 0.0327
# Epoch 47/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0354 - val_loss: 0.0302
# Epoch 48/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0326 - val_loss: 0.0275
# Epoch 49/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0306 - val_loss: 0.0242
# Epoch 50/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0284 - val_loss: 0.0218
# Epoch 51/250
# 48/48 [==============================] - 1s 14ms/step - loss: 0.0265 - val_loss: 0.0192
# Epoch 52/250
# 48/48 [==============================] - 1s 13ms/step - loss: 0.0246 - val_loss: 0.0167
# Epoch 53/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0225 - val_loss: 0.0147
# Epoch 54/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0207 - val_loss: 0.0124
# Epoch 55/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0189 - val_loss: 0.0106
# Epoch 56/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0170 - val_loss: 0.0093
# Epoch 57/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0155 - val_loss: 0.0078
# Epoch 58/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0141 - val_loss: 0.0066
# Epoch 59/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0130 - val_loss: 0.0054
# Epoch 60/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0120 - val_loss: 0.0045
# Epoch 61/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0108 - val_loss: 0.0038
# Epoch 62/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0100 - val_loss: 0.0030
# Epoch 63/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0095 - val_loss: 0.0027
# Epoch 64/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0084 - val_loss: 0.0023
# Epoch 65/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0078 - val_loss: 0.0019
# Epoch 66/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0073 - val_loss: 0.0019
# Epoch 67/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0068 - val_loss: 0.0017
# Epoch 68/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0062 - val_loss: 0.0017
# Epoch 69/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0061 - val_loss: 0.0017
# Epoch 70/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0057 - val_loss: 0.0017
# Epoch 71/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0053 - val_loss: 0.0017
# Epoch 72/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0053 - val_loss: 0.0020
# Epoch 73/250
# 48/48 [==============================] - 1s 13ms/step - loss: 0.0052 - val_loss: 0.0020
# Epoch 74/250
# 48/48 [==============================] - 1s 13ms/step - loss: 0.0047 - val_loss: 0.0022
# Epoch 75/250
# 48/48 [==============================] - 1s 16ms/step - loss: 0.0046 - val_loss: 0.0023
# Epoch 76/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0045 - val_loss: 0.0024
# Epoch 77/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0047 - val_loss: 0.0027
# Epoch 78/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0042 - val_loss: 0.0030
# Epoch 79/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0041 - val_loss: 0.0030
# Epoch 80/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0041 - val_loss: 0.0032
# Epoch 81/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0039 - val_loss: 0.0033
# Epoch 82/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0039 - val_loss: 0.0034
# Epoch 83/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 84/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0036 - val_loss: 0.0038
# Epoch 85/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0036 - val_loss: 0.0040
# Epoch 86/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0035 - val_loss: 0.0039
# Epoch 87/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0036 - val_loss: 0.0042
# Epoch 88/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0035 - val_loss: 0.0042
# Epoch 89/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0036 - val_loss: 0.0042
# Epoch 90/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0034 - val_loss: 0.0044
# Epoch 91/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0035 - val_loss: 0.0044
# Epoch 92/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0034 - val_loss: 0.0044
# Epoch 93/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0032 - val_loss: 0.0046
# Epoch 94/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0032 - val_loss: 0.0046
# Epoch 95/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0034 - val_loss: 0.0044
# Epoch 96/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0032 - val_loss: 0.0045
# Epoch 97/250
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0034 - val_loss: 0.0045
# Epoch 98/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0031 - val_loss: 0.0048
# Epoch 99/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0032 - val_loss: 0.0046
# Epoch 100/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0034 - val_loss: 0.0046
# Epoch 101/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0032 - val_loss: 0.0046
# Epoch 102/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0032 - val_loss: 0.0046
# Epoch 103/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0034 - val_loss: 0.0045
# Epoch 104/250
# 48/48 [==============================] - 1s 14ms/step - loss: 0.0031 - val_loss: 0.0046
# Epoch 105/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0031 - val_loss: 0.0045
# Epoch 106/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0030 - val_loss: 0.0046
# Epoch 107/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0030 - val_loss: 0.0043
# Epoch 108/250
# 48/48 [==============================] - 1s 10ms/step - loss: 0.0030 - val_loss: 0.0045
# Epoch 109/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0031 - val_loss: 0.0044
# Epoch 110/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0029 - val_loss: 0.0043
# Epoch 111/250
# 48/48 [==============================] - 1s 13ms/step - loss: 0.0030 - val_loss: 0.0043
# Epoch 112/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0032 - val_loss: 0.0042
# Epoch 113/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0028 - val_loss: 0.0042
# Epoch 114/250
# 48/48 [==============================] - 1s 13ms/step - loss: 0.0030 - val_loss: 0.0040
# Epoch 115/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0030 - val_loss: 0.0041
# Epoch 116/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0030 - val_loss: 0.0038
# Epoch 117/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0026 - val_loss: 0.0038
# Epoch 118/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0028 - val_loss: 0.0037
# Epoch 119/250
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0026 - val_loss: 0.0034
# Epoch 120/250
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0029 - val_loss: 0.0036
# Epoch 121/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0029 - val_loss: 0.0035
# Epoch 122/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0027 - val_loss: 0.0033
# Epoch 123/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0026 - val_loss: 0.0033
# Epoch 124/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0028 - val_loss: 0.0033
# Epoch 125/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0027 - val_loss: 0.0032
# Epoch 126/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0027 - val_loss: 0.0030
# Epoch 127/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0027 - val_loss: 0.0030
# Epoch 128/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0024 - val_loss: 0.0027
# Epoch 129/250
# 48/48 [==============================] - 1s 10ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 130/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 131/250
# 48/48 [==============================] - 1s 14ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 132/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 133/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 134/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 135/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 136/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0023 - val_loss: 0.0019
# Epoch 137/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0024 - val_loss: 0.0019
# Epoch 138/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0024 - val_loss: 0.0018
# Epoch 139/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0022 - val_loss: 0.0017
# Epoch 140/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0022 - val_loss: 0.0017
# Epoch 141/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 142/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0022 - val_loss: 0.0016
# Epoch 143/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0021 - val_loss: 0.0015
# Epoch 144/250
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 145/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0021 - val_loss: 0.0013
# Epoch 146/250
# 48/48 [==============================] - 1s 13ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 147/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0021 - val_loss: 0.0012
# Epoch 148/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 149/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 150/250
# 48/48 [==============================] - 1s 13ms/step - loss: 0.0020 - val_loss: 0.0010
# Epoch 151/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0019 - val_loss: 9.6583e-04
# Epoch 152/250
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0020 - val_loss: 9.3231e-04
# Epoch 153/250
# 48/48 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 8.7210e-04
# Epoch 154/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0020 - val_loss: 8.2671e-04
# Epoch 155/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0019 - val_loss: 8.5662e-04
# Epoch 156/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0019 - val_loss: 8.3068e-04
# Epoch 157/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0017 - val_loss: 7.3479e-04
# Epoch 158/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0017 - val_loss: 6.9117e-04
# Epoch 159/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0016 - val_loss: 7.2424e-04
# Epoch 160/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0019 - val_loss: 7.0603e-04
# Epoch 161/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0017 - val_loss: 6.7608e-04
# Epoch 162/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0017 - val_loss: 6.9254e-04
# Epoch 163/250
# 48/48 [==============================] - 1s 13ms/step - loss: 0.0018 - val_loss: 6.6549e-04
# Epoch 164/250
# 48/48 [==============================] - 1s 14ms/step - loss: 0.0017 - val_loss: 5.8265e-04
# Epoch 165/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0016 - val_loss: 6.0338e-04
# Epoch 166/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0017 - val_loss: 5.0438e-04
# Epoch 167/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0018 - val_loss: 5.2307e-04
# Epoch 168/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0016 - val_loss: 5.0235e-04
# Epoch 169/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0018 - val_loss: 4.8822e-04
# Epoch 170/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0017 - val_loss: 4.2766e-04
# Epoch 171/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0016 - val_loss: 4.8621e-04
# Epoch 172/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0015 - val_loss: 5.4297e-04
# Epoch 173/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0016 - val_loss: 4.8191e-04
# Epoch 174/250
# 48/48 [==============================] - 1s 13ms/step - loss: 0.0017 - val_loss: 3.9958e-04
# Epoch 175/250
# 48/48 [==============================] - 1s 13ms/step - loss: 0.0015 - val_loss: 5.3320e-04
# Epoch 176/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0014 - val_loss: 4.5054e-04
# Epoch 177/250
# 48/48 [==============================] - 1s 13ms/step - loss: 0.0016 - val_loss: 5.0668e-04
# Epoch 178/250
# 48/48 [==============================] - 1s 13ms/step - loss: 0.0015 - val_loss: 5.3761e-04
# Epoch 179/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0015 - val_loss: 4.8139e-04
# Epoch 180/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0015 - val_loss: 4.0435e-04
# Epoch 181/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0015 - val_loss: 4.3491e-04
# Epoch 182/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0015 - val_loss: 3.9839e-04
# Epoch 183/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0014 - val_loss: 4.3229e-04
# Epoch 184/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0014 - val_loss: 3.2399e-04
# Epoch 185/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0015 - val_loss: 3.7476e-04
# Epoch 186/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0014 - val_loss: 4.0654e-04
# Epoch 187/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0015 - val_loss: 6.7458e-04
# Epoch 188/250
# 48/48 [==============================] - 1s 13ms/step - loss: 0.0014 - val_loss: 4.3617e-04
# Epoch 189/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0014 - val_loss: 3.6126e-04
# Epoch 190/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0016 - val_loss: 3.8156e-04
# Epoch 191/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0015 - val_loss: 3.3848e-04
# Epoch 192/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0015 - val_loss: 3.4038e-04
# Epoch 193/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0013 - val_loss: 4.3340e-04
# Epoch 194/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0015 - val_loss: 4.4522e-04
# Epoch 195/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0015 - val_loss: 3.4776e-04
# Epoch 196/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0016 - val_loss: 2.9023e-04
# Epoch 197/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0014 - val_loss: 3.2697e-04
# Epoch 198/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0014 - val_loss: 4.0686e-04
# Epoch 199/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0014 - val_loss: 3.8285e-04
# Epoch 200/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0014 - val_loss: 3.1881e-04
# Epoch 201/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0014 - val_loss: 3.4221e-04
# Epoch 202/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0013 - val_loss: 3.9420e-04
# Epoch 203/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0014 - val_loss: 4.4808e-04
# Epoch 204/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0014 - val_loss: 4.2137e-04
# Epoch 205/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0014 - val_loss: 3.5155e-04
# Epoch 206/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0014 - val_loss: 3.8586e-04
# Epoch 207/250
# 48/48 [==============================] - 1s 14ms/step - loss: 0.0013 - val_loss: 3.1556e-04
# Epoch 208/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0013 - val_loss: 4.5705e-04
# Epoch 209/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0013 - val_loss: 2.7317e-04
# Epoch 210/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0014 - val_loss: 3.2999e-04
# Epoch 211/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0014 - val_loss: 3.2363e-04
# Epoch 212/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0013 - val_loss: 3.2150e-04
# Epoch 213/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0013 - val_loss: 3.5990e-04
# Epoch 214/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0014 - val_loss: 3.4179e-04
# Epoch 215/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0014 - val_loss: 4.7174e-04
# Epoch 216/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0013 - val_loss: 2.9894e-04
# Epoch 217/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0012 - val_loss: 2.9379e-04
# Epoch 218/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0013 - val_loss: 3.1447e-04
# Epoch 219/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0012 - val_loss: 2.6837e-04
# Epoch 220/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0013 - val_loss: 3.6849e-04
# Epoch 221/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0012 - val_loss: 4.1422e-04
# Epoch 222/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0014 - val_loss: 3.4837e-04
# Epoch 223/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0013 - val_loss: 3.3194e-04
# Epoch 224/250
# 48/48 [==============================] - 1s 13ms/step - loss: 0.0014 - val_loss: 3.4235e-04
# Epoch 225/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0014 - val_loss: 2.9096e-04
# Epoch 226/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0013 - val_loss: 2.9379e-04
# Epoch 227/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0013 - val_loss: 2.6142e-04
# Epoch 228/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0012 - val_loss: 2.9072e-04
# Epoch 229/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0012 - val_loss: 2.7126e-04
# Epoch 230/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0014 - val_loss: 3.0276e-04
# Epoch 231/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0013 - val_loss: 3.2914e-04
# Epoch 232/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0012 - val_loss: 4.0286e-04
# Epoch 233/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0013 - val_loss: 3.3051e-04
# Epoch 234/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0012 - val_loss: 5.2611e-04
# Epoch 235/250
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0012 - val_loss: 3.7066e-04
# Epoch 236/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0013 - val_loss: 2.7720e-04
# Epoch 237/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0012 - val_loss: 3.0136e-04
# Epoch 238/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0012 - val_loss: 3.5261e-04
# Epoch 239/250
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0014 - val_loss: 4.1383e-04
# Epoch 240/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0012 - val_loss: 3.3620e-04
# Epoch 241/250
# 48/48 [==============================] - 1s 14ms/step - loss: 0.0012 - val_loss: 3.7087e-04
# Epoch 242/250
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.6924e-04
# Epoch 243/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0012 - val_loss: 3.9374e-04
# Epoch 244/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0012 - val_loss: 2.7651e-04
# Epoch 245/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0011 - val_loss: 2.4829e-04
# Epoch 246/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0013 - val_loss: 3.1119e-04
# Epoch 247/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0012 - val_loss: 4.5090e-04
# Epoch 248/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0013 - val_loss: 3.2087e-04
# Epoch 249/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0012 - val_loss: 5.2166e-04
# Epoch 250/250
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0012 - val_loss: 3.2712e-04

# %%
# Evaluate the model on the test set
score = model.evaluate(X_test, y_test, verbose=0)
print(f'Test loss: {score:.4f}')
# Out:
# Test loss: 0.0003

# %%
# Step 8: Tuning the Hyperparameters
# You can use techniques such as grid search or random search to find the best values for the model's hyperparameters

# Step 9: Testing the model
y_pred = model.predict(X_test)
print('y_pred',y_pred.shape)
print('y_test',y_test.shape)
#y_pred = y_pred.reshape(-1,1)
#y_pred = np.nan_to_num(y_pred)
#y_pred = scaler.inverse_transform(y_pred)
#y_pred = scaler.inverse_transform(y_pred[:,[-1]])
#y_test = scaler.inverse_transform(y_test.reshape(-1, 1))
#y_test = np.nan_to_num(y_test)


#evaluat
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mape = 100 * np.mean(np.abs((y_test - y_pred) / y_test))
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

print("MAPE: {:.4f}%".format(mape))
print("RMSE: {:.4f}".format(rmse))
print("MSE: {:.4f}".format(mse))
print("MAE:{:.4f}".format(mae))
# Out:
# 12/12 [==============================] - 0s 4ms/step
# y_pred (381, 1)
# y_test (381, 1)
# MAPE: 3.4296%
# RMSE: 0.0181
# MSE: 0.0003
# MAE:0.0135

# %%
def smape(y_true, y_pred):
    return 200 * np.mean(np.abs(y_pred - y_true) / (np.abs(y_pred) + np.abs(y_true)))

SMAPE1 = smape(y_test, y_pred)
print("smape: {:.4f}%".format(SMAPE1))
# Out:
# smape: 3.3590%

# %%
import matplotlib.pyplot as plt

# Assume that you have stored the date information in a variable called 'date'
# Assume that you have stored the predictions in a variable called 'y_pred'
# Assume that you have stored the test data in a variable called 'y_test'

# Plot the test data and predictions on a line chart
plt.plot(data['Date'], y_pred, label='Predictions')
plt.plot(data['Date'], y_test, label='Test Data')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 8
#       1 import matplotlib.pyplot as plt
#       3 # Assume that you have stored the date information in a variable called 'date'
#       4 # Assume that you have stored the predictions in a variable called 'y_pred'
#       5 # Assume that you have stored the test data in a variable called 'y_test'
#       6
#       7 # Plot the test data and predictions on a line chart
# ----> 8 plt.plot(data['Date'], y_pred, label='Predictions')
#       9 plt.plot(data['Date'], y_test, label='Test Data')
#      10 plt.xlabel('Date')
#
# NameError: name 'data' is not defined

# %%
y_pred = scaler.inverse_transform(y_pred)
#y_pred = scaler.inverse_transform(y_pred[:,[-1]])
#y_test = scaler.inverse_transform(y_test.reshape(-1, 1))
print ('y_pred',y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 y_pred = scaler.inverse_transform(y_pred)
#       2 #y_pred = scaler.inverse_transform(y_pred[:,[-1]])
#       3 #y_test = scaler.inverse_transform(y_test.reshape(-1, 1))
#       4 print ('y_pred',y_pred)
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\preprocessing\_data.py:541, in MinMaxScaler.inverse_transform(self, X)
#     535 check_is_fitted(self)
#     537 X = check_array(
#     538     X, copy=self.copy, dtype=FLOAT_DTYPES, force_all_finite="allow-nan"
#     539 )
# --> 541 X -= self.min_
#     542 X /= self.scale_
#     543 return X
#
# ValueError: non-broadcastable output operand with shape (381,1) doesn't match the broadcast shape (381,4)

# %%
plt.figure(figsize=(8,8))
plt.plot(y_test, color = 'blue', label = 'Test')
plt.plot(y_pred, color = 'red', label = 'pred')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 plt.figure(figsize=(8,8))
# ----> 2 plt.plot(y_test, color = 'blue', label = 'Test')
#       3 plt.plot(y_pred, color = 'red', label = 'pred')
#       4 plt.legend()
#
# NameError: name 'y_test' is not defined
