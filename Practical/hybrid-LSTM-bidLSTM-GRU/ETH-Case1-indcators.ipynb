# %%
import pandas as pd
import numpy as np
import pandas_ta as ta
import yfinance as yf
from datetime import timedelta
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error 
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, GRU ,Bidirectional
from keras.layers import Reshape
# For PLotting we will use these library

import matplotlib.pyplot as plt

from itertools import cycle
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

# %%
# Step 1: Data cleaning
data = yf.download(tickers='ETH-usd', start='2017-11-09', end='2022-12-31', interval='1d')
data.dropna(inplace=True)
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2017-11-09   308.644989   329.451996   307.056000   320.884003   320.884003
# 2017-11-10   320.670990   324.717987   294.541992   299.252991   299.252991
# 2017-11-11   298.585999   319.453003   298.191986   314.681000   314.681000
# 2017-11-12   314.690002   319.153015   298.513000   307.907990   307.907990
# 2017-11-13   307.024994   328.415009   307.024994   316.716003   316.716003
# ...                 ...          ...          ...          ...          ...
# 2022-12-26  1218.920166  1226.974365  1214.335938  1226.974365  1226.974365
# 2022-12-27  1226.987061  1230.418091  1205.895630  1212.791626  1212.791626
# 2022-12-28  1212.736572  1213.128906  1185.702148  1189.986084  1189.986084
# 2022-12-29  1190.010132  1204.141602  1188.360229  1201.595337  1201.595337
# 2022-12-30  1201.569580  1202.034668  1187.462524  1199.232788  1199.232788
#
#                 Volume
# Date
# 2017-11-09   893249984
# 2017-11-10   885985984
# 2017-11-11   842300992
# 2017-11-12  1613479936
# 2017-11-13  1041889984
# ...                ...
# 2022-12-26  3282098400
# 2022-12-27  4091530737
# 2022-12-28  4991669631
# 2022-12-29  4132233940
# 2022-12-30  4055668253
#
# [1878 rows x 6 columns]

# %%
# Step 2: Feature engineering
data['RSI']       = ta.rsi(data.Close, length=15)
data['EMA_short'] = ta.ema(data.Close, length=20)
data['EMA_long']  = ta.ema(data.Close, length=100)
data.dropna(inplace=True)
data.reset_index(inplace=True)
data.drop(['Close'], axis=1, inplace=True)
# Setting the index
data.set_index('Date', inplace=True)

# Dropping any NaNs
data.dropna(inplace=True)

data.info()
data.tail(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1779 entries, 2018-02-16 to 2022-12-30
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1779 non-null   float64
#  1   High       1779 non-null   float64
#  2   Low        1779 non-null   float64
#  3   Adj Close  1779 non-null   float64
#  4   Volume     1779 non-null   int64
#  5   RSI        1779 non-null   float64
#  6   EMA_short  1779 non-null   float64
#  7   EMA_long   1779 non-null   float64
# dtypes: float64(7), int64(1)
# memory usage: 125.1 KB
#                    Open         High          Low    Adj Close      Volume  \
# Date
# 2022-12-21  1217.586426  1218.192261  1206.440063  1213.599976  4217182733
# 2022-12-22  1213.672607  1221.986816  1187.127808  1218.182129  5297471739
# 2022-12-23  1218.079346  1226.998779  1215.994873  1220.159424  4835831923
# 2022-12-24  1220.117920  1224.911621  1216.338745  1221.148560  2626153345
# 2022-12-25  1221.171509  1223.517822  1203.719604  1218.962036  3942720070
# 2022-12-26  1218.920166  1226.974365  1214.335938  1226.974365  3282098400
# 2022-12-27  1226.987061  1230.418091  1205.895630  1212.791626  4091530737
# 2022-12-28  1212.736572  1213.128906  1185.702148  1189.986084  4991669631
# 2022-12-29  1190.010132  1204.141602  1188.360229  1201.595337  4132233940
# 2022-12-30  1201.569580  1202.034668  1187.462524  1199.232788  4055668253
#
#                   RSI    EMA_short     EMA_long
# Date
# 2022-12-21  46.360226  1234.022934  1347.684823
# 2022-12-22  46.932819  1232.514286  1345.120413
# 2022-12-23  47.193442  1231.337632  1342.645938
# 2022-12-24  47.332079  1230.367245  1340.240050
# 2022-12-25  47.039585  1229.281034  1337.838505
# 2022-12-26  48.294081  1229.061351  1335.643175
# 2022-12-27  46.217774  1227.511854  1333.210471
# 2022-12-28  43.030513  1223.937971  1330.374345
# 2022-12-29  45.095621  1221.810101  1327.824266
# 2022-12-30  44.741986  1219.659881  1325.277900

# %%
data= data.to_csv('ETH_case1.csv')

# %%
from datetime import datetime

def date_parser(date_str):
    date_obj = datetime.strptime(date_str, '%m/%d/%Y')
    return date_obj.strftime('%m-%d-%Y')

# %%
data_csv = pd.read_csv('ETH_case1.csv')
data_csv.dropna(inplace=True)
# Setting the index

data_csv.set_index('Date', inplace=True)
# Dropping any NaNs
data_csv.dropna(inplace=True)
data_csv.info()
data_csv.tail(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1779 entries, 2018-02-16 to 2022-12-30
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1779 non-null   float64
#  1   High       1779 non-null   float64
#  2   Low        1779 non-null   float64
#  3   Adj Close  1779 non-null   float64
#  4   Volume     1779 non-null   int64
#  5   RSI        1779 non-null   float64
#  6   EMA_short  1779 non-null   float64
#  7   EMA_long   1779 non-null   float64
# dtypes: float64(7), int64(1)
# memory usage: 125.1+ KB
#                    Open         High          Low    Adj Close      Volume  \
# Date
# 2022-12-21  1217.586426  1218.192261  1206.440063  1213.599976  4217182733
# 2022-12-22  1213.672607  1221.986816  1187.127808  1218.182129  5297471739
# 2022-12-23  1218.079346  1226.998779  1215.994873  1220.159424  4835831923
# 2022-12-24  1220.117920  1224.911621  1216.338745  1221.148560  2626153345
# 2022-12-25  1221.171509  1223.517822  1203.719604  1218.962036  3942720070
# 2022-12-26  1218.920166  1226.974365  1214.335938  1226.974365  3282098400
# 2022-12-27  1226.987061  1230.418091  1205.895630  1212.791626  4091530737
# 2022-12-28  1212.736572  1213.128906  1185.702148  1189.986084  4991669631
# 2022-12-29  1190.010132  1204.141602  1188.360229  1201.595337  4132233940
# 2022-12-30  1201.569580  1202.034668  1187.462524  1199.232788  4055668253
#
#                   RSI    EMA_short     EMA_long
# Date
# 2022-12-21  46.360226  1234.022934  1347.684823
# 2022-12-22  46.932819  1232.514286  1345.120413
# 2022-12-23  47.193442  1231.337632  1342.645938
# 2022-12-24  47.332079  1230.367245  1340.240050
# 2022-12-25  47.039585  1229.281034  1337.838505
# 2022-12-26  48.294081  1229.061351  1335.643175
# 2022-12-27  46.217774  1227.511854  1333.210471
# 2022-12-28  43.030513  1223.937971  1330.374345
# 2022-12-29  45.095621  1221.810101  1327.824266
# 2022-12-30  44.741986  1219.659881  1325.277900

# %%
# Split the data into training and test sets
train_df = data_csv[:int(len(data_csv)*0.8)]
test_df = data_csv[int(len(data_csv)*0.8):]
data_csv.shape
# Out:
# (1779, 8)

# %%
test_data =test_df.copy()

# %%
train_x = train_df.index
train_y = train_df['Adj Close']
test_x = test_df.index
test_y = test_df['Adj Close']

fig = go.Figure()
fig.add_trace(go.Scatter(x=train_x, y=train_y, name='train Data'))
fig.add_trace(go.Scatter(x=test_x, y=test_y, name='Test Data'))

fig.update_layout(
    xaxis_title='Date',
    yaxis_title='Price',
    title='Price over time'
)

fig.show()

# %%
print(train_df.info())
print(test_df.info())
print('test_data', test_data.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1423 entries, 2018-02-16 to 2022-01-08
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1423 non-null   float64
#  1   High       1423 non-null   float64
#  2   Low        1423 non-null   float64
#  3   Adj Close  1423 non-null   float64
#  4   Volume     1423 non-null   int64
#  5   RSI        1423 non-null   float64
#  6   EMA_short  1423 non-null   float64
#  7   EMA_long   1423 non-null   float64
# dtypes: float64(7), int64(1)
# memory usage: 100.1+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 356 entries, 2022-01-09 to 2022-12-30
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       356 non-null    float64
#  1   High       356 non-null    float64
#  2   Low        356 non-null    float64
#  3   Adj Close  356 non-null    float64
#  4   Volume     356 non-null    int64
#  5   RSI        356 non-null    float64
#  6   EMA_short  356 non-null    float64
#  7   EMA_long   356 non-null    float64
# dtypes: float64(7), int64(1)
# memory usage: 25.0+ KB
# None
# test_data (356, 8)

# %%
# Preprocess the data
X_train = train_df.drop(['Adj Close'], axis=1).values
y_train = train_df['Adj Close'].values

X_test = test_df.drop(['Adj Close'], axis=1).values
y_test = test_df['Adj Close'].values

print("x_train", X_train.shape)
print("y_train", y_train.shape)
print("X_test", X_test.shape)
print("y_test", y_test.shape)
# Out:
# x_train (1423, 7)
# y_train (1423,)
# X_test (356, 7)
# y_test (356,)

# %%
scaler  = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test  = scaler.fit_transform(X_test)
y_train = y_train.reshape(-1,1)
y_train = scaler.fit_transform(y_train)
y_test  = y_test.reshape(-1,1)
y_test  = scaler.fit_transform(y_test)
#------------------------------------------
print("x_train", X_train.shape)
print("y_train", y_train.shape)
print("X_test", X_test.shape)
print("y_test", y_test.shape)
# Out:
# x_train (1423, 7)
# y_train (1423, 1)
# X_test (356, 7)
# y_test (356, 1)

# %%
# Step 5: Reshaping the data
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

print('X_train', X_train.shape)
print('y_train', y_train.shape)
print('X_test', X_test.shape)
print('Y_test', y_test.shape)
print('X_train.shape[1]', X_train.shape[1])
print('X_train.shape[2]', X_train.shape[2])
# Out:
# X_train (1423, 1, 7)
# y_train (1423, 1)
# X_test (356, 1, 7)
# Y_test (356, 1)
# X_train.shape[1] 1
# X_train.shape[2] 7

# %%
# Step 6: Building the hybrid model (cont.)

model = Sequential()
model.add(LSTM(100, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True , activation= 'tanh'))
model.add(Dropout(0.2))
model.add(LSTM(100, return_sequences=True,activation= 'tanh'))
model.add(Dropout(0.2))
model.add(Reshape((1, 100))) # Add a Reshape layer to convert output shape to (batch_size, timesteps, features)
model.add(Bidirectional(LSTM(75, return_sequences=True,activation= 'tanh')))
model.add(Dropout(0.25))
model.add(Bidirectional(LSTM(75,activation= 'tanh')))
model.add(Dropout(0.25))
model.add(Reshape((1, 150))) # Add a Reshape layer to convert output shape to (batch_size, timesteps, features)
model.add(GRU(50, activation=  "tanh"))
model.add(Dropout(0.3))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy', 'mean_absolute_error'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 1, 100)            43200
#
#  dropout (Dropout)           (None, 1, 100)            0
#
#  lstm_1 (LSTM)               (None, 1, 100)            80400
#
#  dropout_1 (Dropout)         (None, 1, 100)            0
#
#  reshape (Reshape)           (None, 1, 100)            0
#
#  bidirectional (Bidirectiona  (None, 1, 150)           105600
#  l)
#
#  dropout_2 (Dropout)         (None, 1, 150)            0
#
#  bidirectional_1 (Bidirectio  (None, 150)              135600
#  nal)
#
#  dropout_3 (Dropout)         (None, 150)               0
#
#  reshape_1 (Reshape)         (None, 1, 150)            0
#
#  gru (GRU)                   (None, 50)                30300
#
#  dropout_4 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 395,151
# Trainable params: 395,151
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Step 7: Training and evaluating the model
history = model.fit(X_train, y_train, epochs=1000, batch_size=32)
# Out:
# Epoch 1/1000
# 45/45 [==============================] - 40s 26ms/step - loss: 0.0500 - accuracy: 7.0274e-04 - mean_absolute_error: 0.1533
# Epoch 2/1000
# 45/45 [==============================] - 1s 27ms/step - loss: 0.0043 - accuracy: 0.0014 - mean_absolute_error: 0.0390
# Epoch 3/1000
# 45/45 [==============================] - 1s 26ms/step - loss: 0.0034 - accuracy: 0.0014 - mean_absolute_error: 0.0295
# Epoch 4/1000
# 45/45 [==============================] - 1s 28ms/step - loss: 0.0027 - accuracy: 0.0014 - mean_absolute_error: 0.0270
# Epoch 5/1000
# 45/45 [==============================] - 1s 28ms/step - loss: 0.0024 - accuracy: 0.0014 - mean_absolute_error: 0.0249
# Epoch 6/1000
# 45/45 [==============================] - 1s 28ms/step - loss: 0.0022 - accuracy: 0.0014 - mean_absolute_error: 0.0242
# Epoch 7/1000
# 45/45 [==============================] - 2s 34ms/step - loss: 0.0022 - accuracy: 0.0014 - mean_absolute_error: 0.0245
# Epoch 8/1000
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0024 - accuracy: 0.0014 - mean_absolute_error: 0.0253
# Epoch 9/1000
# 45/45 [==============================] - 1s 28ms/step - loss: 0.0024 - accuracy: 0.0014 - mean_absolute_error: 0.0264
# Epoch 10/1000
# 45/45 [==============================] - 1s 24ms/step - loss: 0.0021 - accuracy: 0.0014 - mean_absolute_error: 0.0252
# Epoch 11/1000
# 45/45 [==============================] - 1s 27ms/step - loss: 0.0019 - accuracy: 0.0014 - mean_absolute_error: 0.0233
# Epoch 12/1000
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0018 - accuracy: 0.0014 - mean_absolute_error: 0.0237
# Epoch 13/1000
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0018 - accuracy: 0.0014 - mean_absolute_error: 0.0240
# Epoch 14/1000
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0017 - accuracy: 0.0014 - mean_absolute_error: 0.0234
# Epoch 15/1000
# 45/45 [==============================] - 1s 26ms/step - loss: 0.0017 - accuracy: 0.0014 - mean_absolute_error: 0.0238
# Epoch 16/1000
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0016 - accuracy: 0.0014 - mean_absolute_error: 0.0238
# Epoch 17/1000
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0017 - accuracy: 0.0014 - mean_absolute_error: 0.0230
# Epoch 18/1000
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0016 - accuracy: 0.0014 - mean_absolute_error: 0.0237
# Epoch 19/1000
# 45/45 [==============================] - 1s 24ms/step - loss: 0.0016 - accuracy: 0.0014 - mean_absolute_error: 0.0231
# Epoch 20/1000
# 45/45 [==============================] - 1s 31ms/step - loss: 0.0016 - accuracy: 0.0014 - mean_absolute_error: 0.0237
# Epoch 21/1000
# 45/45 [==============================] - 1s 33ms/step - loss: 0.0016 - accuracy: 0.0014 - mean_absolute_error: 0.0240
# Epoch 22/1000
# 45/45 [==============================] - 2s 37ms/step - loss: 0.0014 - accuracy: 0.0014 - mean_absolute_error: 0.0218
# Epoch 23/1000
# 45/45 [==============================] - 1s 28ms/step - loss: 0.0016 - accuracy: 0.0014 - mean_absolute_error: 0.0232
# Epoch 24/1000
# 45/45 [==============================] - 1s 30ms/step - loss: 0.0015 - accuracy: 0.0014 - mean_absolute_error: 0.0228
# Epoch 25/1000
# 45/45 [==============================] - 1s 33ms/step - loss: 0.0015 - accuracy: 0.0014 - mean_absolute_error: 0.0228
# Epoch 26/1000
# 45/45 [==============================] - 1s 30ms/step - loss: 0.0017 - accuracy: 0.0014 - mean_absolute_error: 0.0230
# Epoch 27/1000
# 45/45 [==============================] - 1s 31ms/step - loss: 0.0015 - accuracy: 0.0014 - mean_absolute_error: 0.0228
# Epoch 28/1000
# 45/45 [==============================] - 1s 31ms/step - loss: 0.0015 - accuracy: 0.0014 - mean_absolute_error: 0.0219
# Epoch 29/1000
# 45/45 [==============================] - 1s 30ms/step - loss: 0.0016 - accuracy: 0.0014 - mean_absolute_error: 0.0226
# Epoch 30/1000
# 45/45 [==============================] - 1s 31ms/step - loss: 0.0016 - accuracy: 0.0014 - mean_absolute_error: 0.0224
# Epoch 31/1000
# 45/45 [==============================] - 2s 37ms/step - loss: 0.0015 - accuracy: 0.0014 - mean_absolute_error: 0.0230
# Epoch 32/1000
# 45/45 [==============================] - 1s 29ms/step - loss: 0.0018 - accuracy: 0.0014 - mean_absolute_error: 0.0240
# Epoch 33/1000
# 45/45 [==============================] - 1s 29ms/step - loss: 0.0015 - accuracy: 0.0014 - mean_absolute_error: 0.0225
# Epoch 34/1000
# 45/45 [==============================] - 1s 32ms/step - loss: 0.0013 - accuracy: 0.0014 - mean_absolute_error: 0.0211
# Epoch 35/1000
# 45/45 [==============================] - 1s 29ms/step - loss: 0.0016 - accuracy: 0.0014 - mean_absolute_error: 0.0246
# Epoch 36/1000
# 45/45 [==============================] - 1s 32ms/step - loss: 0.0014 - accuracy: 0.0014 - mean_absolute_error: 0.0227
# Epoch 37/1000
# 45/45 [==============================] - 2s 40ms/step - loss: 0.0013 - accuracy: 0.0014 - mean_absolute_error: 0.0214
# Epoch 38/1000
# 45/45 [==============================] - 1s 31ms/step - loss: 0.0014 - accuracy: 0.0014 - mean_absolute_error: 0.0219
# Epoch 39/1000
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0014 - accuracy: 0.0014 - mean_absolute_error: 0.0214
# Epoch 40/1000
# 45/45 [==============================] - 1s 28ms/step - loss: 0.0013 - accuracy: 0.0014 - mean_absolute_error: 0.0213
# Epoch 41/1000
# 45/45 [==============================] - 1s 30ms/step - loss: 0.0015 - accuracy: 0.0014 - mean_absolute_error: 0.0225
# Epoch 42/1000
# 45/45 [==============================] - 1s 28ms/step - loss: 0.0015 - accuracy: 0.0014 - mean_absolute_error: 0.0226
# Epoch 43/1000
# 45/45 [==============================] - 1s 30ms/step - loss: 0.0013 - accuracy: 0.0014 - mean_absolute_error: 0.0211
# Epoch 44/1000
# 45/45 [==============================] - 1s 31ms/step - loss: 0.0013 - accuracy: 0.0014 - mean_absolute_error: 0.0218
# Epoch 45/1000
# 45/45 [==============================] - 1s 32ms/step - loss: 0.0014 - accuracy: 0.0014 - mean_absolute_error: 0.0222
# Epoch 46/1000
# 45/45 [==============================] - 1s 29ms/step - loss: 0.0014 - accuracy: 0.0014 - mean_absolute_error: 0.0217
# Epoch 47/1000
# 45/45 [==============================] - 1s 32ms/step - loss: 0.0015 - accuracy: 0.0014 - mean_absolute_error: 0.0228
# Epoch 48/1000
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0015 - accuracy: 0.0014 - mean_absolute_error: 0.0227
# Epoch 49/1000
# 45/45 [==============================] - 1s 30ms/step - loss: 0.0013 - accuracy: 0.0014 - mean_absolute_error: 0.0221
# Epoch 50/1000
# 45/45 [==============================] - 1s 28ms/step - loss: 0.0015 - accuracy: 0.0014 - mean_absolute_error: 0.0239
# Epoch 51/1000
# 45/45 [==============================] - 1s 29ms/step - loss: 0.0015 - accuracy: 0.0014 - mean_absolute_error: 0.0228
# Epoch 52/1000
# 45/45 [==============================] - 1s 30ms/step - loss: 0.0015 - accuracy: 0.0014 - mean_absolute_error: 0.0235
# Epoch 53/1000
# 45/45 [==============================] - 1s 28ms/step - loss: 0.0013 - accuracy: 0.0014 - mean_absolute_error: 0.0221
# Epoch 54/1000
# 45/45 [==============================] - 1s 28ms/step - loss: 0.0013 - accuracy: 0.0014 - mean_absolute_error: 0.0219
# Epoch 55/1000
# 45/45 [==============================] - 1s 33ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0207
# Epoch 56/1000
# 45/45 [==============================] - 2s 37ms/step - loss: 0.0015 - accuracy: 0.0014 - mean_absolute_error: 0.0228
# Epoch 57/1000
# 45/45 [==============================] - 1s 29ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0208
# Epoch 58/1000
# 45/45 [==============================] - 1s 29ms/step - loss: 0.0013 - accuracy: 0.0014 - mean_absolute_error: 0.0212
# Epoch 59/1000
# 45/45 [==============================] - 1s 29ms/step - loss: 0.0012 - accuracy: 0.0014 - mean_absolute_error: 0.0212
# Epoch 60/1000
# 45/45 [==============================] - 1s 30ms/step - loss: 0.0012 - accuracy: 0.0014 - mean_absolute_error: 0.0205
# Epoch 61/1000
# 45/45 [==============================] - 2s 39ms/step - loss: 0.0012 - accuracy: 0.0014 - mean_absolute_error: 0.0214
# Epoch 62/1000
# 45/45 [==============================] - 1s 28ms/step - loss: 0.0013 - accuracy: 0.0014 - mean_absolute_error: 0.0208
# Epoch 63/1000
# 45/45 [==============================] - 1s 30ms/step - loss: 0.0013 - accuracy: 0.0014 - mean_absolute_error: 0.0230
# Epoch 64/1000
# 45/45 [==============================] - 2s 34ms/step - loss: 0.0010 - accuracy: 0.0014 - mean_absolute_error: 0.0196
# Epoch 65/1000
# 45/45 [==============================] - 1s 31ms/step - loss: 0.0012 - accuracy: 0.0014 - mean_absolute_error: 0.0207
# Epoch 66/1000
# 45/45 [==============================] - 2s 33ms/step - loss: 0.0013 - accuracy: 0.0014 - mean_absolute_error: 0.0227
# Epoch 67/1000
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0012 - accuracy: 0.0014 - mean_absolute_error: 0.0203
# Epoch 68/1000
# 45/45 [==============================] - 2s 39ms/step - loss: 0.0012 - accuracy: 0.0014 - mean_absolute_error: 0.0222
# Epoch 69/1000
# 45/45 [==============================] - 2s 37ms/step - loss: 0.0014 - accuracy: 0.0014 - mean_absolute_error: 0.0222
# Epoch 70/1000
# 45/45 [==============================] - 2s 34ms/step - loss: 0.0013 - accuracy: 0.0014 - mean_absolute_error: 0.0219
# Epoch 71/1000
# 45/45 [==============================] - 2s 34ms/step - loss: 0.0013 - accuracy: 0.0014 - mean_absolute_error: 0.0220
# Epoch 72/1000
# 45/45 [==============================] - 2s 44ms/step - loss: 0.0013 - accuracy: 0.0014 - mean_absolute_error: 0.0215
# Epoch 73/1000
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0222
# Epoch 74/1000
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0014 - accuracy: 0.0014 - mean_absolute_error: 0.0241
# Epoch 75/1000
# 45/45 [==============================] - 1s 32ms/step - loss: 0.0013 - accuracy: 0.0014 - mean_absolute_error: 0.0222
# Epoch 76/1000
# 45/45 [==============================] - 1s 32ms/step - loss: 0.0012 - accuracy: 0.0014 - mean_absolute_error: 0.0209
# Epoch 77/1000
# 45/45 [==============================] - 2s 34ms/step - loss: 0.0013 - accuracy: 0.0014 - mean_absolute_error: 0.0215
# Epoch 78/1000
# 45/45 [==============================] - 1s 31ms/step - loss: 0.0013 - accuracy: 0.0014 - mean_absolute_error: 0.0231
# Epoch 79/1000
# 45/45 [==============================] - 2s 44ms/step - loss: 0.0012 - accuracy: 0.0014 - mean_absolute_error: 0.0222
# Epoch 80/1000
# 45/45 [==============================] - 1s 32ms/step - loss: 0.0013 - accuracy: 0.0014 - mean_absolute_error: 0.0228
# Epoch 81/1000
# 45/45 [==============================] - 1s 28ms/step - loss: 0.0016 - accuracy: 0.0014 - mean_absolute_error: 0.0244
# Epoch 82/1000
# 45/45 [==============================] - 1s 29ms/step - loss: 0.0015 - accuracy: 0.0014 - mean_absolute_error: 0.0232
# Epoch 83/1000
# 45/45 [==============================] - 1s 31ms/step - loss: 0.0012 - accuracy: 0.0014 - mean_absolute_error: 0.0219
# Epoch 84/1000
# 45/45 [==============================] - 2s 37ms/step - loss: 0.0012 - accuracy: 0.0014 - mean_absolute_error: 0.0211
# Epoch 85/1000
# 45/45 [==============================] - 1s 30ms/step - loss: 0.0014 - accuracy: 0.0014 - mean_absolute_error: 0.0230
# Epoch 86/1000
# 45/45 [==============================] - 2s 47ms/step - loss: 0.0012 - accuracy: 0.0014 - mean_absolute_error: 0.0215
# Epoch 87/1000
# 45/45 [==============================] - 1s 29ms/step - loss: 0.0012 - accuracy: 0.0014 - mean_absolute_error: 0.0213
# Epoch 88/1000
# 45/45 [==============================] - 1s 31ms/step - loss: 0.0013 - accuracy: 0.0014 - mean_absolute_error: 0.0232
# Epoch 89/1000
# 45/45 [==============================] - 1s 29ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0212
# Epoch 90/1000
# 45/45 [==============================] - 1s 28ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0211
# Epoch 91/1000
# 45/45 [==============================] - 1s 29ms/step - loss: 0.0012 - accuracy: 0.0014 - mean_absolute_error: 0.0223
# Epoch 92/1000
# 45/45 [==============================] - 1s 30ms/step - loss: 0.0012 - accuracy: 0.0014 - mean_absolute_error: 0.0212
# Epoch 93/1000
# 45/45 [==============================] - 2s 32ms/step - loss: 0.0014 - accuracy: 0.0014 - mean_absolute_error: 0.0225
# Epoch 94/1000
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0012 - accuracy: 0.0014 - mean_absolute_error: 0.0224
# Epoch 95/1000
# 45/45 [==============================] - 1s 29ms/step - loss: 0.0014 - accuracy: 0.0014 - mean_absolute_error: 0.0242
# Epoch 96/1000
# 45/45 [==============================] - 1s 30ms/step - loss: 0.0013 - accuracy: 0.0014 - mean_absolute_error: 0.0228
# Epoch 97/1000
# 45/45 [==============================] - 1s 29ms/step - loss: 0.0014 - accuracy: 0.0014 - mean_absolute_error: 0.0231
# Epoch 98/1000
# 45/45 [==============================] - 1s 30ms/step - loss: 0.0013 - accuracy: 0.0014 - mean_absolute_error: 0.0231
# Epoch 99/1000
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0015 - accuracy: 0.0014 - mean_absolute_error: 0.0247
# Epoch 100/1000
# 45/45 [==============================] - 1s 33ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0204
# Epoch 101/1000
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0216
# Epoch 102/1000
# 45/45 [==============================] - 1s 29ms/step - loss: 0.0012 - accuracy: 0.0014 - mean_absolute_error: 0.0223
# Epoch 103/1000
# 45/45 [==============================] - 1s 30ms/step - loss: 0.0013 - accuracy: 0.0014 - mean_absolute_error: 0.0238
# Epoch 104/1000
# 45/45 [==============================] - 1s 32ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0210
# Epoch 105/1000
# 45/45 [==============================] - 1s 31ms/step - loss: 0.0012 - accuracy: 0.0014 - mean_absolute_error: 0.0213
# Epoch 106/1000
# 45/45 [==============================] - 1s 31ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0217
# Epoch 107/1000
# 45/45 [==============================] - 1s 33ms/step - loss: 0.0012 - accuracy: 0.0014 - mean_absolute_error: 0.0223
# Epoch 108/1000
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0012 - accuracy: 0.0014 - mean_absolute_error: 0.0218
# Epoch 109/1000
# 45/45 [==============================] - 1s 29ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0210
# Epoch 110/1000
# 45/45 [==============================] - 1s 33ms/step - loss: 0.0012 - accuracy: 0.0014 - mean_absolute_error: 0.0218
# Epoch 111/1000
# 45/45 [==============================] - 1s 28ms/step - loss: 0.0012 - accuracy: 0.0014 - mean_absolute_error: 0.0222
# Epoch 112/1000
# 45/45 [==============================] - 1s 30ms/step - loss: 0.0014 - accuracy: 0.0014 - mean_absolute_error: 0.0237
# Epoch 113/1000
# 45/45 [==============================] - 1s 25ms/step - loss: 0.0014 - accuracy: 0.0014 - mean_absolute_error: 0.0233
# Epoch 114/1000
# 45/45 [==============================] - 2s 39ms/step - loss: 0.0012 - accuracy: 0.0014 - mean_absolute_error: 0.0218
# Epoch 115/1000
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0012 - accuracy: 0.0014 - mean_absolute_error: 0.0218
# Epoch 116/1000
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0013 - accuracy: 0.0014 - mean_absolute_error: 0.0219
# Epoch 117/1000
# 45/45 [==============================] - 2s 34ms/step - loss: 0.0012 - accuracy: 0.0014 - mean_absolute_error: 0.0218
# Epoch 118/1000
# 45/45 [==============================] - 1s 32ms/step - loss: 0.0013 - accuracy: 0.0014 - mean_absolute_error: 0.0221
# Epoch 119/1000
# 45/45 [==============================] - 1s 33ms/step - loss: 0.0012 - accuracy: 0.0014 - mean_absolute_error: 0.0211
# Epoch 120/1000
# 45/45 [==============================] - 1s 32ms/step - loss: 0.0014 - accuracy: 0.0014 - mean_absolute_error: 0.0239
# Epoch 121/1000
# 45/45 [==============================] - 2s 44ms/step - loss: 0.0012 - accuracy: 0.0014 - mean_absolute_error: 0.0223
# Epoch 122/1000
# 45/45 [==============================] - 1s 33ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0207
# Epoch 123/1000
# 45/45 [==============================] - 1s 33ms/step - loss: 0.0012 - accuracy: 0.0014 - mean_absolute_error: 0.0218
# Epoch 124/1000
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0010 - accuracy: 0.0014 - mean_absolute_error: 0.0201
# Epoch 125/1000
# 45/45 [==============================] - 2s 40ms/step - loss: 0.0010 - accuracy: 0.0014 - mean_absolute_error: 0.0200
# Epoch 126/1000
# 45/45 [==============================] - 2s 46ms/step - loss: 0.0012 - accuracy: 0.0014 - mean_absolute_error: 0.0214
# Epoch 127/1000
# 45/45 [==============================] - 2s 42ms/step - loss: 0.0012 - accuracy: 0.0014 - mean_absolute_error: 0.0216
# Epoch 128/1000
# 45/45 [==============================] - 1s 29ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0210
# Epoch 129/1000
# 45/45 [==============================] - 1s 29ms/step - loss: 0.0012 - accuracy: 0.0014 - mean_absolute_error: 0.0219
# Epoch 130/1000
# 45/45 [==============================] - 1s 33ms/step - loss: 0.0012 - accuracy: 0.0014 - mean_absolute_error: 0.0225
# Epoch 131/1000
# 45/45 [==============================] - 1s 30ms/step - loss: 9.9093e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0201
# Epoch 132/1000
# 45/45 [==============================] - 1s 29ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0211
# Epoch 133/1000
# 45/45 [==============================] - 1s 33ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0214
# Epoch 134/1000
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0010 - accuracy: 0.0014 - mean_absolute_error: 0.0202
# Epoch 135/1000
# 45/45 [==============================] - 1s 32ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0210
# Epoch 136/1000
# 45/45 [==============================] - 1s 28ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0213
# Epoch 137/1000
# 45/45 [==============================] - 1s 30ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0208
# Epoch 138/1000
# 45/45 [==============================] - 1s 29ms/step - loss: 0.0012 - accuracy: 0.0014 - mean_absolute_error: 0.0218
# Epoch 139/1000
# 45/45 [==============================] - 1s 33ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0213
# Epoch 140/1000
# 45/45 [==============================] - 2s 38ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0209
# Epoch 141/1000
# 45/45 [==============================] - 1s 32ms/step - loss: 0.0010 - accuracy: 0.0014 - mean_absolute_error: 0.0198
# Epoch 142/1000
# 45/45 [==============================] - 1s 30ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0213
# Epoch 143/1000
# 45/45 [==============================] - 1s 33ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0216
# Epoch 144/1000
# 45/45 [==============================] - 2s 36ms/step - loss: 9.6889e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0200
# Epoch 145/1000
# 45/45 [==============================] - 1s 32ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0204
# Epoch 146/1000
# 45/45 [==============================] - 2s 41ms/step - loss: 0.0012 - accuracy: 0.0014 - mean_absolute_error: 0.0216
# Epoch 147/1000
# 45/45 [==============================] - 1s 32ms/step - loss: 0.0013 - accuracy: 0.0014 - mean_absolute_error: 0.0229
# Epoch 148/1000
# 45/45 [==============================] - 2s 41ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0209
# Epoch 149/1000
# 45/45 [==============================] - 2s 34ms/step - loss: 0.0012 - accuracy: 0.0014 - mean_absolute_error: 0.0224
# Epoch 150/1000
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0010 - accuracy: 0.0014 - mean_absolute_error: 0.0209
# Epoch 151/1000
# 45/45 [==============================] - 1s 32ms/step - loss: 0.0010 - accuracy: 0.0014 - mean_absolute_error: 0.0211
# Epoch 152/1000
# 45/45 [==============================] - 2s 45ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0209
# Epoch 153/1000
# 45/45 [==============================] - 1s 32ms/step - loss: 9.5879e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0200
# Epoch 154/1000
# 45/45 [==============================] - 2s 34ms/step - loss: 0.0010 - accuracy: 0.0014 - mean_absolute_error: 0.0197
# Epoch 155/1000
# 45/45 [==============================] - 1s 31ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0212
# Epoch 156/1000
# 45/45 [==============================] - 1s 32ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0206
# Epoch 157/1000
# 45/45 [==============================] - 1s 30ms/step - loss: 0.0012 - accuracy: 0.0014 - mean_absolute_error: 0.0214
# Epoch 158/1000
# 45/45 [==============================] - 2s 37ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0216
# Epoch 159/1000
# 45/45 [==============================] - 1s 30ms/step - loss: 0.0012 - accuracy: 0.0014 - mean_absolute_error: 0.0222
# Epoch 160/1000
# 45/45 [==============================] - 1s 32ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0208
# Epoch 161/1000
# 45/45 [==============================] - 1s 29ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0205
# Epoch 162/1000
# 45/45 [==============================] - 1s 29ms/step - loss: 0.0010 - accuracy: 0.0014 - mean_absolute_error: 0.0210
# Epoch 163/1000
# 45/45 [==============================] - 1s 30ms/step - loss: 9.7891e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0201
# Epoch 164/1000
# 45/45 [==============================] - 2s 41ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0204
# Epoch 165/1000
# 45/45 [==============================] - 1s 30ms/step - loss: 0.0012 - accuracy: 0.0014 - mean_absolute_error: 0.0212
# Epoch 166/1000
# 45/45 [==============================] - 1s 29ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0212
# Epoch 167/1000
# 45/45 [==============================] - 1s 33ms/step - loss: 0.0013 - accuracy: 0.0014 - mean_absolute_error: 0.0229
# Epoch 168/1000
# 45/45 [==============================] - 1s 33ms/step - loss: 0.0012 - accuracy: 0.0014 - mean_absolute_error: 0.0227
# Epoch 169/1000
# 45/45 [==============================] - 1s 27ms/step - loss: 9.3632e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0202
# Epoch 170/1000
# 45/45 [==============================] - 2s 36ms/step - loss: 9.8627e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0202
# Epoch 171/1000
# 45/45 [==============================] - 1s 28ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0210
# Epoch 172/1000
# 45/45 [==============================] - 1s 32ms/step - loss: 0.0010 - accuracy: 0.0014 - mean_absolute_error: 0.0209
# Epoch 173/1000
# 45/45 [==============================] - 1s 28ms/step - loss: 8.0680e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0187
# Epoch 174/1000
# 45/45 [==============================] - 1s 27ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0205
# Epoch 175/1000
# 45/45 [==============================] - 2s 34ms/step - loss: 0.0010 - accuracy: 0.0014 - mean_absolute_error: 0.0208
# Epoch 176/1000
# 45/45 [==============================] - 2s 40ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0211
# Epoch 177/1000
# 45/45 [==============================] - 2s 43ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0207
# Epoch 178/1000
# 45/45 [==============================] - 2s 34ms/step - loss: 0.0010 - accuracy: 0.0014 - mean_absolute_error: 0.0207
# Epoch 179/1000
# 45/45 [==============================] - 2s 41ms/step - loss: 9.2314e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0198
# Epoch 180/1000
# 45/45 [==============================] - 1s 33ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0213
# Epoch 181/1000
# 45/45 [==============================] - 1s 29ms/step - loss: 8.9565e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0196
# Epoch 182/1000
# 45/45 [==============================] - 1s 24ms/step - loss: 0.0010 - accuracy: 0.0014 - mean_absolute_error: 0.0202
# Epoch 183/1000
# 45/45 [==============================] - 1s 31ms/step - loss: 0.0012 - accuracy: 0.0014 - mean_absolute_error: 0.0216
# Epoch 184/1000
# 45/45 [==============================] - 1s 31ms/step - loss: 9.4165e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0195
# Epoch 185/1000
# 45/45 [==============================] - 1s 28ms/step - loss: 0.0010 - accuracy: 0.0014 - mean_absolute_error: 0.0209
# Epoch 186/1000
# 45/45 [==============================] - 1s 32ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0210
# Epoch 187/1000
# 45/45 [==============================] - 1s 32ms/step - loss: 9.3362e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0196
# Epoch 188/1000
# 45/45 [==============================] - 1s 29ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0202
# Epoch 189/1000
# 45/45 [==============================] - 1s 28ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0206
# Epoch 190/1000
# 45/45 [==============================] - 1s 31ms/step - loss: 9.6144e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0198
# Epoch 191/1000
# 45/45 [==============================] - 1s 28ms/step - loss: 8.3099e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0185
# Epoch 192/1000
# 45/45 [==============================] - 2s 34ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0205
# Epoch 193/1000
# 45/45 [==============================] - 1s 28ms/step - loss: 9.9768e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0203
# Epoch 194/1000
# 45/45 [==============================] - 1s 31ms/step - loss: 9.8059e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0204
# Epoch 195/1000
# 45/45 [==============================] - 1s 29ms/step - loss: 9.7495e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0209
# Epoch 196/1000
# 45/45 [==============================] - 1s 29ms/step - loss: 9.3897e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0210
# Epoch 197/1000
# 45/45 [==============================] - 2s 33ms/step - loss: 9.5514e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0196
# Epoch 198/1000
# 45/45 [==============================] - 2s 38ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0208
# Epoch 199/1000
# 45/45 [==============================] - 1s 33ms/step - loss: 0.0010 - accuracy: 0.0014 - mean_absolute_error: 0.0204
# Epoch 200/1000
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0205
# Epoch 201/1000
# 45/45 [==============================] - 1s 32ms/step - loss: 9.4490e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0198
# Epoch 202/1000
# 45/45 [==============================] - 1s 28ms/step - loss: 9.1937e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0194
# Epoch 203/1000
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0215
# Epoch 204/1000
# 45/45 [==============================] - 1s 32ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0211
# Epoch 205/1000
# 45/45 [==============================] - 1s 30ms/step - loss: 8.6224e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0191
# Epoch 206/1000
# 45/45 [==============================] - 2s 34ms/step - loss: 0.0010 - accuracy: 0.0014 - mean_absolute_error: 0.0207
# Epoch 207/1000
# 45/45 [==============================] - 1s 32ms/step - loss: 0.0012 - accuracy: 0.0014 - mean_absolute_error: 0.0212
# Epoch 208/1000
# 45/45 [==============================] - 1s 30ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0215
# Epoch 209/1000
# 45/45 [==============================] - 2s 34ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0214
# Epoch 210/1000
# 45/45 [==============================] - 1s 30ms/step - loss: 9.3787e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0201
# Epoch 211/1000
# 45/45 [==============================] - 1s 27ms/step - loss: 8.9315e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0202
# Epoch 212/1000
# 45/45 [==============================] - 1s 29ms/step - loss: 9.8660e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0199
# Epoch 213/1000
# 45/45 [==============================] - 1s 29ms/step - loss: 9.0922e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0194
# Epoch 214/1000
# 45/45 [==============================] - 1s 28ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0207
# Epoch 215/1000
# 45/45 [==============================] - 2s 38ms/step - loss: 9.5513e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0197
# Epoch 216/1000
# 45/45 [==============================] - 1s 28ms/step - loss: 0.0010 - accuracy: 0.0014 - mean_absolute_error: 0.0208
# Epoch 217/1000
# 45/45 [==============================] - 1s 28ms/step - loss: 0.0012 - accuracy: 0.0014 - mean_absolute_error: 0.0216
# Epoch 218/1000
# 45/45 [==============================] - 1s 31ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0213
# Epoch 219/1000
# 45/45 [==============================] - 1s 28ms/step - loss: 9.6989e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0198
# Epoch 220/1000
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0010 - accuracy: 0.0014 - mean_absolute_error: 0.0207
# Epoch 221/1000
# 45/45 [==============================] - 1s 32ms/step - loss: 0.0010 - accuracy: 0.0014 - mean_absolute_error: 0.0207
# Epoch 222/1000
# 45/45 [==============================] - 1s 30ms/step - loss: 0.0012 - accuracy: 0.0014 - mean_absolute_error: 0.0225
# Epoch 223/1000
# 45/45 [==============================] - 1s 30ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0213
# Epoch 224/1000
# 45/45 [==============================] - 2s 33ms/step - loss: 8.9622e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0197
# Epoch 225/1000
# 45/45 [==============================] - 1s 31ms/step - loss: 0.0010 - accuracy: 0.0014 - mean_absolute_error: 0.0204
# Epoch 226/1000
# 45/45 [==============================] - 1s 31ms/step - loss: 9.8747e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0202
# Epoch 227/1000
# 45/45 [==============================] - 1s 33ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0211
# Epoch 228/1000
# 45/45 [==============================] - 1s 31ms/step - loss: 0.0010 - accuracy: 0.0014 - mean_absolute_error: 0.0206
# Epoch 229/1000
# 45/45 [==============================] - 1s 30ms/step - loss: 9.6599e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0202
# Epoch 230/1000
# 45/45 [==============================] - 2s 34ms/step - loss: 0.0010 - accuracy: 0.0014 - mean_absolute_error: 0.0201
# Epoch 231/1000
# 45/45 [==============================] - 1s 31ms/step - loss: 0.0010 - accuracy: 0.0014 - mean_absolute_error: 0.0208
# Epoch 232/1000
# 45/45 [==============================] - 1s 30ms/step - loss: 9.9211e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0204
# Epoch 233/1000
# 45/45 [==============================] - 2s 40ms/step - loss: 9.8969e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0208
# Epoch 234/1000
# 45/45 [==============================] - 1s 30ms/step - loss: 0.0010 - accuracy: 0.0014 - mean_absolute_error: 0.0207
# Epoch 235/1000
# 45/45 [==============================] - 1s 29ms/step - loss: 9.8050e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0200
# Epoch 236/1000
# 45/45 [==============================] - 1s 33ms/step - loss: 0.0010 - accuracy: 0.0014 - mean_absolute_error: 0.0201
# Epoch 237/1000
# 45/45 [==============================] - 1s 29ms/step - loss: 9.9249e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0205
# Epoch 238/1000
# 45/45 [==============================] - 2s 41ms/step - loss: 8.9812e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0197
# Epoch 239/1000
# 45/45 [==============================] - 1s 31ms/step - loss: 9.1170e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0193
# Epoch 240/1000
# 45/45 [==============================] - 1s 29ms/step - loss: 9.3457e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0197
# Epoch 241/1000
# 45/45 [==============================] - 2s 34ms/step - loss: 9.7506e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0204
# Epoch 242/1000
# 45/45 [==============================] - 1s 29ms/step - loss: 0.0010 - accuracy: 0.0014 - mean_absolute_error: 0.0203
# Epoch 243/1000
# 45/45 [==============================] - 1s 30ms/step - loss: 9.9733e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0201
# Epoch 244/1000
# 45/45 [==============================] - 2s 34ms/step - loss: 9.6762e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0198
# Epoch 245/1000
# 45/45 [==============================] - 1s 30ms/step - loss: 8.3228e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0188
# Epoch 246/1000
# 45/45 [==============================] - 1s 30ms/step - loss: 7.7952e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0187
# Epoch 247/1000
# 45/45 [==============================] - 1s 33ms/step - loss: 0.0010 - accuracy: 0.0014 - mean_absolute_error: 0.0206
# Epoch 248/1000
# 45/45 [==============================] - 1s 30ms/step - loss: 7.9418e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0186
# Epoch 249/1000
# 45/45 [==============================] - 2s 38ms/step - loss: 9.7601e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0200
# Epoch 250/1000
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0012 - accuracy: 0.0014 - mean_absolute_error: 0.0214
# Epoch 251/1000
# 45/45 [==============================] - 1s 29ms/step - loss: 9.7030e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0200
# Epoch 252/1000
# 45/45 [==============================] - 1s 32ms/step - loss: 0.0011 - accuracy: 0.0014 - mean_absolute_error: 0.0215
# Epoch 253/1000
# 45/45 [==============================] - 1s 30ms/step - loss: 9.3594e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0200
# Epoch 254/1000
# 45/45 [==============================] - 2s 39ms/step - loss: 0.0010 - accuracy: 0.0014 - mean_absolute_error: 0.0205
# Epoch 255/1000
# 45/45 [==============================] - 2s 33ms/step - loss: 8.1006e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0193
# Epoch 256/1000
# 45/45 [==============================] - 1s 31ms/step - loss: 9.7140e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0212
# Epoch 257/1000
# 45/45 [==============================] - 1s 30ms/step - loss: 9.8754e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0197
# Epoch 258/1000
# 45/45 [==============================] - 1s 33ms/step - loss: 8.0773e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0187
# Epoch 259/1000
# 45/45 [==============================] - 1s 29ms/step - loss: 9.0910e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0194
# Epoch 260/1000
# 45/45 [==============================] - 1s 30ms/step - loss: 0.0010 - accuracy: 0.0014 - mean_absolute_error: 0.0205
# Epoch 261/1000
# 45/45 [==============================] - 1s 33ms/step - loss: 9.2084e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0192
# Epoch 262/1000
# 45/45 [==============================] - 1s 32ms/step - loss: 0.0010 - accuracy: 0.0014 - mean_absolute_error: 0.0206
# Epoch 263/1000
# 45/45 [==============================] - 1s 33ms/step - loss: 9.5894e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0206
# Epoch 264/1000
# 45/45 [==============================] - 1s 31ms/step - loss: 9.1328e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0195
# Epoch 265/1000
# 45/45 [==============================] - 2s 34ms/step - loss: 9.2406e-04 - accuracy: 0.0014 - mean_absolute_error: 0.
-04 - accuracy: 0.0014 - mean_absolute_error: 0.0180
# Epoch 992/1000
# 45/45 [==============================] - 2s 38ms/step - loss: 8.6551e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0194
# Epoch 993/1000
# 45/45 [==============================] - 2s 37ms/step - loss: 8.5488e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0183
# Epoch 994/1000
# 45/45 [==============================] - 2s 38ms/step - loss: 7.6399e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0188
# Epoch 995/1000
# 45/45 [==============================] - 2s 43ms/step - loss: 7.2564e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0184
# Epoch 996/1000
# 45/45 [==============================] - 2s 39ms/step - loss: 8.2023e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0187
# Epoch 997/1000
# 45/45 [==============================] - 2s 43ms/step - loss: 7.7692e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0183
# Epoch 998/1000
# 45/45 [==============================] - 2s 42ms/step - loss: 8.5295e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0194
# Epoch 999/1000
# 45/45 [==============================] - 2s 39ms/step - loss: 7.7065e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0189
# Epoch 1000/1000
# 45/45 [==============================] - 2s 38ms/step - loss: 8.3799e-04 - accuracy: 0.0014 - mean_absolute_error: 0.0183

# %%
def visualize_training_results(results):
    """
    Plots the loss and accuracy for the training and testing data
    """
    history = results.history

    plt.figure(figsize=(16, 5))
    # plt.plot(history['val_mean_absolute_error'])
    plt.plot(history['mean_absolute_error'])
    plt.legend(['val_mean_absolute_error', 'mean_absolute_error'])
    plt.title('mean_absolute_error')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.show()

    plt.figure(figsize=(16, 5))
    # plt.plot(history['val_loss'])
    plt.plot(history['loss'])
    plt.legend(['val_loss', 'loss'])
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.show()

    plt.figure(figsize=(16, 5))
    # plt.plot(history['val_accuracy'])
    plt.plot(history['accuracy'])
    plt.legend(['val_accuracy', 'accuracy'])
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.show()

# %%
visualize_training_results(history)

# %%
# Evaluate the model on the test set
mse, accuracy, mae = model.evaluate(X_test, y_test)
# Out:
# 12/12 [==============================] - 11s 11ms/step - loss: 0.0011 - accuracy: 0.0056 - mean_absolute_error: 0.0280

# %%
# Step 8: Tuning the Hyperparameters
# You can use techniques such as grid search or random search to find the best values for the model's hyperparameters

# Step 9: Testing the model
y_pred = model.predict(X_test)
print('y_pred', y_pred.shape)
print('y_test', y_test.shape)




# evaluat
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

rmse = np.sqrt(mean_squared_error(y_test, y_pred))



print("RMSE: {:.4f}".format(rmse))
print("MSE: {:.4f}".format(mse))
print("MAE:{:.4f}".format(mae))
# Out:
# 12/12 [==============================] - 0s 9ms/step
# y_pred (356, 1)
# y_test (356, 1)
# RMSE: 0.0326
# MSE: 0.0011
# MAE:0.0280

# %%
# convert to original data
y_pred = scaler.inverse_transform(y_pred)
y_test= scaler.inverse_transform(y_test)


# evaluat
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mape = 100 * np.mean(np.abs((y_test - y_pred) / y_test))
rmse = np.sqrt(mean_squared_error(y_test, y_pred))


print("MAPE: {:.4f}%".format(mape))
print("RMSE: {:.4f}".format(rmse))
print("MSE: {:.4f}".format(mse))
print("MAE:{:.4f}".format(mae))
# Out:
# MAPE: 3.6279%
# RMSE: 82.4596
# MSE: 6799.5851
# MAE:70.6914

# %%
y_pred_df = pd.DataFrame(y_pred, columns=["Adj Close"])
y_test_df = pd.DataFrame(y_test, columns=["Adj Close"])

# Get the length of y_pred
y_pred_length = y_pred.shape[0]
y_test_length = y_test.shape[0]

# Generate dates for the next y_pred_length days
today = pd.Timestamp.now().date()
prediction_dates = today - timedelta(days=y_pred_length-1)
test = today - timedelta(days=y_test_length-1)
prediction = pd.date_range(start=test_data.index[0], end=test_data.index[-1], freq='D')
test_dates = pd.date_range(start=test_data.index[0], end=test_data.index[-1], freq='D')

# Use the generated dates as the index of the DataFrame
y_pred_df['Date'] = prediction

y_test_df['Date'] = test_dates

# Set the index of the dataframes to be the 'Date' column
y_pred_df.set_index('Date', inplace=True)
y_test_df.set_index('Date', inplace=True)


# Assuming y_pred is a numpy array

# %%
#y_test_df.to_csv("y_test_2021_2022.csv")
y_test_df
# Out:
#               Adj Close
# Date
# 2022-01-09  3157.751465
# 2022-01-10  3083.097900
# 2022-01-11  3238.111572
# 2022-01-12  3372.258301
# 2022-01-13  3248.288574
# ...                 ...
# 2022-12-26  1226.974365
# 2022-12-27  1212.791626
# 2022-12-28  1189.986084
# 2022-12-29  1201.595337
# 2022-12-30  1199.232788
#
# [356 rows x 1 columns]

# %%
#y_pred_df.to_csv("y_pred_2021_2022.csv")  # index=False to exclude index column in CSV
y_pred_df
# Out:
#               Adj Close
# Date
# 2022-01-09  3051.362549
# 2022-01-10  2943.106201
# 2022-01-11  3092.878662
# 2022-01-12  3223.329102
# 2022-01-13  3161.031250
# ...                 ...
# 2022-12-26  1178.198120
# 2022-12-27  1171.475830
# 2022-12-28  1156.532959
# 2022-12-29  1160.605347
# 2022-12-30  1155.984009
#
# [356 rows x 1 columns]

# %%
names = cycle(['Predictions', 'Test Data'])

fig = go.Figure()
fig.add_trace(go.Scatter(x=y_test_df.index, y=y_pred_df['Adj Close'], name='Predictions',
                         line=dict(width=2, color='blue')))
fig.add_trace(go.Scatter(x=y_test_df.index, y=y_test_df['Adj Close'], name='Test Data',
                         line=dict(width=2, color='red')))
fig.update_layout(xaxis_title='Date', yaxis_title='Price',
                  font_size=15, font_color='black', legend_title_text=' Parameters')
fig.show()

# %%
# Calculate mean absolute percentage error (MAPE)
def mape(y_true, y_pred):
    return 100 * np.mean(np.abs((y_true - y_pred) / y_true))


mape_value = mape(y_test, y_pred)
print(f'MAPE: {mape_value:.4f}%')
# Out:
# MAPE: 3.6279%

# %%
def smape(y_true, y_pred):
    return 200 * np.mean(np.abs(y_pred - y_true) / (np.abs(y_pred) + np.abs(y_true)))


SMAPE1 = smape(y_test, y_pred)
print("smape: {:.4f}%".format(SMAPE1))
# Out:
# smape: 3.6811%

# %%
# Step 1: Data cleaning
data_new = yf.download(tickers='ETH-usd',period='max', interval='1d')
data_new.dropna(inplace=True)
data_new
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2017-11-09   308.644989   329.451996   307.056000   320.884003   320.884003
# 2017-11-10   320.670990   324.717987   294.541992   299.252991   299.252991
# 2017-11-11   298.585999   319.453003   298.191986   314.681000   314.681000
# 2017-11-12   314.690002   319.153015   298.513000   307.907990   307.907990
# 2017-11-13   307.024994   328.415009   307.024994   316.716003   316.716003
# ...                 ...          ...          ...          ...          ...
# 2023-03-07  1567.424683  1579.162231  1543.127563  1561.933105  1561.933105
# 2023-03-08  1561.977905  1568.175293  1534.088257  1534.088257  1534.088257
# 2023-03-09  1534.031616  1544.108398  1423.264771  1438.660767  1438.660767
# 2023-03-10  1438.760132  1438.760132  1378.525391  1429.158081  1429.158081
# 2023-03-11  1429.869873  1481.184814  1429.363525  1441.511108  1441.511108
#
#                  Volume
# Date
# 2017-11-09    893249984
# 2017-11-10    885985984
# 2017-11-11    842300992
# 2017-11-12   1613479936
# 2017-11-13   1041889984
# ...                 ...
# 2023-03-07   6854058349
# 2023-03-08   7130327525
# 2023-03-09   9457897583
# 2023-03-10  12665194936
# 2023-03-11  16264599552
#
# [1949 rows x 6 columns]

# %%
# Step 2: Feature engineering
data_new['RSI']       = ta.rsi(data_new.Close, length=15)
data_new['EMA_short'] = ta.ema(data_new.Close, length=20)
data_new['EMA_long']  = ta.ema(data_new.Close, length=100)
data_new.dropna(inplace=True)
data_new.reset_index(inplace=True)
data_new.drop(['Close'], axis=1, inplace=True)
# Setting the index
data_new.set_index('Date', inplace=True)

# Dropping any NaNs
data_new.dropna(inplace=True)

data_new.info()
data_new.tail(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1850 entries, 2018-02-16 to 2023-03-11
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1850 non-null   float64
#  1   High       1850 non-null   float64
#  2   Low        1850 non-null   float64
#  3   Adj Close  1850 non-null   float64
#  4   Volume     1850 non-null   int64
#  5   RSI        1850 non-null   float64
#  6   EMA_short  1850 non-null   float64
#  7   EMA_long   1850 non-null   float64
# dtypes: float64(7), int64(1)
# memory usage: 130.1 KB
#                    Open         High          Low    Adj Close       Volume  \
# Date
# 2023-03-02  1663.549072  1672.051147  1622.599976  1647.319336   7080950926
# 2023-03-03  1647.557739  1648.475342  1552.451538  1569.167603   9922240199
# 2023-03-04  1569.278076  1575.637207  1551.736816  1566.923950   4389045367
# 2023-03-05  1567.179321  1584.208862  1559.954102  1564.468750   5020886238
# 2023-03-06  1564.383179  1579.456299  1557.363525  1567.398682   5245153345
# 2023-03-07  1567.424683  1579.162231  1543.127563  1561.933105   6854058349
# 2023-03-08  1561.977905  1568.175293  1534.088257  1534.088257   7130327525
# 2023-03-09  1534.031616  1544.108398  1423.264771  1438.660767   9457897583
# 2023-03-10  1438.760132  1438.760132  1378.525391  1429.158081  12665194936
# 2023-03-11  1429.869873  1481.184814  1429.363525  1441.511108  16264599552
#
#                   RSI    EMA_short     EMA_long
# Date
# 2023-03-02  53.607628  1629.743259  1503.225183
# 2023-03-03  45.497589  1623.974149  1504.530974
# 2023-03-04  45.286848  1618.540796  1505.766478
# 2023-03-05  45.042238  1613.391078  1506.928900
# 2023-03-06  45.419181  1609.010849  1508.126321
# 2023-03-07  44.804974  1604.527255  1509.191802
# 2023-03-08  41.725016  1597.818779  1509.684801
# 2023-03-09  33.315721  1582.660873  1508.278384
# 2023-03-10  32.614413  1568.041559  1506.711646
# 2023-03-11  34.533819  1555.991040  1505.420546

# %%
future_data = data_new.iloc[-30:, :]
future_data = future_data.values
future_data = pd.DataFrame(future_data, columns=["Open", "High", "Low", "Adj Close", "Volume", "RSI",
                                                 "EMA_short", "EMA_long"])

# Get the length of future_data
future_length = future_data.shape[0]

# Generate dates for the next 30 days
today = pd.Timestamp.now().date()
future_dates = today + timedelta(days=1)

future = pd.date_range(start=future_dates, end=today +
                       timedelta(days=30), freq='D')

# Generate dates for the next 10 days for predict
today = pd.Timestamp.now().date()
future_dates_pred = pd.date_range(start=today + timedelta(days=1), periods=10, freq='D')

# Use the generated dates as the index of the DataFrame
future_data['Date'] = future

# Set the index of the dataframes to be the 'Date' column
future_data.set_index('Date', inplace=True)

future_data.tail(10)
x_future_data = future_data.drop(['Adj Close'], axis=1).values
y_future_data = future_data['Adj Close'].values
y_future_data = y_future_data.reshape(-1, 1)

print("x_future_data:", x_future_data.shape)
print("y_future_data:", y_future_data.shape)

# x_future_data= np.reshape(x_future_data, (x_future_data.shape[0], 1, x_future_data.shape[1]))

print("x_future_data:", x_future_data.shape)
x_future_data = scaler.fit_transform(x_future_data)
y_future_data = scaler.fit_transform(y_future_data)
for i in range(10):
    future_data_temp = x_future_data[i:i+30, :]
    # future_data_temp = future_data_temp.reshape(-1, 1)
    print("future_data_temp", future_data_temp.shape)
# Out:
# x_future_data: (30, 7)
# y_future_data: (30, 1)
# x_future_data: (30, 7)
# future_data_temp (30, 7)
# future_data_temp (29, 7)
# future_data_temp (28, 7)
# future_data_temp (27, 7)
# future_data_temp (26, 7)
# future_data_temp (25, 7)
# future_data_temp (24, 7)
# future_data_temp (23, 7)
# future_data_temp (22, 7)
# future_data_temp (21, 7)

# %%
# Initialize a numpy array to store the predictions
prediction = np.zeros((10, 1))

for i in range(10):
    future_data_temp = x_future_data[i:i+30, :]

    print("future_data_temp1", future_data_temp.shape)
    future_data_temp = np.reshape(future_data_temp, (future_data_temp.shape[0],
                                                     1, future_data_temp.shape[1]))
    pred = model.predict(future_data_temp)
    print("future_data_temp2", future_data_temp.shape)
    print('---------------------------------------------------')
    prediction[i][0] = pred[0][0]
    x_future_data[i+future_data_temp.shape[0]-1][0] = pred[0][0]
print('3', future_data.shape)
print('prediction:', prediction.shape)
# Reverse the MinMaxScaler
y_future_data = y_future_data.reshape(-1, 1)
y_future_data = scaler.inverse_transform(y_future_data)
prediction = scaler.inverse_transform(prediction)

# Create a new dataframe with the predicted values and the dates as the index
prediction_df = pd.DataFrame(
    prediction, index=future_dates_pred, columns=['Adj Close'])
print('y_future_data', y_future_data.shape)
# Get the length of future_data

y_future_data = pd.DataFrame(y_future_data,  columns=['Adj Close'])

future_length = future_data.shape[0]
test = today - timedelta(days=future_length-1)
test_dates = pd.date_range(start=test, end=today, freq='D')
# Use the generated dates as the index of the DataFrame


y_future_data['Date'] = test_dates

# Set the index of the dataframes to be the 'Date' column

y_future_data.set_index('Date', inplace=True)
# Out:
# future_data_temp1 (30, 7)
# 1/1 [==============================] - 0s 105ms/step
# future_data_temp2 (30, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (29, 7)
# 1/1 [==============================] - 0s 109ms/step
# future_data_temp2 (29, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (28, 7)
# 1/1 [==============================] - 0s 87ms/step
# future_data_temp2 (28, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (27, 7)
# 1/1 [==============================] - 0s 159ms/step
# future_data_temp2 (27, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (26, 7)
# 1/1 [==============================] - 0s 73ms/step
# future_data_temp2 (26, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (25, 7)
# 1/1 [==============================] - 0s 170ms/step
# future_data_temp2 (25, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (24, 7)
# 1/1 [==============================] - 0s 317ms/step
# future_data_temp2 (24, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (23, 7)
# 1/1 [==============================] - 0s 181ms/step
# future_data_temp2 (23, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (22, 7)
# 1/1 [==============================] - 0s 114ms/step
# future_data_temp2 (22, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (21, 7)
# 1/1 [==============================] - 0s 95ms/step
# future_data_temp2 (21, 1, 7)
# ---------------------------------------------------
# 3 (30, 8)
# prediction: (10, 1)
# y_future_data (30, 1)

# %%
prediction_df
# Out:
#               Adj Close
# 2023-03-12  1525.684463
# 2023-03-13  1528.857249
# 2023-03-14  1512.172620
# 2023-03-15  1491.472210
# 2023-03-16  1518.978359
# 2023-03-17  1590.350402
# 2023-03-18  1624.751600
# 2023-03-19  1650.650924
# 2023-03-20  1666.749864
# 2023-03-21  1676.339859

# %%
y_future_data
# Out:
#               Adj Close
# Date
# 2023-02-10  1514.869141
# 2023-02-11  1539.926758
# 2023-02-12  1515.033691
# 2023-02-13  1507.165894
# 2023-02-14  1556.875122
# 2023-02-15  1673.745972
# 2023-02-16  1640.067627
# 2023-02-17  1694.783325
# 2023-02-18  1691.819458
# 2023-02-19  1681.436157
# 2023-02-20  1702.675171
# 2023-02-21  1658.036377
# 2023-02-22  1643.231689
# 2023-02-23  1651.073853
# 2023-02-24  1608.373169
# 2023-02-25  1594.914917
# 2023-02-26  1640.817139
# 2023-02-27  1634.326416
# 2023-02-28  1605.895142
# 2023-03-01  1663.433716
# 2023-03-02  1647.319336
# 2023-03-03  1569.167603
# 2023-03-04  1566.923950
# 2023-03-05  1564.468750
# 2023-03-06  1567.398682
# 2023-03-07  1561.933105
# 2023-03-08  1534.088257
# 2023-03-09  1438.660767
# 2023-03-10  1429.158081
# 2023-03-11  1441.511108

# %%
names = cycle(['Predictions next 10 day', 'Actual data '])

fig = go.Figure()

fig.add_trace(go.Scatter(x=y_future_data.index, y=y_future_data['Adj Close'], name='Actual data ',
                         line=dict(width=2, color='red')))
fig.add_trace(go.Scatter(x=prediction_df.index, y=prediction_df['Adj Close'], name='Predictions next 10 day',
                         line=dict(width=2, color='blue')))

fig.add_shape(type='line',
              x0=prediction_df.index[0], y0=prediction_df['Adj Close'][0],
              x1=y_future_data.index[-1], y1=y_future_data['Adj Close'][-1],
              line=dict(color='grey', width=2))
fig.update_layout(xaxis_title='Date', yaxis_title='Price',
                  font_size=15, font_color='black', legend_title_text=' Parameters')
fig.show()

# %%
actual_x = y_future_data.index
actual_y = y_future_data['Adj Close']
pred_x = prediction_df.index
pred_y = prediction_df['Adj Close']

fig = go.Figure()
fig.add_trace(go.Scatter(x=actual_x, y=actual_y, name='Actual Data'))
fig.add_trace(go.Scatter(x=pred_x, y=pred_y,
              name='Predictions Data for 10 day'))

fig.add_shape(type='line',
              x0=actual_x[-1], y0=actual_y[-1],
              x1=pred_x[0], y1=pred_y[0],
              line=dict(color='grey', width=2, dash='dot'))

fig.update_layout(
    xaxis_title='Date',
    yaxis_title='Price',
    title='predict next 10 day '
)

fig.show()

# %%
future_data_all = data_new.copy()

future_data_all = pd.DataFrame(future_data_all, index= future_data_all.index, 
                               columns=future_data_all.columns)

x_future_data_all = future_data_all.drop(['Adj Close'], axis=1).values
y_future_data_all = future_data_all['Adj Close'].values
y_future_data_all = y_future_data_all.reshape(-1, 1)

print("x_future_data:", x_future_data_all.shape)
print("y_future_data:", y_future_data_all.shape)
# Out:
# x_future_data: (1850, 7)
# y_future_data: (1850, 1)

# %%
x_future_data_all = scaler.fit_transform(x_future_data_all)
y_future_data_all = scaler.fit_transform(y_future_data_all)

x_future_data_all = np.reshape(x_future_data_all, (x_future_data_all.shape[0], 1, x_future_data_all.shape[1]))

pred_future_all = model.predict(x_future_data_all)
# Out:
# 58/58 [==============================] - 1s 11ms/step

# %%
y_future_data_all = scaler.inverse_transform(y_future_data_all)
pred_future_all = scaler.inverse_transform(pred_future_all)
y_future_all = pd.DataFrame(y_future_data_all, index= future_data_all.index,  columns=['Adj Close'])
pred_future_all_df = pd.DataFrame(pred_future_all, index= future_data_all.index,  columns=['Adj Close'])
print("pred_future_all:", pred_future_all.shape)
print("y_future_data:", y_future_data_all.shape)
# Out:
# pred_future_all: (1850, 1)
# y_future_data: (1850, 1)

# %%
names = cycle(['Predictions', 'Test Data'])

fig = go.Figure()
fig.add_trace(go.Scatter(x=y_future_all.index, y=pred_future_all_df['Adj Close'], name='Predictions',
                         line=dict(width=2, color='blue')))
fig.add_trace(go.Scatter(x=y_future_all.index, y=y_future_all['Adj Close'], name='Actual Data',
                         line=dict(width=2, color='red')))
fig.add_trace(go.Scatter(x=prediction_df.index, y=prediction_df['Adj Close'], name='Predictions next 10 day',
                         line=dict(width=2, color='gray')))
fig.add_shape(type='line',
              x0=prediction_df.index[0], y0=prediction_df['Adj Close'][0],
              x1=pred_future_all_df.index[-1], y1=pred_future_all_df['Adj Close'][-1],
              line=dict(color='grey', width=2))

fig.update_layout(xaxis_title='Date', yaxis_title='Price',
                  font_size=15, font_color='black', legend_title_text=' Parameters')
fig.show()
