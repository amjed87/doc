# %%
import pandas as pd
import numpy as np
import pandas_ta as ta
import yfinance as yf
from datetime import timedelta
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error 
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, GRU ,Bidirectional
from keras.layers import Reshape
# For PLotting we will use these library

import matplotlib.pyplot as plt

from itertools import cycle
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

# %%
# Step 1: Data cleaning
data = yf.download(tickers='BTC-usd', start='2014-12-31', end='2022-12-31', interval='1d')
#data = yf.download(tickers='BTC-USD', period='max', interval='1d')
data.dropna(inplace=True)
data
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Step 1: Data cleaning
# ----> 2 data = yf.download(tickers='BTC-usd', start='2014-12-31', end='2022-12-31', interval='1d')
#       3 #data = yf.download(tickers='BTC-USD', period='max', interval='1d')
#       4 data.dropna(inplace=True)
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\yfinance\multi.py:118, in download(tickers, start, end, actions, threads, ignore_tz, group_by, auto_adjust, back_adjust, keepna, progress, period, show_errors, interval, prepost, proxy, rounding, timeout, **kwargs)
#     111         _download_one_threaded(ticker, period=period, interval=interval,
#     112                                start=start, end=end, prepost=prepost,
#     113                                actions=actions, auto_adjust=auto_adjust,
#     114                                back_adjust=back_adjust, keepna=keepna,
#     115                                progress=(progress and i > 0), proxy=proxy,
#     116                                rounding=rounding, timeout=timeout)
#     117     while len(shared._DFS) < len(tickers):
# --> 118         _time.sleep(0.01)
#     120 # download synchronously
#     121 else:
#     122     for i, ticker in enumerate(tickers):
#
# KeyboardInterrupt:

# %%
# Step 2: Feature engineering
data['RSI']       = ta.rsi(data.Close, length=15)
data['EMA_short'] = ta.ema(data.Close, length=20)
data['EMA_long']  = ta.ema(data.Close, length=100)
data.dropna(inplace=True)
data.reset_index(inplace=True)
data.drop(['Close'], axis=1, inplace=True)
# Setting the index
data.set_index('Date', inplace=True)

# Dropping any NaNs
data.dropna(inplace=True)

data.info()
data.tail(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Step 2: Feature engineering
# ----> 2 data['RSI']       = ta.rsi(data.Close, length=15)
#       3 data['EMA_short'] = ta.ema(data.Close, length=20)
#       4 data['EMA_long']  = ta.ema(data.Close, length=100)
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Close'

# %%
data= data.to_csv('btc-2015-2022_case1.csv')

# %%
from datetime import datetime

def date_parser(date_str):
    date_obj = datetime.strptime(date_str, '%m/%d/%Y')
    return date_obj.strftime('%m-%d-%Y')

# %%
data_csv = pd.read_csv('btc-2015-2022_case1.csv')
data_csv.dropna(inplace=True)
# Setting the index

data_csv.set_index('Date', inplace=True)
# Dropping any NaNs
data_csv.dropna(inplace=True)
data_csv.info()
data_csv.tail(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2823 entries, 2015-04-09 to 2022-12-30
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2823 non-null   float64
#  1   High       2823 non-null   float64
#  2   Low        2823 non-null   float64
#  3   Adj Close  2823 non-null   float64
#  4   Volume     2823 non-null   int64
#  5   RSI        2823 non-null   float64
#  6   EMA_short  2823 non-null   float64
#  7   EMA_long   2823 non-null   float64
# dtypes: float64(7), int64(1)
# memory usage: 198.5+ KB
#                     Open          High           Low     Adj Close  \
# Date
# 2022-12-21  16904.527344  16916.800781  16755.912109  16817.535156
# 2022-12-22  16818.380859  16866.673828  16592.408203  16830.341797
# 2022-12-23  16829.644531  16905.218750  16794.458984  16796.953125
# 2022-12-24  16796.976562  16864.703125  16793.527344  16847.755859
# 2022-12-25  16847.505859  16860.554688  16755.253906  16841.986328
# 2022-12-26  16842.250000  16920.123047  16812.369141  16919.804688
# 2022-12-27  16919.291016  16959.845703  16642.072266  16717.173828
# 2022-12-28  16716.400391  16768.169922  16497.556641  16552.572266
# 2022-12-29  16552.322266  16651.755859  16508.683594  16642.341797
# 2022-12-30  16641.330078  16643.427734  16408.474609  16602.585938
#
#                  Volume        RSI     EMA_short      EMA_long
# Date
# 2022-12-21  14882945045  46.354643  16990.208226  18631.716275
# 2022-12-22  16441573050  46.537922  16974.982852  18596.045493
# 2022-12-23  15329265213  46.097985  16958.027640  18560.419901
# 2022-12-24   9744636213  46.916068  16947.525565  18526.505762
# 2022-12-25  11656379938  46.829585  16937.474209  18493.148941
# 2022-12-26  11886957804  48.209222  16935.791398  18461.993610
# 2022-12-27  15748580239  44.954914  16914.970677  18427.442723
# 2022-12-28  17005713920  42.460302  16880.456542  18390.316575
# 2022-12-29  14472237479  44.267447  16857.778948  18355.703213
# 2022-12-30  15929162910  43.617436  16833.474851  18320.988020

# %%
# Split the data into training and test sets
train_df = data_csv[:int(len(data_csv)*0.8)]
test_df = data_csv[int(len(data_csv)*0.8):]
data_csv.shape
# Out:
# (2823, 8)

# %%
test_data =test_df.copy()

# %%
train_x = train_df.index
train_y = train_df['Adj Close']
test_x = test_df.index
test_y = test_df['Adj Close']

fig = go.Figure()
fig.add_trace(go.Scatter(x=train_x, y=train_y, name='train Data'))
fig.add_trace(go.Scatter(x=test_x, y=test_y, name='Test Data'))

fig.update_layout(
    xaxis_title='Date',
    yaxis_title='Price',
    title='Price over time'
)

fig.show()

# %%
print(train_df.info())
print(test_df.info())
print('test_data', test_data.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2258 entries, 2015-04-09 to 2021-06-13
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2258 non-null   float64
#  1   High       2258 non-null   float64
#  2   Low        2258 non-null   float64
#  3   Adj Close  2258 non-null   float64
#  4   Volume     2258 non-null   int64
#  5   RSI        2258 non-null   float64
#  6   EMA_short  2258 non-null   float64
#  7   EMA_long   2258 non-null   float64
# dtypes: float64(7), int64(1)
# memory usage: 158.8+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 565 entries, 2021-06-14 to 2022-12-30
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       565 non-null    float64
#  1   High       565 non-null    float64
#  2   Low        565 non-null    float64
#  3   Adj Close  565 non-null    float64
#  4   Volume     565 non-null    int64
#  5   RSI        565 non-null    float64
#  6   EMA_short  565 non-null    float64
#  7   EMA_long   565 non-null    float64
# dtypes: float64(7), int64(1)
# memory usage: 39.7+ KB
# None
# test_data (565, 8)

# %%
# Preprocess the data
X_train = train_df.drop(['Adj Close'], axis=1).values
y_train = train_df['Adj Close'].values

X_test = test_df.drop(['Adj Close'], axis=1).values
y_test = test_df['Adj Close'].values

print("x_train", X_train.shape)
print("y_train", y_train.shape)
print("X_test", X_test.shape)
print("y_test", y_test.shape)
# Out:
# x_train (2258, 7)
# y_train (2258,)
# X_test (565, 7)
# y_test (565,)

# %%
scaler  = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test  = scaler.fit_transform(X_test)
y_train = y_train.reshape(-1,1)
y_train = scaler.fit_transform(y_train)
y_test  = y_test.reshape(-1,1)
y_test  = scaler.fit_transform(y_test)
#------------------------------------------
print("x_train", X_train.shape)
print("y_train", y_train.shape)
print("X_test", X_test.shape)
print("y_test", y_test.shape)
# Out:
# x_train (2258, 7)
# y_train (2258, 1)
# X_test (565, 7)
# y_test (565, 1)

# %%
# Step 5: Reshaping the data
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

print('X_train', X_train.shape)
print('y_train', y_train.shape)
print('X_test', X_test.shape)
print('Y_test', y_test.shape)
print('X_train.shape[1]', X_train.shape[1])
print('X_train.shape[2]', X_train.shape[2])
# Out:
# X_train (2258, 1, 7)
# y_train (2258, 1)
# X_test (565, 1, 7)
# Y_test (565, 1)
# X_train.shape[1] 1
# X_train.shape[2] 7

# %%
# Step 6: Building the hybrid model (cont.)
model = Sequential()
model.add(LSTM(100, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True , activation= 'tanh'))
model.add(Dropout(0.2))
model.add(LSTM(100, return_sequences=True,activation= 'tanh'))
model.add(Dropout(0.2))
model.add(Reshape((1, 100))) # Add a Reshape layer to convert output shape to (batch_size, timesteps, features)
model.add(Bidirectional(LSTM(75, return_sequences=True,activation= 'tanh')))
model.add(Dropout(0.25))
model.add(Bidirectional(LSTM(75,activation= 'tanh')))
model.add(Dropout(0.25))
model.add(Reshape((1, 150))) # Add a Reshape layer to convert output shape to (batch_size, timesteps, features)
model.add(GRU(50, activation=  "tanh"))
model.add(Dropout(0.3))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy', 'mean_absolute_error'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 1, 100)            43200
#
#  dropout (Dropout)           (None, 1, 100)            0
#
#  lstm_1 (LSTM)               (None, 1, 100)            80400
#
#  dropout_1 (Dropout)         (None, 1, 100)            0
#
#  reshape (Reshape)           (None, 1, 100)            0
#
#  bidirectional (Bidirectiona  (None, 1, 150)           105600
#  l)
#
#  dropout_2 (Dropout)         (None, 1, 150)            0
#
#  bidirectional_1 (Bidirectio  (None, 150)              135600
#  nal)
#
#  dropout_3 (Dropout)         (None, 150)               0
#
#  reshape_1 (Reshape)         (None, 1, 150)            0
#
#  gru (GRU)                   (None, 50)                30300
#
#  dropout_4 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 395,151
# Trainable params: 395,151
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Step 7: Training and evaluating the model
history = model.fit(X_train, y_train, epochs=1000, batch_size=32)
# Out:
# Epoch 1/1000
# 71/71 [==============================] - 43s 26ms/step - loss: 0.0212 - accuracy: 4.4287e-04 - mean_absolute_error: 0.0818
# Epoch 2/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 0.0015 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0211
# Epoch 3/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 0.0014 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0203
# Epoch 4/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 0.0013 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0189
# Epoch 5/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 0.0013 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0188
# Epoch 6/1000
# 71/71 [==============================] - 2s 31ms/step - loss: 0.0011 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0178
# Epoch 7/1000
# 71/71 [==============================] - 2s 33ms/step - loss: 0.0010 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0163
# Epoch 8/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 0.0011 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0169
# Epoch 9/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 9.3592e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0160
# Epoch 10/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 9.4993e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0165
# Epoch 11/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 9.7973e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0166
# Epoch 12/1000
# 71/71 [==============================] - 2s 32ms/step - loss: 9.3373e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0162
# Epoch 13/1000
# 71/71 [==============================] - 2s 35ms/step - loss: 0.0011 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0171
# Epoch 14/1000
# 71/71 [==============================] - 2s 31ms/step - loss: 9.9856e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0174
# Epoch 15/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 0.0010 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0166
# Epoch 16/1000
# 71/71 [==============================] - 2s 31ms/step - loss: 9.9826e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0169
# Epoch 17/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 0.0010 - accuracy: 8.8574e-04 - mean_absolute_error: 0.
-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0145
# Epoch 74/1000
# 71/71 [==============================] - 2s 31ms/step - loss: 6.2315e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0137
# Epoch 75/1000
# 71/71 [==============================] - 2s 31ms/step - loss: 7.3013e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0146
# Epoch 76/1000
# 71/71 [==============================] - 2s 31ms/step - loss: 6.0623e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0137
# Epoch 77/1000
# 71/71 [==============================] - 2s 31ms/step - loss: 5.7413e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0130
# Epoch 78/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 5.3468e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0127
# Epoch 79/1000
# 71/71 [==============================] - 3s 37ms/step - loss: 7.6910e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0153
# Epoch 80/1000
# 71/71 [==============================] - 2s 31ms/step - loss: 6.4544e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0151
# Epoch 81/1000
# 71/71 [==============================] - 2s 31ms/step - loss: 6.3258e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0145
# Epoch 82/1000
# 71/71 [==============================] - 2s 32ms/step - loss: 6.3402e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0139
# Epoch 83/1000
# 71/71 [==============================] - 2s 32ms/step - loss: 5.8167e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0142
# Epoch 84/1000
# 71/71 [==============================] - 2s 32ms/step - loss: 6.7624e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0144
# Epoch 85/1000
# 71/71 [==============================] - 2s 31ms/step - loss: 6.7614e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0147
# Epoch 86/1000
# 71/71 [==============================] - 2s 34ms/step - loss: 6.9300e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0148
# Epoch 87/1000
# 71/71 [==============================] - 2s 33ms/step - loss: 7.1963e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0148
# Epoch 88/1000
# 71/71 [==============================] - 3s 43ms/step - loss: 6.8532e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0141
# Epoch 89/1000
# 71/71 [==============================] - 3s 39ms/step - loss: 6.1403e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0144
# Epoch 90/1000
# 71/71 [==============================] - 3s 35ms/step - loss: 6.6141e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0145
# Epoch 91/1000
# 71/71 [==============================] - 2s 33ms/step - loss: 6.7768e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0145
# Epoch 92/1000
# 71/71 [==============================] - 2s 35ms/step - loss: 6.3617e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0144
# Epoch 93/1000
# 71/71 [==============================] - 2s 31ms/step - loss: 6.2264e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0146
# Epoch 94/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 6.8379e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0144
# Epoch 95/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 6.9005e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0156
# Epoch 96/1000
# 71/71 [==============================] - 2s 34ms/step - loss: 7.2473e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0153
# Epoch 97/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 5.8505e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0138
# Epoch 98/1000
# 71/71 [==============================] - 2s 31ms/step - loss: 5.8686e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0137
# Epoch 99/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 7.0176e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0145
# Epoch 100/1000
# 71/71 [==============================] - 2s 33ms/step - loss: 7.3095e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0150
# Epoch 101/1000
# 71/71 [==============================] - 3s 36ms/step - loss: 7.0441e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0147
# Epoch 102/1000
# 71/71 [==============================] - 2s 31ms/step - loss: 6.3354e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0144
# Epoch 103/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 6.5887e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0147
# Epoch 104/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 6.4121e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0143
# Epoch 105/1000
# 71/71 [==============================] - 3s 37ms/step - loss: 6.8930e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0149
# Epoch 106/1000
# 71/71 [==============================] - 2s 34ms/step - loss: 6.7606e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0144
# Epoch 107/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 5.9540e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0138
# Epoch 108/1000
# 71/71 [==============================] - 2s 31ms/step - loss: 5.9282e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0139
# Epoch 109/1000
# 71/71 [==============================] - 3s 37ms/step - loss: 6.4146e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0143
# Epoch 110/1000
# 71/71 [==============================] - 2s 31ms/step - loss: 6.4821e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0147
# Epoch 111/1000
# 71/71 [==============================] - 2s 32ms/step - loss: 6.6971e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0145
# Epoch 112/1000
# 71/71 [==============================] - 2s 32ms/step - loss: 6.7521e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0145
# Epoch 113/1000
# 71/71 [==============================] - 2s 35ms/step - loss: 6.5724e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0138
# Epoch 114/1000
# 71/71 [==============================] - 2s 31ms/step - loss: 5.9572e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0141
# Epoch 115/1000
# 71/71 [==============================] - 2s 31ms/step - loss: 6.0027e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0143
# Epoch 116/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 7.6564e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0154
# Epoch 117/1000
# 71/71 [==============================] - 3s 36ms/step - loss: 6.6514e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0144
# Epoch 118/1000
# 71/71 [==============================] - 2s 33ms/step - loss: 7.3028e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0160
# Epoch 119/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 6.5996e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0143
# Epoch 120/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 5.9886e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0135
# Epoch 121/1000
# 71/71 [==============================] - 3s 36ms/step - loss: 7.4070e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0152
# Epoch 122/1000
# 71/71 [==============================] - 2s 31ms/step - loss: 7.7064e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0150
# Epoch 123/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 5.7549e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0137
# Epoch 124/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 6.6339e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0143
# Epoch 125/1000
# 71/71 [==============================] - 2s 35ms/step - loss: 6.6207e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0149
# Epoch 126/1000
# 71/71 [==============================] - 2s 33ms/step - loss: 6.0719e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0141
# Epoch 127/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 6.2568e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0143
# Epoch 128/1000
# 71/71 [==============================] - 2s 33ms/step - loss: 6.0929e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0139
# Epoch 129/1000
# 71/71 [==============================] - 3s 37ms/step - loss: 6.7895e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0140
# Epoch 130/1000
# 71/71 [==============================] - 2s 32ms/step - loss: 7.6078e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0153
# Epoch 131/1000
# 71/71 [==============================] - 2s 31ms/step - loss: 5.9348e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0139
# Epoch 132/1000
# 71/71 [==============================] - 2s 32ms/step - loss: 5.7645e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0134
# Epoch 133/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 6.0928e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0145
# Epoch 134/1000
# 71/71 [==============================] - 3s 37ms/step - loss: 6.8970e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.
-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0137
# Epoch 235/1000
# 71/71 [==============================] - 3s 35ms/step - loss: 5.8963e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0133
# Epoch 236/1000
# 71/71 [==============================] - 2s 34ms/step - loss: 5.9431e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0145
# Epoch 237/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 5.5780e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0139
# Epoch 238/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 6.0311e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0142
# Epoch 239/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 4.5636e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0126
# Epoch 240/1000
# 71/71 [==============================] - 2s 33ms/step - loss: 5.5175e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0133
# Epoch 241/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 5.6382e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0136
# Epoch 242/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 5.6161e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0139
# Epoch 243/1000
# 71/71 [==============================] - 2s 33ms/step - loss: 5.3006e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0131
# Epoch 244/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 6.1520e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0145
# Epoch 245/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 5.4470e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0132
# Epoch 246/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 7.0972e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0150
# Epoch 247/1000
# 71/71 [==============================] - 2s 34ms/step - loss: 6.3374e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0147
# Epoch 248/1000
# 71/71 [==============================] - 2s 33ms/step - loss: 6.7015e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0143
# Epoch 249/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 5.4380e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0131
# Epoch 250/1000
# 71/71 [==============================] - 3s 39ms/step - loss: 5.3134e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0129
# Epoch 251/1000
# 71/71 [==============================] - 2s 31ms/step - loss: 4.6664e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0126
# Epoch 252/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 5.3263e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0136
# Epoch 253/1000
# 71/71 [==============================] - 2s 33ms/step - loss: 5.6048e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0136
# Epoch 254/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 5.4236e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0134
# Epoch 255/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 6.5683e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0143
# Epoch 256/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 5.6118e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0147
# Epoch 257/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 5.6910e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0133
# Epoch 258/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 5.6161e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0135
# Epoch 259/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 5.7374e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0138
# Epoch 260/1000
# 71/71 [==============================] - 2s 33ms/step - loss: 5.5437e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0138
# Epoch 261/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 5.9034e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0136
# Epoch 262/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 5.6445e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0139
# Epoch 263/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 6.6688e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0150
# Epoch 264/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 5.3544e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0132
# Epoch 265/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 5.5641e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0133
# Epoch 266/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 5.8252e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0140
# Epoch 267/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 5.3091e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0129
# Epoch 268/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 6.1127e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0140
# Epoch 269/1000
# 71/71 [==============================] - 2s 34ms/step - loss: 6.2687e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0134
# Epoch 270/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 4.8220e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0125
# Epoch 271/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 5.1108e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0132
# Epoch 272/1000
# 71/71 [==============================] - 3s 37ms/step - loss: 5.3389e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0134
# Epoch 273/1000
# 71/71 [==============================] - 2s 32ms/step - loss: 5.2940e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0133
# Epoch 274/1000
# 71/71 [==============================] - 2s 32ms/step - loss: 5.1527e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0131
# Epoch 275/1000
# 71/71 [==============================] - 2s 33ms/step - loss: 4.6673e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0132
# Epoch 276/1000
# 71/71 [==============================] - 2s 32ms/step - loss: 6.2161e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0142
# Epoch 277/1000
# 71/71 [==============================] - 2s 32ms/step - loss: 5.8702e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0145
# Epoch 278/1000
# 71/71 [==============================] - 3s 39ms/step - loss: 5.4792e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0130
# Epoch 279/1000
# 71/71 [==============================] - 2s 33ms/step - loss: 5.3256e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0128
# Epoch 280/1000
# 71/71 [==============================] - 2s 35ms/step - loss: 5.2111e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0129
# Epoch 281/1000
# 71/71 [==============================] - 3s 36ms/step - loss: 6.3464e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0138
# Epoch 282/1000
# 71/71 [==============================] - 2s 32ms/step - loss: 4.1836e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0124
# Epoch 283/1000
# 71/71 [==============================] - 2s 33ms/step - loss: 5.8014e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0135
# Epoch 284/1000
# 71/71 [==============================] - 2s 31ms/step - loss: 5.5243e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0141
# Epoch 285/1000
# 71/71 [==============================] - 2s 33ms/step - loss: 5.8733e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0138
# Epoch 286/1000
# 71/71 [==============================] - 2s 35ms/step - loss: 5.4439e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0130
# Epoch 287/1000
# 71/71 [==============================] - 2s 32ms/step - loss: 5.8840e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0135
# Epoch 288/1000
# 71/71 [==============================] - 3s 38ms/step - loss: 5.0729e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0132
# Epoch 289/1000
# 71/71 [==============================] - 2s 32ms/step - loss: 5.5583e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0135
# Epoch 290/1000
# 71/71 [==============================] - 2s 33ms/step - loss: 5.8283e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0142
# Epoch 291/1000
# 71/71 [==============================] - 2s 32ms/step - loss: 5.9928e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0138
# Epoch 292/1000
# 71/71 [==============================] - 2s 32ms/step - loss: 5.4003e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0134
# Epoch 293/1000
# 71/71 [==============================] - 2s 33ms/step - loss: 5.3562e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0132
# Epoch 294/1000
# 71/71 [==============================] - 3s 36ms/step - loss: 5.9785e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0135
# Epoch 295/1000
# 71/71 [==============================] - 2s 33ms/step - loss: 5.3615e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0139
# Epoch 296/1000
# 71/71 [==============================] - 2s 31ms/step - loss: 5.8154e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0135
# Epoch 297/1000
# 71/71 [==============================] - 3s 39ms/step - loss: 4.8803e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.
-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0121
# Epoch 985/1000
# 71/71 [==============================] - 3s 38ms/step - loss: 5.5819e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0126
# Epoch 986/1000
# 71/71 [==============================] - 3s 44ms/step - loss: 4.7702e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0127
# Epoch 987/1000
# 71/71 [==============================] - 3s 40ms/step - loss: 4.4285e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0121
# Epoch 988/1000
# 71/71 [==============================] - 3s 43ms/step - loss: 4.6012e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0125
# Epoch 989/1000
# 71/71 [==============================] - 3s 41ms/step - loss: 4.3395e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0121
# Epoch 990/1000
# 71/71 [==============================] - 3s 36ms/step - loss: 4.8851e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0127
# Epoch 991/1000
# 71/71 [==============================] - 3s 41ms/step - loss: 5.5770e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0126
# Epoch 992/1000
# 71/71 [==============================] - 3s 40ms/step - loss: 4.5857e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0121
# Epoch 993/1000
# 71/71 [==============================] - 3s 38ms/step - loss: 4.5015e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0123
# Epoch 994/1000
# 71/71 [==============================] - 3s 37ms/step - loss: 4.7002e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0128
# Epoch 995/1000
# 71/71 [==============================] - 3s 42ms/step - loss: 4.6752e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0122
# Epoch 996/1000
# 71/71 [==============================] - 3s 38ms/step - loss: 4.6318e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0122
# Epoch 997/1000
# 71/71 [==============================] - 4s 64ms/step - loss: 4.5431e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0120
# Epoch 998/1000
# 71/71 [==============================] - 3s 46ms/step - loss: 5.4447e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0127
# Epoch 999/1000
# 71/71 [==============================] - 3s 40ms/step - loss: 5.1436e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0133
# Epoch 1000/1000
# 71/71 [==============================] - 4s 50ms/step - loss: 4.6295e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0120

# %%
def visualize_training_results(results):
    """
    Plots the loss and accuracy for the training and testing data
    """
    history = results.history

    plt.figure(figsize=(16, 5))
    # plt.plot(history['val_mean_absolute_error'])
    plt.plot(history['mean_absolute_error'])
    plt.legend(['val_mean_absolute_error', 'mean_absolute_error'])
    plt.title('mean_absolute_error')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.show()

    plt.figure(figsize=(16, 5))
    # plt.plot(history['val_loss'])
    plt.plot(history['loss'])
    plt.legend(['val_loss', 'loss'])
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.show()

    plt.figure(figsize=(16, 5))
    # plt.plot(history['val_accuracy'])
    plt.plot(history['accuracy'])
    plt.legend(['val_accuracy', 'accuracy'])
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.show()

# %%
visualize_training_results(history)

# %%
# Evaluate the model on the test set
mse, accuracy, mae = model.evaluate(X_test, y_test)
# Out:
# 18/18 [==============================] - 9s 11ms/step - loss: 0.0013 - accuracy: 0.0035 - mean_absolute_error: 0.0277

# %%
# Step 8: Tuning the Hyperparameters
# You can use techniques such as grid search or random search to find the best values for the model's hyperparameters

# Step 9: Testing the model
y_pred = model.predict(X_test)
print('y_pred', y_pred.shape)
print('y_test', y_test.shape)




# evaluat
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

rmse = np.sqrt(mean_squared_error(y_test, y_pred))



print("RMSE: {:.4f}".format(rmse))
print("MSE: {:.4f}".format(mse))
print("MAE:{:.4f}".format(mae))
# Out:
# 18/18 [==============================] - 11s 10ms/step
# y_pred (565, 1)
# y_test (565, 1)
# RMSE: 0.0357
# MSE: 0.0013
# MAE:0.0277

# %%
# convert to original data
y_pred = scaler.inverse_transform(y_pred)
y_test= scaler.inverse_transform(y_test)


# evaluat
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mape = 100 * np.mean(np.abs((y_test - y_pred) / y_test))
rmse = np.sqrt(mean_squared_error(y_test, y_pred))


print("MAPE: {:.4f}%".format(mape))
print("RMSE: {:.4f}".format(rmse))
print("MSE: {:.4f}".format(mse))
print("MAE:{:.4f}".format(mae))
# Out:
# MAPE: 3.5391%
# RMSE: 1848.1286
# MSE: 3415579.4481
# MAE:1432.3228

# %%
y_pred_df = pd.DataFrame(y_pred, columns=["Adj Close"])
y_test_df = pd.DataFrame(y_test, columns=["Adj Close"])

# Get the length of y_pred
y_pred_length = y_pred.shape[0]
y_test_length = y_test.shape[0]

# Generate dates for the next y_pred_length days 
today = pd.Timestamp.now().date()
prediction_dates = today - timedelta(days=y_pred_length-1)
test = today - timedelta(days=y_test_length-1)
prediction = pd.date_range(start=test_data.index[0], end=test_data.index[-1], freq='D')
test_dates = pd.date_range(start=test_data.index[0], end=test_data.index[-1], freq='D')

# Use the generated dates as the index of the DataFrame
y_pred_df['Date'] = prediction

y_test_df['Date'] = test_dates

# Set the index of the dataframes to be the 'Date' column
y_pred_df.set_index('Date', inplace=True)
y_test_df.set_index('Date', inplace=True)


# Assuming y_pred is a numpy array

# %%
#y_test_df.to_csv("y_test_2021_2022.csv")
y_test_df
# Out:
#                Adj Close
# Date
# 2021-06-14  40218.476562
# 2021-06-15  40406.269531
# 2021-06-16  38347.062500
# 2021-06-17  38053.503906
# 2021-06-18  35787.246094
# ...                  ...
# 2022-12-26  16919.804688
# 2022-12-27  16717.173828
# 2022-12-28  16552.572266
# 2022-12-29  16642.341797
# 2022-12-30  16602.585938
#
# [565 rows x 1 columns]

# %%
#y_pred_df.to_csv("y_pred_2021_2022.csv")  # index=False to exclude index column in CSV
y_pred_df
# Out:
#                Adj Close
# Date
# 2021-06-14  42144.523438
# 2021-06-15  42463.699219
# 2021-06-16  41128.429688
# 2021-06-17  40623.699219
# 2021-06-18  38568.683594
# ...                  ...
# 2022-12-26  16655.472656
# 2022-12-27  16624.816406
# 2022-12-28  16488.667969
# 2022-12-29  16422.970703
# 2022-12-30  16368.574219
#
# [565 rows x 1 columns]

# %%
names = cycle(['Predictions', 'Test Data'])

fig = go.Figure()
fig.add_trace(go.Scatter(x=y_test_df.index, y=y_pred_df['Adj Close'], name='Predictions',
                         line=dict(width=2, color='blue')))
fig.add_trace(go.Scatter(x=y_test_df.index, y=y_test_df['Adj Close'], name='Test Data',
                         line=dict(width=2, color='red')))
fig.update_layout(xaxis_title='Date', yaxis_title='Price',
                  font_size=15, font_color='black', legend_title_text=' Parameters')
fig.show()

# %%
# Calculate mean absolute percentage error (MAPE)
def mape(y_true, y_pred):
    return 100 * np.mean(np.abs((y_true - y_pred) / y_true))


mape_value = mape(y_test, y_pred)
print(f'MAPE: {mape_value:.4f}%')
# Out:
# MAPE: 3.5391%

# %%
def smape(y_true, y_pred):
    return 200 * np.mean(np.abs(y_pred - y_true) / (np.abs(y_pred) + np.abs(y_true)))


SMAPE1 = smape(y_test, y_pred)
print("smape: {:.4f}%".format(SMAPE1))
# Out:
# smape: 3.4561%

# %%
# Step 1: Data cleaning
data_new = yf.download(tickers='BTC-USD', period='max', interval='1d')
data_new.dropna(inplace=True)
data_new
# Out:
# [*********************100%***********************]  1 of 1 completed
#                     Open          High           Low         Close  \
# Date
# 2014-09-17    465.864014    468.174011    452.421997    457.334015
# 2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2023-03-07  22428.322266  22527.417969  22011.261719  22219.769531
# 2023-03-08  22216.441406  22268.896484  21708.050781  21718.080078
# 2023-03-09  21720.080078  21802.716797  20210.306641  20363.021484
# 2023-03-10  20367.001953  20370.595703  19628.253906  20187.244141
# 2023-03-11  20203.859375  20792.525391  20200.443359  20462.562500
#
#                Adj Close       Volume
# Date
# 2014-09-17    457.334015     21056800
# 2014-09-18    424.440002     34483200
# 2014-09-19    394.795990     37919700
# 2014-09-20    408.903992     36863600
# 2014-09-21    398.821014     26580100
# ...                  ...          ...
# 2023-03-07  22219.769531  22765452204
# 2023-03-08  21718.080078  22536575684
# 2023-03-09  20363.021484  30364664171
# 2023-03-10  20187.244141  39578257695
# 2023-03-11  20462.562500  39583690752
#
# [3098 rows x 6 columns]

# %%
# Step 2: Feature engineering
data_new['RSI']       = ta.rsi(data_new.Close, length=15)
data_new['EMA_short'] = ta.ema(data_new.Close, length=20)
data_new['EMA_long']  = ta.ema(data_new.Close, length=100)
data_new.dropna(inplace=True)
data_new.reset_index(inplace=True)
data_new.drop(['Close'], axis=1, inplace=True)
# Setting the index
data_new.set_index('Date', inplace=True)

# Dropping any NaNs
data_new.dropna(inplace=True)

data_new.info()
data_new.tail(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2999 entries, 2014-12-25 to 2023-03-11
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2999 non-null   float64
#  1   High       2999 non-null   float64
#  2   Low        2999 non-null   float64
#  3   Adj Close  2999 non-null   float64
#  4   Volume     2999 non-null   int64
#  5   RSI        2999 non-null   float64
#  6   EMA_short  2999 non-null   float64
#  7   EMA_long   2999 non-null   float64
# dtypes: float64(7), int64(1)
# memory usage: 210.9 KB
#                     Open          High           Low     Adj Close  \
# Date
# 2023-03-02  23647.019531  23739.138672  23245.021484  23475.466797
# 2023-03-03  23476.632812  23479.347656  22213.238281  22362.679688
# 2023-03-04  22362.923828  22405.177734  22198.980469  22353.349609
# 2023-03-05  22354.144531  22613.685547  22307.142578  22435.513672
# 2023-03-06  22436.816406  22584.292969  22331.314453  22429.757812
# 2023-03-07  22428.322266  22527.417969  22011.261719  22219.769531
# 2023-03-08  22216.441406  22268.896484  21708.050781  21718.080078
# 2023-03-09  21720.080078  21802.716797  20210.306641  20363.021484
# 2023-03-10  20367.001953  20370.595703  19628.253906  20187.244141
# 2023-03-11  20203.859375  20792.525391  20200.443359  20462.562500
#
#                  Volume        RSI     EMA_short      EMA_long
# Date
# 2023-03-02  20386398516  52.763703  23444.603611  21191.250372
# 2023-03-03  26062404610  43.702150  23341.563237  21214.446992
# 2023-03-04  11166012913  43.634831  23247.447654  21236.999519
# 2023-03-05  13317001733  44.442323  23170.120608  21260.732473
# 2023-03-06  17353192895  44.394587  23099.609865  21283.881489
# 2023-03-07  22765452204  42.605759  23015.815548  21302.413926
# 2023-03-08  22536575684  38.622138  22892.221694  21310.644939
# 2023-03-09  30364664171  30.397245  22651.345483  21291.880118
# 2023-03-10  39578257695  29.523412  22416.669165  21270.006138
# 2023-03-11  39583690752  32.766904  22230.563768  21254.017155

# %%
future_data = data_new.iloc[-30:, :]
future_data = future_data.values
future_data = pd.DataFrame(future_data, columns=["Open", "High", "Low", "Adj Close", "Volume", "RSI",
                                                 "EMA_short", "EMA_long"])

# Get the length of future_data
future_length = future_data.shape[0]

# Generate dates for the next 30 days
today = pd.Timestamp.now().date()
future_dates = today + timedelta(days=1)

future = pd.date_range(start=future_dates, end=today +
                       timedelta(days=30), freq='D')

# Generate dates for the next 10 days for predict
today = pd.Timestamp.now().date()
future_dates_pred = pd.date_range(start=today, periods=10, freq='D')

# Use the generated dates as the index of the DataFrame
future_data['Date'] = future

# Set the index of the dataframes to be the 'Date' column
future_data.set_index('Date', inplace=True)

future_data.tail(10)
x_future_data = future_data.drop(['Adj Close'], axis=1).values
y_future_data = future_data['Adj Close'].values
y_future_data = y_future_data.reshape(-1, 1)

print("x_future_data:", x_future_data.shape)
print("y_future_data:", y_future_data.shape)

# x_future_data= np.reshape(x_future_data, (x_future_data.shape[0], 1, x_future_data.shape[1]))

print("x_future_data:", x_future_data.shape)
x_future_data = scaler.fit_transform(x_future_data)
y_future_data = scaler.fit_transform(y_future_data)
for i in range(10):
    future_data_temp = x_future_data[i:i+30, :]
    # future_data_temp = future_data_temp.reshape(-1, 1)
    print("future_data_temp", future_data_temp.shape)
# Out:
# x_future_data: (30, 7)
# y_future_data: (30, 1)
# x_future_data: (30, 7)
# future_data_temp (30, 7)
# future_data_temp (29, 7)
# future_data_temp (28, 7)
# future_data_temp (27, 7)
# future_data_temp (26, 7)
# future_data_temp (25, 7)
# future_data_temp (24, 7)
# future_data_temp (23, 7)
# future_data_temp (22, 7)
# future_data_temp (21, 7)

# %%
# Initialize a numpy array to store the predictions
prediction = np.zeros((10, 1))

for i in range(10):
    future_data_temp = x_future_data[i:i+30, :]

    print("future_data_temp1", future_data_temp.shape)
    future_data_temp = np.reshape(future_data_temp, (future_data_temp.shape[0],
                                                     1, future_data_temp.shape[1]))
    pred = model.predict(future_data_temp)
    print("future_data_temp2", future_data_temp.shape)
    print('---------------------------------------------------')
    prediction[i][0] = pred[0][0]
    x_future_data[i+future_data_temp.shape[0]-1][0] = pred[0][0]
print('3', future_data.shape)
print('prediction:', prediction.shape)
# Reverse the MinMaxScaler
y_future_data = y_future_data.reshape(-1, 1)
y_future_data = scaler.inverse_transform(y_future_data)
prediction = scaler.inverse_transform(prediction)

# Create a new dataframe with the predicted values and the dates as the index
prediction_df = pd.DataFrame(
    prediction, index=future_dates_pred, columns=['Adj Close'])
print('y_future_data', y_future_data.shape)
# Get the length of future_data

y_future_data = pd.DataFrame(y_future_data,  columns=['Adj Close'])

future_length = future_data.shape[0]
test = today - timedelta(days=future_length-1)
test_dates = pd.date_range(start=test, end=today, freq='D')
# Use the generated dates as the index of the DataFrame


y_future_data['Date'] = test_dates

# Set the index of the dataframes to be the 'Date' column

y_future_data.set_index('Date', inplace=True)
# Out:
# future_data_temp1 (30, 7)
# 1/1 [==============================] - 0s 80ms/step
# future_data_temp2 (30, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (29, 7)
# 1/1 [==============================] - 0s 107ms/step
# future_data_temp2 (29, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (28, 7)
# 1/1 [==============================] - 0s 129ms/step
# future_data_temp2 (28, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (27, 7)
# 1/1 [==============================] - 0s 96ms/step
# future_data_temp2 (27, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (26, 7)
# 1/1 [==============================] - 0s 86ms/step
# future_data_temp2 (26, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (25, 7)
# 1/1 [==============================] - 0s 110ms/step
# future_data_temp2 (25, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (24, 7)
# 1/1 [==============================] - 0s 129ms/step
# future_data_temp2 (24, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (23, 7)
# 1/1 [==============================] - 0s 157ms/step
# future_data_temp2 (23, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (22, 7)
# 1/1 [==============================] - 0s 323ms/step
# future_data_temp2 (22, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (21, 7)
# 1/1 [==============================] - 0s 169ms/step
# future_data_temp2 (21, 1, 7)
# ---------------------------------------------------
# 3 (30, 8)
# prediction: (10, 1)
# y_future_data (30, 1)

# %%
prediction_df
# Out:
#                Adj Close
# 2023-03-11  21658.027951
# 2023-03-12  21691.142560
# 2023-03-13  21715.008896
# 2023-03-14  21506.421662
# 2023-03-15  21835.290689
# 2023-03-16  23109.844028
# 2023-03-17  23881.030733
# 2023-03-18  24033.981682
# 2023-03-19  24610.770638
# 2023-03-20  24677.234481

# %%
y_future_data
# Out:
#                Adj Close
# Date
# 2023-02-10  21651.183594
# 2023-02-11  21870.875000
# 2023-02-12  21788.203125
# 2023-02-13  21808.101562
# 2023-02-14  22220.804688
# 2023-02-15  24307.841797
# 2023-02-16  23623.474609
# 2023-02-17  24565.601562
# 2023-02-18  24641.277344
# 2023-02-19  24327.642578
# 2023-02-20  24829.148438
# 2023-02-21  24436.353516
# 2023-02-22  24188.843750
# 2023-02-23  23947.492188
# 2023-02-24  23198.126953
# 2023-02-25  23175.375000
# 2023-02-26  23561.212891
# 2023-02-27  23522.871094
# 2023-02-28  23147.353516
# 2023-03-01  23646.550781
# 2023-03-02  23475.466797
# 2023-03-03  22362.679688
# 2023-03-04  22353.349609
# 2023-03-05  22435.513672
# 2023-03-06  22429.757812
# 2023-03-07  22219.769531
# 2023-03-08  21718.080078
# 2023-03-09  20363.021484
# 2023-03-10  20187.244141
# 2023-03-11  20462.562500

# %%
names = cycle(['Predictions next 10 day', 'Actual data '])

fig = go.Figure()

fig.add_trace(go.Scatter(x=y_future_data.index, y=y_future_data['Adj Close'], name='Actual data ',
                         line=dict(width=2, color='red')))
fig.add_trace(go.Scatter(x=prediction_df.index, y=prediction_df['Adj Close'], name='Predictions next 10 day',
                         line=dict(width=2, color='blue')))

fig.add_shape(type='line',
              x0=prediction_df.index[0], y0=prediction_df['Adj Close'][0],
              x1=y_future_data.index[-1], y1=y_future_data['Adj Close'][-1],
              line=dict(color='grey', width=2))
fig.update_layout(xaxis_title='Date', yaxis_title='Price',
                  font_size=15, font_color='black', legend_title_text=' Parameters')
fig.show()

# %%
actual_x = y_future_data.index
actual_y = y_future_data['Adj Close']
pred_x = prediction_df.index
pred_y = prediction_df['Adj Close']

fig = go.Figure()
fig.add_trace(go.Scatter(x=actual_x, y=actual_y, name='Actual Data'))
fig.add_trace(go.Scatter(x=pred_x, y=pred_y,
              name='Predictions Data for 10 day'))

fig.add_shape(type='line',
              x0=actual_x[-1], y0=actual_y[-1],
              x1=pred_x[0], y1=pred_y[0],
              line=dict(color='grey', width=2, dash='dot'))

fig.update_layout(
    xaxis_title='Date',
    yaxis_title='Price',
    title='predict next 10 day '
)

fig.show()

# %%
future_data_all = data_new.copy()

future_data_all = pd.DataFrame(future_data_all, index= future_data_all.index, 
                               columns=future_data_all.columns)

x_future_data_all = future_data_all.drop(['Adj Close'], axis=1).values
y_future_data_all = future_data_all['Adj Close'].values
y_future_data_all = y_future_data_all.reshape(-1, 1)

print("x_future_data:", x_future_data_all.shape)
print("y_future_data:", y_future_data_all.shape)
# Out:
# x_future_data: (2999, 7)
# y_future_data: (2999, 1)

# %%
x_future_data_all = scaler.fit_transform(x_future_data_all)
y_future_data_all = scaler.fit_transform(y_future_data_all)

x_future_data_all = np.reshape(x_future_data_all, (x_future_data_all.shape[0], 1, x_future_data_all.shape[1]))

pred_future_all = model.predict(x_future_data_all)
# Out:
# 94/94 [==============================] - 3s 17ms/step

# %%
y_future_data_all = scaler.inverse_transform(y_future_data_all)
pred_future_all = scaler.inverse_transform(pred_future_all)
y_future_all = pd.DataFrame(y_future_data_all, index= future_data_all.index,  columns=['Adj Close'])
pred_future_all_df = pd.DataFrame(pred_future_all, index= future_data_all.index,  columns=['Adj Close'])
print("pred_future_all:", pred_future_all.shape)
print("y_future_data:", y_future_data_all.shape)
# Out:
# pred_future_all: (2999, 1)
# y_future_data: (2999, 1)

# %%
names = cycle(['Predictions', 'Test Data'])

fig = go.Figure()
fig.add_trace(go.Scatter(x=y_future_all.index, y=pred_future_all_df['Adj Close'], name='Predictions',
                         line=dict(width=2, color='blue')))
fig.add_trace(go.Scatter(x=y_future_all.index, y=y_future_all['Adj Close'], name='Actual Data',
                         line=dict(width=2, color='red')))
fig.add_trace(go.Scatter(x=prediction_df.index, y=prediction_df['Adj Close'], name='Predictions next 10 day',
                         line=dict(width=2, color='gray')))
fig.add_shape(type='line',
              x0=prediction_df.index[0], y0=prediction_df['Adj Close'][0],
              x1=pred_future_all_df.index[-1], y1=pred_future_all_df['Adj Close'][-1],
              line=dict(color='grey', width=2))

fig.update_layout(xaxis_title='Date', yaxis_title='Price',
                  font_size=15, font_color='black', legend_title_text=' Parameters')
fig.show()
