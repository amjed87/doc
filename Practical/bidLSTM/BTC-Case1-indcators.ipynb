# %%
import pandas as pd
import numpy as np
import pandas_ta as ta
import yfinance as yf
from datetime import timedelta
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error 
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout,Bidirectional

# For PLotting we will use these library

import matplotlib.pyplot as plt

from itertools import cycle
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

# %%
# Step 1: Data cleaning
data = yf.download(tickers='BTC-usd', start='2014-12-31', end='2022-12-31', interval='1d')
#data = yf.download(tickers='BTC-USD', period='max', interval='1d')
data.dropna(inplace=True)
data
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Step 1: Data cleaning
# ----> 2 data = yf.download(tickers='BTC-usd', start='2014-12-31', end='2022-12-31', interval='1d')
#       3 #data = yf.download(tickers='BTC-USD', period='max', interval='1d')
#       4 data.dropna(inplace=True)
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\yfinance\multi.py:118, in download(tickers, start, end, actions, threads, ignore_tz, group_by, auto_adjust, back_adjust, keepna, progress, period, show_errors, interval, prepost, proxy, rounding, timeout, **kwargs)
#     111         _download_one_threaded(ticker, period=period, interval=interval,
#     112                                start=start, end=end, prepost=prepost,
#     113                                actions=actions, auto_adjust=auto_adjust,
#     114                                back_adjust=back_adjust, keepna=keepna,
#     115                                progress=(progress and i > 0), proxy=proxy,
#     116                                rounding=rounding, timeout=timeout)
#     117     while len(shared._DFS) < len(tickers):
# --> 118         _time.sleep(0.01)
#     120 # download synchronously
#     121 else:
#     122     for i, ticker in enumerate(tickers):
#
# KeyboardInterrupt:

# %%
# Step 2: Feature engineering
data['RSI']       = ta.rsi(data.Close, length=15)
data['EMA_short'] = ta.ema(data.Close, length=20)
data['EMA_long']  = ta.ema(data.Close, length=100)
data.dropna(inplace=True)
data.reset_index(inplace=True)
data.drop(['Close'], axis=1, inplace=True)
# Setting the index
data.set_index('Date', inplace=True)

# Dropping any NaNs
data.dropna(inplace=True)

data.info()
data.tail(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2823 entries, 2015-04-09 to 2022-12-30
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2823 non-null   float64
#  1   High       2823 non-null   float64
#  2   Low        2823 non-null   float64
#  3   Adj Close  2823 non-null   float64
#  4   Volume     2823 non-null   int64
#  5   RSI        2823 non-null   float64
#  6   EMA_short  2823 non-null   float64
#  7   EMA_long   2823 non-null   float64
# dtypes: float64(7), int64(1)
# memory usage: 198.5 KB
#                     Open          High           Low     Adj Close  \
# Date
# 2022-12-21  16904.527344  16916.800781  16755.912109  16817.535156
# 2022-12-22  16818.380859  16866.673828  16592.408203  16830.341797
# 2022-12-23  16829.644531  16905.218750  16794.458984  16796.953125
# 2022-12-24  16796.976562  16864.703125  16793.527344  16847.755859
# 2022-12-25  16847.505859  16860.554688  16755.253906  16841.986328
# 2022-12-26  16842.250000  16920.123047  16812.369141  16919.804688
# 2022-12-27  16919.291016  16959.845703  16642.072266  16717.173828
# 2022-12-28  16716.400391  16768.169922  16497.556641  16552.572266
# 2022-12-29  16552.322266  16651.755859  16508.683594  16642.341797
# 2022-12-30  16641.330078  16643.427734  16408.474609  16602.585938
#
#                  Volume        RSI     EMA_short      EMA_long
# Date
# 2022-12-21  14882945045  46.354643  16990.208226  18631.716275
# 2022-12-22  16441573050  46.537922  16974.982852  18596.045493
# 2022-12-23  15329265213  46.097985  16958.027640  18560.419901
# 2022-12-24   9744636213  46.916068  16947.525565  18526.505762
# 2022-12-25  11656379938  46.829585  16937.474209  18493.148941
# 2022-12-26  11886957804  48.209222  16935.791398  18461.993610
# 2022-12-27  15748580239  44.954914  16914.970677  18427.442723
# 2022-12-28  17005713920  42.460302  16880.456542  18390.316575
# 2022-12-29  14472237479  44.267447  16857.778948  18355.703213
# 2022-12-30  15929162910  43.617436  16833.474851  18320.988020

# %%
data= data.to_csv('btc-2015-2022_case1.csv')

# %%
data_csv = pd.read_csv('btc-2015-2022_case1.csv')
data_csv.dropna(inplace=True)
# Setting the index

data_csv.set_index('Date', inplace=True)
# Dropping any NaNs
data_csv.dropna(inplace=True)
data_csv.info()
data_csv.tail(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2823 entries, 2015-04-09 to 2022-12-30
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2823 non-null   float64
#  1   High       2823 non-null   float64
#  2   Low        2823 non-null   float64
#  3   Adj Close  2823 non-null   float64
#  4   Volume     2823 non-null   int64
#  5   RSI        2823 non-null   float64
#  6   EMA_short  2823 non-null   float64
#  7   EMA_long   2823 non-null   float64
# dtypes: float64(7), int64(1)
# memory usage: 198.5+ KB
#                     Open          High           Low     Adj Close  \
# Date
# 2022-12-21  16904.527344  16916.800781  16755.912109  16817.535156
# 2022-12-22  16818.380859  16866.673828  16592.408203  16830.341797
# 2022-12-23  16829.644531  16905.218750  16794.458984  16796.953125
# 2022-12-24  16796.976562  16864.703125  16793.527344  16847.755859
# 2022-12-25  16847.505859  16860.554688  16755.253906  16841.986328
# 2022-12-26  16842.250000  16920.123047  16812.369141  16919.804688
# 2022-12-27  16919.291016  16959.845703  16642.072266  16717.173828
# 2022-12-28  16716.400391  16768.169922  16497.556641  16552.572266
# 2022-12-29  16552.322266  16651.755859  16508.683594  16642.341797
# 2022-12-30  16641.330078  16643.427734  16408.474609  16602.585938
#
#                  Volume        RSI     EMA_short      EMA_long
# Date
# 2022-12-21  14882945045  46.354643  16990.208226  18631.716275
# 2022-12-22  16441573050  46.537922  16974.982852  18596.045493
# 2022-12-23  15329265213  46.097985  16958.027640  18560.419901
# 2022-12-24   9744636213  46.916068  16947.525565  18526.505762
# 2022-12-25  11656379938  46.829585  16937.474209  18493.148941
# 2022-12-26  11886957804  48.209222  16935.791398  18461.993610
# 2022-12-27  15748580239  44.954914  16914.970677  18427.442723
# 2022-12-28  17005713920  42.460302  16880.456542  18390.316575
# 2022-12-29  14472237479  44.267447  16857.778948  18355.703213
# 2022-12-30  15929162910  43.617436  16833.474851  18320.988020

# %%
# Split the data into training and test sets
train_df = data_csv[:int(len(data_csv)*0.8)]
test_df = data_csv[int(len(data_csv)*0.8):]
data_csv.shape
# Out:
# (2823, 8)

# %%
test_data =test_df.copy()

# %%
train_x = train_df.index
train_y = train_df['Adj Close']
test_x = test_df.index
test_y = test_df['Adj Close']

fig = go.Figure()
fig.add_trace(go.Scatter(x=train_x, y=train_y, name='train Data'))
fig.add_trace(go.Scatter(x=test_x, y=test_y, name='Test Data'))

fig.update_layout(
    xaxis_title='Date',
    yaxis_title='Price',
    title='Price over time'
)

fig.show()

# %%
print(train_df.info())
print(test_df.info())
print('test_data', test_data.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2258 entries, 2015-04-09 to 2021-06-13
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2258 non-null   float64
#  1   High       2258 non-null   float64
#  2   Low        2258 non-null   float64
#  3   Adj Close  2258 non-null   float64
#  4   Volume     2258 non-null   int64
#  5   RSI        2258 non-null   float64
#  6   EMA_short  2258 non-null   float64
#  7   EMA_long   2258 non-null   float64
# dtypes: float64(7), int64(1)
# memory usage: 158.8+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 565 entries, 2021-06-14 to 2022-12-30
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       565 non-null    float64
#  1   High       565 non-null    float64
#  2   Low        565 non-null    float64
#  3   Adj Close  565 non-null    float64
#  4   Volume     565 non-null    int64
#  5   RSI        565 non-null    float64
#  6   EMA_short  565 non-null    float64
#  7   EMA_long   565 non-null    float64
# dtypes: float64(7), int64(1)
# memory usage: 39.7+ KB
# None
# test_data (565, 8)

# %%
# Preprocess the data
X_train = train_df.drop(['Adj Close'], axis=1).values
y_train = train_df['Adj Close'].values

X_test = test_df.drop(['Adj Close'], axis=1).values
y_test = test_df['Adj Close'].values

print("x_train", X_train.shape)
print("y_train", y_train.shape)
print("X_test", X_test.shape)
print("y_test", y_test.shape)
# Out:
# x_train (2258, 7)
# y_train (2258,)
# X_test (565, 7)
# y_test (565,)

# %%
scaler  = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test  = scaler.fit_transform(X_test)
y_train = y_train.reshape(-1,1)
y_train = scaler.fit_transform(y_train)
y_test  = y_test.reshape(-1,1)
y_test  = scaler.fit_transform(y_test)
#------------------------------------------
print("x_train", X_train.shape)
print("y_train", y_train.shape)
print("X_test", X_test.shape)
print("y_test", y_test.shape)
# Out:
# x_train (2258, 7)
# y_train (2258, 1)
# X_test (565, 7)
# y_test (565, 1)

# %%
# Step 5: Reshaping the data
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

print('X_train', X_train.shape)
print('y_train', y_train.shape)
print('X_test', X_test.shape)
print('Y_test', y_test.shape)
print('X_train.shape[1]', X_train.shape[1])
print('X_train.shape[2]', X_train.shape[2])
# Out:
# X_train (2258, 1, 7)
# y_train (2258, 1)
# X_test (565, 1, 7)
# Y_test (565, 1)
# X_train.shape[1] 1
# X_train.shape[2] 7

# %%
# Step 6: Building the LSTM model (cont.)

model = Sequential()
model.add(Bidirectional(LSTM(100, input_shape=( X_train.shape[1], X_train.shape[2]),
                             return_sequences=True, activation='tanh')))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(100, return_sequences=True, activation='tanh')))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(75, return_sequences=True, activation='tanh')))
model.add(Dropout(0.25))
model.add(Bidirectional(LSTM(50, activation='tanh')))
model.add(Dropout(0.3))
model.add(Dense(1, activation='linear'))
model.compile(loss='mean_squared_error', optimizer='adam',
              metrics=[ 'mean_absolute_error'])

# %%
# Step 7: Training and evaluating the model
history = model.fit(X_train, y_train, epochs=1000, batch_size=32)
# Out:
# Epoch 1/1000
# 71/71 [==============================] - 34s 24ms/step - loss: 0.0131 - mean_absolute_error: 0.0605
# Epoch 2/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 9.8904e-04 - mean_absolute_error: 0.0163
# Epoch 3/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 9.1278e-04 - mean_absolute_error: 0.0168
# Epoch 4/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 0.0010 - mean_absolute_error: 0.0176
# Epoch 5/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 8.4858e-04 - mean_absolute_error: 0.0154
# Epoch 6/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 7.4082e-04 - mean_absolute_error: 0.0137
# Epoch 7/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 6.7237e-04 - mean_absolute_error: 0.0133
# Epoch 8/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 6.3639e-04 - mean_absolute_error: 0.0130
# Epoch 9/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 6.0349e-04 - mean_absolute_error: 0.0123
# Epoch 10/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 6.1022e-04 - mean_absolute_error: 0.0126
# Epoch 11/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 7.6375e-04 - mean_absolute_error: 0.0141
# Epoch 12/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 6.2492e-04 - mean_absolute_error: 0.0137
# Epoch 13/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 5.0567e-04 - mean_absolute_error: 0.0116
# Epoch 14/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 6.7156e-04 - mean_absolute_error: 0.0138
# Epoch 15/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 5.6887e-04 - mean_absolute_error: 0.0125
# Epoch 16/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 7.0472e-04 - mean_absolute_error: 0.0140
# Epoch 17/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 5.2348e-04 - mean_absolute_error: 0.0120
# Epoch 18/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.2053e-04 - mean_absolute_error: 0.0113
# Epoch 19/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 5.2833e-04 - mean_absolute_error: 0.0119
# Epoch 20/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 5.6708e-04 - mean_absolute_error: 0.0125
# Epoch 21/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 4.2716e-04 - mean_absolute_error: 0.0111
# Epoch 22/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 4.8589e-04 - mean_absolute_error: 0.0126
# Epoch 23/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 4.8242e-04 - mean_absolute_error: 0.0122
# Epoch 24/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 4.8823e-04 - mean_absolute_error: 0.0118
# Epoch 25/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 5.1934e-04 - mean_absolute_error: 0.0123
# Epoch 26/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 4.2179e-04 - mean_absolute_error: 0.0110
# Epoch 27/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 4.8739e-04 - mean_absolute_error: 0.0116
# Epoch 28/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.8991e-04 - mean_absolute_error: 0.0115
# Epoch 29/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 5.2281e-04 - mean_absolute_error: 0.0128
# Epoch 30/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 5.6272e-04 - mean_absolute_error: 0.0127
# Epoch 31/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 3.8562e-04 - mean_absolute_error: 0.0104
# Epoch 32/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 4.1930e-04 - mean_absolute_error: 0.0109
# Epoch 33/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.9810e-04 - mean_absolute_error: 0.0108
# Epoch 34/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 4.1869e-04 - mean_absolute_error: 0.0111
# Epoch 35/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 5.4472e-04 - mean_absolute_error: 0.0128
# Epoch 36/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 4.4353e-04 - mean_absolute_error: 0.0110
# Epoch 37/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 4.6525e-04 - mean_absolute_error: 0.0115
# Epoch 38/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 4.0152e-04 - mean_absolute_error: 0.0113
# Epoch 39/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.3286e-04 - mean_absolute_error: 0.0111
# Epoch 40/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 5.1236e-04 - mean_absolute_error: 0.0123
# Epoch 41/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.9891e-04 - mean_absolute_error: 0.0122
# Epoch 42/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 4.4067e-04 - mean_absolute_error: 0.0113
# Epoch 43/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.8408e-04 - mean_absolute_error: 0.0121
# Epoch 44/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.0096e-04 - mean_absolute_error: 0.0108
# Epoch 45/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 4.3959e-04 - mean_absolute_error: 0.0118
# Epoch 46/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 5.2174e-04 - mean_absolute_error: 0.0123
# Epoch 47/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.3896e-04 - mean_absolute_error: 0.0118
# Epoch 48/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.1767e-04 - mean_absolute_error: 0.0111
# Epoch 49/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 3.5682e-04 - mean_absolute_error: 0.0106
# Epoch 50/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.5961e-04 - mean_absolute_error: 0.0107
# Epoch 51/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 6.0146e-04 - mean_absolute_error: 0.0138
# Epoch 52/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.4775e-04 - mean_absolute_error: 0.0108
# Epoch 53/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 4.6341e-04 - mean_absolute_error: 0.0117
# Epoch 54/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 4.0630e-04 - mean_absolute_error: 0.0108
# Epoch 55/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 4.7118e-04 - mean_absolute_error: 0.0112
# Epoch 56/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.8012e-04 - mean_absolute_error: 0.0121
# Epoch 57/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 4.5454e-04 - mean_absolute_error: 0.0112
# Epoch 58/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 3.9950e-04 - mean_absolute_error: 0.0111
# Epoch 59/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 4.1840e-04 - mean_absolute_error: 0.0113
# Epoch 60/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 4.4245e-04 - mean_absolute_error: 0.0118
# Epoch 61/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 4.7823e-04 - mean_absolute_error: 0.0122
# Epoch 62/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 5.1892e-04 - mean_absolute_error: 0.0124
# Epoch 63/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.6525e-04 - mean_absolute_error: 0.0113
# Epoch 64/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 3.2967e-04 - mean_absolute_error: 0.0104
# Epoch 65/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 4.4980e-04 - mean_absolute_error: 0.0115
# Epoch 66/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 8.1321e-04 - mean_absolute_error: 0.0158
# Epoch 67/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.8823e-04 - mean_absolute_error: 0.0110
# Epoch 68/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 3.7900e-04 - mean_absolute_error: 0.0109
# Epoch 69/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.0641e-04 - mean_absolute_error: 0.0110
# Epoch 70/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.6627e-04 - mean_absolute_error: 0.0104
# Epoch 71/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 3.3195e-04 - mean_absolute_error: 0.0108
# Epoch 72/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 4.7961e-04 - mean_absolute_error: 0.0117
# Epoch 73/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 3.8442e-04 - mean_absolute_error: 0.0111
# Epoch 74/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.5166e-04 - mean_absolute_error: 0.0123
# Epoch 75/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.3861e-04 - mean_absolute_error: 0.0120
# Epoch 76/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 4.0192e-04 - mean_absolute_error: 0.0112
# Epoch 77/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 3.7955e-04 - mean_absolute_error: 0.0110
# Epoch 78/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 4.3105e-04 - mean_absolute_error: 0.0119
# Epoch 79/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 3.4495e-04 - mean_absolute_error: 0.0105
# Epoch 80/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 4.0591e-04 - mean_absolute_error: 0.0110
# Epoch 81/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 5.3655e-04 - mean_absolute_error: 0.0128
# Epoch 82/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.0192e-04 - mean_absolute_error: 0.0115
# Epoch 83/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.2127e-04 - mean_absolute_error: 0.0114
# Epoch 84/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 4.9607e-04 - mean_absolute_error: 0.0119
# Epoch 85/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.6705e-04 - mean_absolute_error: 0.0112
# Epoch 86/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.8276e-04 - mean_absolute_error: 0.0110
# Epoch 87/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 4.5286e-04 - mean_absolute_error: 0.0119
# Epoch 88/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 4.5874e-04 - mean_absolute_error: 0.0126
# Epoch 89/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 3.6167e-04 - mean_absolute_error: 0.0104
# Epoch 90/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 4.3670e-04 - mean_absolute_error: 0.0115
# Epoch 91/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.8553e-04 - mean_absolute_error: 0.0109
# Epoch 92/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 6.0159e-04 - mean_absolute_error: 0.0134
# Epoch 93/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 3.2607e-04 - mean_absolute_error: 0.0102
# Epoch 94/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 3.5808e-04 - mean_absolute_error: 0.0106
# Epoch 95/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 4.5896e-04 - mean_absolute_error: 0.0116
# Epoch 96/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 3.8191e-04 - mean_absolute_error: 0.0116
# Epoch 97/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.1429e-04 - mean_absolute_error: 0.0111
# Epoch 98/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.2198e-04 - mean_absolute_error: 0.0112
# Epoch 99/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 4.4094e-04 - mean_absolute_error: 0.0120
# Epoch 100/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.8019e-04 - mean_absolute_error: 0.0108
# Epoch 101/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.1224e-04 - mean_absolute_error: 0.0114
# Epoch 102/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 3.6903e-04 - mean_absolute_error: 0.0111
# Epoch 103/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 4.0775e-04 - mean_absolute_error: 0.0113
# Epoch 104/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 4.4662e-04 - mean_absolute_error: 0.0118
# Epoch 105/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 3.4581e-04 - mean_absolute_error: 0.0105
# Epoch 106/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 4.0048e-04 - mean_absolute_error: 0.0110
# Epoch 107/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 4.3118e-04 - mean_absolute_error: 0.0113
# Epoch 108/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.7194e-04 - mean_absolute_error: 0.0108
# Epoch 109/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 4.5275e-04 - mean_absolute_error: 0.0114
# Epoch 110/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 4.3210e-04 - mean_absolute_error: 0.0120
# Epoch 111/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 3.6889e-04 - mean_absolute_error: 0.0110
# Epoch 112/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 4.5589e-04 - mean_absolute_error: 0.0116
# Epoch 113/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.8839e-04 - mean_absolute_error: 0.0112
# Epoch 114/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 5.2646e-04 - mean_absolute_error: 0.0132
# Epoch 115/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 3.7394e-04 - mean_absolute_error: 0.0113
# Epoch 116/1000
# 71/71 [==============================] - 3s 35ms/step - loss: 3.7622e-04 - mean_absolute_error: 0.0108
# Epoch 117/1000
# 71/71 [==============================] - 2s 32ms/step - loss: 4.3300e-04 - mean_absolute_error: 0.0112
# Epoch 118/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 4.0611e-04 - mean_absolute_error: 0.0110
# Epoch 119/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.6917e-04 - mean_absolute_error: 0.0105
# Epoch 120/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.0608e-04 - mean_absolute_error: 0.0111
# Epoch 121/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.7121e-04 - mean_absolute_error: 0.0110
# Epoch 122/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.6805e-04 - mean_absolute_error: 0.0109
# Epoch 123/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 3.8086e-04 - mean_absolute_error: 0.0116
# Epoch 124/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 4.4385e-04 - mean_absolute_error: 0.0118
# Epoch 125/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 3.6460e-04 - mean_absolute_error: 0.0106
# Epoch 126/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 4.6879e-04 - mean_absolute_error: 0.0117
# Epoch 127/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.5301e-04 - mean_absolute_error: 0.0112
# Epoch 128/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 3.6367e-04 - mean_absolute_error: 0.0108
# Epoch 129/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.5811e-04 - mean_absolute_error: 0.0109
# Epoch 130/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 3.6455e-04 - mean_absolute_error: 0.0109
# Epoch 131/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.9834e-04 - mean_absolute_error: 0.0119
# Epoch 132/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.4731e-04 - mean_absolute_error: 0.0103
# Epoch 133/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 4.0678e-04 - mean_absolute_error: 0.0114
# Epoch 134/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 3.6909e-04 - mean_absolute_error: 0.0109
# Epoch 135/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.5606e-04 - mean_absolute_error: 0.0107
# Epoch 136/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 4.0796e-04 - mean_absolute_error: 0.0115
# Epoch 137/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 3.6705e-04 - mean_absolute_error: 0.0110
# Epoch 138/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.4804e-04 - mean_absolute_error: 0.0107
# Epoch 139/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 3.8951e-04 - mean_absolute_error: 0.0115
# Epoch 140/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 4.3148e-04 - mean_absolute_error: 0.0119
# Epoch 141/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 3.8454e-04 - mean_absolute_error: 0.0107
# Epoch 142/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 3.2794e-04 - mean_absolute_error: 0.0106
# Epoch 143/1000
# 71/71 [==============================] - 2s 32ms/step - loss: 3.7944e-04 - mean_absolute_error: 0.0111
# Epoch 144/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.6916e-04 - mean_absolute_error: 0.0112
# Epoch 145/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 3.2117e-04 - mean_absolute_error: 0.0104
# Epoch 146/1000
# 71/71 [==============================] - 2s 31ms/step - loss: 3.6470e-04 - mean_absolute_error: 0.0114
# Epoch 147/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.9226e-04 - mean_absolute_error: 0.0107
# Epoch 148/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 4.0330e-04 - mean_absolute_error: 0.0106
# Epoch 149/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 4.3122e-04 - mean_absolute_error: 0.0118
# Epoch 150/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 3.7187e-04 - mean_absolute_error: 0.0107
# Epoch 151/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 4.0734e-04 - mean_absolute_error: 0.0110
# Epoch 152/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 3.8860e-04 - mean_absolute_error: 0.0109
# Epoch 153/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 3.8922e-04 - mean_absolute_error: 0.0110
# Epoch 154/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.6386e-04 - mean_absolute_error: 0.0112
# Epoch 155/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 3.5206e-04 - mean_absolute_error: 0.0116
# Epoch 156/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.7549e-04 - mean_absolute_error: 0.0113
# Epoch 157/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.7503e-04 - mean_absolute_error: 0.0109
# Epoch 158/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 3.4016e-04 - mean_absolute_error: 0.0104
# Epoch 159/1000
# 71/71 [==============================] - 2s 33ms/step - loss: 3.3175e-04 - mean_absolute_error: 0.0104
# Epoch 160/1000
# 71/71 [==============================] - 2s 31ms/step - loss: 4.3973e-04 - mean_absolute_error: 0.0119
# Epoch 161/1000
# 71/71 [==============================] - 2s 33ms/step - loss: 3.6439e-04 - mean_absolute_error: 0.0109
# Epoch 162/1000
# 71/71 [==============================] - 2s 33ms/step - loss: 3.6144e-04 - mean_absolute_error: 0.0104
# Epoch 163/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 3.6809e-04 - mean_absolute_error: 0.0112
# Epoch 164/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 4.3431e-04 - mean_absolute_error: 0.0120
# Epoch 165/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 5.2187e-04 - mean_absolute_error: 0.0127
# Epoch 166/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 3.1100e-04 - mean_absolute_error: 0.0103
# Epoch 167/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 3.3447e-04 - mean_absolute_error: 0.0103
# Epoch 168/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 3.9632e-04 - mean_absolute_error: 0.0111
# Epoch 169/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 4.2727e-04 - mean_absolute_error: 0.0117
# Epoch 170/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 3.3445e-04 - mean_absolute_error: 0.0106
# Epoch 171/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 3.4861e-04 - mean_absolute_error: 0.0106
# Epoch 172/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.6165e-04 - mean_absolute_error: 0.0106
# Epoch 173/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 4.7327e-04 - mean_absolute_error: 0.0123
# Epoch 174/1000
# 71/71 [==============================] - 2s 33ms/step - loss: 3.0774e-04 - mean_absolute_error: 0.0100
# Epoch 175/1000
# 71/71 [==============================] - 2s 34ms/step - loss: 3.3459e-04 - mean_absolute_error: 0.0106
# Epoch 176/1000
# 71/71 [==============================] - 2s 31ms/step - loss: 4.4435e-04 - mean_absolute_error: 0.0119
# Epoch 177/1000
# 71/71 [==============================] - 2s 32ms/step - loss: 3.7151e-04 - mean_absolute_error: 0.0110
# Epoch 178/1000
# 71/71 [==============================] - 2s 32ms/step - loss: 3.7158e-04 - mean_absolute_error: 0.0111
# Epoch 179/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.6748e-04 - mean_absolute_error: 0.0098
# Epoch 180/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 3.4722e-04 - mean_absolute_error: 0.0104
# Epoch 181/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 3.5806e-04 - mean_absolute_error: 0.0105
# Epoch 182/1000
# 71/71 [==============================] - 2s 31ms/step - loss: 3.6160e-04 - mean_absolute_error: 0.0108
# Epoch 183/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 3.6895e-04 - mean_absolute_error: 0.0109
# Epoch 184/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 4.2578e-04 - mean_absolute_error: 0.0110
# Epoch 185/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 3.3691e-04 - mean_absolute_error: 0.0103
# Epoch 186/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.4226e-04 - mean_absolute_error: 0.0102
# Epoch 187/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.6118e-04 - mean_absolute_error: 0.0107
# Epoch 188/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 3.3839e-04 - mean_absolute_error: 0.0106
# Epoch 189/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 4.4623e-04 - mean_absolute_error: 0.0122
# Epoch 190/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 3.2796e-04 - mean_absolute_error: 0.0104
# Epoch 191/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 3.4056e-04 - mean_absolute_error: 0.0108
# Epoch 192/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 2.9905e-04 - mean_absolute_error: 0.0098
# Epoch 193/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 3.5533e-04 - mean_absolute_error: 0.0104
# Epoch 194/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 3.0729e-04 - mean_absolute_error: 0.0104
# Epoch 195/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 3.3878e-04 - mean_absolute_error: 0.0107
# Epoch 196/1000
# 71/71 [==============================] - 2s 31ms/step - loss: 3.5998e-04 - mean_absolute_error: 0.0112
# Epoch 197/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 2.8289e-04 - mean_absolute_error: 0.0098
# Epoch 198/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 4.0480e-04 - mean_absolute_error: 0.0115
# Epoch 199/1000
# 71/71 [==============================] - 2s 31ms/step - loss: 3.2772e-04 - mean_absolute_error: 0.0102
# Epoch 200/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 4.1270e-04 - mean_absolute_error: 0.0113
# Epoch 201/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 3.8551e-04 - mean_absolute_error: 0.0112
# Epoch 202/1000
# 71/71 [==============================] - 3s 35ms/step - loss: 3.4095e-04 - mean_absolute_error: 0.0106
# Epoch 203/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 3.6257e-04 - mean_absolute_error: 0.0105
# Epoch 204/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.4424e-04 - mean_absolute_error: 0.0105
# Epoch 205/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 3.9012e-04 - mean_absolute_error: 0.0109
# Epoch 206/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.1763e-04 - mean_absolute_error: 0.0106
# Epoch 207/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 3.9382e-04 - mean_absolute_error: 0.0111
# Epoch 208/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 4.0844e-04 - mean_absolute_error: 0.0118
# Epoch 209/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.0240e-04 - mean_absolute_error: 0.0111
# Epoch 210/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.7811e-04 - mean_absolute_error: 0.0108
# Epoch 211/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.1215e-04 - mean_absolute_error: 0.0101
# Epoch 212/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.7283e-04 - mean_absolute_error: 0.0115
# Epoch 213/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 4.0386e-04 - mean_absolute_error: 0.0113
# Epoch 214/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 3.3660e-04 - mean_absolute_error: 0.0107
# Epoch 215/1000
# 71/71 [==============================] - 3s 37ms/step - loss: 3.4415e-04 - mean_absolute_error: 0.0110
# Epoch 216/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 3.1151e-04 - mean_absolute_error: 0.0103
# Epoch 217/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 2.9268e-04 - mean_absolute_error: 0.0098
# Epoch 218/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 2.6921e-04 - mean_absolute_error: 0.0103
# Epoch 219/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.1533e-04 - mean_absolute_error: 0.0098
# Epoch 220/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 4.0619e-04 - mean_absolute_error: 0.0115
# Epoch 221/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.3383e-04 - mean_absolute_error: 0.0105
# Epoch 222/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.6036e-04 - mean_absolute_error: 0.0105
# Epoch 223/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 3.4136e-04 - mean_absolute_error: 0.0106
# Epoch 224/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.3773e-04 - mean_absolute_error: 0.0108
# Epoch 225/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 3.6672e-04 - mean_absolute_error: 0.0109
# Epoch 226/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 2.7186e-04 - mean_absolute_error: 0.0096
# Epoch 227/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.6567e-04 - mean_absolute_error: 0.0110
# Epoch 228/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 3.7727e-04 - mean_absolute_error: 0.0110
# Epoch 229/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.4461e-04 - mean_absolute_error: 0.0121
# Epoch 230/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.1655e-04 - mean_absolute_error: 0.0104
# Epoch 231/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 2.9986e-04 - mean_absolute_error: 0.0102
# Epoch 232/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 3.0697e-04 - mean_absolute_error: 0.0103
# Epoch 233/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 4.1482e-04 - mean_absolute_error: 0.0111
# Epoch 234/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 4.0204e-04 - mean_absolute_error: 0.0117
# Epoch 235/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.5801e-04 - mean_absolute_error: 0.0106
# Epoch 236/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 3.1903e-04 - mean_absolute_error: 0.0100
# Epoch 237/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 2.9874e-04 - mean_absolute_error: 0.0099
# Epoch 238/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 4.1162e-04 - mean_absolute_error: 0.0107
# Epoch 239/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.2989e-04 - mean_absolute_error: 0.0104
# Epoch 240/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 3.4885e-04 - mean_absolute_error: 0.0110
# Epoch 241/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 3.7894e-04 - mean_absolute_error: 0.0110
# Epoch 242/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 2.9311e-04 - mean_absolute_error: 0.0098
# Epoch 243/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 3.4535e-04 - mean_absolute_error: 0.0110
# Epoch 244/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 2.9135e-04 - mean_absolute_error: 0.0098
# Epoch 245/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.1773e-04 - mean_absolute_error: 0.0100
# Epoch 246/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 2.8526e-04 - mean_absolute_error: 0.0099
# Epoch 247/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 3.0939e-04 - mean_absolute_error: 0.0100
# Epoch 248/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.9298e-04 - mean_absolute_error: 0.0113
# Epoch 249/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 2.8538e-04 - mean_absolute_error: 0.0100
# Epoch 250/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 3.6978e-04 - mean_absolute_error: 0.0105
# Epoch 251/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 2.9709e-04 - mean_absolute_error: 0.0100
# Epoch 252/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 3.6973e-04 - mean_absolute_error: 0.0112
# Epoch 253/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 3.1199e-04 - mean_absolute_error: 0.0102
# Epoch 254/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 3.2053e-04 - mean_absolute_error: 0.0102
# Epoch 255/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 2.9604e-04 - mean_absolute_error: 0.0102
# Epoch 256/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 3.1484e-04 - mean_absolute_error: 0.0104
# Epoch 257/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.3525e-04 - mean_absolute_error: 0.0107
# Epoch 258/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.0843e-04 - mean_absolute_error: 0.0101
# Epoch 259/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.4929e-04 - mean_absolute_error: 0.0106
# Epoch 260/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 4.0248e-04 - mean_absolute_error: 0.0111
# Epoch 261/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 3.5942e-04 - mean_absolute_error: 0.0104
# Epoch 262/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 3.4870e-04 - mean_absolute_error: 0.0108
# Epoch 263/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 3.3794e-04 - mean_absolute_error: 0.0104
# Epoch 264/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.1693e-04 - mean_absolute_error: 0.0104
# Epoch 265/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.4264e-04 - mean_absolute_error: 0.0106
# Epoch 266/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 2.7725e-04 - mean_absolute_error: 0.0096
# Epoch 267/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 2.6957e-04 - mean_absolute_error: 0.0096
# Epoch 268/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 3.1160e-04 - mean_absolute_error: 0.0102
# Epoch 269/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 3.8180e-04 - mean_absolute_error: 0.0114
# Epoch 270/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 3.1421e-04 - mean_absolute_error: 0.0109
# Epoch 271/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 3.4723e-04 - mean_absolute_error: 0.0107
# Epoch 272/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 3.0055e-04 - mean_absolute_error: 0.0098
# Epoch 273/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 2.9240e-04 - mean_absolute_error: 0.0101
# Epoch 274/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 2.8268e-04 - mean_absolute_error: 0.0097
# Epoch 275/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 3.1106e-04 - mean_absolute_error: 0.0105
# Epoch 276/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 3.9658e-04 - mean_absolute_error: 0.0114
# Epoch 277/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 4.0827e-04 - mean_absolute_error: 0.0113
# Epoch 278/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 3.3458e-04 - mean_absolute_error: 0.0106
# Epoch 279/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.2357e-04 - mean_absolute_error: 0.0106
# Epoch 280/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 2.9811e-04 - mean_absolute_error: 0.0101
# Epoch 281/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 3.4873e-04 - mean_absolute_error: 0.0102
# Epoch 282/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.1394e-04 - mean_absolute_error: 0.0104
# Epoch 283/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.1089e-04 - mean_absolute_error: 0.0104
# Epoch 284/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 2.9846e-04 - mean_absolute_error: 0.0100
# Epoch 285/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 3.0004e-04 - mean_absolute_error: 0.0102
# Epoch 286/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 3.0891e-04 - mean_absolute_error: 0.0100
# Epoch 287/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.3049e-04 - mean_absolute_error: 0.0104
# Epoch 288/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 2.6584e-04 - mean_absolute_error: 0.0096
# Epoch 289/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 3.3387e-04 - mean_absolute_error: 0.0103
# Epoch 290/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 2.6448e-04 - mean_absolute_error: 0.0099
# Epoch 291/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 3.3546e-04 - mean_absolute_error: 0.0104
# Epoch 292/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 3.0688e-04 - mean_absolute_error: 0.0099
# Epoch 293/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.1533e-04 - mean_absolute_error: 0.0103
# Epoch 294/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 2.5147e-04 - mean_absolute_error: 0.0096
# Epoch 295/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 4.1964e-04 - mean_absolute_error: 0.0120
# Epoch 296/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 3.7987e-04 - mean_absolute_error: 0.0112
# Epoch 297/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.4467e-04 - mean_absolute_error: 0.0106
# Epoch 298/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.2898e-04 - mean_absolute_error: 0.0100
# Epoch 299/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 2.9011e-04 - mean_absolute_error: 0.0102
# Epoch 300/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 2.7658e-04 - mean_absolute_error: 0.0093
# Epoch 301/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.6950e-04 - mean_absolute_error: 0.0101
# Epoch 302/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 3.4061e-04 - mean_absolute_error: 0.0100
# Epoch 303/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.1460e-04 - mean_absolute_error: 0.0099
# Epoch 304/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 2.6185e-04 - mean_absolute_error: 0.0096
# Epoch 305/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.1401e-04 - mean_absolute_error: 0.0099
# Epoch 306/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 3.3836e-04 - mean_absolute_error: 0.0106
# Epoch 307/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 3.8280e-04 - mean_absolute_error: 0.0114
# Epoch 308/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.3070e-04 - mean_absolute_error: 0.0108
# Epoch 309/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 2.8477e-04 - mean_absolute_error: 0.0096
# Epoch 310/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.3388e-04 - mean_absolute_error: 0.0104
# Epoch 311/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.1826e-04 - mean_absolute_error: 0.0101
# Epoch 312/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.4707e-04 - mean_absolute_error: 0.0106
# Epoch 313/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.3257e-04 - mean_absolute_error: 0.0108
# Epoch 314/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 2.8257e-04 - mean_absolute_error: 0.0098
# Epoch 315/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.1411e-04 - mean_absolute_error: 0.0099
# Epoch 316/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.2019e-04 - mean_absolute_error: 0.0102
# Epoch 317/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.5113e-04 - mean_absolute_error: 0.0102
# Epoch 318/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.4451e-04 - mean_absolute_error: 0.0106
# Epoch 319/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.0652e-04 - mean_absolute_error: 0.0099
# Epoch 320/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 4.0211e-04 - mean_absolute_error: 0.0112
# Epoch 321/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.0515e-04 - mean_absolute_error: 0.0102
# Epoch 322/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 3.3490e-04 - mean_absolute_error: 0.0104
# Epoch 323/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.5880e-04 - mean_absolute_error: 0.0107
# Epoch 324/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.5054e-04 - mean_absolute_error: 0.0107
# Epoch 325/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.1270e-04 - mean_absolute_error: 0.0102
# Epoch 326/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 3.1646e-04 - mean_absolute_error: 0.0106
# Epoch 327/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 3.3428e-04 - mean_absolute_error: 0.0103
# Epoch 328/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 3.2839e-04 - mean_absolute_error: 0.0103
# Epoch 329/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.4268e-04 - mean_absolute_error: 0.0109
# Epoch 330/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.5884e-04 - mean_absolute_error: 0.0110
# Epoch 331/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.3885e-04 - mean_absolute_error: 0.0099
# Epoch 332/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 2.8365e-04 - mean_absolute_error: 0.0101
# Epoch 333/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 2.7145e-04 - mean_absolute_error: 0.0099
# Epoch 334/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 2.7198e-04 - mean_absolute_error: 0.0096
# Epoch 335/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.4348e-04 - mean_absolute_error: 0.0111
# Epoch 336/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.3716e-04 - mean_absolute_error: 0.0106
# Epoch 337/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.3312e-04 - mean_absolute_error: 0.0110
# Epoch 338/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 2.8649e-04 - mean_absolute_error: 0.0099
# Epoch 339/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 2.6819e-04 - mean_absolute_error: 0.0097
# Epoch 340/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.5765e-04 - mean_absolute_error: 0.0111
# Epoch 341/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 2.7927e-04 - mean_absolute_error: 0.0095
# Epoch 342/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 3.5060e-04 - mean_absolute_error: 0.0107
# Epoch 343/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 2.5541e-04 - mean_absolute_error: 0.0092
# Epoch 344/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 2.8843e-04 - mean_absolute_error: 0.0093
# Epoch 345/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 2.3558e-04 - mean_absolute_error: 0.0093
# Epoch 346/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 2.2819e-04 - mean_absolute_error: 0.0091
# Epoch 347/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.1426e-04 - mean_absolute_error: 0.0099
# Epoch 348/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.5299e-04 - mean_absolute_error: 0.0104
# Epoch 349/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 3.3758e-04 - mean_absolute_error: 0.0107
# Epoch 350/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 2.6796e-04 - mean_absolute_error: 0.0096
# Epoch 351/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.4381e-04 - mean_absolute_error: 0.0103
# Epoch 352/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 3.6099e-04 - mean_absolute_error: 0.0108
# Epoch 353/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 2.7392e-04 - mean_absolute_error: 0.0096
# Epoch 354/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 2.8650e-04 - mean_absolute_error: 0.0099
# Epoch 355/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.3036e-04 - mean_absolute_error: 0.0102
# Epoch 356/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 2.9512e-04 - mean_absolute_error: 0.0095
# Epoch 357/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.3705e-04 - mean_absolute_error: 0.0105
# Epoch 358/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.7390e-04 - mean_absolute_error: 0.0109
# Epoch 359/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.2384e-04 - mean_absolute_error: 0.0109
# Epoch 360/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.1241e-04 - mean_absolute_error: 0.0105
# Epoch 361/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 2.5916e-04 - mean_absolute_error: 0.0099
# Epoch 362/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.2337e-04 - mean_absolute_error: 0.0101
# Epoch 363/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.2288e-04 - mean_absolute_error: 0.0103
# Epoch 364/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.1379e-04 - mean_absolute_error: 0.0098
# Epoch 365/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.9176e-04 - mean_absolute_error: 0.0108
# Epoch 366/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.3907e-04 - mean_absolute_error: 0.0104
# Epoch 367/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 2.8709e-04 - mean_absolute_error: 0.0101
# Epoch 368/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 3.6886e-04 - mean_absolute_error: 0.0104
# Epoch 369/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.4439e-04 - mean_absolute_error: 0.0105
# Epoch 370/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 2.9022e-04 - mean_absolute_error: 0.0100
# Epoch 371/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 3.3995e-04 - mean_absolute_error: 0.0102
# Epoch 372/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 3.5946e-04 - mean_absolute_error: 0.0106
# Epoch 373/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.8935e-04 - mean_absolute_error: 0.0097
# Epoch 374/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.1474e-04 - mean_absolute_error: 0.0103
# Epoch 375/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 3.3118e-04 - mean_absolute_error: 0.0109
# Epoch 376/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 3.0250e-04 - mean_absolute_error: 0.0100
# Epoch 377/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 2.6657e-04 - mean_absolute_error: 0.0094
# Epoch 378/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.0510e-04 - mean_absolute_error: 0.0098
# Epoch 379/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 2.9942e-04 - mean_absolute_error: 0.0102
# Epoch 380/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 3.3471e-04 - mean_absolute_error: 0.0104
# Epoch 381/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 3.3052e-04 - mean_absolute_error: 0.0103
# Epoch 382/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 2.5530e-04 - mean_absolute_error: 0.0096
# Epoch 383/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.9212e-04 - mean_absolute_error: 0.0115
# Epoch 384/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.4150e-04 - mean_absolute_error: 0.0108
# Epoch 385/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 2.9824e-04 - mean_absolute_error: 0.0096
# Epoch 386/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 3.2918e-04 - mean_absolute_error: 0.0101
# Epoch 387/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 2.7197e-04 - mean_absolute_error: 0.0095
# Epoch 388/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 2.8316e-04 - mean_absolute_error: 0.0097
# Epoch 389/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.5926e-04 - mean_absolute_error: 0.0106
# Epoch 390/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 2.9105e-04 - mean_absolute_error: 0.0095
# Epoch 391/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.7838e-04 - mean_absolute_error: 0.0096
# Epoch 392/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.2993e-04 - mean_absolute_error: 0.0106
# Epoch 393/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 2.8202e-04 - mean_absolute_error: 0.0098
# Epoch 394/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.1103e-04 - mean_absolute_error: 0.0097
# Epoch 395/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 2.5794e-04 - mean_absolute_error: 0.0097
# Epoch 396/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.4431e-04 - mean_absolute_error: 0.0101
# Epoch 397/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 2.8656e-04 - mean_absolute_error: 0.0101
# Epoch 398/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 2.8617e-04 - mean_absolute_error: 0.0095
# Epoch 399/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.6111e-04 - mean_absolute_error: 0.0111
# Epoch 400/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.2770e-04 - mean_absolute_error: 0.0105
# Epoch 401/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.2667e-04 - mean_absolute_error: 0.0110
# Epoch 402/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.1562e-04 - mean_absolute_error: 0.0101
# Epoch 403/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 2.9656e-04 - mean_absolute_error: 0.0098
# Epoch 404/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 2.5038e-04 - mean_absolute_error: 0.0095
# Epoch 405/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 2.7272e-04 - mean_absolute_error: 0.0098
# Epoch 406/1000
# 71/71 [==============================] - 2s 31ms/step - loss: 3.3899e-04 - mean_absolute_error: 0.0109
# Epoch 407/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 2.7495e-04 - mean_absolute_error: 0.0100
# Epoch 408/1000
# ...
# Epoch 866/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 2.6600e-04 - mean_absolute_error: 0.0093
# Epoch 867/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.4742e-04 - mean_absolute_error: 0.0091
# Epoch 868/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.5730e-04 - mean_absolute_error: 0.0094
# Epoch 869/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 2.5362e-04 - mean_absolute_error: 0.0096
# Epoch 870/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.6915e-04 - mean_absolute_error: 0.0092
# Epoch 871/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 2.8692e-04 - mean_absolute_error: 0.0094
# Epoch 872/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.6391e-04 - mean_absolute_error: 0.0096
# Epoch 873/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 2.5897e-04 - mean_absolute_error: 0.0092
# Epoch 874/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 2.5114e-04 - mean_absolute_error: 0.0091
# Epoch 875/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 2.7250e-04 - mean_absolute_error: 0.0095
# Epoch 876/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.3906e-04 - mean_absolute_error: 0.0090
# Epoch 877/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.5843e-04 - mean_absolute_error: 0.0091
# Epoch 878/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 2.6657e-04 - mean_absolute_error: 0.0093
# Epoch 879/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 2.9332e-04 - mean_absolute_error: 0.0105
# Epoch 880/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 2.8225e-04 - mean_absolute_error: 0.0094
# Epoch 881/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 2.5137e-04 - mean_absolute_error: 0.0092
# Epoch 882/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.1830e-04 - mean_absolute_error: 0.0088
# Epoch 883/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.4493e-04 - mean_absolute_error: 0.0092
# Epoch 884/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.8631e-04 - mean_absolute_error: 0.0094
# Epoch 885/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 2.5380e-04 - mean_absolute_error: 0.0092
# Epoch 886/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.6567e-04 - mean_absolute_error: 0.0096
# Epoch 887/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.6167e-04 - mean_absolute_error: 0.0090
# Epoch 888/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 2.2730e-04 - mean_absolute_error: 0.0088
# Epoch 889/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 2.5187e-04 - mean_absolute_error: 0.0090
# Epoch 890/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 2.8661e-04 - mean_absolute_error: 0.0094
# Epoch 891/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 2.8235e-04 - mean_absolute_error: 0.0096
# Epoch 892/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 2.7758e-04 - mean_absolute_error: 0.0093
# Epoch 893/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 2.3348e-04 - mean_absolute_error: 0.0088
# Epoch 894/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 2.7400e-04 - mean_absolute_error: 0.0096
# Epoch 895/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 2.3838e-04 - mean_absolute_error: 0.0090
# Epoch 896/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 2.6124e-04 - mean_absolute_error: 0.0091
# Epoch 897/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 3.1525e-04 - mean_absolute_error: 0.0096
# Epoch 898/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 3.0745e-04 - mean_absolute_error: 0.0100
# Epoch 899/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 2.7109e-04 - mean_absolute_error: 0.0095
# Epoch 900/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 2.4373e-04 - mean_absolute_error: 0.0092
# Epoch 901/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 3.2438e-04 - mean_absolute_error: 0.0103
# Epoch 902/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.8115e-04 - mean_absolute_error: 0.0102
# Epoch 903/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 2.6632e-04 - mean_absolute_error: 0.0095
# Epoch 904/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 2.7772e-04 - mean_absolute_error: 0.0097
# Epoch 905/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 2.7588e-04 - mean_absolute_error: 0.0093
# Epoch 906/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.8217e-04 - mean_absolute_error: 0.0097
# Epoch 907/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 2.6457e-04 - mean_absolute_error: 0.0097
# Epoch 908/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.5901e-04 - mean_absolute_error: 0.0094
# Epoch 909/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.5157e-04 - mean_absolute_error: 0.0091
# Epoch 910/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 2.7342e-04 - mean_absolute_error: 0.0094
# Epoch 911/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 2.6037e-04 - mean_absolute_error: 0.0092
# Epoch 912/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.4774e-04 - mean_absolute_error: 0.0093
# Epoch 913/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 2.5418e-04 - mean_absolute_error: 0.0092
# Epoch 914/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 2.6387e-04 - mean_absolute_error: 0.0094
# Epoch 915/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.8835e-04 - mean_absolute_error: 0.0095
# Epoch 916/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.3418e-04 - mean_absolute_error: 0.0092
# Epoch 917/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 2.5483e-04 - mean_absolute_error: 0.0091
# Epoch 918/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 2.3119e-04 - mean_absolute_error: 0.0092
# Epoch 919/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.5154e-04 - mean_absolute_error: 0.0092
# Epoch 920/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 2.5715e-04 - mean_absolute_error: 0.0093
# Epoch 921/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 2.7137e-04 - mean_absolute_error: 0.0095
# Epoch 922/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.7668e-04 - mean_absolute_error: 0.0093
# Epoch 923/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.8095e-04 - mean_absolute_error: 0.0096
# Epoch 924/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.8604e-04 - mean_absolute_error: 0.0097
# Epoch 925/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.8678e-04 - mean_absolute_error: 0.0094
# Epoch 926/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.7256e-04 - mean_absolute_error: 0.0094
# Epoch 927/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.7316e-04 - mean_absolute_error: 0.0095
# Epoch 928/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.6905e-04 - mean_absolute_error: 0.0091
# Epoch 929/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 3.2709e-04 - mean_absolute_error: 0.0098
# Epoch 930/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 2.8973e-04 - mean_absolute_error: 0.0098
# Epoch 931/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 2.8247e-04 - mean_absolute_error: 0.0096
# Epoch 932/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.6821e-04 - mean_absolute_error: 0.0092
# Epoch 933/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.5538e-04 - mean_absolute_error: 0.0092
# Epoch 934/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 2.4694e-04 - mean_absolute_error: 0.0091
# Epoch 935/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 3.1489e-04 - mean_absolute_error: 0.0099
# Epoch 936/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.7909e-04 - mean_absolute_error: 0.0096
# Epoch 937/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.6405e-04 - mean_absolute_error: 0.0093
# Epoch 938/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 2.5507e-04 - mean_absolute_error: 0.0090
# Epoch 939/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 2.5624e-04 - mean_absolute_error: 0.0100
# Epoch 940/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 2.4773e-04 - mean_absolute_error: 0.0091
# Epoch 941/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 2.4027e-04 - mean_absolute_error: 0.0091
# Epoch 942/1000
# 71/71 [==============================] - 2s 31ms/step - loss: 2.5766e-04 - mean_absolute_error: 0.0092
# Epoch 943/1000
# 71/71 [==============================] - 2s 31ms/step - loss: 2.4832e-04 - mean_absolute_error: 0.0090
# Epoch 944/1000
# 71/71 [==============================] - 2s 33ms/step - loss: 2.4032e-04 - mean_absolute_error: 0.0088
# Epoch 945/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.7858e-04 - mean_absolute_error: 0.0095
# Epoch 946/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.2590e-04 - mean_absolute_error: 0.0089
# Epoch 947/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 2.7481e-04 - mean_absolute_error: 0.0093
# Epoch 948/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.9148e-04 - mean_absolute_error: 0.0095
# Epoch 949/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 3.0536e-04 - mean_absolute_error: 0.0099
# Epoch 950/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 2.5415e-04 - mean_absolute_error: 0.0093
# Epoch 951/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.5271e-04 - mean_absolute_error: 0.0093
# Epoch 952/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.7077e-04 - mean_absolute_error: 0.0098
# Epoch 953/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 2.6569e-04 - mean_absolute_error: 0.0095
# Epoch 954/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 3.0673e-04 - mean_absolute_error: 0.0096
# Epoch 955/1000
# 71/71 [==============================] - 2s 33ms/step - loss: 2.5341e-04 - mean_absolute_error: 0.0093
# Epoch 956/1000
# 71/71 [==============================] - 2s 33ms/step - loss: 2.7700e-04 - mean_absolute_error: 0.0092
# Epoch 957/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.5113e-04 - mean_absolute_error: 0.0089
# Epoch 958/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 2.5693e-04 - mean_absolute_error: 0.0089
# Epoch 959/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 2.5995e-04 - mean_absolute_error: 0.0093
# Epoch 960/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 3.0135e-04 - mean_absolute_error: 0.0104
# Epoch 961/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.5650e-04 - mean_absolute_error: 0.0094
# Epoch 962/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 2.7552e-04 - mean_absolute_error: 0.0097
# Epoch 963/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 2.9350e-04 - mean_absolute_error: 0.0098
# Epoch 964/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.6303e-04 - mean_absolute_error: 0.0094
# Epoch 965/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 2.7305e-04 - mean_absolute_error: 0.0096
# Epoch 966/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 2.8676e-04 - mean_absolute_error: 0.0095
# Epoch 967/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 2.4237e-04 - mean_absolute_error: 0.0094
# Epoch 968/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.2693e-04 - mean_absolute_error: 0.0089
# Epoch 969/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 3.1040e-04 - mean_absolute_error: 0.0097
# Epoch 970/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.6314e-04 - mean_absolute_error: 0.0093
# Epoch 971/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.3023e-04 - mean_absolute_error: 0.0088
# Epoch 972/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.9284e-04 - mean_absolute_error: 0.0092
# Epoch 973/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.6426e-04 - mean_absolute_error: 0.0093
# Epoch 974/1000
# 71/71 [==============================] - 2s 31ms/step - loss: 2.6127e-04 - mean_absolute_error: 0.0093
# Epoch 975/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.7373e-04 - mean_absolute_error: 0.0097
# Epoch 976/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 2.4360e-04 - mean_absolute_error: 0.0094
# Epoch 977/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.8778e-04 - mean_absolute_error: 0.0098
# Epoch 978/1000
# 71/71 [==============================] - 2s 31ms/step - loss: 2.0857e-04 - mean_absolute_error: 0.0090
# Epoch 979/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.3879e-04 - mean_absolute_error: 0.0088
# Epoch 980/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.7055e-04 - mean_absolute_error: 0.0094
# Epoch 981/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 2.7851e-04 - mean_absolute_error: 0.0096
# Epoch 982/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 2.7335e-04 - mean_absolute_error: 0.0090
# Epoch 983/1000
# 71/71 [==============================] - 2s 31ms/step - loss: 2.2332e-04 - mean_absolute_error: 0.0088
# Epoch 984/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 3.0945e-04 - mean_absolute_error: 0.0097
# Epoch 985/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 2.8058e-04 - mean_absolute_error: 0.0097
# Epoch 986/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 2.5479e-04 - mean_absolute_error: 0.0091
# Epoch 987/1000
# 71/71 [==============================] - 2s 34ms/step - loss: 2.8716e-04 - mean_absolute_error: 0.0098
# Epoch 988/1000
# 71/71 [==============================] - 2s 34ms/step - loss: 2.9038e-04 - mean_absolute_error: 0.0100
# Epoch 989/1000
# 71/71 [==============================] - 2s 31ms/step - loss: 2.4537e-04 - mean_absolute_error: 0.0092
# Epoch 990/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.6393e-04 - mean_absolute_error: 0.0095
# Epoch 991/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 3.1402e-04 - mean_absolute_error: 0.0100
# Epoch 992/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 2.1561e-04 - mean_absolute_error: 0.0087
# Epoch 993/1000
# 71/71 [==============================] - 2s 30ms/step - loss: 2.5052e-04 - mean_absolute_error: 0.0095
# Epoch 994/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.3437e-04 - mean_absolute_error: 0.0088
# Epoch 995/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 2.7218e-04 - mean_absolute_error: 0.0092
# Epoch 996/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 2.7148e-04 - mean_absolute_error: 0.0089
# Epoch 997/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 2.1807e-04 - mean_absolute_error: 0.0086
# Epoch 998/1000
# 71/71 [==============================] - 2s 33ms/step - loss: 2.7154e-04 - mean_absolute_error: 0.0093
# Epoch 999/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 3.1201e-04 - mean_absolute_error: 0.0104
# Epoch 1000/1000
# 71/71 [==============================] - 2s 31ms/step - loss: 2.9336e-04 - mean_absolute_error: 0.0097

# %%
def visualize_training_results(results):
    """
    Plots the loss and accuracy for the training and testing data
    """
    history = results.history

    plt.figure(figsize=(16, 5))
    # plt.plot(history['val_mean_absolute_error'])
    plt.plot(history['mean_absolute_error'])
    plt.legend(['val_mean_absolute_error', 'mean_absolute_error'])
    plt.title('mean_absolute_error')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.show()

    plt.figure(figsize=(16, 5))
    # plt.plot(history['val_loss'])
    plt.plot(history['loss'])
    plt.legend(['val_loss', 'loss'])
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.show()

# %%
visualize_training_results(history)

# %%
# Evaluate the model on the test set
mse, mae = model.evaluate(X_test, y_test)
# Out:
# 18/18 [==============================] - 6s 8ms/step - loss: 1.7250e-04 - mean_absolute_error: 0.0099

# %%
# Step 8: Tuning the Hyperparameters
# You can use techniques such as grid search or random search to find the best values for the model's hyperparameters

# Step 9: Testing the model
y_pred = model.predict(X_test)
print('y_pred', y_pred.shape)
print('y_test', y_test.shape)



# evaluat
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

rmse = np.sqrt(mean_squared_error(y_test, y_pred))



print("RMSE: {:.4f}".format(rmse))
print("MSE: {:.4f}".format(mse))
print("MAE:{:.4f}".format(mae))
# Out:
# 18/18 [==============================] - 7s 10ms/step
# y_pred (565, 1)
# y_test (565, 1)
# RMSE: 0.0131
# MSE: 0.0002
# MAE:0.0099

# %%
# convert to original data
y_pred = scaler.inverse_transform(y_pred)
y_test= scaler.inverse_transform(y_test)

# evaluat

mape = 100 * np.mean(np.abs((y_test - y_pred) / y_test))

print("MAPE: {:.4f}%".format(mape))
# Out:
# MAPE: 1.5029%

# %%
y_pred_df = pd.DataFrame(y_pred, columns=["Adj Close"])
y_test_df = pd.DataFrame(y_test, columns=["Adj Close"])

# Get the length of y_pred
y_pred_length = y_pred.shape[0]
y_test_length = y_test.shape[0]

# Generate dates for the next y_pred_length days 
today = pd.Timestamp.now().date()
prediction_dates = today - timedelta(days=y_pred_length-1)
test = today - timedelta(days=y_test_length-1)
prediction = pd.date_range(start=test_data.index[0], end=test_data.index[-1], freq='D')
test_dates = pd.date_range(start=test_data.index[0], end=test_data.index[-1], freq='D')

# Use the generated dates as the index of the DataFrame
y_pred_df['Date'] = prediction

y_test_df['Date'] = test_dates

# Set the index of the dataframes to be the 'Date' column
y_pred_df.set_index('Date', inplace=True)
y_test_df.set_index('Date', inplace=True)

# %%
y_test_df.to_csv("y_BTC_case1.csv")
y_test_df
# Out:
#                Adj Close
# Date
# 2021-06-14  40218.476562
# 2021-06-15  40406.269531
# 2021-06-16  38347.062500
# 2021-06-17  38053.503906
# 2021-06-18  35787.246094
# ...                  ...
# 2022-12-26  16919.804688
# 2022-12-27  16717.173828
# 2022-12-28  16552.572266
# 2022-12-29  16642.341797
# 2022-12-30  16602.585938
#
# [565 rows x 1 columns]

# %%
y_pred_df.to_csv("y_pred_BTC_case1.csv") 
y_pred_df
# Out:
#                Adj Close
# Date
# 2021-06-14  39943.117188
# 2021-06-15  40227.035156
# 2021-06-16  38747.332031
# 2021-06-17  38292.828125
# 2021-06-18  36235.671875
# ...                  ...
# 2022-12-26  16765.343750
# 2022-12-27  16748.097656
# 2022-12-28  16624.855469
# 2022-12-29  16556.433594
# 2022-12-30  16507.611328
#
# [565 rows x 1 columns]

# %%
plt.figure(figsize=(13, 6))
plt.plot(y_pred_df, label='Predictions')
plt.plot(y_test_df, label='Test Data')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
names = cycle(['Predictions', 'Test Data'])

fig = go.Figure()
fig.add_trace(go.Scatter(x=y_test_df.index, y=y_pred_df['Adj Close'], name='Predictions',
                         line=dict(width=2, color='blue')))
fig.add_trace(go.Scatter(x=y_test_df.index, y=y_test_df['Adj Close'], name='Test Data',
                         line=dict(width=2, color='red')))
fig.update_layout(xaxis_title='Date', yaxis_title='Price',
                  font_size=15, font_color='black', legend_title_text=' Parameters',title = 'Predictions For BTC case1 (Bi-LSTM)')
fig.show()

# %%
# Step 1: Data cleaning

data_new = yf.download(tickers='BTC-USD', period='max', interval='1d')
data_new.dropna(inplace=True)
data_new
# Out:
# [*********************100%***********************]  1 of 1 completed
#                     Open          High           Low         Close  \
# Date
# 2014-09-17    465.864014    468.174011    452.421997    457.334015
# 2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2023-04-23  27816.144531  27820.244141  27400.314453  27591.384766
# 2023-04-24  27591.730469  27979.982422  27070.849609  27525.339844
# 2023-04-25  27514.873047  28371.078125  27207.931641  28307.597656
# 2023-04-26  28300.058594  29995.837891  27324.548828  28422.701172
# 2023-04-27  28426.058594  29838.089844  28426.058594  29427.089844
#
#                Adj Close       Volume
# Date
# 2014-09-17    457.334015     21056800
# 2014-09-18    424.440002     34483200
# 2014-09-19    394.795990     37919700
# 2014-09-20    408.903992     36863600
# 2014-09-21    398.821014     26580100
# ...                  ...          ...
# 2023-04-23  27591.384766  12785446832
# 2023-04-24  27525.339844  17703288330
# 2023-04-25  28307.597656  17733373139
# 2023-04-26  28422.701172  31854242019
# 2023-04-27  29427.089844  27240368128
#
# [3145 rows x 6 columns]

# %%
# Step 2: Feature engineering
data_new['RSI']       = ta.rsi(data_new.Close, length=15)
data_new['EMA_short'] = ta.ema(data_new.Close, length=20)
data_new['EMA_long']  = ta.ema(data_new.Close, length=100)
data_new.dropna(inplace=True)
data_new.reset_index(inplace=True)
data_new.drop(['Close'], axis=1, inplace=True)
# Setting the index
data_new.set_index('Date', inplace=True)

# Dropping any NaNs
data_new.dropna(inplace=True)

data_new.info()
data_new.tail(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3046 entries, 2014-12-25 to 2023-04-27
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       3046 non-null   float64
#  1   High       3046 non-null   float64
#  2   Low        3046 non-null   float64
#  3   Adj Close  3046 non-null   float64
#  4   Volume     3046 non-null   int64
#  5   RSI        3046 non-null   float64
#  6   EMA_short  3046 non-null   float64
#  7   EMA_long   3046 non-null   float64
# dtypes: float64(7), int64(1)
# memory usage: 214.2 KB
#                     Open          High           Low     Adj Close  \
# Date
# 2023-04-18  29449.091797  30470.302734  29154.849609  30397.552734
# 2023-04-19  30394.187500  30411.054688  28669.898438  28822.679688
# 2023-04-20  28823.683594  29076.400391  28037.257812  28245.988281
# 2023-04-21  28249.230469  28349.968750  27177.365234  27276.910156
# 2023-04-22  27265.894531  27872.142578  27169.570312  27817.500000
# 2023-04-23  27816.144531  27820.244141  27400.314453  27591.384766
# 2023-04-24  27591.730469  27979.982422  27070.849609  27525.339844
# 2023-04-25  27514.873047  28371.078125  27207.931641  28307.597656
# 2023-04-26  28300.058594  29995.837891  27324.548828  28422.701172
# 2023-04-27  28426.058594  29838.089844  28426.058594  29427.089844
#
#                  Volume        RSI     EMA_short      EMA_long
# Date
# 2023-04-18  19480529496  65.327376  29101.983885  24984.228214
# 2023-04-19  24571565421  52.260559  29075.383485  25060.237154
# 2023-04-20  21340360360  48.457795  28996.393465  25123.321335
# 2023-04-21  20759504330  42.844716  28832.633150  25165.966658
# 2023-04-22  13125734602  46.545503  28735.953803  25218.472269
# 2023-04-23  12785446832  45.232947  28626.947228  25265.460635
# 2023-04-24  17703288330  44.837260  28522.032239  25310.210718
# 2023-04-25  17733373139  50.349114  28501.609898  25369.564915
# 2023-04-26  31854242019  51.119118  28494.094781  25430.023059
# 2023-04-27  27240368128  57.308953  28582.951453  25509.172896

# %%
future_data = data_new.iloc[-30:, :]
future_data = future_data.values
future_data = pd.DataFrame(future_data, columns=["Open", "High", "Low", "Adj Close", "Volume", "RSI",
                                                 "EMA_short", "EMA_long"])

# Get the length of future_data
future_length = future_data.shape[0]

# Generate dates for the next 30 days
today = pd.Timestamp.now().date()
future_dates = today + timedelta(days=1)

future = pd.date_range(start=future_dates, end=today +
                       timedelta(days=30), freq='D')

# Generate dates for the next 10 days for predict
today = pd.Timestamp.now().date()
future_dates_pred = pd.date_range(start=today, periods=10, freq='D')

# Use the generated dates as the index of the DataFrame
future_data['Date'] = future

# Set the index of the dataframes to be the 'Date' column
future_data.set_index('Date', inplace=True)

future_data.tail(10)
x_future_data = future_data.drop(['Adj Close'], axis=1).values
y_future_data = future_data['Adj Close'].values
y_future_data = y_future_data.reshape(-1, 1)

print("x_future_data:", x_future_data.shape)
print("y_future_data:", y_future_data.shape)

# x_future_data= np.reshape(x_future_data, (x_future_data.shape[0], 1, x_future_data.shape[1]))

print("x_future_data:", x_future_data.shape)
x_future_data = scaler.fit_transform(x_future_data)
y_future_data = scaler.fit_transform(y_future_data)
for i in range(10):
    future_data_temp = x_future_data[i:i+30, :]
    # future_data_temp = future_data_temp.reshape(-1, 1)
    print("future_data_temp", future_data_temp.shape)
# Out:
# x_future_data: (30, 7)
# y_future_data: (30, 1)
# x_future_data: (30, 7)
# future_data_temp (30, 7)
# future_data_temp (29, 7)
# future_data_temp (28, 7)
# future_data_temp (27, 7)
# future_data_temp (26, 7)
# future_data_temp (25, 7)
# future_data_temp (24, 7)
# future_data_temp (23, 7)
# future_data_temp (22, 7)
# future_data_temp (21, 7)

# %%
# Initialize a numpy array to store the predictions
prediction = np.zeros((10, 1))

for i in range(10):
    future_data_temp = x_future_data[i:i+30, :]

    print("future_data_temp1", future_data_temp.shape)
    future_data_temp = np.reshape(future_data_temp, (future_data_temp.shape[0],
                                                     1, future_data_temp.shape[1]))
    pred = model.predict(future_data_temp)
    print("future_data_temp2", future_data_temp.shape)
    print('---------------------------------------------------')
    prediction[i][0] = pred[0][0]
    x_future_data[i+future_data_temp.shape[0]-1][0] = pred[0][0]
print('3', future_data.shape)
print('prediction:', prediction.shape)
# Reverse the MinMaxScaler
y_future_data = y_future_data.reshape(-1, 1)
y_future_data = scaler.inverse_transform(y_future_data)
prediction = scaler.inverse_transform(prediction)

# Create a new dataframe with the predicted values and the dates as the index
prediction_df = pd.DataFrame(
    prediction, index=future_dates_pred, columns=['Adj Close'])
print('y_future_data', y_future_data.shape)
# Get the length of future_data

y_future_data = pd.DataFrame(y_future_data,  columns=['Adj Close'])

future_length = future_data.shape[0]
test = today - timedelta(days=future_length-1)
test_dates = pd.date_range(start=test, end=today, freq='D')
# Use the generated dates as the index of the DataFrame


y_future_data['Date'] = test_dates

# Set the index of the dataframes to be the 'Date' column

y_future_data.set_index('Date', inplace=True)
# Out:
# future_data_temp1 (30, 7)
# 1/1 [==============================] - 0s 63ms/step
# future_data_temp2 (30, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (29, 7)
# 1/1 [==============================] - 0s 97ms/step
# future_data_temp2 (29, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (28, 7)
# 1/1 [==============================] - 0s 97ms/step
# future_data_temp2 (28, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (27, 7)
# 1/1 [==============================] - 0s 85ms/step
# future_data_temp2 (27, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (26, 7)
# 1/1 [==============================] - 0s 117ms/step
# future_data_temp2 (26, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (25, 7)
# 1/1 [==============================] - 0s 91ms/step
# future_data_temp2 (25, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (24, 7)
# 1/1 [==============================] - 0s 127ms/step
# future_data_temp2 (24, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (23, 7)
# 1/1 [==============================] - 0s 101ms/step
# future_data_temp2 (23, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (22, 7)
# 1/1 [==============================] - 0s 79ms/step
# future_data_temp2 (22, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (21, 7)
# 1/1 [==============================] - 0s 76ms/step
# future_data_temp2 (21, 1, 7)
# ---------------------------------------------------
# 3 (30, 8)
# prediction: (10, 1)
# y_future_data (30, 1)

# %%
prediction_df
# Out:
#                Adj Close
# 2023-04-28  27880.204126
# 2023-04-29  28118.015377
# 2023-04-30  27889.976347
# 2023-05-01  28192.969674
# 2023-05-02  27873.804896
# 2023-05-03  27688.080235
# 2023-05-04  27966.481657
# 2023-05-05  28148.143696
# 2023-05-06  27747.473004
# 2023-05-07  27778.410873

# %%
y_future_data
# Out:
#                Adj Close
# Date
# 2023-03-30  28348.441406
# 2023-03-31  28033.562500
# 2023-04-01  28478.484375
# 2023-04-02  28411.035156
# 2023-04-03  28199.308594
# 2023-04-04  27790.220703
# 2023-04-05  28168.089844
# 2023-04-06  28177.984375
# 2023-04-07  28044.140625
# 2023-04-08  27925.859375
# 2023-04-09  27947.794922
# 2023-04-10  28333.050781
# 2023-04-11  29652.980469
# 2023-04-12  30235.058594
# 2023-04-13  30139.052734
# 2023-04-14  30399.066406
# 2023-04-15  30485.699219
# 2023-04-16  30318.496094
# 2023-04-17  30315.355469
# 2023-04-18  29445.044922
# 2023-04-19  30397.552734
# 2023-04-20  28822.679688
# 2023-04-21  28245.988281
# 2023-04-22  27276.910156
# 2023-04-23  27817.500000
# 2023-04-24  27591.384766
# 2023-04-25  27525.339844
# 2023-04-26  28307.597656
# 2023-04-27  28422.701172
# 2023-04-28  29427.089844

# %%
names = cycle(['Predictions next 10 day', 'Actual data '])

fig = go.Figure()

fig.add_trace(go.Scatter(x=y_future_data.index, y=y_future_data['Adj Close'], name='Actual data ',
                         line=dict(width=2, color='red')))
fig.add_trace(go.Scatter(x=prediction_df.index, y=prediction_df['Adj Close'], name='Predictions next 10 day',
                         line=dict(width=2, color='blue')))

fig.add_shape(type='line',
              x0=prediction_df.index[0], y0=prediction_df['Adj Close'][0],
              x1=y_future_data.index[-1], y1=y_future_data['Adj Close'][-1],
              line=dict(color='grey', width=2))
fig.update_layout(xaxis_title='Date', yaxis_title='Price',
                  font_size=15, font_color='black', legend_title_text=' Parameters')
fig.show()

# %%
actual_x = y_future_data.index
actual_y = y_future_data['Adj Close']
pred_x = prediction_df.index
pred_y = prediction_df['Adj Close']

fig = go.Figure()
fig.add_trace(go.Scatter(x=actual_x, y=actual_y, name='Actual Data'))
fig.add_trace(go.Scatter(x=pred_x, y=pred_y,
              name='Predictions Data for 10 day'))

fig.add_shape(type='line',
              x0=actual_x[-1], y0=actual_y[-1],
              x1=pred_x[0], y1=pred_y[0],
              line=dict(color='grey', width=2))

fig.update_layout(
    xaxis_title='Date',
    yaxis_title='Price',
    title='predict next 10 day '
)

fig.show()

# %%
future_data_all = data_new.copy()

future_data_all = pd.DataFrame(future_data_all, index= future_data_all.index, 
                               columns=future_data_all.columns)

x_future_data_all = future_data_all.drop(['Adj Close'], axis=1).values
y_future_data_all = future_data_all['Adj Close'].values
y_future_data_all = y_future_data_all.reshape(-1, 1)

print("x_future_data:", x_future_data_all.shape)
print("y_future_data:", y_future_data_all.shape)
# Out:
# x_future_data: (3046, 7)
# y_future_data: (3046, 1)

# %%
x_future_data_all = scaler.fit_transform(x_future_data_all)
y_future_data_all = scaler.fit_transform(y_future_data_all)

x_future_data_all = np.reshape(x_future_data_all, (x_future_data_all.shape[0], 1, x_future_data_all.shape[1]))

pred_future_all = model.predict(x_future_data_all)
# Out:
# 96/96 [==============================] - 1s 8ms/step

# %%
y_future_data_all = scaler.inverse_transform(y_future_data_all)
pred_future_all = scaler.inverse_transform(pred_future_all)
y_future_all = pd.DataFrame(y_future_data_all, index= future_data_all.index,  columns=['Adj Close'])
pred_future_all_df = pd.DataFrame(pred_future_all, index= future_data_all.index,  columns=['Adj Close'])
print("pred_future_all:", pred_future_all.shape)
print("y_future_data:", y_future_data_all.shape)
# Out:
# pred_future_all: (3046, 1)
# y_future_data: (3046, 1)

# %%
names = cycle(['Predictions', 'Test Data'])

fig = go.Figure()
fig.add_trace(go.Scatter(x=y_future_all.index, y=pred_future_all_df['Adj Close'], name='Predictions',
                         line=dict(width=2, color='blue')))
fig.add_trace(go.Scatter(x=y_future_all.index, y=y_future_all['Adj Close'], name='Actual Data',
                         line=dict(width=2, color='red')))
fig.add_trace(go.Scatter(x=prediction_df.index, y=prediction_df['Adj Close'], name='Predictions next 10 day',
                         line=dict(width=2, color='gray')))
fig.add_shape(type='line',
              x0=prediction_df.index[0], y0=prediction_df['Adj Close'][0],
              x1=pred_future_all_df.index[-1], y1=pred_future_all_df['Adj Close'][-1],
              line=dict(color='grey', width=2))

fig.update_layout(xaxis_title='Date', yaxis_title='Price',
                  font_size=15, font_color='black', legend_title_text=' Parameters', title = 'Bi-LSTM Predictions BTC case1 10 Days')
fig.show()
