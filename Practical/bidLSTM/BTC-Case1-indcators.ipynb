# %%
import pandas as pd
import numpy as np
import pandas_ta as ta
import yfinance as yf
from datetime import timedelta
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error 
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout,Bidirectional

# For PLotting we will use these library

import matplotlib.pyplot as plt

from itertools import cycle
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

# %%
# Step 1: Data cleaning
data = yf.download(tickers='BTC-usd', start='2014-12-31', end='2022-12-31', interval='1d')
#data = yf.download(tickers='BTC-USD', period='max', interval='1d')
data.dropna(inplace=True)
data
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Step 1: Data cleaning
# ----> 2 data = yf.download(tickers='BTC-usd', start='2014-12-31', end='2022-12-31', interval='1d')
#       3 #data = yf.download(tickers='BTC-USD', period='max', interval='1d')
#       4 data.dropna(inplace=True)
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\yfinance\multi.py:118, in download(tickers, start, end, actions, threads, ignore_tz, group_by, auto_adjust, back_adjust, keepna, progress, period, show_errors, interval, prepost, proxy, rounding, timeout, **kwargs)
#     111         _download_one_threaded(ticker, period=period, interval=interval,
#     112                                start=start, end=end, prepost=prepost,
#     113                                actions=actions, auto_adjust=auto_adjust,
#     114                                back_adjust=back_adjust, keepna=keepna,
#     115                                progress=(progress and i > 0), proxy=proxy,
#     116                                rounding=rounding, timeout=timeout)
#     117     while len(shared._DFS) < len(tickers):
# --> 118         _time.sleep(0.01)
#     120 # download synchronously
#     121 else:
#     122     for i, ticker in enumerate(tickers):
#
# KeyboardInterrupt:

# %%
# Step 2: Feature engineering
data['RSI']       = ta.rsi(data.Close, length=15)
data['EMA_short'] = ta.ema(data.Close, length=20)
data['EMA_long']  = ta.ema(data.Close, length=100)
data.dropna(inplace=True)
data.reset_index(inplace=True)
data.drop(['Close'], axis=1, inplace=True)
# Setting the index
data.set_index('Date', inplace=True)

# Dropping any NaNs
data.dropna(inplace=True)

data.info()
data.tail(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2823 entries, 2015-04-09 to 2022-12-30
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2823 non-null   float64
#  1   High       2823 non-null   float64
#  2   Low        2823 non-null   float64
#  3   Adj Close  2823 non-null   float64
#  4   Volume     2823 non-null   int64
#  5   RSI        2823 non-null   float64
#  6   EMA_short  2823 non-null   float64
#  7   EMA_long   2823 non-null   float64
# dtypes: float64(7), int64(1)
# memory usage: 198.5 KB
#                     Open          High           Low     Adj Close  \
# Date
# 2022-12-21  16904.527344  16916.800781  16755.912109  16817.535156
# 2022-12-22  16818.380859  16866.673828  16592.408203  16830.341797
# 2022-12-23  16829.644531  16905.218750  16794.458984  16796.953125
# 2022-12-24  16796.976562  16864.703125  16793.527344  16847.755859
# 2022-12-25  16847.505859  16860.554688  16755.253906  16841.986328
# 2022-12-26  16842.250000  16920.123047  16812.369141  16919.804688
# 2022-12-27  16919.291016  16959.845703  16642.072266  16717.173828
# 2022-12-28  16716.400391  16768.169922  16497.556641  16552.572266
# 2022-12-29  16552.322266  16651.755859  16508.683594  16642.341797
# 2022-12-30  16641.330078  16643.427734  16408.474609  16602.585938
#
#                  Volume        RSI     EMA_short      EMA_long
# Date
# 2022-12-21  14882945045  46.354643  16990.208226  18631.716275
# 2022-12-22  16441573050  46.537922  16974.982852  18596.045493
# 2022-12-23  15329265213  46.097985  16958.027640  18560.419901
# 2022-12-24   9744636213  46.916068  16947.525565  18526.505762
# 2022-12-25  11656379938  46.829585  16937.474209  18493.148941
# 2022-12-26  11886957804  48.209222  16935.791398  18461.993610
# 2022-12-27  15748580239  44.954914  16914.970677  18427.442723
# 2022-12-28  17005713920  42.460302  16880.456542  18390.316575
# 2022-12-29  14472237479  44.267447  16857.778948  18355.703213
# 2022-12-30  15929162910  43.617436  16833.474851  18320.988020

# %%
data= data.to_csv('btc-2015-2022_case1.csv')

# %%
from datetime import datetime

def date_parser(date_str):
    date_obj = datetime.strptime(date_str, '%m/%d/%Y')
    return date_obj.strftime('%m-%d-%Y')

# %%
data_csv = pd.read_csv('btc-2015-2022_case1.csv')
data_csv.dropna(inplace=True)
# Setting the index

data_csv.set_index('Date', inplace=True)
# Dropping any NaNs
data_csv.dropna(inplace=True)
data_csv.info()
data_csv.tail(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2823 entries, 2015-04-09 to 2022-12-30
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2823 non-null   float64
#  1   High       2823 non-null   float64
#  2   Low        2823 non-null   float64
#  3   Adj Close  2823 non-null   float64
#  4   Volume     2823 non-null   int64
#  5   RSI        2823 non-null   float64
#  6   EMA_short  2823 non-null   float64
#  7   EMA_long   2823 non-null   float64
# dtypes: float64(7), int64(1)
# memory usage: 198.5+ KB
#                     Open          High           Low     Adj Close  \
# Date
# 2022-12-21  16904.527344  16916.800781  16755.912109  16817.535156
# 2022-12-22  16818.380859  16866.673828  16592.408203  16830.341797
# 2022-12-23  16829.644531  16905.218750  16794.458984  16796.953125
# 2022-12-24  16796.976562  16864.703125  16793.527344  16847.755859
# 2022-12-25  16847.505859  16860.554688  16755.253906  16841.986328
# 2022-12-26  16842.250000  16920.123047  16812.369141  16919.804688
# 2022-12-27  16919.291016  16959.845703  16642.072266  16717.173828
# 2022-12-28  16716.400391  16768.169922  16497.556641  16552.572266
# 2022-12-29  16552.322266  16651.755859  16508.683594  16642.341797
# 2022-12-30  16641.330078  16643.427734  16408.474609  16602.585938
#
#                  Volume        RSI     EMA_short      EMA_long
# Date
# 2022-12-21  14882945045  46.354643  16990.208226  18631.716275
# 2022-12-22  16441573050  46.537922  16974.982852  18596.045493
# 2022-12-23  15329265213  46.097985  16958.027640  18560.419901
# 2022-12-24   9744636213  46.916068  16947.525565  18526.505762
# 2022-12-25  11656379938  46.829585  16937.474209  18493.148941
# 2022-12-26  11886957804  48.209222  16935.791398  18461.993610
# 2022-12-27  15748580239  44.954914  16914.970677  18427.442723
# 2022-12-28  17005713920  42.460302  16880.456542  18390.316575
# 2022-12-29  14472237479  44.267447  16857.778948  18355.703213
# 2022-12-30  15929162910  43.617436  16833.474851  18320.988020

# %%
# Split the data into training and test sets
train_df = data_csv[:int(len(data_csv)*0.8)]
test_df = data_csv[int(len(data_csv)*0.8):]
data_csv.shape
# Out:
# (2823, 8)

# %%
test_data =test_df.copy()

# %%
train_x = train_df.index
train_y = train_df['Adj Close']
test_x = test_df.index
test_y = test_df['Adj Close']

fig = go.Figure()
fig.add_trace(go.Scatter(x=train_x, y=train_y, name='train Data'))
fig.add_trace(go.Scatter(x=test_x, y=test_y, name='Test Data'))

fig.update_layout(
    xaxis_title='Date',
    yaxis_title='Price',
    title='Price over time'
)

fig.show()

# %%
print(train_df.info())
print(test_df.info())
print('test_data', test_data.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2258 entries, 2015-04-09 to 2021-06-13
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2258 non-null   float64
#  1   High       2258 non-null   float64
#  2   Low        2258 non-null   float64
#  3   Adj Close  2258 non-null   float64
#  4   Volume     2258 non-null   int64
#  5   RSI        2258 non-null   float64
#  6   EMA_short  2258 non-null   float64
#  7   EMA_long   2258 non-null   float64
# dtypes: float64(7), int64(1)
# memory usage: 158.8+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 565 entries, 2021-06-14 to 2022-12-30
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       565 non-null    float64
#  1   High       565 non-null    float64
#  2   Low        565 non-null    float64
#  3   Adj Close  565 non-null    float64
#  4   Volume     565 non-null    int64
#  5   RSI        565 non-null    float64
#  6   EMA_short  565 non-null    float64
#  7   EMA_long   565 non-null    float64
# dtypes: float64(7), int64(1)
# memory usage: 39.7+ KB
# None
# test_data (565, 8)

# %%
# Preprocess the data
X_train = train_df.drop(['Adj Close'], axis=1).values
y_train = train_df['Adj Close'].values

X_test = test_df.drop(['Adj Close'], axis=1).values
y_test = test_df['Adj Close'].values

print("x_train", X_train.shape)
print("y_train", y_train.shape)
print("X_test", X_test.shape)
print("y_test", y_test.shape)
# Out:
# x_train (2258, 7)
# y_train (2258,)
# X_test (565, 7)
# y_test (565,)

# %%
scaler  = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test  = scaler.fit_transform(X_test)
y_train = y_train.reshape(-1,1)
y_train = scaler.fit_transform(y_train)
y_test  = y_test.reshape(-1,1)
y_test  = scaler.fit_transform(y_test)
#------------------------------------------
print("x_train", X_train.shape)
print("y_train", y_train.shape)
print("X_test", X_test.shape)
print("y_test", y_test.shape)
# Out:
# x_train (2258, 7)
# y_train (2258, 1)
# X_test (565, 7)
# y_test (565, 1)

# %%
# Step 5: Reshaping the data
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

print('X_train', X_train.shape)
print('y_train', y_train.shape)
print('X_test', X_test.shape)
print('Y_test', y_test.shape)
print('X_train.shape[1]', X_train.shape[1])
print('X_train.shape[2]', X_train.shape[2])
# Out:
# X_train (2258, 1, 7)
# y_train (2258, 1)
# X_test (565, 1, 7)
# Y_test (565, 1)
# X_train.shape[1] 1
# X_train.shape[2] 7

# %%
# Step 6: Building the LSTM model (cont.)

model = Sequential()
model.add(Bidirectional(LSTM(100, input_shape=( X_train.shape[1], X_train.shape[2]),
                             return_sequences=True, activation='tanh')))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(100, return_sequences=True, activation='tanh')))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(75, return_sequences=True, activation='tanh')))
model.add(Dropout(0.25))
model.add(Bidirectional(LSTM(50, activation='tanh')))
model.add(Dropout(0.3))
model.add(Dense(1, activation='linear'))
model.compile(loss='mean_squared_error', optimizer='adam',
              metrics=['accuracy', 'mean_absolute_error'])

# %%
# Step 7: Training and evaluating the model
history = model.fit(X_train, y_train, epochs=1000, batch_size=32)
# Out:
# Epoch 1/1000
# 71/71 [==============================] - 29s 23ms/step - loss: 0.0166 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0691
# Epoch 2/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 0.0011 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0174
# Epoch 3/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 8.6875e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0149
# Epoch 4/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 7.6602e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0141
# Epoch 5/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 7.9562e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0141
# Epoch 6/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 6.8354e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0133
# Epoch 7/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 7.5737e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0140
# Epoch 8/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 5.9507e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0134
# Epoch 9/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 9.0714e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0174
# Epoch 10/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 6.3172e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0129
# Epoch 11/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 6.4853e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0140
# Epoch 12/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 4.8779e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0125
# Epoch 13/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 4.2911e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0110
# Epoch 14/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 4.9680e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0116
# Epoch 15/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 6.1135e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0137
# Epoch 16/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 5.5212e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0122
# Epoch 17/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 5.4264e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0118
# Epoch 18/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 5.8631e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0132
# Epoch 19/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.8300e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0112
# Epoch 20/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 4.0667e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0109
# Epoch 21/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 6.5496e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0140
# Epoch 22/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 4.4341e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0110
# Epoch 23/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 5.3361e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0124
# Epoch 24/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 5.2832e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0118
# Epoch 25/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 4.7110e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0117
# Epoch 26/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.2265e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0115
# Epoch 27/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 5.5643e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0126
# Epoch 28/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 4.6634e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0113
# Epoch 29/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 5.5134e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0125
# Epoch 30/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 4.7955e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0120
# Epoch 31/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.9792e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0123
# Epoch 32/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 5.4155e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0122
# Epoch 33/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 4.5728e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0116
# Epoch 34/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.8126e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0117
# Epoch 35/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 4.3583e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0109
# Epoch 36/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 5.6095e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0129
# Epoch 37/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 4.8189e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0115
# Epoch 38/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 5.3575e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0127
# Epoch 39/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 5.7006e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0128
# Epoch 40/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.5286e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0114
# Epoch 41/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.8481e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0122
# Epoch 42/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 4.6008e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0116
# Epoch 43/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 5.2396e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0123
# Epoch 44/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 5.2811e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0126
# Epoch 45/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 3.9776e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0108
# Epoch 46/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 4.9815e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0124
# Epoch 47/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 4.8826e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0110
# Epoch 48/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.5266e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0113
# Epoch 49/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 5.0534e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0111
# Epoch 50/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 4.1854e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0113
# Epoch 51/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 4.2650e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0107
# Epoch 52/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 4.6859e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0119
# Epoch 53/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 3.7236e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0107
# Epoch 54/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 3.9092e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0111
# Epoch 55/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 4.0826e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0112
# Epoch 56/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.5670e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0116
# Epoch 57/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.0728e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0106
# Epoch 58/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.3387e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0116
# Epoch 59/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.2365e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0118
# Epoch 60/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 4.8545e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0120
# Epoch 61/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 3.8796e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0111
# Epoch 62/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 4.8039e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0123
# Epoch 63/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.0842e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0112
# Epoch 64/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 5.7190e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0126
# Epoch 65/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.9567e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0121
# Epoch 66/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.6178e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0111
# Epoch 67/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 5.3999e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0125
# Epoch 68/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 4.3922e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0111
# Epoch 69/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 4.7233e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0118
# Epoch 70/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 4.4291e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0112
# Epoch 71/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 4.8141e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0115
# Epoch 72/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 3.8816e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0108
# Epoch 73/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 4.7066e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0118
# Epoch 74/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 5.3916e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0121
# Epoch 75/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 3.8815e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0107
# Epoch 76/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 4.1795e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0117
# Epoch 77/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 4.2735e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0119
# Epoch 78/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 3.2723e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0102
# Epoch 79/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.9262e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0108
# Epoch 80/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.8825e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0113
# Epoch 81/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 4.1347e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0113
# Epoch 82/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 3.7288e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0109
# Epoch 83/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 4.2119e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.
1000
# 71/71 [==============================] - 1s 21ms/step - loss: 3.5454e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0109
# Epoch 251/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 3.8026e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0120
# Epoch 252/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.8148e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0112
# Epoch 253/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 2.8723e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0098
# Epoch 254/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 3.4666e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0101
# Epoch 255/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 3.1167e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0100
# Epoch 256/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 3.2218e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0105
# Epoch 257/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 3.8820e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0110
# Epoch 258/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 4.1572e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0114
# Epoch 259/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 4.1674e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0112
# Epoch 260/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 3.2332e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0101
# Epoch 261/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 3.5265e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0112
# Epoch 262/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 2.9799e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0098
# Epoch 263/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 2.9918e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0099
# Epoch 264/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 3.7342e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0106
# Epoch 265/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 3.1364e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0108
# Epoch 266/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 2.9416e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0096
# Epoch 267/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 3.7563e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0108
# Epoch 268/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 3.5511e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0108
# Epoch 269/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 3.9035e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0115
# Epoch 270/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 2.7930e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0094
# Epoch 271/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.2481e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0096
# Epoch 272/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 3.4782e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0106
# Epoch 273/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 3.7842e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0112
# Epoch 274/1000
# 71/71 [==============================] - 2s 29ms/step - loss: 3.7666e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0104
# Epoch 275/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.0896e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0106
# Epoch 276/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.4043e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0108
# Epoch 277/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 3.6975e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0112
# Epoch 278/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 2.9761e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0100
# Epoch 279/1000
# 71/71 [==============================] - 2s 21ms/step - loss: 3.8580e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0112
# Epoch 280/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 3.4925e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0105
# Epoch 281/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 3.6121e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0107
# Epoch 282/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 2.8347e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0095
# Epoch 283/1000
# 71/71 [==============================] - 2s 21ms/step - loss: 2.6105e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0093
# Epoch 284/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 3.4487e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0111
# Epoch 285/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 3.6240e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0106
# Epoch 286/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 3.6678e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0108
# Epoch 287/1000
# 71/71 [==============================] - 2s 21ms/step - loss: 3.0054e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0101
# Epoch 288/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 3.1334e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0102
# Epoch 289/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 2.7742e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0098
# Epoch 290/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 2.8138e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0096
# Epoch 291/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 2.8854e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0100
# Epoch 292/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 2.6558e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0095
# Epoch 293/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.0613e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0100
# Epoch 294/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 3.3122e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0101
# Epoch 295/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 4.2824e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0118
# Epoch 296/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.1161e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0104
# Epoch 297/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 3.2481e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0104
# Epoch 298/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 3.1602e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0102
# Epoch 299/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 2.8709e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0094
# Epoch 300/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 3.2866e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0104
# Epoch 301/1000
# 71/71 [==============================] - 1s 20ms/step - loss: 3.3741e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0108
# Epoch 302/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.8015e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0108
# Epoch 303/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 3.6209e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0107
# Epoch 304/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 3.6247e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0104
# Epoch 305/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 3.5000e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0104
# Epoch 306/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 3.2765e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0103
# Epoch 307/1000
# 71/71 [==============================] - 2s 27ms/step - loss: 3.1305e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0102
# Epoch 308/1000
# 71/71 [==============================] - 2s 33ms/step - loss: 3.4039e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0104
# Epoch 309/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 2.9727e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0102
# Epoch 310/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 3.4095e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0109
# Epoch 311/1000
# 71/71 [==============================] - 2s 26ms/step - loss: 3.1174e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0100
# Epoch 312/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 2.9818e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0105
# Epoch 313/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 2.9492e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0100
# Epoch 314/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 3.3070e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0105
# Epoch 315/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.4246e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0108
# Epoch 316/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 3.4455e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0099
# Epoch 317/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 3.3898e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0106
# Epoch 318/1000
# 71/71 [==============================] - 2s 24ms/step - loss: 3.6772e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0108
# Epoch 319/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 3.2872e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0114
# Epoch 320/1000
# 71/71 [==============================] - 2s 25ms/step - loss: 3.2770e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0102
# Epoch 321/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 2.7582e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0099
# Epoch 322/1000
# 71/71 [==============================] - 2s 22ms/step - loss: 2.8646e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0094
# Epoch 323/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 2.9020e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0098
# Epoch 324/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 3.5066e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0103
# Epoch 325/1000
# 71/71 [==============================] - 2s 28ms/step - loss: 3.2237e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0098
# Epoch 326/1000
# 71/71 [==============================] - 1s 21ms/step - loss: 2.6369e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0098
# Epoch 327/1000
# 71/71 [==============================] - 2s 23ms/step - loss: 3.2850e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0104
# Epoch 328/1000
# 71/71 [==============================] - 1s 21ms/step - loss:
-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0096
# Epoch 972/1000
# 71/71 [==============================] - 3s 36ms/step - loss: 2.4972e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0090
# Epoch 973/1000
# 71/71 [==============================] - 3s 42ms/step - loss: 2.7207e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0094
# Epoch 974/1000
# 71/71 [==============================] - 3s 39ms/step - loss: 3.0187e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0097
# Epoch 975/1000
# 71/71 [==============================] - 3s 38ms/step - loss: 3.0511e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0097
# Epoch 976/1000
# 71/71 [==============================] - 2s 35ms/step - loss: 2.5531e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0089
# Epoch 977/1000
# 71/71 [==============================] - 3s 36ms/step - loss: 2.7569e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0094
# Epoch 978/1000
# 71/71 [==============================] - 2s 35ms/step - loss: 3.0740e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0098
# Epoch 979/1000
# 71/71 [==============================] - 2s 34ms/step - loss: 2.7540e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0096
# Epoch 980/1000
# 71/71 [==============================] - 3s 36ms/step - loss: 2.6429e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0090
# Epoch 981/1000
# 71/71 [==============================] - 3s 35ms/step - loss: 2.7974e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0093
# Epoch 982/1000
# 71/71 [==============================] - 3s 36ms/step - loss: 3.3537e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0102
# Epoch 983/1000
# 71/71 [==============================] - 2s 34ms/step - loss: 2.7202e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0095
# Epoch 984/1000
# 71/71 [==============================] - 2s 35ms/step - loss: 2.7465e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0097
# Epoch 985/1000
# 71/71 [==============================] - 2s 34ms/step - loss: 2.4534e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0091
# Epoch 986/1000
# 71/71 [==============================] - 2s 34ms/step - loss: 2.7575e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0093
# Epoch 987/1000
# 71/71 [==============================] - 3s 37ms/step - loss: 2.4092e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0089
# Epoch 988/1000
# 71/71 [==============================] - 3s 37ms/step - loss: 2.3360e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0091
# Epoch 989/1000
# 71/71 [==============================] - 3s 36ms/step - loss: 2.6382e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0092
# Epoch 990/1000
# 71/71 [==============================] - 2s 34ms/step - loss: 2.2924e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0089
# Epoch 991/1000
# 71/71 [==============================] - 3s 36ms/step - loss: 2.8041e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0097
# Epoch 992/1000
# 71/71 [==============================] - 2s 33ms/step - loss: 2.3368e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0090
# Epoch 993/1000
# 71/71 [==============================] - 2s 35ms/step - loss: 2.7545e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0093
# Epoch 994/1000
# 71/71 [==============================] - 3s 38ms/step - loss: 2.4795e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0088
# Epoch 995/1000
# 71/71 [==============================] - 3s 36ms/step - loss: 3.2714e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0095
# Epoch 996/1000
# 71/71 [==============================] - 3s 36ms/step - loss: 2.9284e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0097
# Epoch 997/1000
# 71/71 [==============================] - 3s 38ms/step - loss: 2.5700e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0094
# Epoch 998/1000
# 71/71 [==============================] - 2s 33ms/step - loss: 3.0060e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0095
# Epoch 999/1000
# 71/71 [==============================] - 3s 36ms/step - loss: 2.7509e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0096
# Epoch 1000/1000
# 71/71 [==============================] - 3s 40ms/step - loss: 2.5748e-04 - accuracy: 8.8574e-04 - mean_absolute_error: 0.0095

# %%
def visualize_training_results(results):
    """
    Plots the loss and accuracy for the training and testing data
    """
    history = results.history

    plt.figure(figsize=(16, 5))
    # plt.plot(history['val_mean_absolute_error'])
    plt.plot(history['mean_absolute_error'])
    plt.legend(['val_mean_absolute_error', 'mean_absolute_error'])
    plt.title('mean_absolute_error')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.show()

    plt.figure(figsize=(16, 5))
    # plt.plot(history['val_loss'])
    plt.plot(history['loss'])
    plt.legend(['val_loss', 'loss'])
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.show()

    plt.figure(figsize=(16, 5))
    # plt.plot(history['val_accuracy'])
    plt.plot(history['accuracy'])
    plt.legend(['val_accuracy', 'accuracy'])
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.show()

# %%
visualize_training_results(history)

# %%
# Evaluate the model on the test set
mse, accuracy, mae = model.evaluate(X_test, y_test)
# Out:
# 18/18 [==============================] - 10s 12ms/step - loss: 1.7706e-04 - accuracy: 0.0035 - mean_absolute_error: 0.0097

# %%
# Step 8: Tuning the Hyperparameters
# You can use techniques such as grid search or random search to find the best values for the model's hyperparameters

# Step 9: Testing the model
y_pred = model.predict(X_test)
print('y_pred', y_pred.shape)
print('y_test', y_test.shape)



# evaluat
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mape = 100 * np.mean(np.abs((y_test - y_pred) / y_test))
rmse = np.sqrt(mean_squared_error(y_test, y_pred))


print("MAPE: {:.4f}%".format(mape))
print("RMSE: {:.4f}".format(rmse))
print("MSE: {:.4f}".format(mse))
print("MAE:{:.4f}".format(mae))
# Out:
# 18/18 [==============================] - 14s 10ms/step
# y_pred (565, 1)
# y_test (565, 1)
# MAPE: inf%
# RMSE: 0.0133
# MSE: 0.0002
# MAE:0.0097
# C:\Users\pc\AppData\Local\Temp\ipykernel_12392\3263926648.py:14: RuntimeWarning:
#
# divide by zero encountered in divide

# %%
# convert to original data
y_pred = scaler.inverse_transform(y_pred)
y_test= scaler.inverse_transform(y_test)

# evaluat
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mape = 100 * np.mean(np.abs((y_test - y_pred) / y_test))
rmse = np.sqrt(mean_squared_error(y_test, y_pred))


print("MAPE: {:.4f}%".format(mape))
print("RMSE: {:.4f}".format(rmse))
print("MSE: {:.4f}".format(mse))
print("MAE:{:.4f}".format(mae))
# Out:
# MAPE: 1.4745%
# RMSE: 688.9960
# MSE: 474715.5326
# MAE:502.9364

# %%
y_pred_df = pd.DataFrame(y_pred, columns=["Adj Close"])
y_test_df = pd.DataFrame(y_test, columns=["Adj Close"])

# Get the length of y_pred
y_pred_length = y_pred.shape[0]
y_test_length = y_test.shape[0]

# Generate dates for the next y_pred_length days 
today = pd.Timestamp.now().date()
prediction_dates = today - timedelta(days=y_pred_length-1)
test = today - timedelta(days=y_test_length-1)
prediction = pd.date_range(start=test_data.index[0], end=test_data.index[-1], freq='D')
test_dates = pd.date_range(start=test_data.index[0], end=test_data.index[-1], freq='D')

# Use the generated dates as the index of the DataFrame
y_pred_df['Date'] = prediction

y_test_df['Date'] = test_dates

# Set the index of the dataframes to be the 'Date' column
y_pred_df.set_index('Date', inplace=True)
y_test_df.set_index('Date', inplace=True)

# %%
#y_test_df.to_csv("y_test_2021_2022.csv")
y_test_df
# Out:
#                Adj Close
# Date
# 2021-06-14  40218.476562
# 2021-06-15  40406.269531
# 2021-06-16  38347.062500
# 2021-06-17  38053.503906
# 2021-06-18  35787.246094
# ...                  ...
# 2022-12-26  16919.804688
# 2022-12-27  16717.173828
# 2022-12-28  16552.572266
# 2022-12-29  16642.341797
# 2022-12-30  16602.585938
#
# [565 rows x 1 columns]

# %%
#y_pred_df.to_csv("y_pred_2021_2022.csv")  # index=False to exclude index column in CSV
y_pred_df
# Out:
#                Adj Close
# Date
# 2021-06-14  40003.500000
# 2021-06-15  40274.515625
# 2021-06-16  38791.464844
# 2021-06-17  38355.023438
# 2021-06-18  36266.894531
# ...                  ...
# 2022-12-26  16949.552734
# 2022-12-27  16944.916016
# 2022-12-28  16828.316406
# 2022-12-29  16752.552734
# 2022-12-30  16704.742188
#
# [565 rows x 1 columns]

# %%
plt.figure(figsize=(13, 6))
plt.plot(y_pred_df, label='Predictions')
plt.plot(y_test_df, label='Test Data')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
names = cycle(['Predictions', 'Test Data'])

fig = go.Figure()
fig.add_trace(go.Scatter(x=y_test_df.index, y=y_pred_df['Adj Close'], name='Predictions',
                         line=dict(width=2, color='blue')))
fig.add_trace(go.Scatter(x=y_test_df.index, y=y_test_df['Adj Close'], name='Test Data',
                         line=dict(width=2, color='red')))
fig.update_layout(xaxis_title='Date', yaxis_title='Price',
                  font_size=15, font_color='black', legend_title_text=' Parameters')
fig.show()

# %%
# Calculate mean absolute percentage error (MAPE)
def mape(y_true, y_pred):
    return 100 * np.mean(np.abs((y_true - y_pred) / y_true))


mape_value = mape(y_test, y_pred)
print(f'MAPE: {mape_value:.4f}%')
# Out:
# MAPE: 1.4745%

# %%
def smape(y_true, y_pred):
    return 200 * np.mean(np.abs(y_pred - y_true) / (np.abs(y_pred) + np.abs(y_true)))


SMAPE1 = smape(y_test, y_pred)
print("smape: {:.4f}%".format(SMAPE1))
# Out:
# smape: 1.4711%

# %%
# Step 1: Data cleaning

data_new = yf.download(tickers='BTC-USD', period='max', interval='1d')
data_new.dropna(inplace=True)
data_new
# Out:
# [*********************100%***********************]  1 of 1 completed
#                     Open          High           Low         Close  \
# Date
# 2014-09-17    465.864014    468.174011    452.421997    457.334015
# 2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2023-03-03  23476.632812  23479.347656  22213.238281  22362.679688
# 2023-03-04  22362.923828  22405.177734  22198.980469  22353.349609
# 2023-03-05  22354.144531  22613.685547  22307.142578  22435.513672
# 2023-03-06  22436.816406  22584.292969  22331.314453  22429.757812
# 2023-03-08  22235.023438  22265.742188  21966.826172  22019.175781
#
#                Adj Close       Volume
# Date
# 2014-09-17    457.334015     21056800
# 2014-09-18    424.440002     34483200
# 2014-09-19    394.795990     37919700
# 2014-09-20    408.903992     36863600
# 2014-09-21    398.821014     26580100
# ...                  ...          ...
# 2023-03-03  22362.679688  26062404610
# 2023-03-04  22353.349609  11166012913
# 2023-03-05  22435.513672  13317001733
# 2023-03-06  22429.757812  17353192895
# 2023-03-08  22019.175781  21267283968
#
# [3094 rows x 6 columns]

# %%
# Step 2: Feature engineering
data_new['RSI']       = ta.rsi(data_new.Close, length=15)
data_new['EMA_short'] = ta.ema(data_new.Close, length=20)
data_new['EMA_long']  = ta.ema(data_new.Close, length=100)
data_new.dropna(inplace=True)
data_new.reset_index(inplace=True)
data_new.drop(['Close'], axis=1, inplace=True)
# Setting the index
data_new.set_index('Date', inplace=True)

# Dropping any NaNs
data_new.dropna(inplace=True)

data_new.info()
data_new.tail(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2995 entries, 2014-12-25 to 2023-03-08
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2995 non-null   float64
#  1   High       2995 non-null   float64
#  2   Low        2995 non-null   float64
#  3   Adj Close  2995 non-null   float64
#  4   Volume     2995 non-null   int64
#  5   RSI        2995 non-null   float64
#  6   EMA_short  2995 non-null   float64
#  7   EMA_long   2995 non-null   float64
# dtypes: float64(7), int64(1)
# memory usage: 210.6 KB
#                     Open          High           Low     Adj Close  \
# Date
# 2023-02-26  23174.150391  23654.367188  23084.220703  23561.212891
# 2023-02-27  23561.451172  23857.890625  23205.878906  23522.871094
# 2023-02-28  23521.837891  23585.384766  23077.650391  23147.353516
# 2023-03-01  23150.929688  23880.632812  23088.626953  23646.550781
# 2023-03-02  23647.019531  23739.138672  23245.021484  23475.466797
# 2023-03-03  23476.632812  23479.347656  22213.238281  22362.679688
# 2023-03-04  22362.923828  22405.177734  22198.980469  22353.349609
# 2023-03-05  22354.144531  22613.685547  22307.142578  22435.513672
# 2023-03-06  22436.816406  22584.292969  22331.314453  22429.757812
# 2023-03-08  22235.023438  22265.742188  21966.826172  22019.175781
#
#                  Volume        RSI     EMA_short      EMA_long
# Date
# 2023-02-26  16644534842  54.009507  23440.593160  21003.205585
# 2023-02-27  22660763494  53.657719  23448.429154  21053.099951
# 2023-02-28  20535363434  50.224893  23419.755283  21094.570319
# 2023-03-01  24662841200  54.381735  23441.354855  21145.104585
# 2023-03-02  20386398516  52.763703  23444.603611  21191.250372
# 2023-03-03  26062404610  43.702150  23341.563237  21214.446992
# 2023-03-04  11166012913  43.634831  23247.447654  21236.999519
# 2023-03-05  13317001733  44.442323  23170.120608  21260.732473
# 2023-03-06  17353192895  44.394587  23099.609865  21283.881489
# 2023-03-08  21267283968  41.026598  22996.711381  21298.441772

# %%
future_data = data_new.iloc[-30:, :]
future_data = future_data.values
future_data = pd.DataFrame(future_data, columns=["Open", "High", "Low", "Adj Close", "Volume", "RSI",
                                                 "EMA_short", "EMA_long"])

# Get the length of future_data
future_length = future_data.shape[0]

# Generate dates for the next 30 days
today = pd.Timestamp.now().date()
future_dates = today + timedelta(days=1)

future = pd.date_range(start=future_dates, end=today +
                       timedelta(days=30), freq='D')

# Generate dates for the next 10 days for predict
today = pd.Timestamp.now().date()
future_dates_pred = pd.date_range(start=today, periods=10, freq='D')

# Use the generated dates as the index of the DataFrame
future_data['Date'] = future

# Set the index of the dataframes to be the 'Date' column
future_data.set_index('Date', inplace=True)

future_data.tail(10)
x_future_data = future_data.drop(['Adj Close'], axis=1).values
y_future_data = future_data['Adj Close'].values
y_future_data = y_future_data.reshape(-1, 1)

print("x_future_data:", x_future_data.shape)
print("y_future_data:", y_future_data.shape)

# x_future_data= np.reshape(x_future_data, (x_future_data.shape[0], 1, x_future_data.shape[1]))

print("x_future_data:", x_future_data.shape)
x_future_data = scaler.fit_transform(x_future_data)
y_future_data = scaler.fit_transform(y_future_data)
for i in range(10):
    future_data_temp = x_future_data[i:i+30, :]
    # future_data_temp = future_data_temp.reshape(-1, 1)
    print("future_data_temp", future_data_temp.shape)
# Out:
# x_future_data: (30, 7)
# y_future_data: (30, 1)
# x_future_data: (30, 7)
# future_data_temp (30, 7)
# future_data_temp (29, 7)
# future_data_temp (28, 7)
# future_data_temp (27, 7)
# future_data_temp (26, 7)
# future_data_temp (25, 7)
# future_data_temp (24, 7)
# future_data_temp (23, 7)
# future_data_temp (22, 7)
# future_data_temp (21, 7)

# %%
# Initialize a numpy array to store the predictions
prediction = np.zeros((10, 1))

for i in range(10):
    future_data_temp = x_future_data[i:i+30, :]

    print("future_data_temp1", future_data_temp.shape)
    future_data_temp = np.reshape(future_data_temp, (future_data_temp.shape[0],
                                                     1, future_data_temp.shape[1]))
    pred = model.predict(future_data_temp)
    print("future_data_temp2", future_data_temp.shape)
    print('---------------------------------------------------')
    prediction[i][0] = pred[0][0]
    x_future_data[i+future_data_temp.shape[0]-1][0] = pred[0][0]
print('3', future_data.shape)
print('prediction:', prediction.shape)
# Reverse the MinMaxScaler
y_future_data = y_future_data.reshape(-1, 1)
y_future_data = scaler.inverse_transform(y_future_data)
prediction = scaler.inverse_transform(prediction)

# Create a new dataframe with the predicted values and the dates as the index
prediction_df = pd.DataFrame(
    prediction, index=future_dates_pred, columns=['Adj Close'])
print('y_future_data', y_future_data.shape)
# Get the length of future_data

y_future_data = pd.DataFrame(y_future_data,  columns=['Adj Close'])

future_length = future_data.shape[0]
test = today - timedelta(days=future_length-1)
test_dates = pd.date_range(start=test, end=today, freq='D')
# Use the generated dates as the index of the DataFrame


y_future_data['Date'] = test_dates

# Set the index of the dataframes to be the 'Date' column

y_future_data.set_index('Date', inplace=True)
# Out:
# future_data_temp1 (30, 7)
# 1/1 [==============================] - 0s 371ms/step
# future_data_temp2 (30, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (29, 7)
# 1/1 [==============================] - 0s 330ms/step
# future_data_temp2 (29, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (28, 7)
# 1/1 [==============================] - 0s 323ms/step
# future_data_temp2 (28, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (27, 7)
# 1/1 [==============================] - 1s 706ms/step
# future_data_temp2 (27, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (26, 7)
# 1/1 [==============================] - 0s 350ms/step
# future_data_temp2 (26, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (25, 7)
# 1/1 [==============================] - 0s 185ms/step
# future_data_temp2 (25, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (24, 7)
# 1/1 [==============================] - 0s 240ms/step
# future_data_temp2 (24, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (23, 7)
# 1/1 [==============================] - 0s 195ms/step
# future_data_temp2 (23, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (22, 7)
# 1/1 [==============================] - 0s 119ms/step
# future_data_temp2 (22, 1, 7)
# ---------------------------------------------------
# future_data_temp1 (21, 7)
# 1/1 [==============================] - 0s 162ms/step
# future_data_temp2 (21, 1, 7)
# ---------------------------------------------------
# 3 (30, 8)
# prediction: (10, 1)
# y_future_data (30, 1)

# %%
prediction_df
# Out:
#                Adj Close
# 2023-03-09  22671.972462
# 2023-03-10  22918.186272
# 2023-03-11  22819.424382
# 2023-03-12  22215.858264
# 2023-03-13  21798.355501
# 2023-03-14  21793.234705
# 2023-03-15  21847.259672
# 2023-03-16  21668.324721
# 2023-03-17  21982.689154
# 2023-03-18  23274.456605

# %%
y_future_data
# Out:
#                Adj Close
# Date
# 2023-02-08  22760.109375
# 2023-02-09  23264.291016
# 2023-02-10  22939.398438
# 2023-02-11  21819.039062
# 2023-02-12  21651.183594
# 2023-02-13  21870.875000
# 2023-02-14  21788.203125
# 2023-02-15  21808.101562
# 2023-02-16  22220.804688
# 2023-02-17  24307.841797
# 2023-02-18  23623.474609
# 2023-02-19  24565.601562
# 2023-02-20  24641.277344
# 2023-02-21  24327.642578
# 2023-02-22  24829.148438
# 2023-02-23  24436.353516
# 2023-02-24  24188.843750
# 2023-02-25  23947.492188
# 2023-02-26  23198.126953
# 2023-02-27  23175.375000
# 2023-02-28  23561.212891
# 2023-03-01  23522.871094
# 2023-03-02  23147.353516
# 2023-03-03  23646.550781
# 2023-03-04  23475.466797
# 2023-03-05  22362.679688
# 2023-03-06  22353.349609
# 2023-03-07  22435.513672
# 2023-03-08  22429.757812
# 2023-03-09  22019.175781

# %%
names = cycle(['Predictions next 10 day', 'Actual data '])

fig = go.Figure()

fig.add_trace(go.Scatter(x=y_future_data.index, y=y_future_data['Adj Close'], name='Actual data ',
                         line=dict(width=2, color='red')))
fig.add_trace(go.Scatter(x=prediction_df.index, y=prediction_df['Adj Close'], name='Predictions next 10 day',
                         line=dict(width=2, color='blue')))

fig.add_shape(type='line',
              x0=prediction_df.index[0], y0=prediction_df['Adj Close'][0],
              x1=y_future_data.index[-1], y1=y_future_data['Adj Close'][-1],
              line=dict(color='grey', width=2))
fig.update_layout(xaxis_title='Date', yaxis_title='Price',
                  font_size=15, font_color='black', legend_title_text=' Parameters')
fig.show()

# %%
actual_x = y_future_data.index
actual_y = y_future_data['Adj Close']
pred_x = prediction_df.index
pred_y = prediction_df['Adj Close']

fig = go.Figure()
fig.add_trace(go.Scatter(x=actual_x, y=actual_y, name='Actual Data'))
fig.add_trace(go.Scatter(x=pred_x, y=pred_y,
              name='Predictions Data for 10 day'))

fig.add_shape(type='line',
              x0=actual_x[-1], y0=actual_y[-1],
              x1=pred_x[0], y1=pred_y[0],
              line=dict(color='grey', width=2))

fig.update_layout(
    xaxis_title='Date',
    yaxis_title='Price',
    title='predict next 10 day '
)

fig.show()

# %%
names = cycle(['Predictions', 'Test Data'])

fig = go.Figure()
fig.add_trace(go.Scatter(x=y_test_df.index, y=y_pred_df['Adj Close'], name='Predictions',
                         line=dict(width=2, color='blue')))
fig.add_trace(go.Scatter(x=y_test_df.index, y=y_test_df['Adj Close'], name='Test Data',
                         line=dict(width=2, color='red')))
fig.add_trace(go.Scatter(x=prediction_df.index, y=prediction_df['Adj Close'], name='Predictions next 10 day',
                         line=dict(width=2, color='blue')))
fig.add_shape(type='line',
              x0=prediction_df.index[-1], y0=prediction_df['Adj Close'][-1],
              x1=y_pred_df.index[0], y1=y_pred_df['Adj Close'][0],
              line=dict(color='grey', width=2, dash='dot'))

fig.update_layout(xaxis_title='Date', yaxis_title='Price',
                  font_size=15, font_color='black', legend_title_text=' Parameters')
fig.show()
