# %%
import pandas as pd
import numpy as np
import pandas_ta as ta
import yfinance as yf
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error 
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout

# %%
# Step 1: Data cleaning
data = yf.download(tickers='BTC-usd', period='max', interval='1d')
data.dropna(inplace=True)
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                     Open          High           Low         Close  \
# Date
# 2014-09-17    465.864014    468.174011    452.421997    457.334015
# 2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2023-01-19  20686.746094  21163.011719  20685.380859  21086.792969
# 2023-01-20  21085.373047  22692.357422  20919.126953  22676.552734
# 2023-01-21  22677.427734  23282.347656  22511.833984  22777.625000
# 2023-01-22  22777.986328  23056.730469  22387.900391  22720.416016
# 2023-01-23  22700.687500  22940.173828  22673.906250  22782.232422
#
#                Adj Close       Volume
# Date
# 2014-09-17    457.334015     21056800
# 2014-09-18    424.440002     34483200
# 2014-09-19    394.795990     37919700
# 2014-09-20    408.903992     36863600
# 2014-09-21    398.821014     26580100
# ...                  ...          ...
# 2023-01-19  21086.792969  21152848261
# 2023-01-20  22676.552734  28799154319
# 2023-01-21  22777.625000  32442278429
# 2023-01-22  22720.416016  24746386230
# 2023-01-23  22782.232422  25409984512
#
# [3051 rows x 6 columns]

# %%
data.drop([ 'Close'], axis=1, inplace=True)
data
# Out:
#                     Open          High           Low     Adj Close  \
# Date
# 2014-09-17    465.864014    468.174011    452.421997    457.334015
# 2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2023-01-19  20686.746094  21163.011719  20685.380859  21086.792969
# 2023-01-20  21085.373047  22692.357422  20919.126953  22676.552734
# 2023-01-21  22677.427734  23282.347656  22511.833984  22777.625000
# 2023-01-22  22777.986328  23056.730469  22387.900391  22720.416016
# 2023-01-23  22700.687500  22940.173828  22673.906250  22782.232422
#
#                  Volume
# Date
# 2014-09-17     21056800
# 2014-09-18     34483200
# 2014-09-19     37919700
# 2014-09-20     36863600
# 2014-09-21     26580100
# ...                 ...
# 2023-01-19  21152848261
# 2023-01-20  28799154319
# 2023-01-21  32442278429
# 2023-01-22  24746386230
# 2023-01-23  25409984512
#
# [3051 rows x 5 columns]

# %%
# Step 3: Data normalization (cont.)
scaler = MinMaxScaler()
data_close = data[['Adj Close']]
data_close = scaler.fit_transform(data_close)
data_close
# Out:
# array([[0.00414359],
#        [0.00365546],
#        [0.00321557],
#        ...,
#        [0.33536058],
#        [0.33451164],
#        [0.33542895]])

# %%
# Step 4: Splitting the data
X = data[['Open', 'High', 'Low', 'Volume']]
X = scaler.fit_transform(X)
y = data_close
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %%
# Step 5: Reshaping the data
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))
print("x", X.shape)
print('y',y.shape)
print('X_train', X_train.shape)
print('y_train', y_train.shape)
print('X_test', X_test.shape)
print('Y_test', y_test.shape) 
print('X_train.shape[1]', X_train.shape[1])
print('X_train.shape[2]', X_train.shape[2])
# Out:
# x (3051, 4)
# y (3051, 1)
# X_train (2440, 1, 4)
# y_train (2440, 1)
# X_test (611, 1, 4)
# Y_test (611, 1)
# X_train.shape[1] 1
# X_train.shape[2] 4

# %%
# Step 6: Building the LSTM model (cont.)

model = Sequential()
model.add(LSTM(100, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True , activation= 'softmax'))
model.add(Dropout(0.2))
model.add(LSTM(100, activation= 'softmax'))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 1, 100)            42000
#
#  dropout_2 (Dropout)         (None, 1, 100)            0
#
#  lstm_3 (LSTM)               (None, 100)               80400
#
#  dropout_3 (Dropout)         (None, 100)               0
#
#  dense_1 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 122,501
# Trainable params: 122,501
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Step 7: Training and evaluating the model
history = model.fit(X_train, y_train, epochs=250, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/250
# 77/77 [==============================] - 6s 18ms/step - loss: 0.0343 - val_loss: 0.2238
# Epoch 2/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0292 - val_loss: 0.2052
# Epoch 3/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0291 - val_loss: 0.2050
# Epoch 4/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0291 - val_loss: 0.2033
# Epoch 5/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0291 - val_loss: 0.2025
# Epoch 6/250
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0291 - val_loss: 0.2053
# Epoch 7/250
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0290 - val_loss: 0.2022
# Epoch 8/250
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0291 - val_loss: 0.2043
# Epoch 9/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0290 - val_loss: 0.2038
# Epoch 10/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0290 - val_loss: 0.2046
# Epoch 11/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0290 - val_loss: 0.2017
# Epoch 12/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0290 - val_loss: 0.2020
# Epoch 13/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0290 - val_loss: 0.2020
# Epoch 14/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0289 - val_loss: 0.2019
# Epoch 15/250
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0290 - val_loss: 0.1986
# Epoch 16/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0289 - val_loss: 0.1996
# Epoch 17/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0289 - val_loss: 0.1996
# Epoch 18/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0289 - val_loss: 0.2013
# Epoch 19/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0288 - val_loss: 0.1999
# Epoch 20/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0287 - val_loss: 0.2000
# Epoch 21/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0286 - val_loss: 0.2028
# Epoch 22/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0285 - val_loss: 0.1982
# Epoch 23/250
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0284 - val_loss: 0.1988
# Epoch 24/250
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0282 - val_loss: 0.1989
# Epoch 25/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0281 - val_loss: 0.1975
# Epoch 26/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0279 - val_loss: 0.1908
# Epoch 27/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0277 - val_loss: 0.1924
# Epoch 28/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0274 - val_loss: 0.1915
# Epoch 29/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0271 - val_loss: 0.1889
# Epoch 30/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0267 - val_loss: 0.1823
# Epoch 31/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0264 - val_loss: 0.1800
# Epoch 32/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0258 - val_loss: 0.1786
# Epoch 33/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0253 - val_loss: 0.1707
# Epoch 34/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0247 - val_loss: 0.1697
# Epoch 35/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0238 - val_loss: 0.1594
# Epoch 36/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0232 - val_loss: 0.1566
# Epoch 37/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0224 - val_loss: 0.1472
# Epoch 38/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0214 - val_loss: 0.1393
# Epoch 39/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0203 - val_loss: 0.1348
# Epoch 40/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0192 - val_loss: 0.1249
# Epoch 41/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0184 - val_loss: 0.1165
# Epoch 42/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0171 - val_loss: 0.1046
# Epoch 43/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0159 - val_loss: 0.1014
# Epoch 44/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0148 - val_loss: 0.0904
# Epoch 45/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0137 - val_loss: 0.0821
# Epoch 46/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0127 - val_loss: 0.0712
# Epoch 47/250
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0115 - val_loss: 0.0651
# Epoch 48/250
# 77/77 [==============================] - 2s 31ms/step - loss: 0.0107 - val_loss: 0.0578
# Epoch 49/250
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0097 - val_loss: 0.0520
# Epoch 50/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0089 - val_loss: 0.0460
# Epoch 51/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0078 - val_loss: 0.0419
# Epoch 52/250
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0071 - val_loss: 0.0360
# Epoch 53/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0066 - val_loss: 0.0314
# Epoch 54/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0062 - val_loss: 0.0278
# Epoch 55/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0055 - val_loss: 0.0244
# Epoch 56/250
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0049 - val_loss: 0.0220
# Epoch 57/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0048 - val_loss: 0.0197
# Epoch 58/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0044 - val_loss: 0.0181
# Epoch 59/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0041 - val_loss: 0.0164
# Epoch 60/250
# 77/77 [==============================] - 1s 12ms/step - loss: 0.0040 - val_loss: 0.0153
# Epoch 61/250
# 77/77 [==============================] - 1s 12ms/step - loss: 0.0037 - val_loss: 0.0144
# Epoch 62/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0036 - val_loss: 0.0137
# Epoch 63/250
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0033 - val_loss: 0.0131
# Epoch 64/250
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0034 - val_loss: 0.0126
# Epoch 65/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0031 - val_loss: 0.0122
# Epoch 66/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0031 - val_loss: 0.0120
# Epoch 67/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0029 - val_loss: 0.0117
# Epoch 68/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0030 - val_loss: 0.0115
# Epoch 69/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0029 - val_loss: 0.0115
# Epoch 70/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0030 - val_loss: 0.0113
# Epoch 71/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0028 - val_loss: 0.0109
# Epoch 72/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0028 - val_loss: 0.0110
# Epoch 73/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0026 - val_loss: 0.0110
# Epoch 74/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0026 - val_loss: 0.0112
# Epoch 75/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0026 - val_loss: 0.0107
# Epoch 76/250
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0025 - val_loss: 0.0111
# Epoch 77/250
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0025 - val_loss: 0.0103
# Epoch 78/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0025 - val_loss: 0.0107
# Epoch 79/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0026 - val_loss: 0.0104
# Epoch 80/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0025 - val_loss: 0.0103
# Epoch 81/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0024 - val_loss: 0.0102
# Epoch 82/250
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0024 - val_loss: 0.0098
# Epoch 83/250
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0024 - val_loss: 0.0101
# Epoch 84/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0025 - val_loss: 0.0103
# Epoch 85/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0023 - val_loss: 0.0100
# Epoch 86/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0025 - val_loss: 0.0098
# Epoch 87/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0024 - val_loss: 0.0096
# Epoch 88/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0023 - val_loss: 0.0092
# Epoch 89/250
# 77/77 [==============================] - 1s 15ms/step - loss: 0.0022 - val_loss: 0.0092
# Epoch 90/250
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0022 - val_loss: 0.0094
# Epoch 91/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0023 - val_loss: 0.0090
# Epoch 92/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0023 - val_loss: 0.0087
# Epoch 93/250
# 77/77 [==============================] - 1s 12ms/step - loss: 0.0023 - val_loss: 0.0087
# Epoch 94/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0021 - val_loss: 0.0085
# Epoch 95/250
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0022 - val_loss: 0.0082
# Epoch 96/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0020 - val_loss: 0.0080
# Epoch 97/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0020 - val_loss: 0.0079
# Epoch 98/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0021 - val_loss: 0.0077
# Epoch 99/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0078
# Epoch 100/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0021 - val_loss: 0.0075
# Epoch 101/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0072
# Epoch 102/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0020 - val_loss: 0.0067
# Epoch 103/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0021 - val_loss: 0.0065
# Epoch 104/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0063
# Epoch 105/250
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0017 - val_loss: 0.0060
# Epoch 106/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0061
# Epoch 107/250
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0017 - val_loss: 0.0060
# Epoch 108/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0017 - val_loss: 0.0056
# Epoch 109/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0053
# Epoch 110/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0017 - val_loss: 0.0053
# Epoch 111/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0017 - val_loss: 0.0051
# Epoch 112/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0017 - val_loss: 0.0048
# Epoch 113/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0045
# Epoch 114/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0015 - val_loss: 0.0045
# Epoch 115/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0043
# Epoch 116/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0015 - val_loss: 0.0040
# Epoch 117/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0015 - val_loss: 0.0036
# Epoch 118/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0014 - val_loss: 0.0035
# Epoch 119/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0014 - val_loss: 0.0034
# Epoch 120/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0014 - val_loss: 0.0033
# Epoch 121/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0013 - val_loss: 0.0034
# Epoch 122/250
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0013 - val_loss: 0.0029
# Epoch 123/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0013 - val_loss: 0.0029
# Epoch 124/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0013 - val_loss: 0.0028
# Epoch 125/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0012 - val_loss: 0.0027
# Epoch 126/250
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0012 - val_loss: 0.0027
# Epoch 127/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0012 - val_loss: 0.0024
# Epoch 128/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0012 - val_loss: 0.0024
# Epoch 129/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0011 - val_loss: 0.0023
# Epoch 130/250
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0011 - val_loss: 0.0023
# Epoch 131/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0011 - val_loss: 0.0020
# Epoch 132/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0011 - val_loss: 0.0020
# Epoch 133/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0011 - val_loss: 0.0020
# Epoch 134/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 135/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0011 - val_loss: 0.0020
# Epoch 136/250
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0010 - val_loss: 0.0019
# Epoch 137/250
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 138/250
# 77/77 [==============================] - 1s 10ms/step - loss: 9.7472e-04 - val_loss: 0.0017
# Epoch 139/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 140/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 141/250
# 77/77 [==============================] - 1s 10ms/step - loss: 9.9224e-04 - val_loss: 0.0016
# Epoch 142/250
# 77/77 [==============================] - 1s 10ms/step - loss: 9.8962e-04 - val_loss: 0.0015
# Epoch 143/250
# 77/77 [==============================] - 1s 12ms/step - loss: 9.8195e-04 - val_loss: 0.0015
# Epoch 144/250
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 145/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0010 - val_loss: 0.0014
# Epoch 146/250
# 77/77 [==============================] - 1s 10ms/step - loss: 9.6775e-04 - val_loss: 0.0014
# Epoch 147/250
# 77/77 [==============================] - 1s 9ms/step - loss: 9.6543e-04 - val_loss: 0.0014
# Epoch 148/250
# 77/77 [==============================] - 1s 10ms/step - loss: 8.8232e-04 - val_loss: 0.0013
# Epoch 149/250
# 77/77 [==============================] - 1s 10ms/step - loss: 9.0672e-04 - val_loss: 0.0013
# Epoch 150/250
# 77/77 [==============================] - 1s 10ms/step - loss: 9.3776e-04 - val_loss: 0.0013
# 77/77 [==============================] - 1s 10ms/step - loss: 6.0834e-04 - val_loss: 8.6783e-04
# Epoch 229/250
# 77/77 [==============================] - 1s 12ms/step - loss: 6.4798e-04 - val_loss: 9.3732e-04
# Epoch 230/250
# 77/77 [==============================] - 1s 11ms/step - loss: 6.2502e-04 - val_loss: 9.1471e-04
# Epoch 231/250
# 77/77 [==============================] - 1s 10ms/step - loss: 5.8996e-04 - val_loss: 8.8484e-04
# Epoch 232/250
# 77/77 [==============================] - 1s 10ms/step - loss: 6.1342e-04 - val_loss: 9.3896e-04
# Epoch 233/250
# 77/77 [==============================] - 1s 10ms/step - loss: 6.0642e-04 - val_loss: 0.0010
# Epoch 234/250
# 77/77 [==============================] - 1s 10ms/step - loss: 5.8675e-04 - val_loss: 9.2578e-04
# Epoch 235/250
# 77/77 [==============================] - 1s 11ms/step - loss: 5.7841e-04 - val_loss: 9.7196e-04
# Epoch 236/250
# 77/77 [==============================] - 1s 10ms/step - loss: 5.8606e-04 - val_loss: 9.5044e-04
# Epoch 237/250
# 77/77 [==============================] - 1s 11ms/step - loss: 5.9139e-04 - val_loss: 9.0625e-04
# Epoch 238/250
# 77/77 [==============================] - 1s 9ms/step - loss: 6.0701e-04 - val_loss: 8.6322e-04
# Epoch 239/250
# 77/77 [==============================] - 1s 10ms/step - loss: 5.9674e-04 - val_loss: 0.0010
# Epoch 240/250
# 77/77 [==============================] - 1s 12ms/step - loss: 6.1928e-04 - val_loss: 0.0010
# Epoch 241/250
# 77/77 [==============================] - 1s 9ms/step - loss: 5.8092e-04 - val_loss: 9.7120e-04
# Epoch 242/250
# 77/77 [==============================] - 1s 10ms/step - loss: 5.2214e-04 - val_loss: 8.8182e-04
# Epoch 243/250
# 77/77 [==============================] - 1s 9ms/step - loss: 5.8049e-04 - val_loss: 8.9921e-04
# Epoch 244/250
# 77/77 [==============================] - 1s 10ms/step - loss: 5.4740e-04 - val_loss: 8.9447e-04
# Epoch 245/250
# 77/77 [==============================] - 1s 10ms/step - loss: 5.8165e-04 - val_loss: 9.5214e-04
# Epoch 246/250
# 77/77 [==============================] - 1s 11ms/step - loss: 6.1165e-04 - val_loss: 8.9671e-04
# Epoch 247/250
# 77/77 [==============================] - 1s 12ms/step - loss: 5.5949e-04 - val_loss: 8.6890e-04
# Epoch 248/250
# 77/77 [==============================] - 1s 12ms/step - loss: 6.2878e-04 - val_loss: 9.4291e-04
# Epoch 249/250
# 77/77 [==============================] - 1s 11ms/step - loss: 6.2228e-04 - val_loss: 9.5219e-04
# Epoch 250/250
# 77/77 [==============================] - 1s 12ms/step - loss: 5.6622e-04 - val_loss: 9.3889e-04

# %%
# Evaluate the model on the test set
score = model.evaluate(X_test, y_test, verbose=0)
print(f'Test loss: {score:.4f}')
# Out:
# Test loss: 0.0009

# %%
# Step 8: Tuning the Hyperparameters
# You can use techniques such as grid search or random search to find the best values for the model's hyperparameters

# Step 9: Testing the model
y_pred = model.predict(X_test)
print('y_pred',y_pred.shape)
print('y_test',y_test.shape)
#y_pred = y_pred.reshape(-1,1)
#y_pred = np.nan_to_num(y_pred)
#y_pred = scaler.inverse_transform(y_pred)
#y_pred = scaler.inverse_transform(y_pred[:,[-1]])
#y_test = scaler.inverse_transform(y_test.reshape(-1, 1))
#y_test = np.nan_to_num(y_test)


#evaluat
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mape = 100 * np.mean(np.abs((y_test - y_pred) / y_test))
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

print("MAPE: {:.4f}%".format(mape))
print("RMSE: {:.4f}".format(rmse))
print("MSE: {:.4f}".format(mse))
print("MAE:{:.4f}".format(mae))
# Out:
# 20/20 [==============================] - 0s 5ms/step
# y_pred (611, 1)
# y_test (611, 1)
# MAPE: 4.1675%
# RMSE: 0.0306
# MSE: 0.0009
# MAE:0.0230

# %%
def smape(y_true, y_pred):
    return 200 * np.mean(np.abs(y_pred - y_true) / (np.abs(y_pred) + np.abs(y_true)))

SMAPE1 = smape(y_test, y_pred)
print("smape: {:.4f}%".format(SMAPE1))
# Out:
# smape: 4.1606%

# %%
import matplotlib.pyplot as plt

# Assume that you have stored the date information in a variable called 'date'
# Assume that you have stored the predictions in a variable called 'y_pred'
# Assume that you have stored the test data in a variable called 'y_test'

# Plot the test data and predictions on a line chart
plt.plot(data['Date'], y_pred, label='Predictions')
plt.plot(data['Date'], y_test, label='Test Data')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 8
#       1 import matplotlib.pyplot as plt
#       3 # Assume that you have stored the date information in a variable called 'date'
#       4 # Assume that you have stored the predictions in a variable called 'y_pred'
#       5 # Assume that you have stored the test data in a variable called 'y_test'
#       6
#       7 # Plot the test data and predictions on a line chart
# ----> 8 plt.plot(data['Date'], y_pred, label='Predictions')
#       9 plt.plot(data['Date'], y_test, label='Test Data')
#      10 plt.xlabel('Date')
#
# NameError: name 'data' is not defined

# %%
y_pred = scaler.inverse_transform(y_pred)
#y_pred = scaler.inverse_transform(y_pred[:,[-1]])
#y_test = scaler.inverse_transform(y_test.reshape(-1, 1))
print ('y_pred',y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 y_pred = scaler.inverse_transform(y_pred)
#       2 #y_pred = scaler.inverse_transform(y_pred[:,[-1]])
#       3 #y_test = scaler.inverse_transform(y_test.reshape(-1, 1))
#       4 print ('y_pred',y_pred)
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\preprocessing\_data.py:541, in MinMaxScaler.inverse_transform(self, X)
#     535 check_is_fitted(self)
#     537 X = check_array(
#     538     X, copy=self.copy, dtype=FLOAT_DTYPES, force_all_finite="allow-nan"
#     539 )
# --> 541 X -= self.min_
#     542 X /= self.scale_
#     543 return X
#
# ValueError: non-broadcastable output operand with shape (611,1) doesn't match the broadcast shape (611,4)

# %%
plt.figure(figsize=(8,8))
plt.plot(y_test, color = 'blue', label = 'Test')
plt.plot(y_pred, color = 'red', label = 'pred')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 plt.figure(figsize=(8,8))
# ----> 2 plt.plot(y_test, color = 'blue', label = 'Test')
#       3 plt.plot(y_pred, color = 'red', label = 'pred')
#       4 plt.legend()
#
# NameError: name 'y_test' is not defined
