# %%
import pandas as pd
import numpy as np
import pandas_ta as ta
import yfinance as yf
from datetime import timedelta
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error 
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout

# For PLotting we will use these library

import matplotlib.pyplot as plt

from itertools import cycle
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

# %%
# Step 1: Data cleaning

data = yf.download(tickers='ETH-usd', start='2017-11-09', end='2022-12-31', interval='1d')
#data = yf.download(tickers='BTC-USD', period='max', interval='1d')
data.dropna(inplace=True)
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2017-11-09   308.644989   329.451996   307.056000   320.884003   320.884003
# 2017-11-10   320.670990   324.717987   294.541992   299.252991   299.252991
# 2017-11-11   298.585999   319.453003   298.191986   314.681000   314.681000
# 2017-11-12   314.690002   319.153015   298.513000   307.907990   307.907990
# 2017-11-13   307.024994   328.415009   307.024994   316.716003   316.716003
# ...                 ...          ...          ...          ...          ...
# 2022-12-26  1218.920166  1226.974365  1214.335938  1226.974365  1226.974365
# 2022-12-27  1226.987061  1230.418091  1205.895630  1212.791626  1212.791626
# 2022-12-28  1212.736572  1213.128906  1185.702148  1189.986084  1189.986084
# 2022-12-29  1190.010132  1204.141602  1188.360229  1201.595337  1201.595337
# 2022-12-30  1201.569580  1202.034668  1187.462524  1199.232788  1199.232788
#
#                 Volume
# Date
# 2017-11-09   893249984
# 2017-11-10   885985984
# 2017-11-11   842300992
# 2017-11-12  1613479936
# 2017-11-13  1041889984
# ...                ...
# 2022-12-26  3282098400
# 2022-12-27  4091530737
# 2022-12-28  4991669631
# 2022-12-29  4132233940
# 2022-12-30  4055668253
#
# [1878 rows x 6 columns]

# %%
data = data.drop(['Close'], axis=1)
data
# Out:
#                    Open         High          Low    Adj Close      Volume
# Date
# 2017-11-09   308.644989   329.451996   307.056000   320.884003   893249984
# 2017-11-10   320.670990   324.717987   294.541992   299.252991   885985984
# 2017-11-11   298.585999   319.453003   298.191986   314.681000   842300992
# 2017-11-12   314.690002   319.153015   298.513000   307.907990  1613479936
# 2017-11-13   307.024994   328.415009   307.024994   316.716003  1041889984
# ...                 ...          ...          ...          ...         ...
# 2022-12-26  1218.920166  1226.974365  1214.335938  1226.974365  3282098400
# 2022-12-27  1226.987061  1230.418091  1205.895630  1212.791626  4091530737
# 2022-12-28  1212.736572  1213.128906  1185.702148  1189.986084  4991669631
# 2022-12-29  1190.010132  1204.141602  1188.360229  1201.595337  4132233940
# 2022-12-30  1201.569580  1202.034668  1187.462524  1199.232788  4055668253
#
# [1878 rows x 5 columns]

# %%
data= data.to_csv('ETH_case2.csv')

# %%
from datetime import datetime

def date_parser(date_str):
    date_obj = datetime.strptime(date_str, '%m/%d/%Y')
    return date_obj.strftime('%m-%d-%Y')

# %%
data_csv = pd.read_csv('ETH_case2.csv')
data_csv.dropna(inplace=True)
# Setting the index

data_csv.set_index('Date', inplace=True)
# Dropping any NaNs
data_csv.dropna(inplace=True)
data_csv.info()
data_csv.tail(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1878 entries, 2017-11-09 to 2022-12-30
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1878 non-null   float64
#  1   High       1878 non-null   float64
#  2   Low        1878 non-null   float64
#  3   Adj Close  1878 non-null   float64
#  4   Volume     1878 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 88.0+ KB
#                    Open         High          Low    Adj Close      Volume
# Date
# 2022-12-21  1217.586426  1218.192261  1206.440063  1213.599976  4217182733
# 2022-12-22  1213.672607  1221.986816  1187.127808  1218.182129  5297471739
# 2022-12-23  1218.079346  1226.998779  1215.994873  1220.159424  4835831923
# 2022-12-24  1220.117920  1224.911621  1216.338745  1221.148560  2626153345
# 2022-12-25  1221.171509  1223.517822  1203.719604  1218.962036  3942720070
# 2022-12-26  1218.920166  1226.974365  1214.335938  1226.974365  3282098400
# 2022-12-27  1226.987061  1230.418091  1205.895630  1212.791626  4091530737
# 2022-12-28  1212.736572  1213.128906  1185.702148  1189.986084  4991669631
# 2022-12-29  1190.010132  1204.141602  1188.360229  1201.595337  4132233940
# 2022-12-30  1201.569580  1202.034668  1187.462524  1199.232788  4055668253

# %%
# Split the data into training and test sets
train_df = data_csv[:int(len(data_csv)*0.8)]
test_df = data_csv[int(len(data_csv)*0.8):]
data_csv.shape
# Out:
# (1878, 5)

# %%
test_data =test_df.copy()

# %%
train_x = train_df.index
train_y = train_df['Adj Close']
test_x = test_df.index
test_y = test_df['Adj Close']

fig = go.Figure()
fig.add_trace(go.Scatter(x=train_x, y=train_y, name='train Data'))
fig.add_trace(go.Scatter(x=test_x, y=test_y, name='Test Data'))

fig.update_layout(
    xaxis_title='Date',
    yaxis_title='Price',
    title='Price over time'
)

fig.show()

# %%
print(train_df.info())
print(test_df.info())
print('test_data', test_data.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1502 entries, 2017-11-09 to 2021-12-19
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1502 non-null   float64
#  1   High       1502 non-null   float64
#  2   Low        1502 non-null   float64
#  3   Adj Close  1502 non-null   float64
#  4   Volume     1502 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 70.4+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 376 entries, 2021-12-20 to 2022-12-30
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       376 non-null    float64
#  1   High       376 non-null    float64
#  2   Low        376 non-null    float64
#  3   Adj Close  376 non-null    float64
#  4   Volume     376 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 17.6+ KB
# None
# test_data (376, 5)

# %%
# Preprocess the data
X_train = train_df.drop(['Adj Close'], axis=1).values
y_train = train_df['Adj Close'].values

X_test = test_df.drop(['Adj Close'], axis=1).values
y_test = test_df['Adj Close'].values

print("x_train", X_train.shape)
print("y_train", y_train.shape)
print("X_test", X_test.shape)
print("y_test", y_test.shape)
# Out:
# x_train (1502, 4)
# y_train (1502,)
# X_test (376, 4)
# y_test (376,)

# %%
scaler  = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test  = scaler.fit_transform(X_test)
y_train = y_train.reshape(-1,1)
y_train = scaler.fit_transform(y_train)
y_test  = y_test.reshape(-1,1)
y_test  = scaler.fit_transform(y_test)
#------------------------------------------
print("x_train", X_train.shape)
print("y_train", y_train.shape)
print("X_test", X_test.shape)
print("y_test", y_test.shape)
# Out:
# x_train (1502, 4)
# y_train (1502, 1)
# X_test (376, 4)
# y_test (376, 1)

# %%
# Step 5: Reshaping the data
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

print('X_train', X_train.shape)
print('y_train', y_train.shape)
print('X_test', X_test.shape)
print('Y_test', y_test.shape)
print('X_train.shape[1]', X_train.shape[1])
print('X_train.shape[2]', X_train.shape[2])
# Out:
# X_train (1502, 1, 4)
# y_train (1502, 1)
# X_test (376, 1, 4)
# Y_test (376, 1)
# X_train.shape[1] 1
# X_train.shape[2] 4

# %%
# Step 6: Building the LSTM model (cont.)

model = Sequential()
model.add(LSTM(100, input_shape=( X_train.shape[1], X_train.shape[2]), return_sequences=True, activation='tanh'))
model.add(Dropout(0.2))
model.add(LSTM(100, return_sequences=True, activation='tanh'))
model.add(Dropout(0.2))
model.add(LSTM(75, return_sequences=True, activation='tanh'))
model.add(Dropout(0.25))
model.add(LSTM(50, activation='tanh'))
model.add(Dropout(0.3))
model.add(Dense(1, activation='linear'))
model.compile(loss='mean_squared_error', optimizer='adam',
              metrics=['accuracy', 'mean_absolute_error'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 1, 100)            42000
#
#  dropout (Dropout)           (None, 1, 100)            0
#
#  lstm_1 (LSTM)               (None, 1, 100)            80400
#
#  dropout_1 (Dropout)         (None, 1, 100)            0
#
#  lstm_2 (LSTM)               (None, 1, 75)             52800
#
#  dropout_2 (Dropout)         (None, 1, 75)             0
#
#  lstm_3 (LSTM)               (None, 50)                25200
#
#  dropout_3 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 200,451
# Trainable params: 200,451
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Step 7: Training and evaluating the model
history = model.fit(X_train, y_train, epochs=1000, batch_size=32)
# Out:
# Epoch 1/1000
# 47/47 [==============================] - 33s 20ms/step - loss: 0.0541 - accuracy: 6.6578e-04 - mean_absolute_error: 0.1553
# Epoch 2/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 0.0046 - accuracy: 0.0013 - mean_absolute_error: 0.0429
# Epoch 3/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 0.0026 - accuracy: 0.0013 - mean_absolute_error: 0.0296
# Epoch 4/1000
# 47/47 [==============================] - 1s 19ms/step - loss: 0.0024 - accuracy: 0.0013 - mean_absolute_error: 0.0287
# Epoch 5/1000
# 47/47 [==============================] - 1s 19ms/step - loss: 0.0019 - accuracy: 0.0013 - mean_absolute_error: 0.0227
# Epoch 6/1000
# 47/47 [==============================] - 2s 32ms/step - loss: 0.0020 - accuracy: 0.0013 - mean_absolute_error: 0.0222
# Epoch 7/1000
# 47/47 [==============================] - 1s 19ms/step - loss: 0.0017 - accuracy: 0.0013 - mean_absolute_error: 0.0201
# Epoch 8/1000
# 47/47 [==============================] - 1s 20ms/step - loss: 0.0014 - accuracy: 0.0013 - mean_absolute_error: 0.0182
# Epoch 9/1000
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0016 - accuracy: 0.0013 - mean_absolute_error: 0.0198
# Epoch 10/1000
# 47/47 [==============================] - 1s 21ms/step - loss: 0.0016 - accuracy: 0.0013 - mean_absolute_error: 0.0206
# Epoch 11/1000
# 47/47 [==============================] - 1s 21ms/step - loss: 0.0014 - accuracy: 0.0013 - mean_absolute_error: 0.0194
# Epoch 12/1000
# 47/47 [==============================] - 1s 21ms/step - loss: 0.0013 - accuracy: 0.0013 - mean_absolute_error: 0.0182
# Epoch 13/1000
# 47/47 [==============================] - 1s 21ms/step - loss: 0.0012 - accuracy: 0.0013 - mean_absolute_error: 0.0178
# Epoch 14/1000
# 47/47 [==============================] - 1s 20ms/step - loss: 0.0017 - accuracy: 0.0013 - mean_absolute_error: 0.0216
# Epoch 15/1000
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0178
# Epoch 16/1000
# 47/47 [==============================] - 1s 20ms/step - loss: 0.0014 - accuracy: 0.0013 - mean_absolute_error: 0.0193
# Epoch 17/1000
# 47/47 [==============================] - 1s 21ms/step - loss: 0.0016 - accuracy: 0.0013 - mean_absolute_error: 0.0198
# Epoch 18/1000
# 47/47 [==============================] - 1s 20ms/step - loss: 0.0017 - accuracy: 0.0013 - mean_absolute_error: 0.0208
# Epoch 19/1000
# 47/47 [==============================] - 1s 20ms/step - loss: 0.0014 - accuracy: 0.0013 - mean_absolute_error: 0.0206
# Epoch 20/1000
# 47/47 [==============================] - 1s 20ms/step - loss: 0.0013 - accuracy: 0.0013 - mean_absolute_error: 0.0199
# Epoch 21/1000
# 47/47 [==============================] - 1s 20ms/step - loss: 0.0015 - accuracy: 0.0013 - mean_absolute_error: 0.0203
# Epoch 22/1000
# 47/47 [==============================] - 1s 25ms/step - loss: 9.9468e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0177
# Epoch 23/1000
# 47/47 [==============================] - 1s 23ms/step - loss: 0.0012 - accuracy: 0.0013 - mean_absolute_error: 0.0197
# Epoch 24/1000
# 47/47 [==============================] - 1s 20ms/step - loss: 0.0014 - accuracy: 0.0013 - mean_absolute_error: 0.0198
# Epoch 25/1000
# 47/47 [==============================] - 1s 21ms/step - loss: 0.0013 - accuracy: 0.0013 - mean_absolute_error: 0.0196
# Epoch 26/1000
# 47/47 [==============================] - 1s 21ms/step - loss: 0.0012 - accuracy: 0.0013 - mean_absolute_error: 0.0190
# Epoch 27/1000
# 47/47 [==============================] - 1s 22ms/step - loss: 0.0013 - accuracy: 0.0013 - mean_absolute_error: 0.0194
# Epoch 28/1000
# 47/47 [==============================] - 1s 23ms/step - loss: 0.0010 - accuracy: 0.0013 - mean_absolute_error: 0.0182
# Epoch 29/1000
# 47/47 [==============================] - 1s 21ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0188
# Epoch 30/1000
# 47/47 [==============================] - 1s 26ms/step - loss: 0.0012 - accuracy: 0.0013 - mean_absolute_error: 0.0203
# Epoch 31/1000
# 47/47 [==============================] - 1s 28ms/step - loss: 0.0012 - accuracy: 0.0013 - mean_absolute_error: 0.0188
# Epoch 32/1000
# 47/47 [==============================] - 1s 21ms/step - loss: 0.0014 - accuracy: 0.0013 - mean_absolute_error: 0.0207
# Epoch 33/1000
# 47/47 [==============================] - 1s 22ms/step - loss: 0.0012 - accuracy: 0.0013 - mean_absolute_error: 0.0198
# Epoch 34/1000
# 47/47 [==============================] - 1s 21ms/step - loss: 0.0013 - accuracy: 0.0013 - mean_absolute_error: 0.0204
# Epoch 35/1000
# 47/47 [==============================] - 1s 22ms/step - loss: 0.0013 - accuracy: 0.0013 - mean_absolute_error: 0.0202
# Epoch 36/1000
# 47/47 [==============================] - 1s 20ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0196
# Epoch 37/1000
# 47/47 [==============================] - 1s 20ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0199
# Epoch 38/1000
# 47/47 [==============================] - 1s 19ms/step - loss: 0.0012 - accuracy: 0.0013 - mean_absolute_error: 0.0210
# Epoch 39/1000
# 47/47 [==============================] - 1s 20ms/step - loss: 0.0014 - accuracy: 0.0013 - mean_absolute_error: 0.0217
# Epoch 40/1000
# 47/47 [==============================] - 1s 22ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0189
# Epoch 41/1000
# 47/47 [==============================] - 1s 28ms/step - loss: 0.0010 - accuracy: 0.0013 - mean_absolute_error: 0.0190
# Epoch 42/1000
# 47/47 [==============================] - 1s 21ms/step - loss: 0.0014 - accuracy: 0.0013 - mean_absolute_error: 0.0209
# Epoch 43/1000
# 47/47 [==============================] - 1s 21ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0203
# Epoch 44/1000
# 47/47 [==============================] - 1s 26ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0201
# Epoch 45/1000
# 47/47 [==============================] - 1s 20ms/step - loss: 0.0012 - accuracy: 0.0013 - mean_absolute_error: 0.0201
# Epoch 46/1000
# 47/47 [==============================] - 1s 20ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0205
# Epoch 47/1000
# 47/47 [==============================] - 1s 21ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0196
# Epoch 48/1000
# 47/47 [==============================] - 1s 21ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0193
# Epoch 49/1000
# 47/47 [==============================] - 1s 22ms/step - loss: 0.0012 - accuracy: 0.0013 - mean_absolute_error: 0.0197
# Epoch 50/1000
# 47/47 [==============================] - 1s 22ms/step - loss: 9.6029e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0191
# Epoch 51/1000
# 47/47 [==============================] - 1s 22ms/step - loss: 9.2504e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0186
# Epoch 52/1000
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0013 - accuracy: 0.0013 - mean_absolute_error: 0.0211
# Epoch 53/1000
# 47/47 [==============================] - 1s 23ms/step - loss: 0.0012 - accuracy: 0.0013 - mean_absolute_error: 0.0204
# Epoch 54/1000
# 47/47 [==============================] - 1s 21ms/step - loss: 9.1833e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0192
# Epoch 55/1000
# 47/47 [==============================] - 1s 23ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0196
# Epoch 56/1000
# 47/47 [==============================] - 1s 21ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0203
# Epoch 57/1000
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0012 - accuracy: 0.0013 - mean_absolute_error: 0.0216
# Epoch 58/1000
# 47/47 [==============================] - 1s 25ms/step - loss: 9.8838e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0193
# Epoch 59/1000
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0013 - accuracy: 0.0013 - mean_absolute_error: 0.0208
# Epoch 60/1000
# 47/47 [==============================] - 1s 20ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0206
# Epoch 61/1000
# 47/47 [==============================] - 1s 20ms/step - loss: 0.0012 - accuracy: 0.0013 - mean_absolute_error: 0.0202
# Epoch 62/1000
# 47/47 [==============================] - 1s 22ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0195
# Epoch 63/1000
# 47/47 [==============================] - 1s 22ms/step - loss: 0.0012 - accuracy: 0.0013 - mean_absolute_error: 0.0208
# Epoch 64/1000
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0199
# Epoch 65/1000
# 47/47 [==============================] - 1s 23ms/step - loss: 9.4569e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0194
# Epoch 66/1000
# 47/47 [==============================] - 1s 21ms/step - loss: 9.9240e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0190
# Epoch 67/1000
# 47/47 [==============================] - 1s 23ms/step - loss: 0.0012 - accuracy: 0.0013 - mean_absolute_error: 0.0212
# Epoch 68/1000
# 47/47 [==============================] - 1s 29ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0206
# Epoch 69/1000
# 47/47 [==============================] - 1s 25ms/step - loss: 9.7862e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0193
# Epoch 70/1000
# 47/47 [==============================] - 1s 22ms/step - loss: 0.0010 - accuracy: 0.0013 - mean_absolute_error: 0.0198
# Epoch 71/1000
# 47/47 [==============================] - 1s 19ms/step - loss: 0.0012 - accuracy: 0.0013 - mean_absolute_error: 0.0207
# Epoch 72/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0202
# Epoch 73/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0201
# Epoch 74/1000
# 47/47 [==============================] - 1s 20ms/step - loss: 0.0012 - accuracy: 0.0013 - mean_absolute_error: 0.0205
# Epoch 75/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 0.0013 - accuracy: 0.0013 - mean_absolute_error: 0.0215
# Epoch 76/1000
# 47/47 [==============================] - 1s 21ms/step - loss: 0.0012 - accuracy: 0.0013 - mean_absolute_error: 0.0207
# Epoch 77/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0202
# Epoch 78/1000
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0012 - accuracy: 0.0013 - mean_absolute_error: 0.0211
# Epoch 79/1000
# 47/47 [==============================] - 1s 20ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0211
# Epoch 80/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 0.0013 - accuracy: 0.0013 - mean_absolute_error: 0.0218
# Epoch 81/1000
# 47/47 [==============================] - 1s 19ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0206
# Epoch 82/1000
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0012 - accuracy: 0.0013 - mean_absolute_error: 0.0199
# Epoch 83/1000
# 47/47 [==============================] - 1s 22ms/step - loss: 0.0010 - accuracy: 0.0013 - mean_absolute_error: 0.0196
# Epoch 84/1000
# 47/47 [==============================] - 1s 19ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0211
# Epoch 85/1000
# 47/47 [==============================] - 1s 20ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0197
# Epoch 86/1000
# 47/47 [==============================] - 1s 19ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0199
# Epoch 87/1000
# 47/47 [==============================] - 1s 20ms/step - loss: 0.0013 - accuracy: 0.0013 - mean_absolute_error: 0.0221
# Epoch 88/1000
# 47/47 [==============================] - 1s 20ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0205
# Epoch 89/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0206
# Epoch 90/1000
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0203
# Epoch 91/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 0.0012 - accuracy: 0.0013 - mean_absolute_error: 0.0206
# Epoch 92/1000
# 47/47 [==============================] - 1s 19ms/step - loss: 9.9832e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0198
# Epoch 93/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 9.6379e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0196
# Epoch 94/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0207
# Epoch 95/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 0.0012 - accuracy: 0.0013 - mean_absolute_error: 0.0202
# Epoch 96/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 0.0012 - accuracy: 0.0013 - mean_absolute_error: 0.0211
# Epoch 97/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0212
# Epoch 98/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 0.0010 - accuracy: 0.0013 - mean_absolute_error: 0.0199
# Epoch 99/1000
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0198
# Epoch 100/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 9.6982e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0194
# Epoch 101/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 9.4897e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0194
# Epoch 102/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0204
# Epoch 103/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 9.6891e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0200
# Epoch 104/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 0.0010 - accuracy: 0.0013 - mean_absolute_error: 0.0198
# Epoch 105/1000
# 47/47 [==============================] - 1s 23ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0201
# Epoch 106/1000
# 47/47 [==============================] - 1s 21ms/step - loss: 0.0012 - accuracy: 0.0013 - mean_absolute_error: 0.0206
# Epoch 107/1000
# 47/47 [==============================] - 1s 23ms/step - loss: 9.8860e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0196
# Epoch 108/1000
# 47/47 [==============================] - 1s 22ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0205
# Epoch 109/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0204
# Epoch 110/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 0.0010 - accuracy: 0.0013 - mean_absolute_error: 0.0199
# Epoch 111/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0199
# Epoch 112/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 9.7147e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0195
# Epoch 113/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0204
# Epoch 114/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 9.3688e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0200
# Epoch 115/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 0.0010 - accuracy: 0.0013 - mean_absolute_error: 0.0202
# Epoch 116/1000
# 47/47 [==============================] - 1s 19ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0208
# Epoch 117/1000
# 47/47 [==============================] - 1s 26ms/step - loss: 0.0010 - accuracy: 0.0013 - mean_absolute_error: 0.0196
# Epoch 118/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 9.8441e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0195
# Epoch 119/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 9.9162e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0195
# Epoch 120/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0205
# Epoch 121/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0207
# Epoch 122/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0210
# Epoch 123/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 0.0010 - accuracy: 0.0013 - mean_absolute_error: 0.0203
# Epoch 124/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0214
# Epoch 125/1000
# 47/47 [==============================] - 1s 23ms/step - loss: 8.9426e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0191
# Epoch 126/1000
# 47/47 [==============================] - 1s 22ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0198
# Epoch 127/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 0.0012 - accuracy: 0.0013 - mean_absolute_error: 0.0208
# Epoch 128/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 0.0010 - accuracy: 0.0013 - mean_absolute_error: 0.0202
# Epoch 129/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0201
# Epoch 130/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0204
# Epoch 131/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 0.0012 - accuracy: 0.0013 - mean_absolute_error: 0.0211
# Epoch 132/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 0.0010 - accuracy: 0.0013 - mean_absolute_error: 0.0199
# Epoch 133/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0207
# Epoch 134/1000
# 47/47 [==============================] - 1s 23ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0199
# Epoch 135/1000
# 47/47 [==============================] - 1s 19ms/step - loss: 9.2020e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0194
# Epoch 136/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 0.0010 - accuracy: 0.0013 - mean_absolute_error: 0.0196
# Epoch 137/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 9.2656e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0197
# Epoch 138/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 9.7170e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0194
# Epoch 139/1000
# 47/47 [==============================] - 1s 20ms/step - loss: 9.6918e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0195
# Epoch 140/1000
# 47/47 [==============================] - 1s 20ms/step - loss: 9.4278e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0198
# Epoch 141/1000
# 47/47 [==============================] - 1s 20ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0212
# Epoch 142/1000
# 47/47 [==============================] - 1s 25ms/step - loss: 9.7308e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0196
# Epoch 143/1000
# 47/47 [==============================] - 1s 23ms/step - loss: 9.5176e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0194
# Epoch 144/1000
# 47/47 [==============================] - 1s 21ms/step - loss: 0.0010 - accuracy: 0.0013 - mean_absolute_error: 0.0206
# Epoch 145/1000
# 47/47 [==============================] - 1s 21ms/step - loss: 0.0012 - accuracy: 0.0013 - mean_absolute_error: 0.0213
# Epoch 146/1000
# 47/47 [==============================] - 1s 20ms/step - loss: 0.0010 - accuracy: 0.0013 - mean_absolute_error: 0.0202
# Epoch 147/1000
# 47/47 [==============================] - 1s 23ms/step - loss: 9.9633e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0200
# Epoch 148/1000
# 47/47 [==============================] - 1s 21ms/step - loss: 7.9312e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0183
# Epoch 149/1000
# 47/47 [==============================] - 1s 21ms/step - loss: 0.0010 - accuracy: 0.0013 - mean_absolute_error: 0.0193
# Epoch 150/1000
# 47/47 [==============================] - 1s 20ms/step - loss: 8.8365e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0188
# Epoch 151/1000
# 47/47 [==============================] - 1s 27ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0200
# Epoch 152/1000
# 47/47 [==============================] - 1s 19ms/step - loss: 0.0010 - accuracy: 0.0013 - mean_absolute_error: 0.0196
# Epoch 153/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 9.3139e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0191
# Epoch 154/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0202
# Epoch 155/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 0.0010 - accuracy: 0.0013 - mean_absolute_error: 0.0199
# Epoch 156/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 8.6759e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0192
# Epoch 157/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 8.5262e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0190
# Epoch 158/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 9.6349e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0190
# Epoch 159/1000
# 47/47 [==============================] - 1s 19ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0196
# Epoch 160/1000
# 47/47 [==============================] - 1s 25ms/step - loss: 9.5335e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0189
# Epoch 161/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 8.9867e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0190
# Epoch 162/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 0.0010 - accuracy: 0.0013 - mean_absolute_error: 0.0197
# Epoch 163/1000
# 47/47 [==============================] - 1s 19ms/step - loss: 0.0010 - accuracy: 0.0013 - mean_absolute_error: 0.0190
# Epoch 164/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 9.9968e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0198
# Epoch 165/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 0.0010 - accuracy: 0.0013 - mean_absolute_error: 0.0196
# Epoch 166/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 9.0443e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0186
# Epoch 167/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 9.4571e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0197
# Epoch 168/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0199
# Epoch 169/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 7.6332e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0177
# Epoch 170/1000
# 47/47 [==============================] - 1s 25ms/step - loss: 9.3321e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0187
# Epoch 171/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 0.0010 - accuracy: 0.0013 - mean_absolute_error: 0.0192
# Epoch 172/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 9.7736e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0189
# Epoch 173/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 9.6799e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0190
# Epoch 174/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0205
# Epoch 175/1000
# 47/47 [==============================] - 1s 19ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0208
# Epoch 176/1000
# 47/47 [==============================] - 1s 22ms/step - loss: 9.3683e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0190
# Epoch 177/1000
# 47/47 [==============================] - 1s 20ms/step - loss: 8.9852e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0194
# Epoch 178/1000
# 47/47 [==============================] - 1s 19ms/step - loss: 9.1997e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0188
# Epoch 179/1000
# 47/47 [==============================] - 1s 19ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0208
# Epoch 180/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 0.0010 - accuracy: 0.0013 - mean_absolute_error: 0.0205
# Epoch 181/1000
# 47/47 [==============================] - 1s 19ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0200
# Epoch 182/1000
# 47/47 [==============================] - 1s 19ms/step - loss: 9.4995e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0190
# Epoch 183/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 9.9664e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0189
# Epoch 184/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 0.0010 - accuracy: 0.0013 - mean_absolute_error: 0.0199
# Epoch 185/1000
# 47/47 [==============================] - 1s 19ms/step - loss: 7.7217e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0179
# Epoch 186/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 9.6482e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0194
# Epoch 187/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 9.4867e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0188
# Epoch 188/1000
# 47/47 [==============================] - 1s 21ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0201
# Epoch 189/1000
# 47/47 [==============================] - 1s 23ms/step - loss: 8.4934e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0186
# Epoch 190/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 8.8488e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0189
# Epoch 191/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 9.0958e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0188
# Epoch 192/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 0.0010 - accuracy: 0.0013 - mean_absolute_error: 0.0193
# Epoch 193/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 9.0966e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0188
# Epoch 194/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 7.9320e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0180
# Epoch 195/1000
# 47/47 [==============================] - 1s 22ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0209
# Epoch 196/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 0.0010 - accuracy: 0.0013 - mean_absolute_error: 0.0201
# Epoch 197/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 8.5516e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0184
# Epoch 198/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 0.0010 - accuracy: 0.0013 - mean_absolute_error: 0.0201
# Epoch 199/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0203
# Epoch 200/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 9.6771e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0192
# Epoch 201/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 0.0010 - accuracy: 0.0013 - mean_absolute_error: 0.0190
# Epoch 202/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 9.5224e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0193
# Epoch 203/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 8.2964e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0188
# Epoch 204/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 9.6980e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0198
# Epoch 205/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0203
# Epoch 206/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 9.8641e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0191
# Epoch 207/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 9.8829e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0194
# Epoch 208/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0208
# Epoch 209/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 8.8230e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0188
# Epoch 210/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 7.3626e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0175
# Epoch 211/1000
# 47/47 [==============================] - 1s 19ms/step - loss: 9.5959e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0190
# Epoch 212/1000
# 47/47 [==============================] - 1s 20ms/step - loss: 8.6815e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0187
# Epoch 213/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 8.3233e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0184
# Epoch 214/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 8.5465e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0187
# Epoch 215/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 9.8596e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0193
# Epoch 216/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 9.5515e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0191
# Epoch 217/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 9.6011e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0191
# Epoch 218/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 8.0390e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0187
# Epoch 219/1000
# 47/47 [==============================] - 1s 21ms/step - loss: 8.9188e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0186
# Epoch 220/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 8.7637e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0185
# Epoch 221/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 8.5145e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0180
# Epoch 222/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 9.0420e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0186
# Epoch 223/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 0.0010 - accuracy: 0.0013 - mean_absolute_error: 0.0195
# Epoch 224/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 9.0917e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0181
# Epoch 225/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 0.0010 - accuracy: 0.0013 - mean_absolute_error: 0.0193
# Epoch 226/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 8.0130e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0180
# Epoch 227/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 8.8791e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0183
# Epoch 228/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 9.3008e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0186
# Epoch 229/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 8.2640e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0181
# Epoch 230/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 7.9083e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0174
# Epoch 231/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 0.0010 - accuracy: 0.0013 - mean_absolute_error: 0.0190
# Epoch 232/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 9.1450e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0190
# Epoch 233/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 9.3006e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0196
# Epoch 234/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0207
# Epoch 235/1000
# 47/47 [==============================] - 1s 22ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0209
# Epoch 236/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 8.4404e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0181
# Epoch 237/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 8.2371e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0181
# Epoch 238/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 9.1030e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0191
# Epoch 239/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 9.4161e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0188
# Epoch 240/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 8.6737e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0184
# Epoch 241/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 9.1519e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0185
# Epoch 242/1000
# 47/47 [==============================] - 1s 20ms/step - loss: 9.0002e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0183
# Epoch 243/1000
# 47/47 [==============================] - 1s 19ms/step - loss: 9.1524e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0191
# Epoch 244/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 8.9535e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0185
# Epoch 245/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 0.0010 - accuracy: 0.0013 - mean_absolute_error: 0.0203
# Epoch 246/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 9.0947e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0190
# Epoch 247/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0197
# Epoch 248/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 0.0010 - accuracy: 0.0013 - mean_absolute_error: 0.0192
# Epoch 249/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 8.7413e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0180
# Epoch 250/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 8.4963e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0182
# Epoch 251/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 9.6068e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0196
# Epoch 252/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 8.9202e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0184
# Epoch 253/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0201
# Epoch 254/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 9.0692e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0191
# Epoch 255/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 7.8146e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0174
# Epoch 256/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 8.9882e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0187
# Epoch 257/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 0.0010 - accuracy: 0.0013 - mean_absolute_error: 0.0196
# Epoch 258/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 8.6464e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0186
# Epoch 259/1000
# 47/47 [==============================] - 1s 21ms/step - loss: 0.0010 - accuracy: 0.0013 - mean_absolute_error: 0.0193
# Epoch 260/1000
# 47/47 [==============================] - 1s 20ms/step - loss: 8.2982e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0192
# Epoch 261/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 0.0010 - accuracy: 0.0013 - mean_absolute_error: 0.0188
# Epoch 262/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 9.3931e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0189
# Epoch 263/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 0.0010 - accuracy: 0.0013 - mean_absolute_error: 0.0193
# Epoch 264/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 8.5074e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0184
# Epoch 265/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 8.4203e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0184
# Epoch 266/1000
# 47/47 [==============================] - 1s 21ms/step - loss: 8.3352e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0182
# Epoch 267/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0205
# Epoch 268/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 8.8139e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0188
# Epoch 269/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0193
# Epoch 270/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 9.6489e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0199
# Epoch 271/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 7.7960e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0181
# Epoch 272/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 8.3739e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0183
# Epoch 273/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 8.3072e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0184
# Epoch 274/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 9.0344e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0186
# Epoch 275/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 8.9768e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0188
# Epoch 276/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 8.2378e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0183
# Epoch 277/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 9.1611e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0188
# Epoch 278/1000
# 47/47 [==============================] - 1s 22ms/step - loss: 8.4901e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0184
# Epoch 279/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 8.6195e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0179
# Epoch 280/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 9.7469e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0194
# Epoch 281/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 8.4112e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0180
# Epoch 282/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 0.0011 - accuracy: 0.0013 - mean_absolute_error: 0.0201
# Epoch 283/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 8.8795e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0187
# Epoch 284/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 9.1479e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0187
# Epoch 285/1000
# 47/47 [==============================] - 1s 21ms/step - loss: 9.0569e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0193
# Epoch 286/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 8.7902e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0185
# Epoch 287/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 8.8515e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0192
# Epoch 288/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 9.1100e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0187
# Epoch 289/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 9.2344e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0190
# Epoch 290/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 7.8867e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0176
# Epoch 291/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 7.8103e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0180
# Epoch 292/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 9.0387e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0189
# Epoch 293/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 8.0007e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0177
# Epoch 294/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 9.8977e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0193
# Epoch 295/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 8.6513e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0187
# Epoch 296/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 9.6767e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0188
# Epoch 297/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 9.3060e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0189
# Epoch 298/1000
# 47/47 [==============================] - 1s 19ms/step - loss: 9.4848e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0188
# Epoch 299/1000
# 47/47 [==============================] - 1s 19ms/step - loss: 8.6579e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0185
# Epoch 300/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 8.8411e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0186
# Epoch 301/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 8.4991e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0186
# Epoch 302/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 9.9942e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0189
# Epoch 303/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 8.7906e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0187
# Epoch 304/1000
# 47/47 [==============================] - 1s 19ms/step - loss: 9.1074e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0186
# Epoch 305/1000
# 47/47 [==============================] - 1s 19ms/step - loss: 0.0010 - accuracy: 0.0013 - mean_absolute_error: 0.0200
# Epoch 306/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 7.8304e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0179
# Epoch 307/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 8.6882e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0185
# Epoch 308/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 8.9392e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0187
# Epoch 309/1000
# 47/47 [==============================] - 1s 19ms/step - loss: 8.3068e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0183
# Epoch 310/1000
# 47/47 [==============================] - 1s 19ms/step - loss: 7.6716e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0184
# Epoch 311/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 8.9297e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0188
# Epoch 312/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 9.6471e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0192
# Epoch 313/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 8.5521e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0182
# Epoch 314/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 8.5632e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0177
# Epoch 315/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 8.4744e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0180
# Epoch 316/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 8.9740e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0191
# Epoch 317/1000
# 47/47 [==============================] - 1s 20ms/step - loss: 8.2445e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0182
# Epoch 318/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 8.5343e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0185
# Epoch 319/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 7.9858e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0173
# Epoch 320/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 7.9850e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0179
# Epoch 321/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 7.6878e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0177
# Epoch 322/1000
# 47/47 [==============================] - 1s 22ms/step - loss: 9.9459e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0195
# Epoch 323/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 9.7104e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0189
# Epoch 324/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 0.0010 - accuracy: 0.0013 - mean_absolute_error: 0.0195
# Epoch 325/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 8.5613e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0185
# Epoch 326/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 7.7835e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0179
# Epoch 327/1000
# 47/47 [==============================] - 1s 19ms/step - loss: 8.0773e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0181
# Epoch 328/1000
# 47/47 [==============================] - 1s 21ms/step - loss: 7.6133e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0179
# Epoch 329/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 7.8959e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0176
# Epoch 330/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 8.6986e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0188
# Epoch 331/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 9.6704e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0189
# Epoch 332/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 7.5747e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0183
# Epoch 333/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 8.7180e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0188
# Epoch 334/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 9.0277e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0188
# Epoch 335/1000
# 47/47 [==============================] - 1s 21ms/step - loss: 0.0010 - accuracy: 0.0013 - mean_absolute_error: 0.0196
# Epoch 336/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 9.5628e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0202
# Epoch 337/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 8.8203e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0188
# Epoch 338/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 8.0279e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0179
# Epoch 339/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 8.0416e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0176
# Epoch 340/1000
# 47/47 [==============================] - 1s 20ms/step - loss: 9.8512e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0193
# Epoch 341/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 8.6550e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0180
# Epoch 342/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 8.6245e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0183
# Epoch 343/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 0.0010 - accuracy: 0.0013 - mean_absolute_error: 0.0197
# Epoch 344/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 8.2487e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0182
# Epoch 345/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 9.6643e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0199
# Epoch 346/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 7.8768e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0181
# Epoch 347/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 8.5717e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0188
# Epoch 348/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 7.9811e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0182
# Epoch 349/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 9.6634e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0193
# Epoch 350/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 8.6452e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0183
# Epoch 351/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 8.9215e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0190
# Epoch 352/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 9.3132e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0188
# Epoch 353/1000
# 47/47 [==============================] - 1s 15ms/step - loss: 8.1777e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0180
# Epoch 354/1000
# 47/47 [==============================] - 1s 21ms/step - loss: 8.0290e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0179
# Epoch 355/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 8.3700e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0189
# Epoch 356/1000
# ...
# Epoch 885/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 8.1993e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0181
# Epoch 886/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 6.8952e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0168
# Epoch 887/1000
# 47/47 [==============================] - 1s 22ms/step - loss: 6.6461e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0169
# Epoch 888/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 7.3657e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0177
# Epoch 889/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 7.6069e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0175
# Epoch 890/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 7.7583e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0170
# Epoch 891/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 9.1380e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0187
# Epoch 892/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 7.0272e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0168
# Epoch 893/1000
# 47/47 [==============================] - 1s 23ms/step - loss: 7.3022e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0171
# Epoch 894/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 7.2690e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0175
# Epoch 895/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 7.5890e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0169
# Epoch 896/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 7.4998e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0177
# Epoch 897/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 7.3536e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0174
# Epoch 898/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 6.9977e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0172
# Epoch 899/1000
# 47/47 [==============================] - 1s 24ms/step - loss: 7.1899e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0177
# Epoch 900/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 7.3213e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0175
# Epoch 901/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 8.7079e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0181
# Epoch 902/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 7.1595e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0170
# Epoch 903/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 7.0344e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0173
# Epoch 904/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 6.9926e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0163
# Epoch 905/1000
# 47/47 [==============================] - 1s 25ms/step - loss: 6.4139e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0165
# Epoch 906/1000
# 47/47 [==============================] - 1s 19ms/step - loss: 6.8000e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0168
# Epoch 907/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 7.6389e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0173
# Epoch 908/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 7.6644e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0179
# Epoch 909/1000
# 47/47 [==============================] - 1s 24ms/step - loss: 7.7326e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0178
# Epoch 910/1000
# 47/47 [==============================] - 1s 19ms/step - loss: 7.9500e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0179
# Epoch 911/1000
# 47/47 [==============================] - 1s 20ms/step - loss: 7.4472e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0173
# Epoch 912/1000
# 47/47 [==============================] - 1s 20ms/step - loss: 7.5369e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0175
# Epoch 913/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 6.9095e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0171
# Epoch 914/1000
# 47/47 [==============================] - 1s 20ms/step - loss: 7.2589e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0171
# Epoch 915/1000
# 47/47 [==============================] - 1s 25ms/step - loss: 7.6388e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0185
# Epoch 916/1000
# 47/47 [==============================] - 1s 22ms/step - loss: 8.5558e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0176
# Epoch 917/1000
# 47/47 [==============================] - 1s 21ms/step - loss: 7.0443e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0170
# Epoch 918/1000
# 47/47 [==============================] - 1s 20ms/step - loss: 7.1748e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0174
# Epoch 919/1000
# 47/47 [==============================] - 1s 21ms/step - loss: 7.9174e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0179
# Epoch 920/1000
# 47/47 [==============================] - 1s 25ms/step - loss: 7.0204e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0170
# Epoch 921/1000
# 47/47 [==============================] - 1s 20ms/step - loss: 7.8607e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0180
# Epoch 922/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 7.2593e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0173
# Epoch 923/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 7.4092e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0180
# Epoch 924/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 6.3590e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0166
# Epoch 925/1000
# 47/47 [==============================] - 1s 23ms/step - loss: 7.4669e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0178
# Epoch 926/1000
# 47/47 [==============================] - 1s 19ms/step - loss: 7.7203e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0177
# Epoch 927/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 6.9720e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0168
# Epoch 928/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 8.2666e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0175
# Epoch 929/1000
# 47/47 [==============================] - 1s 19ms/step - loss: 7.0425e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0165
# Epoch 930/1000
# 47/47 [==============================] - 1s 21ms/step - loss: 8.6057e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0182
# Epoch 931/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 8.2132e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0175
# Epoch 932/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 8.9558e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0186
# Epoch 933/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 9.0056e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0183
# Epoch 934/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 7.5619e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0175
# Epoch 935/1000
# 47/47 [==============================] - 1s 24ms/step - loss: 6.9177e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0172
# Epoch 936/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 7.3405e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0168
# Epoch 937/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 8.3909e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0181
# Epoch 938/1000
# 47/47 [==============================] - 1s 25ms/step - loss: 7.4354e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0175
# Epoch 939/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 7.3390e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0175
# Epoch 940/1000
# 47/47 [==============================] - 1s 19ms/step - loss: 7.4122e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0176
# Epoch 941/1000
# 47/47 [==============================] - 1s 21ms/step - loss: 6.3244e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0163
# Epoch 942/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 6.9586e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0167
# Epoch 943/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 8.1486e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0181
# Epoch 944/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 7.6426e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0177
# Epoch 945/1000
# 47/47 [==============================] - 1s 22ms/step - loss: 8.4023e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0184
# Epoch 946/1000
# 47/47 [==============================] - 1s 19ms/step - loss: 7.8652e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0176
# Epoch 947/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 8.5218e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0183
# Epoch 948/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 8.1486e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0176
# Epoch 949/1000
# 47/47 [==============================] - 1s 23ms/step - loss: 7.9612e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0175
# Epoch 950/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 8.0076e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0184
# Epoch 951/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 8.8758e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0183
# Epoch 952/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 7.1436e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0170
# Epoch 953/1000
# 47/47 [==============================] - 1s 16ms/step - loss: 7.2514e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0176
# Epoch 954/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 6.7599e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0168
# Epoch 955/1000
# 47/47 [==============================] - 1s 24ms/step - loss: 7.2180e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0174
# Epoch 956/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 8.1307e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0184
# Epoch 957/1000
# 47/47 [==============================] - 1s 21ms/step - loss: 7.7752e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0180
# Epoch 958/1000
# 47/47 [==============================] - 1s 21ms/step - loss: 6.8670e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0171
# Epoch 959/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 6.6480e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0168
# Epoch 960/1000
# 47/47 [==============================] - 1s 25ms/step - loss: 7.4828e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0177
# Epoch 961/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 8.2399e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0184
# Epoch 962/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 8.6393e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0182
# Epoch 963/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 8.1204e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0180
# Epoch 964/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 6.7749e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0172
# Epoch 965/1000
# 47/47 [==============================] - 1s 20ms/step - loss: 8.3744e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0180
# Epoch 966/1000
# 47/47 [==============================] - 1s 22ms/step - loss: 7.9020e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0182
# Epoch 967/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 7.1330e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0171
# Epoch 968/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 6.9530e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0173
# Epoch 969/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 7.7275e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0180
# Epoch 970/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 8.1460e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0177
# Epoch 971/1000
# 47/47 [==============================] - 1s 23ms/step - loss: 7.2888e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0172
# Epoch 972/1000
# 47/47 [==============================] - 1s 18ms/step - loss: 7.5956e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0178
# Epoch 973/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 8.0815e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0175
# Epoch 974/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 7.3100e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0173
# Epoch 975/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 7.6908e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0179
# Epoch 976/1000
# 47/47 [==============================] - 1s 23ms/step - loss: 8.0704e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0176
# Epoch 977/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 6.8786e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0170
# Epoch 978/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 7.1163e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0170
# Epoch 979/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 7.4775e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0177
# Epoch 980/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 7.8688e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0178
# Epoch 981/1000
# 47/47 [==============================] - 1s 23ms/step - loss: 6.7964e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0165
# Epoch 982/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 8.3258e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0178
# Epoch 983/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 8.0740e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0177
# Epoch 984/1000
# 47/47 [==============================] - 1s 17ms/step - loss: 6.2232e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0164
# Epoch 985/1000
# 47/47 [==============================] - 1s 20ms/step - loss: 8.7164e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0184
# Epoch 986/1000
# 47/47 [==============================] - 1s 29ms/step - loss: 8.0462e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0175
# Epoch 987/1000
# 47/47 [==============================] - 1s 20ms/step - loss: 7.6459e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0177
# Epoch 988/1000
# 47/47 [==============================] - 1s 22ms/step - loss: 7.4036e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0177
# Epoch 989/1000
# 47/47 [==============================] - 1s 28ms/step - loss: 7.2006e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0168
# Epoch 990/1000
# 47/47 [==============================] - 1s 27ms/step - loss: 7.7785e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0172
# Epoch 991/1000
# 47/47 [==============================] - 1s 28ms/step - loss: 7.3668e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0174
# Epoch 992/1000
# 47/47 [==============================] - 1s 29ms/step - loss: 7.8795e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0176
# Epoch 993/1000
# 47/47 [==============================] - 1s 24ms/step - loss: 7.1587e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0170
# Epoch 994/1000
# 47/47 [==============================] - 1s 27ms/step - loss: 7.3235e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0175
# Epoch 995/1000
# 47/47 [==============================] - 1s 26ms/step - loss: 8.2601e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0179
# Epoch 996/1000
# 47/47 [==============================] - 1s 27ms/step - loss: 7.5815e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0176
# Epoch 997/1000
# 47/47 [==============================] - 1s 28ms/step - loss: 6.9804e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0169
# Epoch 998/1000
# 47/47 [==============================] - 1s 24ms/step - loss: 8.0550e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0182
# Epoch 999/1000
# 47/47 [==============================] - 1s 28ms/step - loss: 7.0009e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0169
# Epoch 1000/1000
# 47/47 [==============================] - 1s 24ms/step - loss: 7.0437e-04 - accuracy: 0.0013 - mean_absolute_error: 0.0171

# %%
def visualize_training_results(results):
    """
    Plots the loss and accuracy for the training and testing data
    """
    history = results.history

    plt.figure(figsize=(16, 5))
    # plt.plot(history['val_mean_absolute_error'])
    plt.plot(history['mean_absolute_error'])
    plt.legend(['val_mean_absolute_error', 'mean_absolute_error'])
    plt.title('mean_absolute_error')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.show()

    plt.figure(figsize=(16, 5))
    # plt.plot(history['val_loss'])
    plt.plot(history['loss'])
    plt.legend(['val_loss', 'loss'])
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.show()

    plt.figure(figsize=(16, 5))
    # plt.plot(history['val_accuracy'])
    plt.plot(history['accuracy'])
    plt.legend(['val_accuracy', 'accuracy'])
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.show()

# %%
visualize_training_results(history)

# %%
# Evaluate the model on the test set
mse, accuracy, mae = model.evaluate(X_test, y_test)
# Out:
# 12/12 [==============================] - 8s 11ms/step - loss: 2.5053e-04 - accuracy: 0.0053 - mean_absolute_error: 0.0121

# %%
# Step 8: Tuning the Hyperparameters
# You can use techniques such as grid search or random search to find the best values for the model's hyperparameters

# Step 9: Testing the model
y_pred = model.predict(X_test)
print('y_pred', y_pred.shape)
print('y_test', y_test.shape)




# evaluat
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

rmse = np.sqrt(mean_squared_error(y_test, y_pred))



print("RMSE: {:.4f}".format(rmse))
print("MSE: {:.4f}".format(mse))
print("MAE:{:.4f}".format(mae))
# Out:
# 12/12 [==============================] - 0s 7ms/step
# y_pred (376, 1)
# y_test (376, 1)
# RMSE: 0.0158
# MSE: 0.0003
# MAE:0.0121

# %%
# convert to original data
y_pred = scaler.inverse_transform(y_pred)
y_test= scaler.inverse_transform(y_test)


# evaluat
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mape = 100 * np.mean(np.abs((y_test - y_pred) / y_test))
rmse = np.sqrt(mean_squared_error(y_test, y_pred))


print("MAPE: {:.4f}%".format(mape))
print("RMSE: {:.4f}".format(rmse))
print("MSE: {:.4f}".format(mse))
print("MAE:{:.4f}".format(mae))
# Out:
# MAPE: 1.8400%
# RMSE: 49.2945
# MSE: 2429.9476
# MAE:37.6148

# %%
y_pred_df = pd.DataFrame(y_pred, columns=["Adj Close"])
y_test_df = pd.DataFrame(y_test, columns=["Adj Close"])

# Get the length of y_pred
y_pred_length = y_pred.shape[0]
y_test_length = y_test.shape[0]

# Generate dates for the next y_pred_length days 
today = pd.Timestamp.now().date()
prediction_dates = today - timedelta(days=y_pred_length-1)
test = today - timedelta(days=y_test_length-1)
prediction = pd.date_range(start=test_data.index[0], end=test_data.index[-1], freq='D')
test_dates = pd.date_range(start=test_data.index[0], end=test_data.index[-1], freq='D')

# Use the generated dates as the index of the DataFrame
y_pred_df['Date'] = prediction

y_test_df['Date'] = test_dates

# Set the index of the dataframes to be the 'Date' column
y_pred_df.set_index('Date', inplace=True)
y_test_df.set_index('Date', inplace=True)


# Assuming y_pred is a numpy array

# %%
#y_test_df.to_csv("y_test_2021_2022.csv")
y_test_df
# Out:
#               Adj Close
# Date
# 2021-12-20  3933.844482
# 2021-12-21  4020.260010
# 2021-12-22  3982.099609
# 2021-12-23  4108.015625
# 2021-12-24  4047.982910
# ...                 ...
# 2022-12-26  1226.974365
# 2022-12-27  1212.791626
# 2022-12-28  1189.986084
# 2022-12-29  1201.595337
# 2022-12-30  1199.232788
#
# [376 rows x 1 columns]

# %%
#y_pred_df.to_csv("y_pred_2021_2022.csv")  # index=False to exclude index column in CSV
y_pred_df
# Out:
#               Adj Close
# Date
# 2021-12-20  3840.952148
# 2021-12-21  3936.584961
# 2021-12-22  3943.051758
# 2021-12-23  3954.757568
# 2021-12-24  3976.068848
# ...                 ...
# 2022-12-26  1199.638672
# 2022-12-27  1193.708252
# 2022-12-28  1173.045776
# 2022-12-29  1178.234009
# 2022-12-30  1169.330200
#
# [376 rows x 1 columns]

# %%
names = cycle(['Predictions', 'Test Data'])

fig = go.Figure()
fig.add_trace(go.Scatter(x=y_test_df.index, y=y_pred_df['Adj Close'], name='Predictions',
                         line=dict(width=2, color='blue')))
fig.add_trace(go.Scatter(x=y_test_df.index, y=y_test_df['Adj Close'], name='Test Data',
                         line=dict(width=2, color='red')))
fig.update_layout(xaxis_title='Date', yaxis_title='Price',
                  font_size=15, font_color='black', legend_title_text=' Parameters')
fig.show()

# %%
# Calculate mean absolute percentage error (MAPE)
def mape(y_true, y_pred):
    return 100 * np.mean(np.abs((y_true - y_pred) / y_true))


mape_value = mape(y_test, y_pred)
print(f'MAPE: {mape_value:.4f}%')
# Out:
# MAPE: 1.8400%

# %%
def smape(y_true, y_pred):
    return 200 * np.mean(np.abs(y_pred - y_true) / (np.abs(y_pred) + np.abs(y_true)))


SMAPE1 = smape(y_test, y_pred)
print("smape: {:.4f}%".format(SMAPE1))
# Out:
# smape: 1.8456%

# %%
# Step 1: Data cleaning
data_new = yf.download(tickers='BTC-USD', period='max', interval='1d')
data_new.dropna(inplace=True)
data_new
# Out:
# [*********************100%***********************]  1 of 1 completed
#                     Open          High           Low         Close  \
# Date
# 2014-09-17    465.864014    468.174011    452.421997    457.334015
# 2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2023-03-07  22428.322266  22527.417969  22011.261719  22219.769531
# 2023-03-08  22216.441406  22268.896484  21708.050781  21718.080078
# 2023-03-09  21720.080078  21802.716797  20210.306641  20363.021484
# 2023-03-10  20367.001953  20370.595703  19628.253906  20187.244141
# 2023-03-11  20203.859375  20792.525391  20069.201172  20225.300781
#
#                Adj Close       Volume
# Date
# 2014-09-17    457.334015     21056800
# 2014-09-18    424.440002     34483200
# 2014-09-19    394.795990     37919700
# 2014-09-20    408.903992     36863600
# 2014-09-21    398.821014     26580100
# ...                  ...          ...
# 2023-03-07  22219.769531  22765452204
# 2023-03-08  21718.080078  22536575684
# 2023-03-09  20363.021484  30364664171
# 2023-03-10  20187.244141  39578257695
# 2023-03-11  20225.300781  35672162304
#
# [3098 rows x 6 columns]

# %%
data_new = data_new.drop(['Close'], axis=1)
data_new
# Out:
#                     Open          High           Low     Adj Close  \
# Date
# 2014-09-17    465.864014    468.174011    452.421997    457.334015
# 2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2023-03-07  22428.322266  22527.417969  22011.261719  22219.769531
# 2023-03-08  22216.441406  22268.896484  21708.050781  21718.080078
# 2023-03-09  21720.080078  21802.716797  20210.306641  20363.021484
# 2023-03-10  20367.001953  20370.595703  19628.253906  20187.244141
# 2023-03-11  20203.859375  20792.525391  20069.201172  20225.300781
#
#                  Volume
# Date
# 2014-09-17     21056800
# 2014-09-18     34483200
# 2014-09-19     37919700
# 2014-09-20     36863600
# 2014-09-21     26580100
# ...                 ...
# 2023-03-07  22765452204
# 2023-03-08  22536575684
# 2023-03-09  30364664171
# 2023-03-10  39578257695
# 2023-03-11  35672162304
#
# [3098 rows x 5 columns]

# %%
future_data = data_new.iloc[-30:, :]
future_data = future_data.values
future_data = pd.DataFrame(future_data, columns=["Open", "High", "Low", "Adj Close", "Volume"])

# Get the length of future_data
future_length = future_data.shape[0]

# Generate dates for the next 30 days
today = pd.Timestamp.now().date()
future_dates = today + timedelta(days=1)

future = pd.date_range(start=future_dates, end=today +
                       timedelta(days=30), freq='D')

# Generate dates for the next 10 days for predict
today = pd.Timestamp.now().date()
future_dates_pred = pd.date_range(start=today + timedelta(days=1), periods=10, freq='D')

# Use the generated dates as the index of the DataFrame
future_data['Date'] = future

# Set the index of the dataframes to be the 'Date' column
future_data.set_index('Date', inplace=True)

future_data.tail(10)
x_future_data = future_data.drop(['Adj Close'], axis=1).values
y_future_data = future_data['Adj Close'].values
y_future_data = y_future_data.reshape(-1, 1)

print("x_future_data:", x_future_data.shape)
print("y_future_data:", y_future_data.shape)

# x_future_data= np.reshape(x_future_data, (x_future_data.shape[0], 1, x_future_data.shape[1]))

print("x_future_data:", x_future_data.shape)
x_future_data = scaler.fit_transform(x_future_data)
y_future_data = scaler.fit_transform(y_future_data)
for i in range(10):
    future_data_temp = x_future_data[i:i+30, :]
    # future_data_temp = future_data_temp.reshape(-1, 1)
    print("future_data_temp", future_data_temp.shape)
# Out:
# x_future_data: (30, 4)
# y_future_data: (30, 1)
# x_future_data: (30, 4)
# future_data_temp (30, 4)
# future_data_temp (29, 4)
# future_data_temp (28, 4)
# future_data_temp (27, 4)
# future_data_temp (26, 4)
# future_data_temp (25, 4)
# future_data_temp (24, 4)
# future_data_temp (23, 4)
# future_data_temp (22, 4)
# future_data_temp (21, 4)

# %%
# Initialize a numpy array to store the predictions
prediction = np.zeros((10, 1))

for i in range(10):
    future_data_temp = x_future_data[i:i+30, :]

    print("future_data_temp1", future_data_temp.shape)
    future_data_temp = np.reshape(future_data_temp, (future_data_temp.shape[0],
                                                     1, future_data_temp.shape[1]))
    pred = model.predict(future_data_temp)
    print("future_data_temp2", future_data_temp.shape)
    print('---------------------------------------------------')
    prediction[i][0] = pred[0][0]
    x_future_data[i+future_data_temp.shape[0]-1][0] = pred[0][0]
print('3', future_data.shape)
print('prediction:', prediction.shape)
# Reverse the MinMaxScaler
y_future_data = y_future_data.reshape(-1, 1)
y_future_data = scaler.inverse_transform(y_future_data)
prediction = scaler.inverse_transform(prediction)

# Create a new dataframe with the predicted values and the dates as the index
prediction_df = pd.DataFrame(
    prediction, index=future_dates_pred, columns=['Adj Close'])
print('y_future_data', y_future_data.shape)
# Get the length of future_data

y_future_data = pd.DataFrame(y_future_data,  columns=['Adj Close'])

future_length = future_data.shape[0]
test = today - timedelta(days=future_length-1)
test_dates = pd.date_range(start=test, end=today, freq='D')
# Use the generated dates as the index of the DataFrame


y_future_data['Date'] = test_dates

# Set the index of the dataframes to be the 'Date' column

y_future_data.set_index('Date', inplace=True)
# Out:
# future_data_temp1 (30, 4)
# 1/1 [==============================] - 0s 296ms/step
# future_data_temp2 (30, 1, 4)
# ---------------------------------------------------
# future_data_temp1 (29, 4)
# 1/1 [==============================] - 0s 303ms/step
# future_data_temp2 (29, 1, 4)
# ---------------------------------------------------
# future_data_temp1 (28, 4)
# 1/1 [==============================] - 0s 141ms/step
# future_data_temp2 (28, 1, 4)
# ---------------------------------------------------
# future_data_temp1 (27, 4)
# 1/1 [==============================] - 0s 159ms/step
# future_data_temp2 (27, 1, 4)
# ---------------------------------------------------
# future_data_temp1 (26, 4)
# 1/1 [==============================] - 0s 167ms/step
# future_data_temp2 (26, 1, 4)
# ---------------------------------------------------
# future_data_temp1 (25, 4)
# 1/1 [==============================] - 0s 166ms/step
# future_data_temp2 (25, 1, 4)
# ---------------------------------------------------
# future_data_temp1 (24, 4)
# 1/1 [==============================] - 0s 385ms/step
# future_data_temp2 (24, 1, 4)
# ---------------------------------------------------
# future_data_temp1 (23, 4)
# 1/1 [==============================] - 0s 134ms/step
# future_data_temp2 (23, 1, 4)
# ---------------------------------------------------
# future_data_temp1 (22, 4)
# 1/1 [==============================] - 0s 99ms/step
# future_data_temp2 (22, 1, 4)
# ---------------------------------------------------
# future_data_temp1 (21, 4)
# 1/1 [==============================] - 0s 71ms/step
# future_data_temp2 (21, 1, 4)
# ---------------------------------------------------
# 3 (30, 5)
# prediction: (10, 1)
# y_future_data (30, 1)

# %%
prediction_df
# Out:
#                Adj Close
# 2023-03-12  21881.215539
# 2023-03-13  21937.467988
# 2023-03-14  22009.546064
# 2023-03-15  21813.130080
# 2023-03-16  22182.479466
# 2023-03-17  23487.845999
# 2023-03-18  24372.356572
# 2023-03-19  24308.459757
# 2023-03-20  24564.272233
# 2023-03-21  24603.325482

# %%
y_future_data
# Out:
#                Adj Close
# Date
# 2023-02-10  21651.183594
# 2023-02-11  21870.875000
# 2023-02-12  21788.203125
# 2023-02-13  21808.101562
# 2023-02-14  22220.804688
# 2023-02-15  24307.841797
# 2023-02-16  23623.474609
# 2023-02-17  24565.601562
# 2023-02-18  24641.277344
# 2023-02-19  24327.642578
# 2023-02-20  24829.148438
# 2023-02-21  24436.353516
# 2023-02-22  24188.843750
# 2023-02-23  23947.492188
# 2023-02-24  23198.126953
# 2023-02-25  23175.375000
# 2023-02-26  23561.212891
# 2023-02-27  23522.871094
# 2023-02-28  23147.353516
# 2023-03-01  23646.550781
# 2023-03-02  23475.466797
# 2023-03-03  22362.679688
# 2023-03-04  22353.349609
# 2023-03-05  22435.513672
# 2023-03-06  22429.757812
# 2023-03-07  22219.769531
# 2023-03-08  21718.080078
# 2023-03-09  20363.021484
# 2023-03-10  20187.244141
# 2023-03-11  20225.300781

# %%
names = cycle(['Predictions next 10 day', 'Actual data '])

fig = go.Figure()

fig.add_trace(go.Scatter(x=y_future_data.index, y=y_future_data['Adj Close'], name='Actual data ',
                         line=dict(width=2, color='red')))
fig.add_trace(go.Scatter(x=prediction_df.index, y=prediction_df['Adj Close'], name='Predictions next 10 day',
                         line=dict(width=2, color='blue')))

fig.add_shape(type='line',
              x0=prediction_df.index[0], y0=prediction_df['Adj Close'][0],
              x1=y_future_data.index[-1], y1=y_future_data['Adj Close'][-1],
              line=dict(color='grey', width=2))
fig.update_layout(xaxis_title='Date', yaxis_title='Price',
                  font_size=15, font_color='black', legend_title_text=' Parameters')
fig.show()

# %%
actual_x = y_future_data.index
actual_y = y_future_data['Adj Close']
pred_x = prediction_df.index
pred_y = prediction_df['Adj Close']

fig = go.Figure()
fig.add_trace(go.Scatter(x=actual_x, y=actual_y, name='Actual Data'))
fig.add_trace(go.Scatter(x=pred_x, y=pred_y,
              name='Predictions Data for 10 day'))

fig.add_shape(type='line',
              x0=actual_x[-1], y0=actual_y[-1],
              x1=pred_x[0], y1=pred_y[0],
              line=dict(color='grey', width=2, dash='dot'))

fig.update_layout(
    xaxis_title='Date',
    yaxis_title='Price',
    title='predict next 10 day '
)

fig.show()

# %%
future_data_all = data_new.copy()

future_data_all = pd.DataFrame(future_data_all, index= future_data_all.index, 
                               columns=future_data_all.columns)

x_future_data_all = future_data_all.drop(['Adj Close'], axis=1).values
y_future_data_all = future_data_all['Adj Close'].values
y_future_data_all = y_future_data_all.reshape(-1, 1)

print("x_future_data:", x_future_data_all.shape)
print("y_future_data:", y_future_data_all.shape)
# Out:
# x_future_data: (3098, 4)
# y_future_data: (3098, 1)

# %%
x_future_data_all = scaler.fit_transform(x_future_data_all)
y_future_data_all = scaler.fit_transform(y_future_data_all)

x_future_data_all = np.reshape(x_future_data_all, (x_future_data_all.shape[0], 1, x_future_data_all.shape[1]))

pred_future_all = model.predict(x_future_data_all)
# Out:
# 97/97 [==============================] - 1s 7ms/step

# %%
y_future_data_all = scaler.inverse_transform(y_future_data_all)
pred_future_all = scaler.inverse_transform(pred_future_all)
y_future_all = pd.DataFrame(y_future_data_all, index= future_data_all.index,  columns=['Adj Close'])
pred_future_all_df = pd.DataFrame(pred_future_all, index= future_data_all.index,  columns=['Adj Close'])
print("pred_future_all:", pred_future_all.shape)
print("y_future_data:", y_future_data_all.shape)
# Out:
# pred_future_all: (3098, 1)
# y_future_data: (3098, 1)

# %%
names = cycle(['Predictions', 'Test Data'])

fig = go.Figure()
fig.add_trace(go.Scatter(x=y_future_all.index, y=pred_future_all_df['Adj Close'], name='Predictions',
                         line=dict(width=2, color='blue')))
fig.add_trace(go.Scatter(x=y_future_all.index, y=y_future_all['Adj Close'], name='Actual Data',
                         line=dict(width=2, color='red')))
fig.add_trace(go.Scatter(x=prediction_df.index, y=prediction_df['Adj Close'], name='Predictions next 10 day',
                         line=dict(width=2, color='gray')))
fig.add_shape(type='line',
              x0=prediction_df.index[0], y0=prediction_df['Adj Close'][0],
              x1=pred_future_all_df.index[-1], y1=pred_future_all_df['Adj Close'][-1],
              line=dict(color='grey', width=2))

fig.update_layout(xaxis_title='Date', yaxis_title='Price',
                  font_size=15, font_color='black', legend_title_text=' Parameters')
fig.show()
