# %%
import pandas as pd
import numpy as np
import pandas_ta as ta
import yfinance as yf
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error 
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout

# %%
# Step 1: Data cleaning
data = yf.download(tickers='BTC-usd', period='max', interval='1d')
data.dropna(inplace=True)
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                     Open          High           Low         Close  \
# Date
# 2014-09-17    465.864014    468.174011    452.421997    457.334015
# 2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2023-01-24  22929.626953  23134.011719  22549.744141  22636.468750
# 2023-01-25  22639.267578  23722.099609  22406.076172  23117.859375
# 2023-01-26  23108.955078  23237.078125  22911.373047  23032.777344
# 2023-01-27  23030.716797  23417.720703  22654.593750  23078.728516
# 2023-01-28  23086.451172  23163.541016  22917.281250  23023.035156
#
#                Adj Close       Volume
# Date
# 2014-09-17    457.334015     21056800
# 2014-09-18    424.440002     34483200
# 2014-09-19    394.795990     37919700
# 2014-09-20    408.903992     36863600
# 2014-09-21    398.821014     26580100
# ...                  ...          ...
# 2023-01-24  22636.468750  26405069715
# 2023-01-25  23117.859375  30685366709
# 2023-01-26  23032.777344  26357839322
# 2023-01-27  23078.728516  25383335641
# 2023-01-28  23023.035156  14764229632
#
# [3056 rows x 6 columns]

# %%
data.drop([ 'Close'], axis=1, inplace=True)
data
# Out:
#                     Open          High           Low     Adj Close  \
# Date
# 2014-09-17    465.864014    468.174011    452.421997    457.334015
# 2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2023-01-24  22929.626953  23134.011719  22549.744141  22636.468750
# 2023-01-25  22639.267578  23722.099609  22406.076172  23117.859375
# 2023-01-26  23108.955078  23237.078125  22911.373047  23032.777344
# 2023-01-27  23030.716797  23417.720703  22654.593750  23078.728516
# 2023-01-28  23086.451172  23163.541016  22917.281250  23023.035156
#
#                  Volume
# Date
# 2014-09-17     21056800
# 2014-09-18     34483200
# 2014-09-19     37919700
# 2014-09-20     36863600
# 2014-09-21     26580100
# ...                 ...
# 2023-01-24  26405069715
# 2023-01-25  30685366709
# 2023-01-26  26357839322
# 2023-01-27  25383335641
# 2023-01-28  14764229632
#
# [3056 rows x 5 columns]

# %%
# Step 3: Data normalization (cont.)
scaler = MinMaxScaler()
data_close = data[['Adj Close']]
data_close = scaler.fit_transform(data_close)
data_close
# Out:
# array([[0.00414359],
#        [0.00365546],
#        [0.00321557],
#        ...,
#        [0.33914686],
#        [0.33982874],
#        [0.33900229]])

# %%
# Step 4: Splitting the data
X = data[['Open', 'High', 'Low', 'Volume']]
X = scaler.fit_transform(X)
y = data_close
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %%
# Step 5: Reshaping the data
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))
print("x", X.shape)
print('y',y.shape)
print('X_train', X_train.shape)
print('y_train', y_train.shape)
print('X_test', X_test.shape)
print('Y_test', y_test.shape) 
print('X_train.shape[1]', X_train.shape[1])
print('X_train.shape[2]', X_train.shape[2])
# Out:
# x (3056, 4)
# y (3056, 1)
# X_train (2444, 1, 4)
# y_train (2444, 1)
# X_test (612, 1, 4)
# Y_test (612, 1)
# X_train.shape[1] 1
# X_train.shape[2] 4

# %%
# Step 6: Building the LSTM model (cont.)

model = Sequential()
model.add(LSTM(100, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True , activation= 'softmax'))
model.add(Dropout(0.2))
model.add(LSTM(100, activation= 'softmax'))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 1, 100)            42000
#
#  dropout_2 (Dropout)         (None, 1, 100)            0
#
#  lstm_3 (LSTM)               (None, 100)               80400
#
#  dropout_3 (Dropout)         (None, 100)               0
#
#  dense_1 (Dense)             (None, 4)                 404
#
# =================================================================
# Total params: 122,804
# Trainable params: 122,804
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Step 7: Training and evaluating the model
history = model.fit(X_train, y_train, epochs=250, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/250
# 77/77 [==============================] - 6s 16ms/step - loss: 0.0321 - val_loss: 0.2096
# Epoch 2/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0294 - val_loss: 0.1993
# Epoch 3/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0294 - val_loss: 0.2009
# Epoch 4/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0293 - val_loss: 0.2021
# Epoch 5/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0294 - val_loss: 0.2026
# Epoch 6/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0294 - val_loss: 0.2035
# Epoch 7/250
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0293 - val_loss: 0.2001
# Epoch 8/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0294 - val_loss: 0.2024
# Epoch 9/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0293 - val_loss: 0.1989
# Epoch 10/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0293 - val_loss: 0.2011
# Epoch 11/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0293 - val_loss: 0.2017
# Epoch 12/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0293 - val_loss: 0.2004
# Epoch 13/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0293 - val_loss: 0.2004
# Epoch 14/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0292 - val_loss: 0.2009
# Epoch 15/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0292 - val_loss: 0.1986
# Epoch 16/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0292 - val_loss: 0.2017
# Epoch 17/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0292 - val_loss: 0.1976
# Epoch 18/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0291 - val_loss: 0.2044
# Epoch 19/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0290 - val_loss: 0.1972
# Epoch 20/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0290 - val_loss: 0.1962
# Epoch 21/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0289 - val_loss: 0.1947
# Epoch 22/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0288 - val_loss: 0.1994
# Epoch 23/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0286 - val_loss: 0.1922
# Epoch 24/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0286 - val_loss: 0.1981
# Epoch 25/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0283 - val_loss: 0.1887
# Epoch 26/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0281 - val_loss: 0.1877
# Epoch 27/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0278 - val_loss: 0.1905
# Epoch 28/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0276 - val_loss: 0.1888
# Epoch 29/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0271 - val_loss: 0.1823
# Epoch 30/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0268 - val_loss: 0.1831
# Epoch 31/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0263 - val_loss: 0.1716
# Epoch 32/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0257 - val_loss: 0.1743
# Epoch 33/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0251 - val_loss: 0.1715
# Epoch 34/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0244 - val_loss: 0.1636
# Epoch 35/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0237 - val_loss: 0.1530
# Epoch 36/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0229 - val_loss: 0.1511
# Epoch 37/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0217 - val_loss: 0.1388
# Epoch 38/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0211 - val_loss: 0.1338
# Epoch 39/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0196 - val_loss: 0.1276
# Epoch 40/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0185 - val_loss: 0.1169
# Epoch 41/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0173 - val_loss: 0.1066
# Epoch 42/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0162 - val_loss: 0.0991
# Epoch 43/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0149 - val_loss: 0.0903
# Epoch 44/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0139 - val_loss: 0.0813
# Epoch 45/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0127 - val_loss: 0.0711
# Epoch 46/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0116 - val_loss: 0.0651
# Epoch 47/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0105 - val_loss: 0.0566
# Epoch 48/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0095 - val_loss: 0.0509
# Epoch 49/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0087 - val_loss: 0.0430
# Epoch 50/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0078 - val_loss: 0.0392
# Epoch 51/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0072 - val_loss: 0.0342
# Epoch 52/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0065 - val_loss: 0.0292
# Epoch 53/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0057 - val_loss: 0.0255
# Epoch 54/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0054 - val_loss: 0.0228
# Epoch 55/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0049 - val_loss: 0.0203
# Epoch 56/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0044 - val_loss: 0.0182
# Epoch 57/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0042 - val_loss: 0.0166
# Epoch 58/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0039 - val_loss: 0.0152
# Epoch 59/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0036 - val_loss: 0.0143
# Epoch 60/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0035 - val_loss: 0.0136
# Epoch 61/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0033 - val_loss: 0.0132
# Epoch 62/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0032 - val_loss: 0.0125
# Epoch 63/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0032 - val_loss: 0.0123
# Epoch 64/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0029 - val_loss: 0.0116
# Epoch 65/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0030 - val_loss: 0.0118
# Epoch 66/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0031 - val_loss: 0.0115
# Epoch 67/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0030 - val_loss: 0.0110
# Epoch 68/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0027 - val_loss: 0.0109
# Epoch 69/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0029 - val_loss: 0.0105
# Epoch 70/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0028 - val_loss: 0.0104
# Epoch 71/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0026 - val_loss: 0.0103
# Epoch 72/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0028 - val_loss: 0.0102
# Epoch 73/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0025 - val_loss: 0.0100
# Epoch 74/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0024 - val_loss: 0.0104
# Epoch 75/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0025 - val_loss: 0.0100
# Epoch 76/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0023 - val_loss: 0.0093
# Epoch 77/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0024 - val_loss: 0.0094
# Epoch 78/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0024 - val_loss: 0.0092
# Epoch 79/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0023 - val_loss: 0.0086
# Epoch 80/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0023 - val_loss: 0.0086
# Epoch 81/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0023 - val_loss: 0.0087
# Epoch 82/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0021 - val_loss: 0.0086
# Epoch 83/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0022 - val_loss: 0.0083
# Epoch 84/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0021 - val_loss: 0.0081
# Epoch 85/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0020 - val_loss: 0.0079
# Epoch 86/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0020 - val_loss: 0.0082
# Epoch 87/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0021 - val_loss: 0.0076
# Epoch 88/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0020 - val_loss: 0.0075
# Epoch 89/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0020 - val_loss: 0.0074
# Epoch 90/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0020 - val_loss: 0.0070
# Epoch 91/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0018 - val_loss: 0.0068
# Epoch 92/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0018 - val_loss: 0.0068
# Epoch 93/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0019 - val_loss: 0.0065
# Epoch 94/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0018 - val_loss: 0.0063
# Epoch 95/250
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0019 - val_loss: 0.0062
# Epoch 96/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0017 - val_loss: 0.0060
# Epoch 97/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0018 - val_loss: 0.0056
# Epoch 98/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0016 - val_loss: 0.0057
# Epoch 99/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0017 - val_loss: 0.0052
# Epoch 100/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0017 - val_loss: 0.0049
# Epoch 101/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0017 - val_loss: 0.0048
# Epoch 102/250
# 77/77 [==============================] - 1s 9ms/step - loss: 0.0015 - val_loss: 0.0045
# Epoch 103/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0015 - val_loss: 0.0042
# Epoch 104/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0016 - val_loss: 0.0043
# Epoch 105/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0015 - val_loss: 0.0040
# Epoch 106/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0015 - val_loss: 0.0040
# Epoch 107/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0014 - val_loss: 0.0038
# Epoch 108/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0014 - val_loss: 0.0035
# Epoch 109/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0013 - val_loss: 0.0033
# Epoch 110/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0013 - val_loss: 0.0032
# Epoch 111/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0014 - val_loss: 0.0031
# Epoch 112/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0012 - val_loss: 0.0030
# Epoch 113/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0013 - val_loss: 0.0028
# Epoch 114/250
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0012 - val_loss: 0.0029
# Epoch 115/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0012 - val_loss: 0.0028
# Epoch 116/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0011 - val_loss: 0.0025
# Epoch 117/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.0012 - val_loss: 0.0024
# Epoch 118/250
# 77/77 [==============================] - 1s 8ms/step - loss: 0.
# Epoch 232/250
# 77/77 [==============================] - 1s 10ms/step - loss: 5.3267e-04 - val_loss: 7.4982e-04
# Epoch 233/250
# 77/77 [==============================] - 1s 10ms/step - loss: 6.4975e-04 - val_loss: 7.8517e-04
# Epoch 234/250
# 77/77 [==============================] - 1s 11ms/step - loss: 5.4360e-04 - val_loss: 7.6639e-04
# Epoch 235/250
# 77/77 [==============================] - 1s 11ms/step - loss: 5.4973e-04 - val_loss: 7.3746e-04
# Epoch 236/250
# 77/77 [==============================] - 1s 10ms/step - loss: 5.3992e-04 - val_loss: 7.1732e-04
# Epoch 237/250
# 77/77 [==============================] - 1s 10ms/step - loss: 5.9747e-04 - val_loss: 7.2638e-04
# Epoch 238/250
# 77/77 [==============================] - 1s 10ms/step - loss: 5.1017e-04 - val_loss: 7.5909e-04
# Epoch 239/250
# 77/77 [==============================] - 1s 10ms/step - loss: 5.3562e-04 - val_loss: 7.2606e-04
# Epoch 240/250
# 77/77 [==============================] - 1s 11ms/step - loss: 6.0750e-04 - val_loss: 7.4174e-04
# Epoch 241/250
# 77/77 [==============================] - 1s 12ms/step - loss: 5.4613e-04 - val_loss: 7.2378e-04
# Epoch 242/250
# 77/77 [==============================] - 1s 12ms/step - loss: 5.7150e-04 - val_loss: 7.3134e-04
# Epoch 243/250
# 77/77 [==============================] - 1s 11ms/step - loss: 5.6572e-04 - val_loss: 7.2667e-04
# Epoch 244/250
# 77/77 [==============================] - 1s 10ms/step - loss: 5.2298e-04 - val_loss: 7.2142e-04
# Epoch 245/250
# 77/77 [==============================] - 1s 9ms/step - loss: 6.0399e-04 - val_loss: 7.3921e-04
# Epoch 246/250
# 77/77 [==============================] - 1s 9ms/step - loss: 5.3403e-04 - val_loss: 8.1013e-04
# Epoch 247/250
# 77/77 [==============================] - 1s 10ms/step - loss: 5.9319e-04 - val_loss: 7.2374e-04
# Epoch 248/250
# 77/77 [==============================] - 1s 9ms/step - loss: 5.2361e-04 - val_loss: 7.4784e-04
# Epoch 249/250
# 77/77 [==============================] - 1s 11ms/step - loss: 5.9615e-04 - val_loss: 7.2648e-04
# Epoch 250/250
# 77/77 [==============================] - 1s 9ms/step - loss: 5.8713e-04 - val_loss: 7.8254e-04

# %%
# Evaluate the model on the test set
score = model.evaluate(X_test, y_test, verbose=0)
print(f'Test loss: {score:.4f}')
# Out:
# Test loss: 0.0008

# %%
# Step 8: Tuning the Hyperparameters
# You can use techniques such as grid search or random search to find the best values for the model's hyperparameters

# Step 9: Testing the model
y_pred = model.predict(X_test)
print('y_pred',y_pred.shape)
print('y_test',y_test.shape)
#y_pred = y_pred.reshape(-1,1)
#y_pred = np.nan_to_num(y_pred)
#y_pred = scaler.inverse_transform(y_pred)
#y_pred = scaler.inverse_transform(y_pred[:,[-1]])
#y_test = scaler.inverse_transform(y_test.reshape(-1, 1))
#y_test = np.nan_to_num(y_test)


#evaluat
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mape = 100 * np.mean(np.abs((y_test - y_pred) / y_test))
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

print("MAPE: {:.4f}%".format(mape))
print("RMSE: {:.4f}".format(rmse))
print("MSE: {:.4f}".format(mse))
print("MAE:{:.4f}".format(mae))
# Out:
# 20/20 [==============================] - 1s 4ms/step
# y_pred (612, 1)
# y_test (612, 1)
# MAPE: 3.6935%
# RMSE: 0.0280
# MSE: 0.0008
# MAE:0.0207

# %%
def smape(y_true, y_pred):
    return 200 * np.mean(np.abs(y_pred - y_true) / (np.abs(y_pred) + np.abs(y_true)))

SMAPE1 = smape(y_test, y_pred)
print("smape: {:.4f}%".format(SMAPE1))
# Out:
# smape: 3.6783%

# %%
import matplotlib.pyplot as plt

# Assume that you have stored the date information in a variable called 'date'
# Assume that you have stored the predictions in a variable called 'y_pred'
# Assume that you have stored the test data in a variable called 'y_test'

# Plot the test data and predictions on a line chart
plt.plot(data['Date'], y_pred, label='Predictions')
plt.plot(data['Date'], y_test, label='Test Data')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 8
#       1 import matplotlib.pyplot as plt
#       3 # Assume that you have stored the date information in a variable called 'date'
#       4 # Assume that you have stored the predictions in a variable called 'y_pred'
#       5 # Assume that you have stored the test data in a variable called 'y_test'
#       6
#       7 # Plot the test data and predictions on a line chart
# ----> 8 plt.plot(data['Date'], y_pred, label='Predictions')
#       9 plt.plot(data['Date'], y_test, label='Test Data')
#      10 plt.xlabel('Date')
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 'Date'

# %%
y_pred = scaler.inverse_transform(y_pred)
#y_pred = scaler.inverse_transform(y_pred[:,[-1]])
#y_test = scaler.inverse_transform(y_test.reshape(-1, 1))
print ('y_pred',y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 y_pred = scaler.inverse_transform(y_pred)
#       2 #y_pred = scaler.inverse_transform(y_pred[:,[-1]])
#       3 #y_test = scaler.inverse_transform(y_test.reshape(-1, 1))
#       4 print ('y_pred',y_pred)
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\preprocessing\_data.py:541, in MinMaxScaler.inverse_transform(self, X)
#     535 check_is_fitted(self)
#     537 X = check_array(
#     538     X, copy=self.copy, dtype=FLOAT_DTYPES, force_all_finite="allow-nan"
#     539 )
# --> 541 X -= self.min_
#     542 X /= self.scale_
#     543 return X
#
# ValueError: non-broadcastable output operand with shape (611,1) doesn't match the broadcast shape (611,4)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,8))
plt.plot(y_test, color = 'blue', label = 'Test')
plt.plot(y_pred, color = 'red', label = 'pred')
plt.legend()
plt.show()
